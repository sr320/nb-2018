# %%
# !/Applications/bioinfo/bowtie2-2.2.4/bowtie2-build \
/Volumes/Serine/wd/18-03-05/mkfasta/duck4-10k.1.fasta \
/Volumes/Serine/wd/18-03-05/bowtie/duck4-10k.1.bowtie-index \
2> /Volumes/Serine/wd/18-03-05/bowtie/duck4-10k.1.bw.stderr
# Out:
# Settings:
#   Output files: "/Volumes/Serine/wd/18-03-05/bowtie/duck4-10k.1.bowtie-index.*.bt2"
#   Line rate: 6 (line is 64 bytes)
#   Lines per side: 1 (side is 64 bytes)
#   Offset rate: 4 (one in 16)
#   FTable chars: 10
#   Strings: unpacked
#   Max bucket size: default
#   Max bucket size, sqrt multiplier: default
#   Max bucket size, len divisor: 4
#   Difference-cover sample period: 1024
#   Endianness: little
#   Actual local endianness: little
#   Sanity checking: disabled
#   Assertions: disabled
#   Random seed: 0
#   Sizeofs: void*:8, int:4, long:8, size_t:8
# Input files DNA, FASTA:
#   /Volumes/Serine/wd/18-03-05/mkfasta/duck4-10k.1.fasta
# Reading reference sizes
#   Time reading reference sizes: 00:00:31
# Calculating joined length
# Writing header
# Reserving space for joined string
# Joining reference sequences
#   Time to join reference sequences: 00:00:20
# bmax according to bmaxDivN setting: 299481385
# Using parameters --bmax 224611039 --dcv 1024
# ...

# %%
# !/Applications/bioinfo/bowtie2-2.2.4/bowtie2 \
-x /Volumes/Serine/wd/18-03-05/bowtie/duck4-10k.1.bowtie-index \
-U /Volumes/Serine/wd/18-03-05/160103_I137_FCH3V5YBBXX_L5_WHPANwalDDACDTAAPEI-102_1.fq.gz \
-p 6 \
--very-fast \
-S /Volumes/Serine/wd/18-03-05/bowtie/60103_I137-duck4-10k.1.sam
# Out:
# 41762399 reads; of these:
#   41762399 (100.00%) were unpaired; of these:
#     14348692 (34.36%) aligned 0 times
#     14157807 (33.90%) aligned exactly 1 time
#     13255900 (31.74%) aligned >1 times
# 65.64% overall alignment rate

# %%
# !/Applications/bioinfo/bowtie2-2.2.4/bowtie2-build \
/Volumes/Serine/wd/18-03-05/mkfasta/duck4.1.fasta \
/Volumes/Serine/wd/18-03-05/bowtie/duck4.1.bowtie-index \
2> /Volumes/Serine/wd/18-03-05/bowtie/duck4-1.bw.stderr
# Out:
# Settings:
#   Output files: "/Volumes/Serine/wd/18-03-05/bowtie/duck4.1.bowtie-index.*.bt2"
#   Line rate: 6 (line is 64 bytes)
#   Lines per side: 1 (side is 64 bytes)
#   Offset rate: 4 (one in 16)
#   FTable chars: 10
#   Strings: unpacked
#   Max bucket size: default
#   Max bucket size, sqrt multiplier: default
#   Max bucket size, len divisor: 4
#   Difference-cover sample period: 1024
#   Endianness: little
#   Actual local endianness: little
#   Sanity checking: disabled
#   Assertions: disabled
#   Random seed: 0
#   Sizeofs: void*:8, int:4, long:8, size_t:8
# Input files DNA, FASTA:
#   /Volumes/Serine/wd/18-03-05/mkfasta/duck4.1.fasta
# Reading reference sizes
#   Time reading reference sizes: 00:00:59
# Calculating joined length
# Writing header
# Reserving space for joined string
# Joining reference sequences
#   Time to join reference sequences: 00:00:22
# bmax according to bmaxDivN setting: 501007182
# Using parameters --bmax 375755387 --dcv 1024
# ...

# %%
# !/Applications/bioinfo/bowtie2-2.2.4/bowtie2 \
-x /Volumes/Serine/wd/18-03-05/bowtie/duck4.1.bowtie-index \
-U /Volumes/Serine/wd/18-03-05/160103_I137_FCH3V5YBBXX_L5_WHPANwalDDACDTAAPEI-102_1.fq.gz \
-p 6 \
--very-fast \
-S /Volumes/Serine/wd/18-03-05/bowtie/60103_I137-duck4.1.sam
# Out:
# 41762399 reads; of these:
#   41762399 (100.00%) were unpaired; of these:
#     9294085 (22.25%) aligned 0 times
#     14293014 (34.22%) aligned exactly 1 time
#     18175300 (43.52%) aligned >1 times
# 77.75% overall alignment rate
