# %%
# !ls /Volumes/web-1/nightingales/C_virginica
# Out:
# 2112_lane1_ACAGTG_L001_R1_001.fastq.gz
# 2112_lane1_ACAGTG_L001_R1_002.fastq.gz
# 2112_lane1_ATCACG_L001_R1_001.fastq.gz
# 2112_lane1_ATCACG_L001_R1_002.fastq.gz
# 2112_lane1_ATCACG_L001_R1_003.fastq.gz
# 2112_lane1_CAGATC_L001_R1_001.fastq.gz
# 2112_lane1_CAGATC_L001_R1_002.fastq.gz
# 2112_lane1_CAGATC_L001_R1_003.fastq.gz
# 2112_lane1_GCCAAT_L001_R1_001.fastq.gz
# 2112_lane1_GCCAAT_L001_R1_002.fastq.gz
# 2112_lane1_NoIndex_L001_R1_001.fastq.gz
# 2112_lane1_NoIndex_L001_R1_002.fastq.gz
# 2112_lane1_NoIndex_L001_R1_003.fastq.gz
# 2112_lane1_NoIndex_L001_R1_004.fastq.gz
# 2112_lane1_NoIndex_L001_R1_005.fastq.gz
# 2112_lane1_NoIndex_L001_R1_006.fastq.gz
# 2112_lane1_NoIndex_L001_R1_007.fastq.gz
# 2112_lane1_NoIndex_L001_R1_008.fastq.gz
# 2112_lane1_NoIndex_L001_R1_009.fastq.gz
# 2112_lane1_NoIndex_L001_R1_010.fastq.gz
# 2112_lane1_NoIndex_L001_R1_011.fastq.gz
# 2112_lane1_NoIndex_L001_R1_012.fastq.gz
# 2112_lane1_NoIndex_L001_R1_013.fastq.gz
# 2112_lane1_NoIndex_L001_R1_014.fastq.gz
# ...

# %%
# !cat !ls /Volumes/web-1/nightingales/C_virginica/readme.md
# Out:
# cat: !ls: No such file or directory
# ##High-throughput Sequencing Projects
# ---
# ###[LSU Oil Spill MBD BS-Seq](http://onsnetwork.org/kubu4/category/lsu-c-virginica-oil-spill-mbd-bs-sequencing/)
# ####Tissue: gill
# ####Illumina 100SE
# ####Received: 20150209
# 2112_lane1_NoIndex_L001_R1_001.fastq.gz
# 2112_lane1_NoIndex_L001_R1_002.fastq.gz
# 2112_lane1_NoIndex_L001_R1_003.fastq.gz
# 2112_lane1_NoIndex_L001_R1_004.fastq.gz
# 2112_lane1_NoIndex_L001_R1_005.fastq.gz
# 2112_lane1_NoIndex_L001_R1_006.fastq.gz
# 2112_lane1_NoIndex_L001_R1_007.fastq.gz
# 2112_lane1_NoIndex_L001_R1_008.fastq.gz
# 2112_lane1_NoIndex_L001_R1_009.fastq.gz
# 2112_lane1_NoIndex_L001_R1_010.fastq.gz
# 2112_lane1_NoIndex_L001_R1_011.fastq.gz
# 2112_lane1_NoIndex_L001_R1_012.fastq.gz
# 2112_lane1_NoIndex_L001_R1_013.fastq.gz
# 2112_lane1_NoIndex_L001_R1_014.fastq.gz
# 2112_lane1_NoIndex_L001_R1_015.fastq.gz
#
# ---
# ...

# %%
# !rsync -avz --progress /Volumes/web-1/nightingales/C_virginica/2*[^N]* \
/Volumes/Serine/wd/18-04-10/oil
# Out:
# building file list ...
# 28 files to consider
# 2112_lane1_ACAGTG_L001_R1_001.fastq.gz
#   1485135700 100%   33.38MB/s    0:00:42 (xfer#1, to-check=27/28)
# 2112_lane1_ACAGTG_L001_R1_002.fastq.gz
#    121735714 100%   19.03MB/s    0:00:06 (xfer#2, to-check=26/28)
# 2112_lane1_ATCACG_L001_R1_001.fastq.gz
#   1580443828 100%   32.07MB/s    0:00:46 (xfer#3, to-check=25/28)
# 2112_lane1_ATCACG_L001_R1_002.fastq.gz
#   1526716066 100%   33.41MB/s    0:00:43 (xfer#4, to-check=24/28)
# 2112_lane1_ATCACG_L001_R1_003.fastq.gz
#    138426686 100%   30.62MB/s    0:00:04 (xfer#5, to-check=23/28)
# 2112_lane1_CAGATC_L001_R1_001.fastq.gz
#   1536705345 100%   32.66MB/s    0:00:44 (xfer#6, to-check=22/28)
# 2112_lane1_CAGATC_L001_R1_002.fastq.gz
#   1495856527 100%   32.95MB/s    0:00:43 (xfer#7, to-check=21/28)
# 2112_lane1_CAGATC_L001_R1_003.fastq.gz
#    723351386 100%   30.93MB/s    0:00:22 (xfer#8, to-check=20/28)
# 2112_lane1_GCCAAT_L001_R1_001.fastq.gz
# ...

# %%
# !/Applications/bioinfo/FastQC/fastqc -t 1 \
-o /Volumes/Serine/wd/18-04-10/oil/fqc \
/Volumes/Serine/wd/18-04-10/oil/2112*
# Out:
# Started analysis of 2112_lane1_ACAGTG_L001_R1_001.fastq.gz
# Approx 5% complete for 2112_lane1_ACAGTG_L001_R1_001.fastq.gz
# Approx 10% complete for 2112_lane1_ACAGTG_L001_R1_001.fastq.gz
# Approx 15% complete for 2112_lane1_ACAGTG_L001_R1_001.fastq.gz
# Approx 20% complete for 2112_lane1_ACAGTG_L001_R1_001.fastq.gz
# Approx 25% complete for 2112_lane1_ACAGTG_L001_R1_001.fastq.gz
# Approx 30% complete for 2112_lane1_ACAGTG_L001_R1_001.fastq.gz
# Approx 35% complete for 2112_lane1_ACAGTG_L001_R1_001.fastq.gz
# Approx 40% complete for 2112_lane1_ACAGTG_L001_R1_001.fastq.gz
# Approx 45% complete for 2112_lane1_ACAGTG_L001_R1_001.fastq.gz
# Approx 50% complete for 2112_lane1_ACAGTG_L001_R1_001.fastq.gz
# Approx 55% complete for 2112_lane1_ACAGTG_L001_R1_001.fastq.gz
# Approx 60% complete for 2112_lane1_ACAGTG_L001_R1_001.fastq.gz
# Approx 65% complete for 2112_lane1_ACAGTG_L001_R1_001.fastq.gz
# Approx 70% complete for 2112_lane1_ACAGTG_L001_R1_001.fastq.gz
# ...

# %%
ls /Volumes/web/Arabidopsis/20150414_trimmed_2112*z
# Out:
# /Volumes/web/Arabidopsis/20150414_trimmed_2112_lane1_HB16_Oil_25000ppm_TTAGGC.fastq.gz*
# /Volumes/web/Arabidopsis/20150414_trimmed_2112_lane1_HB2_Oil_25000ppm_ATCACG.fastq.gz*
# /Volumes/web/Arabidopsis/20150414_trimmed_2112_lane1_HB30_Oil_25000ppm_TGACCA.fastq.gz*
# /Volumes/web/Arabidopsis/20150414_trimmed_2112_lane1_NB11_NoOil_CAGATC.fastq.gz*
# /Volumes/web/Arabidopsis/20150414_trimmed_2112_lane1_NB3_NoOil_ACAGTG.fastq.gz*
# /Volumes/web/Arabidopsis/20150414_trimmed_2112_lane1_NB6_NoOil_GCCAAT.fastq.gz*

# %%
# !rsync -avz --progress /Volumes/web/Arabidopsis/20150414_trimmed_2112*z \
/Volumes/Serine/wd/18-04-10/oil
# Out:
# building file list ...
# 6 files to consider
# 20150414_trimmed_2112_lane1_HB16_Oil_25000ppm_TTAGGC.fastq.gz
#    736395264  42%   29.91MB/s    0:00:32
