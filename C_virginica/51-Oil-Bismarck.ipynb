# %%
cd /Users/sr320/Desktop/oil/01
# Out:
# /Users/sr320/Desktop/oil/01

# %%
# %%bash
# find /Users/sr320/Desktop/Qiagen/20150414_trimmed*.fastq.gz \
# | xargs basename -s fastq.gz | xargs -I{} /Applications/bioinfo/Bismark_v0.19.0/bismark \
# --path_to_bowtie /Applications/bioinfo/bowtie2-2.3.4.1-macos-x86_64 \
# --genome /Users/sr320/Desktop/oakl/genome \
# --score_min L,0,-1.2 \
# -p 4 \
# -u 1000 \
# --non_directional \
# /Users/sr320/Desktop/Qiagen/{}fastq.gz \
# 2> bismark.err
# Out:
# FastQ format assumed (by default)
# Each Bowtie 2 instance is going to be run with 4 threads. Please monitor performance closely and tune down if needed!
# chr NC_035780.1 (65668440 bp)
# chr NC_035781.1 (61752955 bp)
# chr NC_035782.1 (77061148 bp)
# chr NC_035783.1 (59691872 bp)
# chr NC_035784.1 (98698416 bp)
# chr NC_035785.1 (51258098 bp)
# chr NC_035786.1 (57830854 bp)
# chr NC_035787.1 (75944018 bp)
# chr NC_035788.1 (104168038 bp)
# chr NC_035789.1 (32650045 bp)
# chr NC_007175.2 (17244 bp)
#
# Processed 1000 sequences in total
#
# Sequences with no alignments under any condition:	105
# Sequences did not map uniquely:	283
# Sequences which were discarded because genomic sequence could not be extracted:	0
#
# Number of sequences with unique best (first) alignment came from the bowtie output:
# CT/CT:	27	((converted) top strand)
# CT/GA:	32	((converted) bottom strand)
# GA/CT:	270	(complementary to (converted) top strand)
# ...

# %%
# !grep Mapping efficiency bismark.err
# Out:
# grep: efficiency: No such file or directory
# bismark.err:Mapping efficiency:	61.2%
# bismark.err:Mapping efficiency:	59.8%
# bismark.err:Mapping efficiency:	50.1%
# bismark.err:Mapping efficiency:	62.1%
# bismark.err:Mapping efficiency:	57.4%
# bismark.err:Mapping efficiency:	53.6%

# %%
# %%bash
# find /Users/sr320/Desktop/Qiagen/20150414_trimmed*.fastq.gz \
# | xargs basename -s fastq.gz | xargs -I{} /Applications/bioinfo/Bismark_v0.19.0/bismark \
# --path_to_bowtie /Applications/bioinfo/bowtie2-2.3.4.1-macos-x86_64 \
# --genome /Users/sr320/Desktop/oakl/genome \
# --score_min L,0,-0.9 \
# -p 4 \
# -u 1000 \
# --non_directional \
# /Users/sr320/Desktop/Qiagen/{}fastq.gz \
# 2> bismark.err2
# Out:
# FastQ format assumed (by default)
# Each Bowtie 2 instance is going to be run with 4 threads. Please monitor performance closely and tune down if needed!
# chr NC_035780.1 (65668440 bp)
# chr NC_035781.1 (61752955 bp)
# chr NC_035782.1 (77061148 bp)
# chr NC_035783.1 (59691872 bp)
# chr NC_035784.1 (98698416 bp)
# chr NC_035785.1 (51258098 bp)
# chr NC_035786.1 (57830854 bp)
# chr NC_035787.1 (75944018 bp)
# chr NC_035788.1 (104168038 bp)
# chr NC_035789.1 (32650045 bp)
# chr NC_007175.2 (17244 bp)
#
# Processed 1000 sequences in total
#
# Sequences with no alignments under any condition:	145
# Sequences did not map uniquely:	269
# Sequences which were discarded because genomic sequence could not be extracted:	0
#
# Number of sequences with unique best (first) alignment came from the bowtie output:
# CT/CT:	22	((converted) top strand)
# CT/GA:	28	((converted) bottom strand)
# GA/CT:	263	(complementary to (converted) top strand)
# ...

# %%
# !grep Mapping efficiency bismark.err2
# Out:
# grep: efficiency: No such file or directory
# bismark.err2:Mapping efficiency:	58.6%
# bismark.err2:Mapping efficiency:	55.6%
# bismark.err2:Mapping efficiency:	47.8%
# bismark.err2:Mapping efficiency:	58.2%
# bismark.err2:Mapping efficiency:	54.3%
# bismark.err2:Mapping efficiency:	48.2%

# %%
# %%bash
# find /Users/sr320/Desktop/Qiagen/20150414_trimmed*.fastq.gz \
# | xargs basename -s fastq.gz | xargs -I{} /Applications/bioinfo/Bismark_v0.19.0/bismark \
# --path_to_bowtie /Applications/bioinfo/bowtie2-2.3.4.1-macos-x86_64 \
# --genome /Users/sr320/Desktop/oakl/genome \
# -p 4 \
# -u 1000 \
# --non_directional \
# /Users/sr320/Desktop/Qiagen/{}fastq.gz \
# 2> bismark.err3
# grep Mapping efficiency bismark.err3
# Out:
# FastQ format assumed (by default)
# Each Bowtie 2 instance is going to be run with 4 threads. Please monitor performance closely and tune down if needed!
# chr NC_035780.1 (65668440 bp)
# chr NC_035781.1 (61752955 bp)
# chr NC_035782.1 (77061148 bp)
# chr NC_035783.1 (59691872 bp)
# chr NC_035784.1 (98698416 bp)
# chr NC_035785.1 (51258098 bp)
# chr NC_035786.1 (57830854 bp)
# chr NC_035787.1 (75944018 bp)
# chr NC_035788.1 (104168038 bp)
# chr NC_035789.1 (32650045 bp)
# chr NC_007175.2 (17244 bp)
#
# Processed 1000 sequences in total
#
# Sequences with no alignments under any condition:	501
# Sequences did not map uniquely:	174
# Sequences which were discarded because genomic sequence could not be extracted:	0
#
# Number of sequences with unique best (first) alignment came from the bowtie output:
# CT/CT:	10	((converted) top strand)
# CT/GA:	15	((converted) bottom strand)
# GA/CT:	145	(complementary to (converted) top strand)
# ...

# %%
# %%bash
# find /Users/sr320/Desktop/Qiagen/20150414_trimmed*.fastq.gz \
# | xargs basename -s fastq.gz | xargs -I{} /Applications/bioinfo/Bismark_v0.19.0/bismark \
# --path_to_bowtie /Applications/bioinfo/bowtie2-2.3.4.1-macos-x86_64 \
# --genome /Users/sr320/Desktop/oakl/genome \
# -u 1000 \
# /Users/sr320/Desktop/Qiagen/{}fastq.gz \
# 2> bismark.err4
# grep Mapping efficiency bismark.err4
# Out:
# FastQ format assumed (by default)
# chr NC_035780.1 (65668440 bp)
# chr NC_035781.1 (61752955 bp)
# chr NC_035782.1 (77061148 bp)
# chr NC_035783.1 (59691872 bp)
# chr NC_035784.1 (98698416 bp)
# chr NC_035785.1 (51258098 bp)
# chr NC_035786.1 (57830854 bp)
# chr NC_035787.1 (75944018 bp)
# chr NC_035788.1 (104168038 bp)
# chr NC_035789.1 (32650045 bp)
# chr NC_007175.2 (17244 bp)
#
# Processed 1000 sequences in total
#
# Sequences with no alignments under any condition:	913
# Sequences did not map uniquely:	37
# Sequences which were discarded because genomic sequence could not be extracted:	0
#
# Number of sequences with unique best (first) alignment came from the bowtie output:
# CT/CT:	24	((converted) top strand)
# CT/GA:	26	((converted) bottom strand)
# GA/CT:	0	(complementary to (converted) top strand)
# GA/GA:	0	(complementary to (converted) bottom strand)
#
# Number of alignments to (merely theoretical) complementary strands being rejected in total:	0
#
# ...

# %%
# %%bash
# find /Users/sr320/Desktop/Qiagen/20150414_trimmed*.fastq.gz \
# | xargs basename -s fastq.gz | xargs -I{} /Applications/bioinfo/Bismark_v0.19.0/bismark \
# --path_to_bowtie /Applications/bioinfo/bowtie2-2.3.4.1-macos-x86_64 \
# --genome /Users/sr320/Desktop/oakl/genome \
# --score_min L,0,-0.6 \
# -u 1000 \
# --non_directional \
# /Users/sr320/Desktop/Qiagen/{}fastq.gz \
# 2> bismark.err4
# grep Mapping efficiency bismark.err4
# Out:
# FastQ format assumed (by default)
# chr NC_035780.1 (65668440 bp)
# chr NC_035781.1 (61752955 bp)
# chr NC_035782.1 (77061148 bp)
# chr NC_035783.1 (59691872 bp)
# chr NC_035784.1 (98698416 bp)
# chr NC_035785.1 (51258098 bp)
# chr NC_035786.1 (57830854 bp)
# chr NC_035787.1 (75944018 bp)
# chr NC_035788.1 (104168038 bp)
# chr NC_035789.1 (32650045 bp)
# chr NC_007175.2 (17244 bp)
#
# Processed 1000 sequences in total
#
# Sequences with no alignments under any condition:	240
# Sequences did not map uniquely:	246
# Sequences which were discarded because genomic sequence could not be extracted:	0
#
# Number of sequences with unique best (first) alignment came from the bowtie output:
# CT/CT:	19	((converted) top strand)
# CT/GA:	22	((converted) bottom strand)
# GA/CT:	231	(complementary to (converted) top strand)
# GA/GA:	242	(complementary to (converted) bottom strand)
#
# FastQ format assumed (by default)
# chr NC_035780.1 (65668440 bp)
# chr NC_035781.1 (61752955 bp)
# ...

# %%
cd ../02
# Out:
# /Users/sr320/Desktop/oil/02

# %%
# %%bash
# find /Users/sr320/Desktop/Qiagen/20150414_trimmed*.fastq.gz \
# | xargs basename -s fastq.gz | xargs -I{} /Applications/bioinfo/Bismark_v0.19.0/bismark \
# --path_to_bowtie /Applications/bioinfo/bowtie2-2.3.4.1-macos-x86_64 \
# --genome /Users/sr320/Desktop/oakl/genome \
# --score_min L,0,-0.6 \
# --non_directional \
# -p 2 \
# /Users/sr320/Desktop/Qiagen/{}fastq.gz \
# 2> bismark.err
# grep Mapping efficiency bismark.err
#
#
#
# /Applications/bioinfo/Bismark_v0.19.0/deduplicate_bismark \
# --bam -s \
# *.bam \
# 2> dedup.err
#
#
# /Applications/bioinfo/Bismark_v0.19.0/bismark_methylation_extractor \
# --bedGraph --counts --scaffolds \
# --multicore 2 \
# *deduplicated.bam \
# 2> bme.err
# Out:
# Process is terminated.
