# %%
# %%bash
# /Applications/bioinfo/Bismark_v0.19.0/bismark \
# --path_to_bowtie /Applications/bioinfo/bowtie2-2.3.4.1-macos-x86_64 \
# --genome /Volumes/Serine/wd/18-03-15/genome \
# --non_directional \
# --score_min L,0,-0.6 \
# -1 /Volumes/Serine/wd/18-03-16/10_32_S32_L001_R1_001.fastq.gz \
# -2 /Volumes/Serine/wd/18-03-16/10_32_S32_L001_R2_001.fastq.gz \

# %%
# %%bash
# find /Volumes/Serine/wd/18-04-07/zr2096_*R1* \
# | xargs basename -s _s1_R1.fastq.gz
# Out:
# zr2096_10
# zr2096_1
# zr2096_2
# zr2096_3
# zr2096_4
# zr2096_5
# zr2096_6
# zr2096_7
# zr2096_8
# zr2096_9

# %%
# !mkdir /Volumes/Serine/wd/18-04-07/bm01

# %%
cd /Volumes/Serine/wd/18-04-07/bm01
# Out:
# /Volumes/Serine/wd/18-04-07/bm01

# %%
# %%bash
# find /Volumes/Serine/wd/18-04-07/zr2096_*R1* \
# | xargs basename -s _s1_R1.fastq.gz | xargs -I{} /Applications/bioinfo/Bismark_v0.19.0/bismark \
# --path_to_bowtie /Applications/bioinfo/bowtie2-2.3.4.1-macos-x86_64 \
# --genome /Volumes/Serine/wd/18-03-15/genome \
# --score_min L,0,-0.6 \
# -p 4 \
# -1 /Volumes/Serine/wd/18-04-07/{}_s1_R1.fastq.gz \
# -2 /Volumes/Serine/wd/18-04-07/{}_s1_R2.fastq.gz  \
# Out:
# FastQ format assumed (by default)
# Each Bowtie 2 instance is going to be run with 4 threads. Please monitor performance closely and tune down if needed!
# chr NC_035780.1 (65668440 bp)
# chr NC_035781.1 (61752955 bp)
# chr NC_035782.1 (77061148 bp)
# chr NC_035783.1 (59691872 bp)
# chr NC_035784.1 (98698416 bp)
# chr NC_035785.1 (51258098 bp)
# chr NC_035786.1 (57830854 bp)
# chr NC_035787.1 (75944018 bp)
# chr NC_035788.1 (104168038 bp)
# chr NC_035789.1 (32650045 bp)
# chr NC_007175.2 (17244 bp)
#
# Number of paired-end alignments with a unique best hit:	3229397
# Mapping efficiency:	18.2%
#
# Sequence pairs with no alignments under any condition:	13321198
# Sequence pairs did not map uniquely:	1166532
# Sequence pairs which were discarded because genomic sequence could not be extracted:	0
#
# Number of sequence pairs with unique best (first) alignment came from the bowtie output:
# CT/GA/CT:	1611649	((converted) top strand)
# GA/CT/CT:	0	(complementary to (converted) top strand)
# GA/CT/GA:	0	(complementary to (converted) bottom strand)
# CT/GA/GA:	1617748	((converted) bottom strand)
#
# Number of alignments to (merely theoretical) complementary strands being rejected in total:	0
#
# FastQ format assumed (by default)
# Each Bowtie 2 instance is going to be run with 4 threads. Please monitor performance closely and tune down if needed!
# chr NC_035780.1 (65668440 bp)
# chr NC_035781.1 (61752955 bp)
# chr NC_035782.1 (77061148 bp)
# chr NC_035783.1 (59691872 bp)
# chr NC_035784.1 (98698416 bp)
# chr NC_035785.1 (51258098 bp)
# chr NC_035786.1 (57830854 bp)
# chr NC_035787.1 (75944018 bp)
# chr NC_035788.1 (104168038 bp)
# chr NC_035789.1 (32650045 bp)
# chr NC_007175.2 (17244 bp)
#
# Number of paired-end alignments with a unique best hit:	2033691
# Mapping efficiency:	7.0%
#
# Sequence pairs with no alignments under any condition:	26209079
# Sequence pairs did not map uniquely:	739996
# Sequence pairs which were discarded because genomic sequence could not be extracted:	2
#
# Number of sequence pairs with unique best (first) alignment came from the bowtie output:
# CT/GA/CT:	1014935	((converted) top strand)
# GA/CT/CT:	0	(complementary to (converted) top strand)
# GA/CT/GA:	0	(complementary to (converted) bottom strand)
# CT/GA/GA:	1018754	((converted) bottom strand)
#
# Number of alignments to (merely theoretical) complementary strands being rejected in total:	0
#
# FastQ format assumed (by default)
# Each Bowtie 2 instance is going to be run with 4 threads. Please monitor performance closely and tune down if needed!
# chr NC_035780.1 (65668440 bp)
# chr NC_035781.1 (61752955 bp)
# chr NC_035782.1 (77061148 bp)
# chr NC_035783.1 (59691872 bp)
# chr NC_035784.1 (98698416 bp)
# chr NC_035785.1 (51258098 bp)
# chr NC_035786.1 (57830854 bp)
# chr NC_035787.1 (75944018 bp)
# chr NC_035788.1 (104168038 bp)
# chr NC_035789.1 (32650045 bp)
# chr NC_007175.2 (17244 bp)
#
# Number of paired-end alignments with a unique best hit:	5003424
# Mapping efficiency:	16.2%
#
# Sequence pairs with no alignments under any condition:	23887292
# Sequence pairs did not map uniquely:	1907866
# Sequence pairs which were discarded because genomic sequence could not be extracted:	0
#
# Number of sequence pairs with unique best (first) alignment came from the bowtie output:
# CT/GA/CT:	2496390	((converted) top strand)
# GA/CT/CT:	0	(complementary to (converted) top strand)
# GA/CT/GA:	0	(complementary to (converted) bottom strand)
# CT/GA/GA:	2507034	((converted) bottom strand)
#
# Number of alignments to (merely theoretical) complementary strands being rejected in total:	0
#
# FastQ format assumed (by default)
# Each Bowtie 2 instance is going to be run with 4 threads. Please monitor performance closely and tune down if needed!
# chr NC_035780.1 (65668440 bp)
# chr NC_035781.1 (61752955 bp)
# chr NC_035782.1 (77061148 bp)
# chr NC_035783.1 (59691872 bp)
# chr NC_035784.1 (98698416 bp)
# chr NC_035785.1 (51258098 bp)
# chr NC_035786.1 (57830854 bp)
# chr NC_035787.1 (75944018 bp)
# chr NC_035788.1 (104168038 bp)
# chr NC_035789.1 (32650045 bp)
# chr NC_007175.2 (17244 bp)
#
# Number of paired-end alignments with a unique best hit:	5310557
# Mapping efficiency:	17.8%
#
# Sequence pairs with no alignments under any condition:	22495650
# Sequence pairs did not map uniquely:	2085795
# Sequence pairs which were discarded because genomic sequence could not be extracted:	0
#
# Number of sequence pairs with unique best (first) alignment came from the bowtie output:
# CT/GA/CT:	2649044	((converted) top strand)
# GA/CT/CT:	0	(complementary to (converted) top strand)
# GA/CT/GA:	0	(complementary to (converted) bottom strand)
# CT/GA/GA:	2661513	((converted) bottom strand)
#
# Number of alignments to (merely theoretical) complementary strands being rejected in total:	0
#
# FastQ format assumed (by default)
# Each Bowtie 2 instance is going to be run with 4 threads. Please monitor performance closely and tune down if needed!
# chr NC_035780.1 (65668440 bp)
# chr NC_035781.1 (61752955 bp)
# chr NC_035782.1 (77061148 bp)
# chr NC_035783.1 (59691872 bp)
# chr NC_035784.1 (98698416 bp)
# chr NC_035785.1 (51258098 bp)
# chr NC_035786.1 (57830854 bp)
# chr NC_035787.1 (75944018 bp)
# chr NC_035788.1 (104168038 bp)
# chr NC_035789.1 (32650045 bp)
# chr NC_007175.2 (17244 bp)
#
# Number of paired-end alignments with a unique best hit:	4516691
# Mapping efficiency:	18.6%
#
# Sequence pairs with no alignments under any condition:	18136564
# Sequence pairs did not map uniquely:	1688713
# Sequence pairs which were discarded because genomic sequence could not be extracted:	2
#
# Number of sequence pairs with unique best (first) alignment came from the bowtie output:
# CT/GA/CT:	2251307	((converted) top strand)
# GA/CT/CT:	0	(complementary to (converted) top strand)
# GA/CT/GA:	0	(complementary to (converted) bottom strand)
# CT/GA/GA:	2265382	((converted) bottom strand)
#
# Number of alignments to (merely theoretical) complementary strands being rejected in total:	0
#
# FastQ format assumed (by default)
# Each Bowtie 2 instance is going to be run with 4 threads. Please monitor performance closely and tune down if needed!
# chr NC_035780.1 (65668440 bp)
# chr NC_035781.1 (61752955 bp)
# chr NC_035782.1 (77061148 bp)
# chr NC_035783.1 (59691872 bp)
# chr NC_035784.1 (98698416 bp)
# chr NC_035785.1 (51258098 bp)
# chr NC_035786.1 (57830854 bp)
# chr NC_035787.1 (75944018 bp)
# chr NC_035788.1 (104168038 bp)
# chr NC_035789.1 (32650045 bp)
# chr NC_007175.2 (17244 bp)
#
# Number of paired-end alignments with a unique best hit:	5499890
# Mapping efficiency:	17.3%
#
# Sequence pairs with no alignments under any condition:	24300069
# Sequence pairs did not map uniquely:	1978756
# Sequence pairs which were discarded because genomic sequence could not be extracted:	1
#
# Number of sequence pairs with unique best (first) alignment came from the bowtie output:
# CT/GA/CT:	2749961	((converted) top strand)
# GA/CT/CT:	0	(complementary to (converted) top strand)
# GA/CT/GA:	0	(complementary to (converted) bottom strand)
# CT/GA/GA:	2749928	((converted) bottom strand)
#
# Number of alignments to (merely theoretical) complementary strands being rejected in total:	0
#
# FastQ format assumed (by default)
# Each Bowtie 2 instance is going to be run with 4 threads. Please monitor performance closely and tune down if needed!
# chr NC_035780.1 (65668440 bp)
# chr NC_035781.1 (61752955 bp)
# chr NC_035782.1 (77061148 bp)
# chr NC_035783.1 (59691872 bp)
# chr NC_035784.1 (98698416 bp)
# chr NC_035785.1 (51258098 bp)
# chr NC_035786.1 (57830854 bp)
# chr NC_035787.1 (75944018 bp)
# chr NC_035788.1 (104168038 bp)
# chr NC_035789.1 (32650045 bp)
# chr NC_007175.2 (17244 bp)
#
# Number of paired-end alignments with a unique best hit:	4541444
# Mapping efficiency:	18.7%
#
# Sequence pairs with no alignments under any condition:	17961401
# Sequence pairs did not map uniquely:	1734445
# Sequence pairs which were discarded because genomic sequence could not be extracted:	0
#
# Number of sequence pairs with unique best (first) alignment came from the bowtie output:
# CT/GA/CT:	2266667	((converted) top strand)
# GA/CT/CT:	0	(complementary to (converted) top strand)
# GA/CT/GA:	0	(complementary to (converted) bottom strand)
# CT/GA/GA:	2274777	((converted) bottom strand)
#
# Number of alignments to (merely theoretical) complementary strands being rejected in total:	0
#
# FastQ format assumed (by default)
# Each Bowtie 2 instance is going to be run with 4 threads. Please monitor performance closely and tune down if needed!
# chr NC_035780.1 (65668440 bp)
# chr NC_035781.1 (61752955 bp)
# chr NC_035782.1 (77061148 bp)
# chr NC_035783.1 (59691872 bp)
# chr NC_035784.1 (98698416 bp)
# chr NC_035785.1 (51258098 bp)
# chr NC_035786.1 (57830854 bp)
# chr NC_035787.1 (75944018 bp)
# chr NC_035788.1 (104168038 bp)
# chr NC_035789.1 (32650045 bp)
# chr NC_007175.2 (17244 bp)
#
# Number of paired-end alignments with a unique best hit:	5038566
# Mapping efficiency:	17.1%
#
# Sequence pairs with no alignments under any condition:	22726177
# Sequence pairs did not map uniquely:	1770003
# Sequence pairs which were discarded because genomic sequence could not be extracted:	2
#
# Number of sequence pairs with unique best (first) alignment came from the bowtie output:
# CT/GA/CT:	2514606	((converted) top strand)
# GA/CT/CT:	0	(complementary to (converted) top strand)
# GA/CT/GA:	0	(complementary to (converted) bottom strand)
# CT/GA/GA:	2523958	((converted) bottom strand)
#
# Number of alignments to (merely theoretical) complementary strands being rejected in total:	0
#
# FastQ format assumed (by default)
# Each Bowtie 2 instance is going to be run with 4 threads. Please monitor performance closely and tune down if needed!
# chr NC_035780.1 (65668440 bp)
# chr NC_035781.1 (61752955 bp)
# chr NC_035782.1 (77061148 bp)
# chr NC_035783.1 (59691872 bp)
# chr NC_035784.1 (98698416 bp)
# chr NC_035785.1 (51258098 bp)
# chr NC_035786.1 (57830854 bp)
# chr NC_035787.1 (75944018 bp)
# chr NC_035788.1 (104168038 bp)
# chr NC_035789.1 (32650045 bp)
# chr NC_007175.2 (17244 bp)
#
# Number of paired-end alignments with a unique best hit:	4646143
# Mapping efficiency:	15.6%
#
# Sequence pairs with no alignments under any condition:	23487537
# Sequence pairs did not map uniquely:	1628157
# Sequence pairs which were discarded because genomic sequence could not be extracted:	2
#
# Number of sequence pairs with unique best (first) alignment came from the bowtie output:
# CT/GA/CT:	2325979	((converted) top strand)
# GA/CT/CT:	0	(complementary to (converted) top strand)
# GA/CT/GA:	0	(complementary to (converted) bottom strand)
# CT/GA/GA:	2320162	((converted) bottom strand)
#
# Number of alignments to (merely theoretical) complementary strands being rejected in total:	0
#
# FastQ format assumed (by default)
# Each Bowtie 2 instance is going to be run with 4 threads. Please monitor performance closely and tune down if needed!
# chr NC_035780.1 (65668440 bp)
# chr NC_035781.1 (61752955 bp)
# chr NC_035782.1 (77061148 bp)
# chr NC_035783.1 (59691872 bp)
# chr NC_035784.1 (98698416 bp)
# chr NC_035785.1 (51258098 bp)
# chr NC_035786.1 (57830854 bp)
# chr NC_035787.1 (75944018 bp)
# chr NC_035788.1 (104168038 bp)
# chr NC_035789.1 (32650045 bp)
# chr NC_007175.2 (17244 bp)
#
# Number of paired-end alignments with a unique best hit:	5644532
# Mapping efficiency:	17.3%
#
# Sequence pairs with no alignments under any condition:	24857593
# Sequence pairs did not map uniquely:	2134106
# Sequence pairs which were discarded because genomic sequence could not be extracted:	1
#
# Number of sequence pairs with unique best (first) alignment came from the bowtie output:
# CT/GA/CT:	2816231	((converted) top strand)
# GA/CT/CT:	0	(complementary to (converted) top strand)
# GA/CT/GA:	0	(complementary to (converted) bottom strand)
# CT/GA/GA:	2828300	((converted) bottom strand)
#
# Number of alignments to (merely theoretical) complementary strands being rejected in total:	0
# Bowtie seems to be working fine (tested command '/Applications/bioinfo/bowtie2-2.3.4.1-macos-x86_64/bowtie2 --version' [2.3.4])
# Output format is BAM (default)
# Alignments will be written out in BAM format. Samtools found here: '/Applications/bioinfo/samtools-1.3.1/samtools'
# Reference genome folder provided is /Volumes/Serine/wd/18-03-15/genome/	(absolute path is '/Volumes/Serine/wd/18-03-15/genome/)'
#
# Input files to be analysed (in current folder '/Volumes/Serine/wd/18-04-07/bm01'):
# /Volumes/Serine/wd/18-04-07/zr2096_10_s1_R1.fastq.gz
# /Volumes/Serine/wd/18-04-07/zr2096_10_s1_R2.fastq.gz
# Library is assumed to be strand-specific (directional), alignments to strands complementary to the original top or bottom strands will be ignored (i.e. not performed!)
# Setting parallelization to single-threaded (default)
#
# Current working directory is: /Volumes/Serine/wd/18-04-07/bm01
#
# Now reading in and storing sequence information of the genome specified in: /Volumes/Serine/wd/18-03-15/genome/
#
# Single-core mode: setting pid to 1
#
# Paired-end alignments will be performed
# =======================================
#
# The provided filenames for paired-end alignments are /Volumes/Serine/wd/18-04-07/zr2096_10_s1_R1.fastq.gz and /Volumes/Serine/wd/18-04-07/zr2096_10_s1_R2.fastq.gz
# Input files are in FastQ format
# Writing a C -> T converted version of the input file zr2096_10_s1_R1.fastq.gz to zr2096_10_s1_R1.fastq.gz_C_to_T.fastq
#
# Created C -> T converted version of the FastQ file zr2096_10_s1_R1.fastq.gz (17717127 sequences in total)
#
# Writing a G -> A converted version of the input file zr2096_10_s1_R2.fastq.gz to zr2096_10_s1_R2.fastq.gz_G_to_A.fastq
#
# Created G -> A converted version of the FastQ file zr2096_10_s1_R2.fastq.gz (17717127 sequences in total)
#
# Input files are zr2096_10_s1_R1.fastq.gz_C_to_T.fastq and zr2096_10_s1_R2.fastq.gz_G_to_A.fastq (FastQ)
# Now running 2 instances of Bowtie 2 against the bisulfite genome of /Volumes/Serine/wd/18-03-15/genome/ with the specified options: -q --score-min L,0,-0.6 -p 4 --reorder --ignore-quals --no-mixed --no-discordant --dovetail --maxins 500
#
# Now starting a Bowtie 2 paired-end alignment for CTread1GAread2CTgenome (reading in sequences from zr2096_10_s1_R1.fastq.gz_C_to_T.fastq and zr2096_10_s1_R2.fastq.gz_G_to_A.fastq, with the options: -q --score-min L,0,-0.6 -p 4 --reorder --ignore-quals --no-mixed --no-discordant --dovetail --maxins 500 --norc))
# Found first alignment:
# HWI-C00124:321:CC781ANXX:2:1101:1232:2155_1:N:0:GATCAG/1	77	*	0	0	*	*	0	0	GTTATATATAATTGTATTAATTATAAAAAATATNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNATTTATTATTAAAAATATTAAATATATTATTTTA	BBBBBFFFFFFFFFFFFFFBFFFFFFFFFFFFF#################################<</<FFFFFFFFFFFFFFFFFFFFFFFFFF<FFF	YT:Z:UP	YF:Z:NS
# HWI-C00124:321:CC781ANXX:2:1101:1232:2155_2:N:0:GATCAG/2	141	*	0	0	*	*	0	0	NNNNNATTTTATATTTTTAATAATAAATATAATTATATATTAAAATAAAATAATATATTTAATATTTTTAATAATAAATACAATTAAATATCATAATAA	#####BB<FFFFFFFFFFFFFBFFFFFFFFFFFFFFFFBFFBFFFFFFFFFBFFFBFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFF	YT:Z:UP
# Now starting a Bowtie 2 paired-end alignment for CTread1GAread2GAgenome (reading in sequences from zr2096_10_s1_R1.fastq.gz_C_to_T.fastq and zr2096_10_s1_R2.fastq.gz_G_to_A.fastq, with the options: -q --score-min L,0,-0.6 -p 4 --reorder --ignore-quals --no-mixed --no-discordant --dovetail --maxins 500 --nofw))
# Found first alignment:
# HWI-C00124:321:CC781ANXX:2:1101:1232:2155_1:N:0:GATCAG/1	77	*	0	0	*	*	0	0	GTTATATATAATTGTATTAATTATAAAAAATATNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNATTTATTATTAAAAATATTAAATATATTATTTTA	BBBBBFFFFFFFFFFFFFFBFFFFFFFFFFFFF#################################<</<FFFFFFFFFFFFFFFFFFFFFFFFFF<FFF	YT:Z:UP	YF:Z:NS
# HWI-C00124:321:CC781ANXX:2:1101:1232:2155_2:N:0:GATCAG/2	141	*	0	0	*	*	0	0	NNNNNATTTTATATTTTTAATAATAAATATAATTATATATTAAAATAAAATAATATATTTAATATTTTTAATAATAAATACAATTAAATATCATAATAA	#####BB<FFFFFFFFFFFFFBFFFFFFFFFFFFFFFFBFFBFFFFFFFFFBFFFBFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFF	YT:Z:UP
#
# >>> Writing bisulfite mapping results to zr2096_10_s1_R1_bismark_bt2_pe.bam <<<
#
#
# Reading in the sequence files /Volumes/Serine/wd/18-04-07/zr2096_10_s1_R1.fastq.gz and /Volumes/Serine/wd/18-04-07/zr2096_10_s1_R2.fastq.gz
# Processed 1000000 sequence pairs so far
# Processed 2000000 sequence pairs so far
# Processed 3000000 sequence pairs so far
# Processed 4000000 sequence pairs so far
# Processed 5000000 sequence pairs so far
# Processed 6000000 sequence pairs so far
# Processed 7000000 sequence pairs so far
# Processed 8000000 sequence pairs so far
# Processed 9000000 sequence pairs so far
# Processed 10000000 sequence pairs so far
# Processed 11000000 sequence pairs so far
# Processed 12000000 sequence pairs so far
# Processed 13000000 sequence pairs so far
# Processed 14000000 sequence pairs so far
# Processed 15000000 sequence pairs so far
# Processed 16000000 sequence pairs so far
# Processed 17000000 sequence pairs so far
# 17717127 reads; of these:
#   17717127 (100.00%) were paired; of these:
#     14747848 (83.24%) aligned concordantly 0 times
#     1470661 (8.30%) aligned concordantly exactly 1 time
#     1498618 (8.46%) aligned concordantly >1 times
# 16.76% overall alignment rate
# 17717127 reads; of these:
#   17717127 (100.00%) were paired; of these:
#     14757625 (83.30%) aligned concordantly 0 times
#     1460774 (8.24%) aligned concordantly exactly 1 time
#     1498728 (8.46%) aligned concordantly >1 times
# 16.70% overall alignment rate
# Processed 17717127 sequences in total
#
#
# Successfully deleted the temporary files zr2096_10_s1_R1.fastq.gz_C_to_T.fastq and zr2096_10_s1_R2.fastq.gz_G_to_A.fastq
#
# Final Alignment report
# ======================
# Sequence pairs analysed in total:	17717127
# Final Cytosine Methylation Report
# =================================
# Total number of C's analysed:	115390413
#
# Total methylated C's in CpG context:	12245061
# Total methylated C's in CHG context:	893329
# Total methylated C's in CHH context:	3246422
# Total methylated C's in Unknown context:	143378
#
# Total unmethylated C's in CpG context:	4475568
# Total unmethylated C's in CHG context:	26065245
# Total unmethylated C's in CHH context:	68464788
# Total unmethylated C's in Unknown context:	445618
#
# C methylated in CpG context:	73.2%
# C methylated in CHG context:	3.3%
# C methylated in CHH context:	4.5%
# C methylated in unknown context (CN or CHN):	24.3%
#
#
# Bismark completed in 0d 1h 20m 30s
#
# ====================
# Bismark run complete
# ====================
#
# Bowtie seems to be working fine (tested command '/Applications/bioinfo/bowtie2-2.3.4.1-macos-x86_64/bowtie2 --version' [2.3.4])
# Output format is BAM (default)
# Alignments will be written out in BAM format. Samtools found here: '/Applications/bioinfo/samtools-1.3.1/samtools'
# Reference genome folder provided is /Volumes/Serine/wd/18-03-15/genome/	(absolute path is '/Volumes/Serine/wd/18-03-15/genome/)'
#
# Input files to be analysed (in current folder '/Volumes/Serine/wd/18-04-07/bm01'):
# /Volumes/Serine/wd/18-04-07/zr2096_1_s1_R1.fastq.gz
# /Volumes/Serine/wd/18-04-07/zr2096_1_s1_R2.fastq.gz
# Library is assumed to be strand-specific (directional), alignments to strands complementary to the original top or bottom strands will be ignored (i.e. not performed!)
# Setting parallelization to single-threaded (default)
#
# Current working directory is: /Volumes/Serine/wd/18-04-07/bm01
#
# Now reading in and storing sequence information of the genome specified in: /Volumes/Serine/wd/18-03-15/genome/
#
# Single-core mode: setting pid to 1
#
# Paired-end alignments will be performed
# =======================================
#
# The provided filenames for paired-end alignments are /Volumes/Serine/wd/18-04-07/zr2096_1_s1_R1.fastq.gz and /Volumes/Serine/wd/18-04-07/zr2096_1_s1_R2.fastq.gz
# Input files are in FastQ format
# Writing a C -> T converted version of the input file zr2096_1_s1_R1.fastq.gz to zr2096_1_s1_R1.fastq.gz_C_to_T.fastq
#
# Created C -> T converted version of the FastQ file zr2096_1_s1_R1.fastq.gz (28982766 sequences in total)
#
# Writing a G -> A converted version of the input file zr2096_1_s1_R2.fastq.gz to zr2096_1_s1_R2.fastq.gz_G_to_A.fastq
#
# Created G -> A converted version of the FastQ file zr2096_1_s1_R2.fastq.gz (28982766 sequences in total)
#
# Input files are zr2096_1_s1_R1.fastq.gz_C_to_T.fastq and zr2096_1_s1_R2.fastq.gz_G_to_A.fastq (FastQ)
# Now running 2 instances of Bowtie 2 against the bisulfite genome of /Volumes/Serine/wd/18-03-15/genome/ with the specified options: -q --score-min L,0,-0.6 -p 4 --reorder --ignore-quals --no-mixed --no-discordant --dovetail --maxins 500
#
# Now starting a Bowtie 2 paired-end alignment for CTread1GAread2CTgenome (reading in sequences from zr2096_1_s1_R1.fastq.gz_C_to_T.fastq and zr2096_1_s1_R2.fastq.gz_G_to_A.fastq, with the options: -q --score-min L,0,-0.6 -p 4 --reorder --ignore-quals --no-mixed --no-discordant --dovetail --maxins 500 --norc))
# Found first alignment:
# HWI-C00124:321:CC781ANXX:1:1101:1249:2156_1:N:0:CGATGT/1	99	NC_035789.1_CT_converted	4531039	2	37M4I59M	=	4531139	200	GAGTTTTTTTGATTATTTGTTGTTTGTTGTTTGTTTGNNNNTNNNTNNGTTTGTTTGTTTGTTTGTTTGTTTGTAAATTTTTTATATTTTTATTTTTTTT	BBBBBFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFF####<###<##<<<FFFFFFFFFFFFFFFF<FFFFFF/</FFFFFF/B/FFFFF/FFFFFFFF	AS:i:-22	XS:i:-31	XN:i:0	XM:i:5	XO:i:1	XG:i:4	NM:i:9	MD:Z:38T0T0G1T0T52	YS:i:-24	YT:Z:CP
# HWI-C00124:321:CC781ANXX:1:1101:1249:2156_2:N:0:CGATGT/2	147	NC_035789.1_CT_converted	4531139	2	100M	=	4531039	-200	GAATTATTGGGTTAATTTTAATTAAATTTGATATAAAGTATTTTTAGGTGAAGGGGATTTAAGTTTGTTTGAATGAAGGGTTTTGTTTTTTTTTAAGGGG	FFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFBBBBB	AS:i:-24	XS:i:-12	XN:i:0	XM:i:4	XO:i:0	XG:i:0	NM:i:4	MD:Z:30G14G9A14A29	YS:i:-22	YT:Z:CP
# Now starting a Bowtie 2 paired-end alignment for CTread1GAread2GAgenome (reading in sequences from zr2096_1_s1_R1.fastq.gz_C_to_T.fastq and zr2096_1_s1_R2.fastq.gz_G_to_A.fastq, with the options: -q --score-min L,0,-0.6 -p 4 --reorder --ignore-quals --no-mixed --no-discordant --dovetail --maxins 500 --nofw))
# Found first alignment:
# HWI-C00124:321:CC781ANXX:1:1101:1249:2156_1:N:0:CGATGT/1	83	NC_035780.1_GA_converted	8090288	6	26M4D74M	=	8090028	-364	AAAAAAAATAAAAATATAAAAAATTTACAAACAAACAAACAAACAAACAAACNNANNNANNNNCAAACAAACAACAAACAACAAATAATCAAAAAAACTC	FFFFFFFF/FFFFF/B/FFFFFF/</FFFFFF<FFFFFFFFFFFFFFFF<<<##<###<####FFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFBBBBB	AS:i:-26	XS:i:-9	XN:i:0	XM:i:9	XO:i:1	XG:i:4	NM:i:13	MD:Z:26^ACAA26A0A1C0A0A1C0A0A0A37	YS:i:-6	YT:Z:CP
# HWI-C00124:321:CC781ANXX:1:1101:1249:2156_2:N:0:CGATGT/2	163	NC_035780.1_GA_converted	8090028	6	100M	=	8090288	364	CCCCTTAAAAAAAAACAAAACCCTTCATTCAAACAAACTTAAATCCCCTTCACCTAAAAATACTTTATATCAAATTTAATTAAAATTAACCCAATAATTC	BBBBBFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFF	AS:i:-6	XS:i:-18	XN:i:0	XM:i:1	XO:i:0	XG:i:0	NM:i:1	MD:Z:29T70	YS:i:-26	YT:Z:CP
#
# >>> Writing bisulfite mapping results to zr2096_1_s1_R1_bismark_bt2_pe.bam <<<
#
#
# Reading in the sequence files /Volumes/Serine/wd/18-04-07/zr2096_1_s1_R1.fastq.gz and /Volumes/Serine/wd/18-04-07/zr2096_1_s1_R2.fastq.gz
# Processed 1000000 sequence pairs so far
# Processed 2000000 sequence pairs so far
# Chromosomal sequence could not be extracted for	HWI-C00124:321:CC781ANXX:1:1109:8558:78841_1:N:0:CGATGT	NC_035780.1	2
# Processed 3000000 sequence pairs so far
# Processed 4000000 sequence pairs so far
# Processed 5000000 sequence pairs so far
# Processed 6000000 sequence pairs so far
# Processed 7000000 sequence pairs so far
# Processed 8000000 sequence pairs so far
# Processed 9000000 sequence pairs so far
# Processed 10000000 sequence pairs so far
# Processed 11000000 sequence pairs so far
# Processed 12000000 sequence pairs so far
# Chromosomal sequence could not be extracted for	HWI-C00124:321:CC781ANXX:1:1309:7531:24389_1:N:0:CGATGT	NC_035781.1	2
# Processed 13000000 sequence pairs so far
# Processed 14000000 sequence pairs so far
# Processed 15000000 sequence pairs so far
# Processed 16000000 sequence pairs so far
# Processed 17000000 sequence pairs so far
# Processed 18000000 sequence pairs so far
# Processed 19000000 sequence pairs so far
# Processed 20000000 sequence pairs so far
# Processed 21000000 sequence pairs so far
# Processed 22000000 sequence pairs so far
# Processed 23000000 sequence pairs so far
# Processed 24000000 sequence pairs so far
# Processed 25000000 sequence pairs so far
# Processed 26000000 sequence pairs so far
# Processed 27000000 sequence pairs so far
# Processed 28000000 sequence pairs so far
# 28982766 reads; of these:
#   28982766 (100.00%) were paired; of these:
#     27108904 (93.53%) aligned concordantly 0 times
#     922592 (3.18%) aligned concordantly exactly 1 time
#     951270 (3.28%) aligned concordantly >1 times
# 6.47% overall alignment rate
# 28982766 reads; of these:
#   28982766 (100.00%) were paired; of these:
#     27112037 (93.55%) aligned concordantly 0 times
#     917899 (3.17%) aligned concordantly exactly 1 time
#     952830 (3.29%) aligned concordantly >1 times
# 6.45% overall alignment rate
# Processed 28982766 sequences in total
#
#
# Successfully deleted the temporary files zr2096_1_s1_R1.fastq.gz_C_to_T.fastq and zr2096_1_s1_R2.fastq.gz_G_to_A.fastq
#
# Final Alignment report
# ======================
# Sequence pairs analysed in total:	28982766
# Final Cytosine Methylation Report
# =================================
# Total number of C's analysed:	71179750
#
# Total methylated C's in CpG context:	7169367
# Total methylated C's in CHG context:	509609
# Total methylated C's in CHH context:	2063668
# Total methylated C's in Unknown context:	92234
#
# Total unmethylated C's in CpG context:	2455710
# Total unmethylated C's in CHG context:	15623504
# Total unmethylated C's in CHH context:	43357892
# Total unmethylated C's in Unknown context:	305784
#
# C methylated in CpG context:	74.5%
# C methylated in CHG context:	3.2%
# C methylated in CHH context:	4.5%
# C methylated in unknown context (CN or CHN):	23.2%
#
#
# Bismark completed in 0d 1h 20m 23s
#
# ====================
# Bismark run complete
# ====================
#
# Bowtie seems to be working fine (tested command '/Applications/bioinfo/bowtie2-2.3.4.1-macos-x86_64/bowtie2 --version' [2.3.4])
# Output format is BAM (default)
# Alignments will be written out in BAM format. Samtools found here: '/Applications/bioinfo/samtools-1.3.1/samtools'
# Reference genome folder provided is /Volumes/Serine/wd/18-03-15/genome/	(absolute path is '/Volumes/Serine/wd/18-03-15/genome/)'
#
# Input files to be analysed (in current folder '/Volumes/Serine/wd/18-04-07/bm01'):
# /Volumes/Serine/wd/18-04-07/zr2096_2_s1_R1.fastq.gz
# /Volumes/Serine/wd/18-04-07/zr2096_2_s1_R2.fastq.gz
# Library is assumed to be strand-specific (directional), alignments to strands complementary to the original top or bottom strands will be ignored (i.e. not performed!)
# Setting parallelization to single-threaded (default)
#
# Current working directory is: /Volumes/Serine/wd/18-04-07/bm01
#
# Now reading in and storing sequence information of the genome specified in: /Volumes/Serine/wd/18-03-15/genome/
#
# Single-core mode: setting pid to 1
#
# Paired-end alignments will be performed
# =======================================
#
# The provided filenames for paired-end alignments are /Volumes/Serine/wd/18-04-07/zr2096_2_s1_R1.fastq.gz and /Volumes/Serine/wd/18-04-07/zr2096_2_s1_R2.fastq.gz
# Input files are in FastQ format
# Writing a C -> T converted version of the input file zr2096_2_s1_R1.fastq.gz to zr2096_2_s1_R1.fastq.gz_C_to_T.fastq
#
# Created C -> T converted version of the FastQ file zr2096_2_s1_R1.fastq.gz (30798582 sequences in total)
#
# Writing a G -> A converted version of the input file zr2096_2_s1_R2.fastq.gz to zr2096_2_s1_R2.fastq.gz_G_to_A.fastq
#
# Created G -> A converted version of the FastQ file zr2096_2_s1_R2.fastq.gz (30798582 sequences in total)
#
# Input files are zr2096_2_s1_R1.fastq.gz_C_to_T.fastq and zr2096_2_s1_R2.fastq.gz_G_to_A.fastq (FastQ)
# Now running 2 instances of Bowtie 2 against the bisulfite genome of /Volumes/Serine/wd/18-03-15/genome/ with the specified options: -q --score-min L,0,-0.6 -p 4 --reorder --ignore-quals --no-mixed --no-discordant --dovetail --maxins 500
#
# Now starting a Bowtie 2 paired-end alignment for CTread1GAread2CTgenome (reading in sequences from zr2096_2_s1_R1.fastq.gz_C_to_T.fastq and zr2096_2_s1_R2.fastq.gz_G_to_A.fastq, with the options: -q --score-min L,0,-0.6 -p 4 --reorder --ignore-quals --no-mixed --no-discordant --dovetail --maxins 500 --norc))
# Found first alignment:
# HWI-C00124:321:CC781ANXX:1:1101:1148:2157_1:N:0:TGACCA/1	77	*	0	0	*	*	0	0	TTTTTTATTAAAATTTATTATTTTAAAAATAAAAATTNNNNTNNNTTTTATTATTTTTTTTAATATTTTTTAATATAATTAAATAATAAAAAAAATTAAT	BBBBBFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFF####<###<<<FFFFFFFFBFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFF	YT:Z:UP
# HWI-C00124:321:CC781ANXX:1:1101:1148:2157_2:N:0:TGACCA/2	141	*	0	0	*	*	0	0	TCACTTCAAAAAAATAATAAATAAAAAAAATTAATACAACAATATTTTTAATAATACAACAATATTTAAAAAATTATTTATTAATTTTTTTTATTATTT	BBBBBFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFBFFFFFFFFFFFFFFFFFFBFFFFFFFFBFF/BFF	YT:Z:UP
# Now starting a Bowtie 2 paired-end alignment for CTread1GAread2GAgenome (reading in sequences from zr2096_2_s1_R1.fastq.gz_C_to_T.fastq and zr2096_2_s1_R2.fastq.gz_G_to_A.fastq, with the options: -q --score-min L,0,-0.6 -p 4 --reorder --ignore-quals --no-mixed --no-discordant --dovetail --maxins 500 --nofw))
# Found first alignment:
# HWI-C00124:321:CC781ANXX:1:1101:1148:2157_1:N:0:TGACCA/1	77	*	0	0	*	*	0	0	TTTTTTATTAAAATTTATTATTTTAAAAATAAAAATTNNNNTNNNTTTTATTATTTTTTTTAATATTTTTTAATATAATTAAATAATAAAAAAAATTAAT	BBBBBFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFF####<###<<<FFFFFFFFBFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFF	YT:Z:UP
# HWI-C00124:321:CC781ANXX:1:1101:1148:2157_2:N:0:TGACCA/2	141	*	0	0	*	*	0	0	TCACTTCAAAAAAATAATAAATAAAAAAAATTAATACAACAATATTTTTAATAATACAACAATATTTAAAAAATTATTTATTAATTTTTTTTATTATTT	BBBBBFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFBFFFFFFFFFFFFFFFFFFBFFFFFFFFBFF/BFF	YT:Z:UP
#
# >>> Writing bisulfite mapping results to zr2096_2_s1_R1_bismark_bt2_pe.bam <<<
#
#
# Reading in the sequence files /Volumes/Serine/wd/18-04-07/zr2096_2_s1_R1.fastq.gz and /Volumes/Serine/wd/18-04-07/zr2096_2_s1_R2.fastq.gz
# Processed 1000000 sequence pairs so far
# Processed 2000000 sequence pairs so far
# Processed 3000000 sequence pairs so far
# Processed 4000000 sequence pairs so far
# Processed 5000000 sequence pairs so far
# Processed 6000000 sequence pairs so far
# Processed 7000000 sequence pairs so far
# Processed 8000000 sequence pairs so far
# Processed 9000000 sequence pairs so far
# Processed 10000000 sequence pairs so far
# Processed 11000000 sequence pairs so far
# Processed 12000000 sequence pairs so far
# Processed 13000000 sequence pairs so far
# Processed 14000000 sequence pairs so far
# Processed 15000000 sequence pairs so far
# Processed 16000000 sequence pairs so far
# Processed 17000000 sequence pairs so far
# Processed 18000000 sequence pairs so far
# Processed 19000000 sequence pairs so far
# Processed 20000000 sequence pairs so far
# Processed 21000000 sequence pairs so far
# Processed 22000000 sequence pairs so far
# Processed 23000000 sequence pairs so far
# Processed 24000000 sequence pairs so far
# Processed 25000000 sequence pairs so far
# Processed 26000000 sequence pairs so far
# Processed 27000000 sequence pairs so far
# Processed 28000000 sequence pairs so far
# Processed 29000000 sequence pairs so far
# Processed 30000000 sequence pairs so far
# 30798582 reads; of these:
#   30798582 (100.00%) were paired; of these:
#     26162568 (84.95%) aligned concordantly 0 times
#     2337766 (7.59%) aligned concordantly exactly 1 time
#     2298248 (7.46%) aligned concordantly >1 times
# 15.05% overall alignment rate
# 30798582 reads; of these:
#   30798582 (100.00%) were paired; of these:
#     26171347 (84.98%) aligned concordantly 0 times
#     2324622 (7.55%) aligned concordantly exactly 1 time
#     2302613 (7.48%) aligned concordantly >1 times
# 15.02% overall alignment rate
# Processed 30798582 sequences in total
#
#
# Successfully deleted the temporary files zr2096_2_s1_R1.fastq.gz_C_to_T.fastq and zr2096_2_s1_R2.fastq.gz_G_to_A.fastq
#
# Final Alignment report
# ======================
# Sequence pairs analysed in total:	30798582
# Final Cytosine Methylation Report
# =================================
# Total number of C's analysed:	166030240
#
# Total methylated C's in CpG context:	17625283
# Total methylated C's in CHG context:	1346374
# Total methylated C's in CHH context:	5725619
# Total methylated C's in Unknown context:	225266
#
# Total unmethylated C's in CpG context:	5879632
# Total unmethylated C's in CHG context:	38361849
# Total unmethylated C's in CHH context:	97091483
# Total unmethylated C's in Unknown context:	693976
#
# C methylated in CpG context:	75.0%
# C methylated in CHG context:	3.4%
# C methylated in CHH context:	5.6%
# C methylated in unknown context (CN or CHN):	24.5%
#
#
# Bismark completed in 0d 2h 0m 2s
#
# ====================
# Bismark run complete
# ====================
#
# Bowtie seems to be working fine (tested command '/Applications/bioinfo/bowtie2-2.3.4.1-macos-x86_64/bowtie2 --version' [2.3.4])
# Output format is BAM (default)
# Alignments will be written out in BAM format. Samtools found here: '/Applications/bioinfo/samtools-1.3.1/samtools'
# Reference genome folder provided is /Volumes/Serine/wd/18-03-15/genome/	(absolute path is '/Volumes/Serine/wd/18-03-15/genome/)'
#
# Input files to be analysed (in current folder '/Volumes/Serine/wd/18-04-07/bm01'):
# /Volumes/Serine/wd/18-04-07/zr2096_3_s1_R1.fastq.gz
# /Volumes/Serine/wd/18-04-07/zr2096_3_s1_R2.fastq.gz
# Library is assumed to be strand-specific (directional), alignments to strands complementary to the original top or bottom strands will be ignored (i.e. not performed!)
# Setting parallelization to single-threaded (default)
#
# Current working directory is: /Volumes/Serine/wd/18-04-07/bm01
#
# Now reading in and storing sequence information of the genome specified in: /Volumes/Serine/wd/18-03-15/genome/
#
# Single-core mode: setting pid to 1
#
# Paired-end alignments will be performed
# =======================================
#
# The provided filenames for paired-end alignments are /Volumes/Serine/wd/18-04-07/zr2096_3_s1_R1.fastq.gz and /Volumes/Serine/wd/18-04-07/zr2096_3_s1_R2.fastq.gz
# Input files are in FastQ format
# Writing a C -> T converted version of the input file zr2096_3_s1_R1.fastq.gz to zr2096_3_s1_R1.fastq.gz_C_to_T.fastq
#
# Created C -> T converted version of the FastQ file zr2096_3_s1_R1.fastq.gz (29892002 sequences in total)
#
# Writing a G -> A converted version of the input file zr2096_3_s1_R2.fastq.gz to zr2096_3_s1_R2.fastq.gz_G_to_A.fastq
#
# Created G -> A converted version of the FastQ file zr2096_3_s1_R2.fastq.gz (29892002 sequences in total)
#
# Input files are zr2096_3_s1_R1.fastq.gz_C_to_T.fastq and zr2096_3_s1_R2.fastq.gz_G_to_A.fastq (FastQ)
# Now running 2 instances of Bowtie 2 against the bisulfite genome of /Volumes/Serine/wd/18-03-15/genome/ with the specified options: -q --score-min L,0,-0.6 -p 4 --reorder --ignore-quals --no-mixed --no-discordant --dovetail --maxins 500
#
# Now starting a Bowtie 2 paired-end alignment for CTread1GAread2CTgenome (reading in sequences from zr2096_3_s1_R1.fastq.gz_C_to_T.fastq and zr2096_3_s1_R2.fastq.gz_G_to_A.fastq, with the options: -q --score-min L,0,-0.6 -p 4 --reorder --ignore-quals --no-mixed --no-discordant --dovetail --maxins 500 --norc))
# Found first alignment:
# HWI-C00124:321:CC781ANXX:1:1101:1059:2153_1:N:0:ACAGTG/1	77	*	0	0	*	*	0	0	TNTTTTAAAATAATTTAAATAATTTTATATAAATNNNNNNNNNNNNNNNTATTTAAATTAAAAATTTAAATAAATTTTTTTAATTATTTATTGTTTAATG	B#<<BFFFFFFFFFFFFFFFFFFFFFFFFFFFFF###############<<<FFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFF	YT:Z:UP	YF:Z:NS
# HWI-C00124:321:CC781ANXX:1:1101:1059:2153_2:N:0:ACAGTG/2	141	*	0	0	*	*	0	0	NNNNAAATAAACATTAAACAATAAATAATTAAAAAAATTTATTTAAATTTTTAATTTAAATAAATTAAAAATATTAAATTTATATAAAATTATTTAAAT	####<BBFFFFFFFFFFFFF<FFFFFF<FFFFFFFFBFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFBFFFFFFFFFFFFB	YT:Z:UP
# Now starting a Bowtie 2 paired-end alignment for CTread1GAread2GAgenome (reading in sequences from zr2096_3_s1_R1.fastq.gz_C_to_T.fastq and zr2096_3_s1_R2.fastq.gz_G_to_A.fastq, with the options: -q --score-min L,0,-0.6 -p 4 --reorder --ignore-quals --no-mixed --no-discordant --dovetail --maxins 500 --nofw))
# Found first alignment:
# HWI-C00124:321:CC781ANXX:1:1101:1059:2153_1:N:0:ACAGTG/1	77	*	0	0	*	*	0	0	TNTTTTAAAATAATTTAAATAATTTTATATAAATNNNNNNNNNNNNNNNTATTTAAATTAAAAATTTAAATAAATTTTTTTAATTATTTATTGTTTAATG	B#<<BFFFFFFFFFFFFFFFFFFFFFFFFFFFFF###############<<<FFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFF	YT:Z:UP	YF:Z:NS
# HWI-C00124:321:CC781ANXX:1:1101:1059:2153_2:N:0:ACAGTG/2	141	*	0	0	*	*	0	0	NNNNAAATAAACATTAAACAATAAATAATTAAAAAAATTTATTTAAATTTTTAATTTAAATAAATTAAAAATATTAAATTTATATAAAATTATTTAAAT	####<BBFFFFFFFFFFFFF<FFFFFF<FFFFFFFFBFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFBFFFFFFFFFFFFB	YT:Z:UP
#
# >>> Writing bisulfite mapping results to zr2096_3_s1_R1_bismark_bt2_pe.bam <<<
#
#
# Reading in the sequence files /Volumes/Serine/wd/18-04-07/zr2096_3_s1_R1.fastq.gz and /Volumes/Serine/wd/18-04-07/zr2096_3_s1_R2.fastq.gz
# Processed 1000000 sequence pairs so far
# Processed 2000000 sequence pairs so far
# Processed 3000000 sequence pairs so far
# Processed 4000000 sequence pairs so far
# Processed 5000000 sequence pairs so far
# Processed 6000000 sequence pairs so far
# Processed 7000000 sequence pairs so far
# Processed 8000000 sequence pairs so far
# Processed 9000000 sequence pairs so far
# Processed 10000000 sequence pairs so far
# Processed 11000000 sequence pairs so far
# Processed 12000000 sequence pairs so far
# Processed 13000000 sequence pairs so far
# Processed 14000000 sequence pairs so far
# Processed 15000000 sequence pairs so far
# Processed 16000000 sequence pairs so far
# Processed 17000000 sequence pairs so far
# Processed 18000000 sequence pairs so far
# Processed 19000000 sequence pairs so far
# Processed 20000000 sequence pairs so far
# Processed 21000000 sequence pairs so far
# Processed 22000000 sequence pairs so far
# Processed 23000000 sequence pairs so far
# Processed 24000000 sequence pairs so far
# Processed 25000000 sequence pairs so far
# Processed 26000000 sequence pairs so far
# Processed 27000000 sequence pairs so far
# Processed 28000000 sequence pairs so far
# Processed 29000000 sequence pairs so far
# 29892002 reads; of these:
#   29892002 (100.00%)2 9w8e9r2e0 0p2ai red; of these:
#     24805854 (r82.e9a8%) alignedd s; of thconcordantly 0ese:
#    tim29892002 (es
# 1 0   2396064 (8.00.00%) were paired; of these:
#     24824535 (83.2%) al0i5%) agned concordantly exactly 1 time
#     ligned concordantly 0 times
#     2374860 (7.94%) aligned concordantly exactly 1 time
#     2692607 (9.01%) aligned concordantly >1 times
# 16.95% overall alignment rate
# 2690084 (9.00%) aligned concordantly >1 times
# 17.02% overall alignment rate
# Processed 29892002 sequences in total
#
#
# Successfully deleted the temporary files zr2096_3_s1_R1.fastq.gz_C_to_T.fastq and zr2096_3_s1_R2.fastq.gz_G_to_A.fastq
#
# Final Alignment report
# ======================
# Sequence pairs analysed in total:	29892002
# Final Cytosine Methylation Report
# =================================
# Total number of C's analysed:	189484349
#
# Total methylated C's in CpG context:	22776539
# Total methylated C's in CHG context:	1476555
# Total methylated C's in CHH context:	5479846
# Total methylated C's in Unknown context:	243262
#
# Total unmethylated C's in CpG context:	5703037
# Total unmethylated C's in CHG context:	42937976
# Total unmethylated C's in CHH context:	111110396
# Total unmethylated C's in Unknown context:	758691
#
# C methylated in CpG context:	80.0%
# C methylated in CHG context:	3.3%
# C methylated in CHH context:	4.7%
# C methylated in unknown context (CN or CHN):	24.3%
#
#
# Bismark completed in 0d 2h 18m 46s
#
# ====================
# Bismark run complete
# ====================
#
# Bowtie seems to be working fine (tested command '/Applications/bioinfo/bowtie2-2.3.4.1-macos-x86_64/bowtie2 --version' [2.3.4])
# Output format is BAM (default)
# Alignments will be written out in BAM format. Samtools found here: '/Applications/bioinfo/samtools-1.3.1/samtools'
# Reference genome folder provided is /Volumes/Serine/wd/18-03-15/genome/	(absolute path is '/Volumes/Serine/wd/18-03-15/genome/)'
#
# Input files to be analysed (in current folder '/Volumes/Serine/wd/18-04-07/bm01'):
# /Volumes/Serine/wd/18-04-07/zr2096_4_s1_R1.fastq.gz
# /Volumes/Serine/wd/18-04-07/zr2096_4_s1_R2.fastq.gz
# Library is assumed to be strand-specific (directional), alignments to strands complementary to the original top or bottom strands will be ignored (i.e. not performed!)
# Setting parallelization to single-threaded (default)
#
# Current working directory is: /Volumes/Serine/wd/18-04-07/bm01
#
# Now reading in and storing sequence information of the genome specified in: /Volumes/Serine/wd/18-03-15/genome/
#
# Single-core mode: setting pid to 1
#
# Paired-end alignments will be performed
# =======================================
#
# The provided filenames for paired-end alignments are /Volumes/Serine/wd/18-04-07/zr2096_4_s1_R1.fastq.gz and /Volumes/Serine/wd/18-04-07/zr2096_4_s1_R2.fastq.gz
# Input files are in FastQ format
# Writing a C -> T converted version of the input file zr2096_4_s1_R1.fastq.gz to zr2096_4_s1_R1.fastq.gz_C_to_T.fastq
#
# Created C -> T converted version of the FastQ file zr2096_4_s1_R1.fastq.gz (24341968 sequences in total)
#
# Writing a G -> A converted version of the input file zr2096_4_s1_R2.fastq.gz to zr2096_4_s1_R2.fastq.gz_G_to_A.fastq
#
# Created G -> A converted version of the FastQ file zr2096_4_s1_R2.fastq.gz (24341968 sequences in total)
#
# Input files are zr2096_4_s1_R1.fastq.gz_C_to_T.fastq and zr2096_4_s1_R2.fastq.gz_G_to_A.fastq (FastQ)
# Now running 2 instances of Bowtie 2 against the bisulfite genome of /Volumes/Serine/wd/18-03-15/genome/ with the specified options: -q --score-min L,0,-0.6 -p 4 --reorder --ignore-quals --no-mixed --no-discordant --dovetail --maxins 500
#
# Now starting a Bowtie 2 paired-end alignment for CTread1GAread2CTgenome (reading in sequences from zr2096_4_s1_R1.fastq.gz_C_to_T.fastq and zr2096_4_s1_R2.fastq.gz_G_to_A.fastq, with the options: -q --score-min L,0,-0.6 -p 4 --reorder --ignore-quals --no-mixed --no-discordant --dovetail --maxins 500 --norc))
# Found first alignment:
# HWI-C00124:321:CC781ANXX:1:1101:1343:2133_1:N:0:GCCAAT/1	77	*	0	0	*	*	0	0	NGATTAGTGTATAGTGGTTGTTATGGAAATTAGNNNNNNNNNNNNNNNNNNNNNNNNNTGNANTNTTTTTATTAGAATTGTTAAGGTTTATTTGATTTAT	#<<BBFFFFFFFFFFFFFFFFFFFFFFFFFFFF#########################<<#<#/#<<FFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFF	YT:Z:UP	YF:Z:NS
# HWI-C00124:321:CC781ANXX:1:1101:1343:2133_2:N:0:GCCAAT/2	141	*	0	0	*	*	0	0	NNNNNTCCATCATTAATTTTTAAAAAAAAAAAACCATCCTTAATATCAATTTTATAAATCAAATAAACCTTAACAATTCTAATAAAAACACTTCATATAT	#####BBBFFFFFFFFFFFFFFFFFFFFFFFFFFFFBFFFFFFFFFFFFFFFF/BBFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFBFFF	YT:Z:UP
# Now starting a Bowtie 2 paired-end alignment for CTread1GAread2GAgenome (reading in sequences from zr2096_4_s1_R1.fastq.gz_C_to_T.fastq and zr2096_4_s1_R2.fastq.gz_G_to_A.fastq, with the options: -q --score-min L,0,-0.6 -p 4 --reorder --ignore-quals --no-mixed --no-discordant --dovetail --maxins 500 --nofw))
# Found first alignment:
# HWI-C00124:321:CC781ANXX:1:1101:1343:2133_1:N:0:GCCAAT/1	77	*	0	0	*	*	0	0	NGATTAGTGTATAGTGGTTGTTATGGAAATTAGNNNNNNNNNNNNNNNNNNNNNNNNNTGNANTNTTTTTATTAGAATTGTTAAGGTTTATTTGATTTAT	#<<BBFFFFFFFFFFFFFFFFFFFFFFFFFFFF#########################<<#<#/#<<FFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFF	YT:Z:UP	YF:Z:NS
# HWI-C00124:321:CC781ANXX:1:1101:1343:2133_2:N:0:GCCAAT/2	141	*	0	0	*	*	0	0	NNNNNTCCATCATTAATTTTTAAAAAAAAAAAACCATCCTTAATATCAATTTTATAAATCAAATAAACCTTAACAATTCTAATAAAAACACTTCATATAT	#####BBBFFFFFFFFFFFFFFFFFFFFFFFFFFFFBFFFFFFFFFFFFFFFF/BBFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFBFFF	YT:Z:UP
#
# >>> Writing bisulfite mapping results to zr2096_4_s1_R1_bismark_bt2_pe.bam <<<
#
#
# Reading in the sequence files /Volumes/Serine/wd/18-04-07/zr2096_4_s1_R1.fastq.gz and /Volumes/Serine/wd/18-04-07/zr2096_4_s1_R2.fastq.gz
# Processed 1000000 sequence pairs so far
# Processed 2000000 sequence pairs so far
# Processed 3000000 sequence pairs so far
# Processed 4000000 sequence pairs so far
# Processed 5000000 sequence pairs so far
# Processed 6000000 sequence pairs so far
# Processed 7000000 sequence pairs so far
# Processed 8000000 sequence pairs so far
# Processed 9000000 sequence pairs so far
# Processed 10000000 sequence pairs so far
# Processed 11000000 sequence pairs so far
# Processed 12000000 sequence pairs so far
# Processed 13000000 sequence pairs so far
# Processed 14000000 sequence pairs so far
# Processed 15000000 sequence pairs so far
# Processed 16000000 sequence pairs so far
# Processed 17000000 sequence pairs so far
# Processed 18000000 sequence pairs so far
# Processed 19000000 sequence pairs so far
# Chromosomal sequence could not be extracted for	HWI-C00124:321:CC781ANXX:1:2213:19455:71351_1:N:0:GCCAAT	NC_035780.1	2
# Processed 20000000 sequence pairs so far
# Processed 21000000 sequence pairs so far
# Processed 22000000 sequence pairs so far
# Chromosomal sequence could not be extracted for	HWI-C00124:321:CC781ANXX:1:2310:6331:40757_1:N:0:GCCAAT	NC_035780.1	2
# Processed 23000000 sequence pairs so far
# Processed 24000000 sequence pairs so far
# 24341968 reads; of these:
#   24341968 (100.00%) were paired; of these:
#     20185330 (82.92%) aligned concordantly 0 times
#     2086737 (8.57%) aligned concordantly exactly 1 time
#     2069901 (8.50%) aligned concordantly >1 times
# 17.08% overall alignment rate
# 24341968 reads; of these:
#   24341968 (100.00%) were paired; of these:
#     20177991 (82.89%) aligned concordantly 0 times
#     2097974 (8.62%) aligned concordantly exactly 1 time
#     2066003 (8.49%) aligned concordantly >1 times
# 17.11% overall alignment rate
# Processed 24341968 sequences in total
#
#
# Successfully deleted the temporary files zr2096_4_s1_R1.fastq.gz_C_to_T.fastq and zr2096_4_s1_R2.fastq.gz_G_to_A.fastq
#
# Final Alignment report
# ======================
# Sequence pairs analysed in total:	24341968
# Final Cytosine Methylation Report
# =================================
# Total number of C's analysed:	148447494
#
# Total methylated C's in CpG context:	14022606
# Total methylated C's in CHG context:	1147944
# Total methylated C's in CHH context:	4897777
# Total methylated C's in Unknown context:	205137
#
# Total unmethylated C's in CpG context:	5922512
# Total unmethylated C's in CHG context:	33264805
# Total unmethylated C's in CHH context:	89191850
# Total unmethylated C's in Unknown context:	643585
#
# C methylated in CpG context:	70.3%
# C methylated in CHG context:	3.3%
# C methylated in CHH context:	5.2%
# C methylated in unknown context (CN or CHN):	24.2%
#
#
# Bismark completed in 0d 1h 44m 39s
#
# ====================
# Bismark run complete
# ====================
#
# Bowtie seems to be working fine (tested command '/Applications/bioinfo/bowtie2-2.3.4.1-macos-x86_64/bowtie2 --version' [2.3.4])
# Output format is BAM (default)
# Alignments will be written out in BAM format. Samtools found here: '/Applications/bioinfo/samtools-1.3.1/samtools'
# Reference genome folder provided is /Volumes/Serine/wd/18-03-15/genome/	(absolute path is '/Volumes/Serine/wd/18-03-15/genome/)'
#
# Input files to be analysed (in current folder '/Volumes/Serine/wd/18-04-07/bm01'):
# /Volumes/Serine/wd/18-04-07/zr2096_5_s1_R1.fastq.gz
# /Volumes/Serine/wd/18-04-07/zr2096_5_s1_R2.fastq.gz
# Library is assumed to be strand-specific (directional), alignments to strands complementary to the original top or bottom strands will be ignored (i.e. not performed!)
# Setting parallelization to single-threaded (default)
#
# Current working directory is: /Volumes/Serine/wd/18-04-07/bm01
#
# Now reading in and storing sequence information of the genome specified in: /Volumes/Serine/wd/18-03-15/genome/
#
# Single-core mode: setting pid to 1
#
# Paired-end alignments will be performed
# =======================================
#
# The provided filenames for paired-end alignments are /Volumes/Serine/wd/18-04-07/zr2096_5_s1_R1.fastq.gz and /Volumes/Serine/wd/18-04-07/zr2096_5_s1_R2.fastq.gz
# Input files are in FastQ format
# Writing a C -> T converted version of the input file zr2096_5_s1_R1.fastq.gz to zr2096_5_s1_R1.fastq.gz_C_to_T.fastq
#
# Created C -> T converted version of the FastQ file zr2096_5_s1_R1.fastq.gz (31778715 sequences in total)
#
# Writing a G -> A converted version of the input file zr2096_5_s1_R2.fastq.gz to zr2096_5_s1_R2.fastq.gz_G_to_A.fastq
#
# Created G -> A converted version of the FastQ file zr2096_5_s1_R2.fastq.gz (31778715 sequences in total)
#
# Input files are zr2096_5_s1_R1.fastq.gz_C_to_T.fastq and zr2096_5_s1_R2.fastq.gz_G_to_A.fastq (FastQ)
# Now running 2 instances of Bowtie 2 against the bisulfite genome of /Volumes/Serine/wd/18-03-15/genome/ with the specified options: -q --score-min L,0,-0.6 -p 4 --reorder --ignore-quals --no-mixed --no-discordant --dovetail --maxins 500
#
# ...
# Processed 16000000 sequence pairs so far
# Processed 17000000 sequence pairs so far
# Processed 18000000 sequence pairs so far
# Processed 19000000 sequence pairs so far
# Processed 20000000 sequence pairs so far
# Processed 21000000 sequence pairs so far
# Processed 22000000 sequence pairs so far
# Processed 23000000 sequence pairs so far
# Processed 24000000 sequence pairs so far
# Processed 25000000 sequence pairs so far
# Processed 26000000 sequence pairs so far
# Processed 27000000 sequence pairs so far
# Processed 28000000 sequence pairs so far
# Processed 29000000 sequence pairs so far
# 29534746 reads; of these:
#   29534746 (100.00%) were paired; of these:
#     24968913 (84.54%) aligned concordantly 0 times
#     2301909 (7.79%) aligned concordantly exactly 1 time
#     2263924 (7.67%) aligned concordantly >1 times
# 15.46% overall alignment rate
# 29534746 reads; of these:
#   29534746 (100.00%) were paired; of these:
#     24981202 (84.58%) aligned concordantly 0 times
#     2293473 (7.77%) aligned concordantly exactly 1 time
#     2260071 (7.65%) aligned concordantly >1 times
# 15.42% overall alignment rate
# Processed 29534746 sequences in total
#
#
# Successfully deleted the temporary files zr2096_7_s1_R1.fastq.gz_C_to_T.fastq and zr2096_7_s1_R2.fastq.gz_G_to_A.fastq
#
# Final Alignment report
# ======================
# Sequence pairs analysed in total:	29534746
# Final Cytosine Methylation Report
# =================================
# Total number of C's analysed:	175381402
#
# Total methylated C's in CpG context:	17526556
# Total methylated C's in CHG context:	1367591
# Total methylated C's in CHH context:	5269964
# Total methylated C's in Unknown context:	227515
#
# Total unmethylated C's in CpG context:	5641309
# Total unmethylated C's in CHG context:	38963896
# Total unmethylated C's in CHH context:	106612086
# Total unmethylated C's in Unknown context:	735121
#
# C methylated in CpG context:	75.7%
# C methylated in CHG context:	3.4%
# C methylated in CHH context:	4.7%
# C methylated in unknown context (CN or CHN):	23.6%
#
#
# Bismark completed in 0d 2h 6m 34s
#
# ====================
# Bismark run complete
# ====================
#
# Bowtie seems to be working fine (tested command '/Applications/bioinfo/bowtie2-2.3.4.1-macos-x86_64/bowtie2 --version' [2.3.4])
# Output format is BAM (default)
# Alignments will be written out in BAM format. Samtools found here: '/Applications/bioinfo/samtools-1.3.1/samtools'
# Reference genome folder provided is /Volumes/Serine/wd/18-03-15/genome/	(absolute path is '/Volumes/Serine/wd/18-03-15/genome/)'
#
# Input files to be analysed (in current folder '/Volumes/Serine/wd/18-04-07/bm01'):
# /Volumes/Serine/wd/18-04-07/zr2096_8_s1_R1.fastq.gz
# /Volumes/Serine/wd/18-04-07/zr2096_8_s1_R2.fastq.gz
# Library is assumed to be strand-specific (directional), alignments to strands complementary to the original top or bottom strands will be ignored (i.e. not performed!)
# Setting parallelization to single-threaded (default)
#
# Current working directory is: /Volumes/Serine/wd/18-04-07/bm01
#
# Now reading in and storing sequence information of the genome specified in: /Volumes/Serine/wd/18-03-15/genome/
#
# Single-core mode: setting pid to 1
#
# Paired-end alignments will be performed
# =======================================
#
# The provided filenames for paired-end alignments are /Volumes/Serine/wd/18-04-07/zr2096_8_s1_R1.fastq.gz and /Volumes/Serine/wd/18-04-07/zr2096_8_s1_R2.fastq.gz
# Input files are in FastQ format
# Writing a C -> T converted version of the input file zr2096_8_s1_R1.fastq.gz to zr2096_8_s1_R1.fastq.gz_C_to_T.fastq
#
# Created C -> T converted version of the FastQ file zr2096_8_s1_R1.fastq.gz (29761837 sequences in total)
#
# Writing a G -> A converted version of the input file zr2096_8_s1_R2.fastq.gz to zr2096_8_s1_R2.fastq.gz_G_to_A.fastq
#
# Created G -> A converted version of the FastQ file zr2096_8_s1_R2.fastq.gz (29761837 sequences in total)
#
# Input files are zr2096_8_s1_R1.fastq.gz_C_to_T.fastq and zr2096_8_s1_R2.fastq.gz_G_to_A.fastq (FastQ)
# Now running 2 instances of Bowtie 2 against the bisulfite genome of /Volumes/Serine/wd/18-03-15/genome/ with the specified options: -q --score-min L,0,-0.6 -p 4 --reorder --ignore-quals --no-mixed --no-discordant --dovetail --maxins 500
#
# Now starting a Bowtie 2 paired-end alignment for CTread1GAread2CTgenome (reading in sequences from zr2096_8_s1_R1.fastq.gz_C_to_T.fastq and zr2096_8_s1_R2.fastq.gz_G_to_A.fastq, with the options: -q --score-min L,0,-0.6 -p 4 --reorder --ignore-quals --no-mixed --no-discordant --dovetail --maxins 500 --norc))
# Found first alignment:
# HWI-C00124:321:CC781ANXX:1:1101:1281:2170_1:N:0:TTAGGC/1	77	*	0	0	*	*	0	0	TAATTTAAAATTAAAAAATTTATTAAATTTATTATTATTTNTTATTTTTTATAAAAGAAAATAGAGAGAGAGAGAGAGAGAGAGAGAG	BBBBBFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFF#<<FFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFF<FFFFFFFFF	YT:Z:UP
# HWI-C00124:321:CC781ANXX:1:1101:1281:2170_2:N:0:TTAGGC/2	141	*	0	0	*	*	0	0	CTCTCTCTCTCTCTCTCTCTCTCTCTATTTTCTTTTATAAAAAATAATAAATAATAATAAATTTAATAAATTTTTTAATTTTAAATTA	BBBBBFFFFFFFFFFFFFFFFFFFFF/FFFF<FFFFBF</F</<<<<FF/<FF/<<</F//<FF</BFF/FFFFFF//<FFFB//BF/	YT:Z:UP
# Now starting a Bowtie 2 paired-end alignment for CTread1GAread2GAgenome (reading in sequences from zr2096_8_s1_R1.fastq.gz_C_to_T.fastq and zr2096_8_s1_R2.fastq.gz_G_to_A.fastq, with the options: -q --score-min L,0,-0.6 -p 4 --reorder --ignore-quals --no-mixed --no-discordant --dovetail --maxins 500 --nofw))
# Found first alignment:
# HWI-C00124:321:CC781ANXX:1:1101:1281:2170_1:N:0:TTAGGC/1	77	*	0	0	*	*	0	0	TAATTTAAAATTAAAAAATTTATTAAATTTATTATTATTTNTTATTTTTTATAAAAGAAAATAGAGAGAGAGAGAGAGAGAGAGAGAG	BBBBBFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFF#<<FFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFF<FFFFFFFFF	YT:Z:UP
# HWI-C00124:321:CC781ANXX:1:1101:1281:2170_2:N:0:TTAGGC/2	141	*	0	0	*	*	0	0	CTCTCTCTCTCTCTCTCTCTCTCTCTATTTTCTTTTATAAAAAATAATAAATAATAATAAATTTAATAAATTTTTTAATTTTAAATTA	BBBBBFFFFFFFFFFFFFFFFFFFFF/FFFF<FFFFBF</F</<<<<FF/<FF/<<</F//<FF</BFF/FFFFFF//<FFFB//BF/	YT:Z:UP
#
# >>> Writing bisulfite mapping results to zr2096_8_s1_R1_bismark_bt2_pe.bam <<<
#
#
# Reading in the sequence files /Volumes/Serine/wd/18-04-07/zr2096_8_s1_R1.fastq.gz and /Volumes/Serine/wd/18-04-07/zr2096_8_s1_R2.fastq.gz
# Processed 1000000 sequence pairs so far
# Processed 2000000 sequence pairs so far
# Processed 3000000 sequence pairs so far
# Processed 4000000 sequence pairs so far
# Processed 5000000 sequence pairs so far
# Processed 6000000 sequence pairs so far
# Processed 7000000 sequence pairs so far
# Processed 8000000 sequence pairs so far
# Processed 9000000 sequence pairs so far
# Processed 10000000 sequence pairs so far
# Chromosomal sequence could not be extracted for	HWI-C00124:321:CC781ANXX:1:1303:16780:7528_1:N:0:TTAGGC	NC_007175.2	17147
# Processed 11000000 sequence pairs so far
# Processed 12000000 sequence pairs so far
# Processed 13000000 sequence pairs so far
# Processed 14000000 sequence pairs so far
# Chromosomal sequence could not be extracted for	HWI-C00124:321:CC781ANXX:1:1315:20840:40040_1:N:0:TTAGGC	NC_007175.2	17163
# Processed 15000000 sequence pairs so far
# Processed 16000000 sequence pairs so far
# Processed 17000000 sequence pairs so far
# Processed 18000000 sequence pairs so far
# Processed 19000000 sequence pairs so far
# Processed 20000000 sequence pairs so far
# Processed 21000000 sequence pairs so far
# Processed 22000000 sequence pairs so far
# Processed 23000000 sequence pairs so far
# Processed 24000000 sequence pairs so far
# Processed 25000000 sequence pairs so far
# Processed 26000000 sequence pairs so far
# Processed 27000000 sequence pairs so far
# Processed 28000000 sequence pairs so far
# Processed 29000000 sequence pairs so far
# 29761837 reads; of these:
#   29761837 (100.00%) were paired; of these:
#     25580112 (85.95%) aligned concordantly 0 times
#     2143425 (7.20%) aligned concordantly exactly 1 time
#     2038300 (6.85%) aligned concordantly >1 times
# 14.05% overall alignment rate
# 29761837 reads; of these:
#   29761837 (100.00%) were paired; of these:
#     25587746 (85.98%) aligned concordantly 0 times
#     2136784 (7.18%) aligned concordantly exactly 1 time
#     2037307 (6.85%) aligned concordantly >1 times
# 14.02% overall alignment rate
# Processed 29761837 sequences in total
#
#
# Successfully deleted the temporary files zr2096_8_s1_R1.fastq.gz_C_to_T.fastq and zr2096_8_s1_R2.fastq.gz_G_to_A.fastq
#
# Final Alignment report
# ======================
# Sequence pairs analysed in total:	29761837
# Final Cytosine Methylation Report
# =================================
# Total number of C's analysed:	157822868
#
# Total methylated C's in CpG context:	14123725
# Total methylated C's in CHG context:	1232277
# Total methylated C's in CHH context:	5100411
# Total methylated C's in Unknown context:	204421
#
# Total unmethylated C's in CpG context:	5895006
# Total unmethylated C's in CHG context:	35229169
# Total unmethylated C's in CHH context:	96242280
# Total unmethylated C's in Unknown context:	663867
#
# C methylated in CpG context:	70.6%
# C methylated in CHG context:	3.4%
# C methylated in CHH context:	5.0%
# C methylated in unknown context (CN or CHN):	23.5%
#
#
# Bismark completed in 0d 1h 58m 10s
#
# ====================
# Bismark run complete
# ====================
#
# Bowtie seems to be working fine (tested command '/Applications/bioinfo/bowtie2-2.3.4.1-macos-x86_64/bowtie2 --version' [2.3.4])
# Output format is BAM (default)
# Alignments will be written out in BAM format. Samtools found here: '/Applications/bioinfo/samtools-1.3.1/samtools'
# Reference genome folder provided is /Volumes/Serine/wd/18-03-15/genome/	(absolute path is '/Volumes/Serine/wd/18-03-15/genome/)'
#
# Input files to be analysed (in current folder '/Volumes/Serine/wd/18-04-07/bm01'):
# /Volumes/Serine/wd/18-04-07/zr2096_9_s1_R1.fastq.gz
# /Volumes/Serine/wd/18-04-07/zr2096_9_s1_R2.fastq.gz
# Library is assumed to be strand-specific (directional), alignments to strands complementary to the original top or bottom strands will be ignored (i.e. not performed!)
# Setting parallelization to single-threaded (default)
#
# Current working directory is: /Volumes/Serine/wd/18-04-07/bm01
#
# Now reading in and storing sequence information of the genome specified in: /Volumes/Serine/wd/18-03-15/genome/
#
# Single-core mode: setting pid to 1
#
# Paired-end alignments will be performed
# =======================================
#
# The provided filenames for paired-end alignments are /Volumes/Serine/wd/18-04-07/zr2096_9_s1_R1.fastq.gz and /Volumes/Serine/wd/18-04-07/zr2096_9_s1_R2.fastq.gz
# Input files are in FastQ format
# Writing a C -> T converted version of the input file zr2096_9_s1_R1.fastq.gz to zr2096_9_s1_R1.fastq.gz_C_to_T.fastq
#
# Created C -> T converted version of the FastQ file zr2096_9_s1_R1.fastq.gz (32636231 sequences in total)
#
# Writing a G -> A converted version of the input file zr2096_9_s1_R2.fastq.gz to zr2096_9_s1_R2.fastq.gz_G_to_A.fastq
#
# Created G -> A converted version of the FastQ file zr2096_9_s1_R2.fastq.gz (32636231 sequences in total)
#
# Input files are zr2096_9_s1_R1.fastq.gz_C_to_T.fastq and zr2096_9_s1_R2.fastq.gz_G_to_A.fastq (FastQ)
# Now running 2 instances of Bowtie 2 against the bisulfite genome of /Volumes/Serine/wd/18-03-15/genome/ with the specified options: -q --score-min L,0,-0.6 -p 4 --reorder --ignore-quals --no-mixed --no-discordant --dovetail --maxins 500
#
# Now starting a Bowtie 2 paired-end alignment for CTread1GAread2CTgenome (reading in sequences from zr2096_9_s1_R1.fastq.gz_C_to_T.fastq and zr2096_9_s1_R2.fastq.gz_G_to_A.fastq, with the options: -q --score-min L,0,-0.6 -p 4 --reorder --ignore-quals --no-mixed --no-discordant --dovetail --maxins 500 --norc))
# Found first alignment:
# HWI-C00124:321:CC781ANXX:2:1101:1135:2128_1:N:0:ACTTGA/1	77	*	0	0	*	*	0	0	NATTAAATAAAAAATAATAAATAATAAATTANNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNTTATAGG	#/<<</<<B<<B<FF<BBFFBFFFF<B/FFF####################################<<<<FBF	YT:Z:UP	YF:Z:NS
# HWI-C00124:321:CC781ANXX:2:1101:1135:2128_2:N:0:ACTTGA/2	141	*	0	0	*	*	0	0	NNNNNAANTAAAAAAATAAAAAACACATTAAAAATCTATAATTTAATTTATTATTTATTATTTTTTATTTAATTAAATCNNNNAAACATCATATAAAAAA	#####<<#</BFFFB/FBFBF<FFFFF/FBFF//<FFF/</<FFF//</<<B/FB//FB/<FFFFF/B/F/FFFFB///####<</FFF<FBFF/F</7B	YT:Z:UP
# Now starting a Bowtie 2 paired-end alignment for CTread1GAread2GAgenome (reading in sequences from zr2096_9_s1_R1.fastq.gz_C_to_T.fastq and zr2096_9_s1_R2.fastq.gz_G_to_A.fastq, with the options: -q --score-min L,0,-0.6 -p 4 --reorder --ignore-quals --no-mixed --no-discordant --dovetail --maxins 500 --nofw))
# Found first alignment:
# HWI-C00124:321:CC781ANXX:2:1101:1135:2128_1:N:0:ACTTGA/1	77	*	0	0	*	*	0	0	NATTAAATAAAAAATAATAAATAATAAATTANNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNTTATAGG	#/<<</<<B<<B<FF<BBFFBFFFF<B/FFF####################################<<<<FBF	YT:Z:UP	YF:Z:NS
# HWI-C00124:321:CC781ANXX:2:1101:1135:2128_2:N:0:ACTTGA/2	141	*	0	0	*	*	0	0	NNNNNAANTAAAAAAATAAAAAACACATTAAAAATCTATAATTTAATTTATTATTTATTATTTTTTATTTAATTAAATCNNNNAAACATCATATAAAAAA	#####<<#</BFFFB/FBFBF<FFFFF/FBFF//<FFF/</<FFF//</<<B/FB//FB/<FFFFF/B/F/FFFFB///####<</FFF<FBFF/F</7B	YT:Z:UP
#
# >>> Writing bisulfite mapping results to zr2096_9_s1_R1_bismark_bt2_pe.bam <<<
#
#
# Reading in the sequence files /Volumes/Serine/wd/18-04-07/zr2096_9_s1_R1.fastq.gz and /Volumes/Serine/wd/18-04-07/zr2096_9_s1_R2.fastq.gz
# Processed 1000000 sequence pairs so far
# Processed 2000000 sequence pairs so far
# Processed 3000000 sequence pairs so far
# Processed 4000000 sequence pairs so far
# Processed 5000000 sequence pairs so far
# Processed 6000000 sequence pairs so far
# Processed 7000000 sequence pairs so far
# Processed 8000000 sequence pairs so far
# Processed 9000000 sequence pairs so far
# Processed 10000000 sequence pairs so far
# Chromosomal sequence could not be extracted for	HWI-C00124:321:CC781ANXX:2:1214:4921:70468_1:N:0:ACTTGA	NC_007175.2	17151
# Processed 11000000 sequence pairs so far
# Processed 12000000 sequence pairs so far
# Processed 13000000 sequence pairs so far
# Processed 14000000 sequence pairs so far
# Processed 15000000 sequence pairs so far
# Processed 16000000 sequence pairs so far
# Processed 17000000 sequence pairs so far
# Processed 18000000 sequence pairs so far
# Processed 19000000 sequence pairs so far
# Processed 20000000 sequence pairs so far
# Processed 21000000 sequence pairs so far
# Processed 22000000 sequence pairs so far
# Processed 23000000 sequence pairs so far
# Processed 24000000 sequence pairs so far
# Processed 25000000 sequence pairs so far
# Processed 26000000 sequence pairs so far
# Processed 27000000 sequence pairs so far
# Processed 28000000 sequence pairs so far
# Processed 29000000 sequence pairs so far
# Processed 30000000 sequence pairs so far
# Processed 31000000 sequence pairs so far
# Processed 32000000 sequence pairs so far
# 32636231 reads; of these:
#   32636231 (100.00%) were paired; of these:
#     27375708 (83.88%) aligned concordantly 0 times
#     2603810 (7.98%) aligned concordantly exactly 1 time
#     2656713 (8.14%) aligned concordantly >1 times
# 16.12% overall alignment rate
# 32636231 reads; of these:
#   32636231 (100.00%) were paired; of these:
#     27380120 (83.89%) aligned concordantly 0 times
#     2587080 (7.93%) aligned concordantly exactly 1 time
#     2669031 (8.18%) aligned concordantly >1 times
# 16.11% overall alignment rate
# Processed 32636231 sequences in total
#
#
# Successfully deleted the temporary files zr2096_9_s1_R1.fastq.gz_C_to_T.fastq and zr2096_9_s1_R2.fastq.gz_G_to_A.fastq
#
# Final Alignment report
# ======================
# Sequence pairs analysed in total:	32636231
# Final Cytosine Methylation Report
# =================================
# Total number of C's analysed:	203684656
#
# Total methylated C's in CpG context:	23798172
# Total methylated C's in CHG context:	1639976
# Total methylated C's in CHH context:	5453380
# Total methylated C's in Unknown context:	272146
#
# Total unmethylated C's in CpG context:	6006825
# Total unmethylated C's in CHG context:	45798164
# Total unmethylated C's in CHH context:	120988139
# Total unmethylated C's in Unknown context:	826171
#
# C methylated in CpG context:	79.8%
# C methylated in CHG context:	3.5%
# C methylated in CHH context:	4.3%
# C methylated in unknown context (CN or CHN):	24.8%
#
#
# Bismark completed in 0d 2h 19m 33s
#
# ====================
# Bismark run complete
# ====================

# %%
cd /Volumes/Serine/wd/18-04-10/bm01
# Out:
# /Volumes/Serine/wd/18-04-10/bm01

# %%
# %%bash
# /Applications/bioinfo/Bismark_v0.19.0/bismark \
# --path_to_bowtie /Applications/bioinfo/bowtie2-2.3.4.1-macos-x86_64 \
# --genome /Volumes/Serine/wd/18-03-15/genome \
# --score_min L,0,-0.6 \
# -p 4 \
# --non_directional \
# -1 /Volumes/Serine/wd/18-04-07/zr2096_5_s1_R1.fastq.gz \
# -2 /Volumes/Serine/wd/18-04-07/zr2096_5_s1_R2.fastq.gz  \
