# %% [markdown]
# # Set working directory

# %%
wd="~/Desktop/wd/0414"

# %%
mkdir $wd

# %%
cd $wd
# Out:
# /Users/sr320/Desktop/wd/0414

# %%
# %%bash
# find /Users/sr320/Desktop/trim14/zr2096_*R1* \
# | xargs basename -s _s1_R1_val_1.fq.gz | xargs -I{} /Applications/bioinfo/Bismark_v0.19.0/bismark \
# --path_to_bowtie /Applications/bioinfo/bowtie2-2.3.4.1-macos-x86_64 \
# --genome /Users/sr320/Dropbox/wd/18-03-15/genome \
# --score_min L,0,-1.2 \
# -u 10000 \
# -p 2 \
# --non_directional \
# -1 /Users/sr320/Desktop/trim14/{}_s1_R1_val_1.fq.gz \
# -2 /Users/sr320/Desktop/trim14/{}_s1_R2_val_2.fq.gz \
# 2> bismark.err
# Out:
# FastQ format assumed (by default)
# Each Bowtie 2 instance is going to be run with 2 threads. Please monitor performance closely and tune down if needed!
# chr NC_035780.1 (65668440 bp)
# chr NC_035781.1 (61752955 bp)
# chr NC_035782.1 (77061148 bp)
# chr NC_035783.1 (59691872 bp)
# chr NC_035784.1 (98698416 bp)
# chr NC_035785.1 (51258098 bp)
# chr NC_035786.1 (57830854 bp)
# chr NC_035787.1 (75944018 bp)
# chr NC_035788.1 (104168038 bp)
# chr NC_035789.1 (32650045 bp)
# chr NC_007175.2 (17244 bp)
#
# Number of paired-end alignments with a unique best hit:	5633
# Mapping efficiency:	56.3%
#
# Sequence pairs with no alignments under any condition:	2487
# Sequence pairs did not map uniquely:	1880
# Sequence pairs which were discarded because genomic sequence could not be extracted:	0
#
# Number of sequence pairs with unique best (first) alignment came from the bowtie output:
# CT/GA/CT:	1459	((converted) top strand)
# GA/CT/CT:	1404	(complementary to (converted) top strand)
# GA/CT/GA:	1399	(complementary to (converted) bottom strand)
# CT/GA/GA:	1371	((converted) bottom strand)
#
# FastQ format assumed (by default)
# Each Bowtie 2 instance is going to be run with 2 threads. Please monitor performance closely and tune down if needed!
# chr NC_035780.1 (65668440 bp)
# chr NC_035781.1 (61752955 bp)
# chr NC_035782.1 (77061148 bp)
# chr NC_035783.1 (59691872 bp)
# chr NC_035784.1 (98698416 bp)
# chr NC_035785.1 (51258098 bp)
# chr NC_035786.1 (57830854 bp)
# chr NC_035787.1 (75944018 bp)
# chr NC_035788.1 (104168038 bp)
# chr NC_035789.1 (32650045 bp)
# chr NC_007175.2 (17244 bp)
#
# Number of paired-end alignments with a unique best hit:	2716
# Mapping efficiency:	27.2%
#
# Sequence pairs with no alignments under any condition:	6421
# Sequence pairs did not map uniquely:	863
# Sequence pairs which were discarded because genomic sequence could not be extracted:	0
#
# Number of sequence pairs with unique best (first) alignment came from the bowtie output:
# CT/GA/CT:	678	((converted) top strand)
# GA/CT/CT:	727	(complementary to (converted) top strand)
# GA/CT/GA:	620	(complementary to (converted) bottom strand)
# CT/GA/GA:	691	((converted) bottom strand)
#
# FastQ format assumed (by default)
# Each Bowtie 2 instance is going to be run with 2 threads. Please monitor performance closely and tune down if needed!
# chr NC_035780.1 (65668440 bp)
# chr NC_035781.1 (61752955 bp)
# chr NC_035782.1 (77061148 bp)
# chr NC_035783.1 (59691872 bp)
# chr NC_035784.1 (98698416 bp)
# chr NC_035785.1 (51258098 bp)
# chr NC_035786.1 (57830854 bp)
# chr NC_035787.1 (75944018 bp)
# chr NC_035788.1 (104168038 bp)
# chr NC_035789.1 (32650045 bp)
# chr NC_007175.2 (17244 bp)
#
# Number of paired-end alignments with a unique best hit:	5054
# Mapping efficiency:	50.5%
#
# Sequence pairs with no alignments under any condition:	3239
# Sequence pairs did not map uniquely:	1707
# Sequence pairs which were discarded because genomic sequence could not be extracted:	0
#
# Number of sequence pairs with unique best (first) alignment came from the bowtie output:
# CT/GA/CT:	1289	((converted) top strand)
# GA/CT/CT:	1231	(complementary to (converted) top strand)
# GA/CT/GA:	1276	(complementary to (converted) bottom strand)
# CT/GA/GA:	1258	((converted) bottom strand)
#
# FastQ format assumed (by default)
# Each Bowtie 2 instance is going to be run with 2 threads. Please monitor performance closely and tune down if needed!
# chr NC_035780.1 (65668440 bp)
# chr NC_035781.1 (61752955 bp)
# chr NC_035782.1 (77061148 bp)
# chr NC_035783.1 (59691872 bp)
# chr NC_035784.1 (98698416 bp)
# chr NC_035785.1 (51258098 bp)
# chr NC_035786.1 (57830854 bp)
# chr NC_035787.1 (75944018 bp)
# chr NC_035788.1 (104168038 bp)
# chr NC_035789.1 (32650045 bp)
# chr NC_007175.2 (17244 bp)
#
# Number of paired-end alignments with a unique best hit:	5653
# Mapping efficiency:	56.5%
#
# Sequence pairs with no alignments under any condition:	2384
# Sequence pairs did not map uniquely:	1963
# Sequence pairs which were discarded because genomic sequence could not be extracted:	0
#
# Number of sequence pairs with unique best (first) alignment came from the bowtie output:
# CT/GA/CT:	1389	((converted) top strand)
# GA/CT/CT:	1385	(complementary to (converted) top strand)
# GA/CT/GA:	1464	(complementary to (converted) bottom strand)
# CT/GA/GA:	1415	((converted) bottom strand)
#
# FastQ format assumed (by default)
# Each Bowtie 2 instance is going to be run with 2 threads. Please monitor performance closely and tune down if needed!
# chr NC_035780.1 (65668440 bp)
# chr NC_035781.1 (61752955 bp)
# chr NC_035782.1 (77061148 bp)
# chr NC_035783.1 (59691872 bp)
# chr NC_035784.1 (98698416 bp)
# chr NC_035785.1 (51258098 bp)
# chr NC_035786.1 (57830854 bp)
# chr NC_035787.1 (75944018 bp)
# chr NC_035788.1 (104168038 bp)
# chr NC_035789.1 (32650045 bp)
# chr NC_007175.2 (17244 bp)
#
# Number of paired-end alignments with a unique best hit:	5610
# Mapping efficiency:	56.1%
#
# Sequence pairs with no alignments under any condition:	2472
# Sequence pairs did not map uniquely:	1918
# Sequence pairs which were discarded because genomic sequence could not be extracted:	0
#
# Number of sequence pairs with unique best (first) alignment came from the bowtie output:
# CT/GA/CT:	1481	((converted) top strand)
# GA/CT/CT:	1339	(complementary to (converted) top strand)
# GA/CT/GA:	1346	(complementary to (converted) bottom strand)
# CT/GA/GA:	1444	((converted) bottom strand)
#
# FastQ format assumed (by default)
# Each Bowtie 2 instance is going to be run with 2 threads. Please monitor performance closely and tune down if needed!
# chr NC_035780.1 (65668440 bp)
# chr NC_035781.1 (61752955 bp)
# chr NC_035782.1 (77061148 bp)
# chr NC_035783.1 (59691872 bp)
# chr NC_035784.1 (98698416 bp)
# chr NC_035785.1 (51258098 bp)
# chr NC_035786.1 (57830854 bp)
# chr NC_035787.1 (75944018 bp)
# chr NC_035788.1 (104168038 bp)
# chr NC_035789.1 (32650045 bp)
# chr NC_007175.2 (17244 bp)
#
# Number of paired-end alignments with a unique best hit:	5413
# Mapping efficiency:	54.1%
#
# Sequence pairs with no alignments under any condition:	2801
# Sequence pairs did not map uniquely:	1786
# Sequence pairs which were discarded because genomic sequence could not be extracted:	0
#
# Number of sequence pairs with unique best (first) alignment came from the bowtie output:
# CT/GA/CT:	1361	((converted) top strand)
# GA/CT/CT:	1357	(complementary to (converted) top strand)
# GA/CT/GA:	1299	(complementary to (converted) bottom strand)
# CT/GA/GA:	1396	((converted) bottom strand)
#
# FastQ format assumed (by default)
# Each Bowtie 2 instance is going to be run with 2 threads. Please monitor performance closely and tune down if needed!
# chr NC_035780.1 (65668440 bp)
# chr NC_035781.1 (61752955 bp)
# chr NC_035782.1 (77061148 bp)
# chr NC_035783.1 (59691872 bp)
# chr NC_035784.1 (98698416 bp)
# chr NC_035785.1 (51258098 bp)
# chr NC_035786.1 (57830854 bp)
# chr NC_035787.1 (75944018 bp)
# chr NC_035788.1 (104168038 bp)
# chr NC_035789.1 (32650045 bp)
# chr NC_007175.2 (17244 bp)
#
# Number of paired-end alignments with a unique best hit:	5791
# Mapping efficiency:	57.9%
#
# Sequence pairs with no alignments under any condition:	2268
# Sequence pairs did not map uniquely:	1941
# Sequence pairs which were discarded because genomic sequence could not be extracted:	0
#
# Number of sequence pairs with unique best (first) alignment came from the bowtie output:
# CT/GA/CT:	1586	((converted) top strand)
# GA/CT/CT:	1325	(complementary to (converted) top strand)
# GA/CT/GA:	1318	(complementary to (converted) bottom strand)
# CT/GA/GA:	1562	((converted) bottom strand)
#
# FastQ format assumed (by default)
# Each Bowtie 2 instance is going to be run with 2 threads. Please monitor performance closely and tune down if needed!
# chr NC_035780.1 (65668440 bp)
# chr NC_035781.1 (61752955 bp)
# chr NC_035782.1 (77061148 bp)
# chr NC_035783.1 (59691872 bp)
# chr NC_035784.1 (98698416 bp)
# chr NC_035785.1 (51258098 bp)
# chr NC_035786.1 (57830854 bp)
# chr NC_035787.1 (75944018 bp)
# chr NC_035788.1 (104168038 bp)
# chr NC_035789.1 (32650045 bp)
# chr NC_007175.2 (17244 bp)
#
# Number of paired-end alignments with a unique best hit:	5450
# Mapping efficiency:	54.5%
#
# Sequence pairs with no alignments under any condition:	2835
# Sequence pairs did not map uniquely:	1715
# Sequence pairs which were discarded because genomic sequence could not be extracted:	0
#
# Number of sequence pairs with unique best (first) alignment came from the bowtie output:
# CT/GA/CT:	1347	((converted) top strand)
# GA/CT/CT:	1332	(complementary to (converted) top strand)
# GA/CT/GA:	1357	(complementary to (converted) bottom strand)
# CT/GA/GA:	1414	((converted) bottom strand)
#
# FastQ format assumed (by default)
# Each Bowtie 2 instance is going to be run with 2 threads. Please monitor performance closely and tune down if needed!
# chr NC_035780.1 (65668440 bp)
# chr NC_035781.1 (61752955 bp)
# chr NC_035782.1 (77061148 bp)
# chr NC_035783.1 (59691872 bp)
# chr NC_035784.1 (98698416 bp)
# chr NC_035785.1 (51258098 bp)
# chr NC_035786.1 (57830854 bp)
# chr NC_035787.1 (75944018 bp)
# chr NC_035788.1 (104168038 bp)
# chr NC_035789.1 (32650045 bp)
# chr NC_007175.2 (17244 bp)
#
# Number of paired-end alignments with a unique best hit:	4999
# Mapping efficiency:	50.0%
#
# Sequence pairs with no alignments under any condition:	3412
# Sequence pairs did not map uniquely:	1589
# Sequence pairs which were discarded because genomic sequence could not be extracted:	0
#
# Number of sequence pairs with unique best (first) alignment came from the bowtie output:
# CT/GA/CT:	1229	((converted) top strand)
# GA/CT/CT:	1255	(complementary to (converted) top strand)
# GA/CT/GA:	1221	(complementary to (converted) bottom strand)
# CT/GA/GA:	1294	((converted) bottom strand)
#
# FastQ format assumed (by default)
# Each Bowtie 2 instance is going to be run with 2 threads. Please monitor performance closely and tune down if needed!
# chr NC_035780.1 (65668440 bp)
# chr NC_035781.1 (61752955 bp)
# chr NC_035782.1 (77061148 bp)
# chr NC_035783.1 (59691872 bp)
# chr NC_035784.1 (98698416 bp)
# chr NC_035785.1 (51258098 bp)
# chr NC_035786.1 (57830854 bp)
# chr NC_035787.1 (75944018 bp)
# chr NC_035788.1 (104168038 bp)
# chr NC_035789.1 (32650045 bp)
# chr NC_007175.2 (17244 bp)
#
# Number of paired-end alignments with a unique best hit:	5333
# Mapping efficiency:	53.3%
#
# Sequence pairs with no alignments under any condition:	2830
# Sequence pairs did not map uniquely:	1837
# Sequence pairs which were discarded because genomic sequence could not be extracted:	0
#
# Number of sequence pairs with unique best (first) alignment came from the bowtie output:
# CT/GA/CT:	1425	((converted) top strand)
# GA/CT/CT:	1286	(complementary to (converted) top strand)
# GA/CT/GA:	1126	(complementary to (converted) bottom strand)
# CT/GA/GA:	1496	((converted) bottom strand)

# %%
ls
# Out:
# bismark.err
# zr2096_10_s1_R1_val_1_bismark_bt2_PE_report.txt
# zr2096_10_s1_R1_val_1_bismark_bt2_pe.bam
# zr2096_1_s1_R1_val_1_bismark_bt2_PE_report.txt
# zr2096_1_s1_R1_val_1_bismark_bt2_pe.bam
# zr2096_2_s1_R1_val_1_bismark_bt2_PE_report.txt
# zr2096_2_s1_R1_val_1_bismark_bt2_pe.bam
# zr2096_3_s1_R1_val_1_bismark_bt2_PE_report.txt
# zr2096_3_s1_R1_val_1_bismark_bt2_pe.bam
# zr2096_4_s1_R1_val_1_bismark_bt2_PE_report.txt
# zr2096_4_s1_R1_val_1_bismark_bt2_pe.bam
# zr2096_5_s1_R1_val_1_bismark_bt2_PE_report.txt
# zr2096_5_s1_R1_val_1_bismark_bt2_pe.bam
# zr2096_6_s1_R1_val_1_bismark_bt2_PE_report.txt
# zr2096_6_s1_R1_val_1_bismark_bt2_pe.bam
# zr2096_7_s1_R1_val_1_bismark_bt2_PE_report.txt
# zr2096_7_s1_R1_val_1_bismark_bt2_pe.bam
# zr2096_8_s1_R1_val_1_bismark_bt2_PE_report.txt
# zr2096_8_s1_R1_val_1_bismark_bt2_pe.bam
# zr2096_9_s1_R1_val_1_bismark_bt2_PE_report.txt
# zr2096_9_s1_R1_val_1_bismark_bt2_pe.bam

# %%
# %%bash
#
# /Applications/bioinfo/Bismark_v0.19.0/deduplicate_bismark \
# --bam -p \
# *.bam \
# 2> dedup.err
# Out:
# Now testing Bismark result file zr2096_10_s1_R1_val_1_bismark_bt2_pe.bam for positional sorting (which would be bad...)	skipping header line:	@HD	VN:1.0	SO:unsorted
# skipping header line:	@SQ	SN:NC_035780.1	LN:65668440
# skipping header line:	@SQ	SN:NC_035781.1	LN:61752955
# skipping header line:	@SQ	SN:NC_035782.1	LN:77061148
# skipping header line:	@SQ	SN:NC_035783.1	LN:59691872
# skipping header line:	@SQ	SN:NC_035784.1	LN:98698416
# skipping header line:	@SQ	SN:NC_035785.1	LN:51258098
# skipping header line:	@SQ	SN:NC_035786.1	LN:57830854
# skipping header line:	@SQ	SN:NC_035787.1	LN:75944018
# skipping header line:	@SQ	SN:NC_035788.1	LN:104168038
# skipping header line:	@SQ	SN:NC_035789.1	LN:32650045
# skipping header line:	@SQ	SN:NC_007175.2	LN:17244
# skipping header line:	@PG	ID:Bismark	VN:v0.19.0	CL:"bismark --path_to_bowtie /Applications/bioinfo/bowtie2-2.3.4.1-macos-x86_64 --genome /Users/sr320/Dropbox/wd/18-03-15/genome --score_min L,0,-1.2 -u 10000 -p 2 --non_directional -1 /Users/sr320/Desktop/trim14/zr2096_10_s1_R1_val_1.fq.gz -2 /Users/sr320/Desktop/trim14/zr2096_10_s1_R2_val_2.fq.gz"
#
# Now testing Bismark result file zr2096_1_s1_R1_val_1_bismark_bt2_pe.bam for positional sorting (which would be bad...)	skipping header line:	@HD	VN:1.0	SO:unsorted
# skipping header line:	@SQ	SN:NC_035780.1	LN:65668440
# skipping header line:	@SQ	SN:NC_035781.1	LN:61752955
# skipping header line:	@SQ	SN:NC_035782.1	LN:77061148
# skipping header line:	@SQ	SN:NC_035783.1	LN:59691872
# skipping header line:	@SQ	SN:NC_035784.1	LN:98698416
# skipping header line:	@SQ	SN:NC_035785.1	LN:51258098
# skipping header line:	@SQ	SN:NC_035786.1	LN:57830854
# skipping header line:	@SQ	SN:NC_035787.1	LN:75944018
# skipping header line:	@SQ	SN:NC_035788.1	LN:104168038
# skipping header line:	@SQ	SN:NC_035789.1	LN:32650045
# skipping header line:	@SQ	SN:NC_007175.2	LN:17244
# skipping header line:	@PG	ID:Bismark	VN:v0.19.0	CL:"bismark --path_to_bowtie /Applications/bioinfo/bowtie2-2.3.4.1-macos-x86_64 --genome /Users/sr320/Dropbox/wd/18-03-15/genome --score_min L,0,-1.2 -u 10000 -p 2 --non_directional -1 /Users/sr320/Desktop/trim14/zr2096_1_s1_R1_val_1.fq.gz -2 /Users/sr320/Desktop/trim14/zr2096_1_s1_R2_val_2.fq.gz"
#
# Now testing Bismark result file zr2096_2_s1_R1_val_1_bismark_bt2_pe.bam for positional sorting (which would be bad...)	skipping header line:	@HD	VN:1.0	SO:unsorted
# skipping header line:	@SQ	SN:NC_035780.1	LN:65668440
# skipping header line:	@SQ	SN:NC_035781.1	LN:61752955
# skipping header line:	@SQ	SN:NC_035782.1	LN:77061148
# skipping header line:	@SQ	SN:NC_035783.1	LN:59691872
# skipping header line:	@SQ	SN:NC_035784.1	LN:98698416
# skipping header line:	@SQ	SN:NC_035785.1	LN:51258098
# skipping header line:	@SQ	SN:NC_035786.1	LN:57830854
# skipping header line:	@SQ	SN:NC_035787.1	LN:75944018
# skipping header line:	@SQ	SN:NC_035788.1	LN:104168038
# skipping header line:	@SQ	SN:NC_035789.1	LN:32650045
# skipping header line:	@SQ	SN:NC_007175.2	LN:17244
# skipping header line:	@PG	ID:Bismark	VN:v0.19.0	CL:"bismark --path_to_bowtie /Applications/bioinfo/bowtie2-2.3.4.1-macos-x86_64 --genome /Users/sr320/Dropbox/wd/18-03-15/genome --score_min L,0,-1.2 -u 10000 -p 2 --non_directional -1 /Users/sr320/Desktop/trim14/zr2096_2_s1_R1_val_1.fq.gz -2 /Users/sr320/Desktop/trim14/zr2096_2_s1_R2_val_2.fq.gz"
#
# Now testing Bismark result file zr2096_3_s1_R1_val_1_bismark_bt2_pe.bam for positional sorting (which would be bad...)	skipping header line:	@HD	VN:1.0	SO:unsorted
# skipping header line:	@SQ	SN:NC_035780.1	LN:65668440
# skipping header line:	@SQ	SN:NC_035781.1	LN:61752955
# skipping header line:	@SQ	SN:NC_035782.1	LN:77061148
# skipping header line:	@SQ	SN:NC_035783.1	LN:59691872
# skipping header line:	@SQ	SN:NC_035784.1	LN:98698416
# skipping header line:	@SQ	SN:NC_035785.1	LN:51258098
# skipping header line:	@SQ	SN:NC_035786.1	LN:57830854
# skipping header line:	@SQ	SN:NC_035787.1	LN:75944018
# skipping header line:	@SQ	SN:NC_035788.1	LN:104168038
# skipping header line:	@SQ	SN:NC_035789.1	LN:32650045
# skipping header line:	@SQ	SN:NC_007175.2	LN:17244
# skipping header line:	@PG	ID:Bismark	VN:v0.19.0	CL:"bismark --path_to_bowtie /Applications/bioinfo/bowtie2-2.3.4.1-macos-x86_64 --genome /Users/sr320/Dropbox/wd/18-03-15/genome --score_min L,0,-1.2 -u 10000 -p 2 --non_directional -1 /Users/sr320/Desktop/trim14/zr2096_3_s1_R1_val_1.fq.gz -2 /Users/sr320/Desktop/trim14/zr2096_3_s1_R2_val_2.fq.gz"
#
# Now testing Bismark result file zr2096_4_s1_R1_val_1_bismark_bt2_pe.bam for positional sorting (which would be bad...)	skipping header line:	@HD	VN:1.0	SO:unsorted
# skipping header line:	@SQ	SN:NC_035780.1	LN:65668440
# skipping header line:	@SQ	SN:NC_035781.1	LN:61752955
# skipping header line:	@SQ	SN:NC_035782.1	LN:77061148
# skipping header line:	@SQ	SN:NC_035783.1	LN:59691872
# skipping header line:	@SQ	SN:NC_035784.1	LN:98698416
# skipping header line:	@SQ	SN:NC_035785.1	LN:51258098
# skipping header line:	@SQ	SN:NC_035786.1	LN:57830854
# skipping header line:	@SQ	SN:NC_035787.1	LN:75944018
# skipping header line:	@SQ	SN:NC_035788.1	LN:104168038
# skipping header line:	@SQ	SN:NC_035789.1	LN:32650045
# skipping header line:	@SQ	SN:NC_007175.2	LN:17244
# skipping header line:	@PG	ID:Bismark	VN:v0.19.0	CL:"bismark --path_to_bowtie /Applications/bioinfo/bowtie2-2.3.4.1-macos-x86_64 --genome /Users/sr320/Dropbox/wd/18-03-15/genome --score_min L,0,-1.2 -u 10000 -p 2 --non_directional -1 /Users/sr320/Desktop/trim14/zr2096_4_s1_R1_val_1.fq.gz -2 /Users/sr320/Desktop/trim14/zr2096_4_s1_R2_val_2.fq.gz"
#
# Now testing Bismark result file zr2096_5_s1_R1_val_1_bismark_bt2_pe.bam for positional sorting (which would be bad...)	skipping header line:	@HD	VN:1.0	SO:unsorted
# skipping header line:	@SQ	SN:NC_035780.1	LN:65668440
# skipping header line:	@SQ	SN:NC_035781.1	LN:61752955
# skipping header line:	@SQ	SN:NC_035782.1	LN:77061148
# skipping header line:	@SQ	SN:NC_035783.1	LN:59691872
# skipping header line:	@SQ	SN:NC_035784.1	LN:98698416
# skipping header line:	@SQ	SN:NC_035785.1	LN:51258098
# skipping header line:	@SQ	SN:NC_035786.1	LN:57830854
# skipping header line:	@SQ	SN:NC_035787.1	LN:75944018
# skipping header line:	@SQ	SN:NC_035788.1	LN:104168038
# skipping header line:	@SQ	SN:NC_035789.1	LN:32650045
# skipping header line:	@SQ	SN:NC_007175.2	LN:17244
# skipping header line:	@PG	ID:Bismark	VN:v0.19.0	CL:"bismark --path_to_bowtie /Applications/bioinfo/bowtie2-2.3.4.1-macos-x86_64 --genome /Users/sr320/Dropbox/wd/18-03-15/genome --score_min L,0,-1.2 -u 10000 -p 2 --non_directional -1 /Users/sr320/Desktop/trim14/zr2096_5_s1_R1_val_1.fq.gz -2 /Users/sr320/Desktop/trim14/zr2096_5_s1_R2_val_2.fq.gz"
#
# Now testing Bismark result file zr2096_6_s1_R1_val_1_bismark_bt2_pe.bam for positional sorting (which would be bad...)	skipping header line:	@HD	VN:1.0	SO:unsorted
# skipping header line:	@SQ	SN:NC_035780.1	LN:65668440
# skipping header line:	@SQ	SN:NC_035781.1	LN:61752955
# skipping header line:	@SQ	SN:NC_035782.1	LN:77061148
# skipping header line:	@SQ	SN:NC_035783.1	LN:59691872
# skipping header line:	@SQ	SN:NC_035784.1	LN:98698416
# skipping header line:	@SQ	SN:NC_035785.1	LN:51258098
# skipping header line:	@SQ	SN:NC_035786.1	LN:57830854
# skipping header line:	@SQ	SN:NC_035787.1	LN:75944018
# skipping header line:	@SQ	SN:NC_035788.1	LN:104168038
# skipping header line:	@SQ	SN:NC_035789.1	LN:32650045
# skipping header line:	@SQ	SN:NC_007175.2	LN:17244
# skipping header line:	@PG	ID:Bismark	VN:v0.19.0	CL:"bismark --path_to_bowtie /Applications/bioinfo/bowtie2-2.3.4.1-macos-x86_64 --genome /Users/sr320/Dropbox/wd/18-03-15/genome --score_min L,0,-1.2 -u 10000 -p 2 --non_directional -1 /Users/sr320/Desktop/trim14/zr2096_6_s1_R1_val_1.fq.gz -2 /Users/sr320/Desktop/trim14/zr2096_6_s1_R2_val_2.fq.gz"
#
# Now testing Bismark result file zr2096_7_s1_R1_val_1_bismark_bt2_pe.bam for positional sorting (which would be bad...)	skipping header line:	@HD	VN:1.0	SO:unsorted
# skipping header line:	@SQ	SN:NC_035780.1	LN:65668440
# skipping header line:	@SQ	SN:NC_035781.1	LN:61752955
# skipping header line:	@SQ	SN:NC_035782.1	LN:77061148
# skipping header line:	@SQ	SN:NC_035783.1	LN:59691872
# skipping header line:	@SQ	SN:NC_035784.1	LN:98698416
# skipping header line:	@SQ	SN:NC_035785.1	LN:51258098
# skipping header line:	@SQ	SN:NC_035786.1	LN:57830854
# skipping header line:	@SQ	SN:NC_035787.1	LN:75944018
# skipping header line:	@SQ	SN:NC_035788.1	LN:104168038
# skipping header line:	@SQ	SN:NC_035789.1	LN:32650045
# skipping header line:	@SQ	SN:NC_007175.2	LN:17244
# skipping header line:	@PG	ID:Bismark	VN:v0.19.0	CL:"bismark --path_to_bowtie /Applications/bioinfo/bowtie2-2.3.4.1-macos-x86_64 --genome /Users/sr320/Dropbox/wd/18-03-15/genome --score_min L,0,-1.2 -u 10000 -p 2 --non_directional -1 /Users/sr320/Desktop/trim14/zr2096_7_s1_R1_val_1.fq.gz -2 /Users/sr320/Desktop/trim14/zr2096_7_s1_R2_val_2.fq.gz"
#
# Now testing Bismark result file zr2096_8_s1_R1_val_1_bismark_bt2_pe.bam for positional sorting (which would be bad...)	skipping header line:	@HD	VN:1.0	SO:unsorted
# skipping header line:	@SQ	SN:NC_035780.1	LN:65668440
# skipping header line:	@SQ	SN:NC_035781.1	LN:61752955
# skipping header line:	@SQ	SN:NC_035782.1	LN:77061148
# skipping header line:	@SQ	SN:NC_035783.1	LN:59691872
# skipping header line:	@SQ	SN:NC_035784.1	LN:98698416
# skipping header line:	@SQ	SN:NC_035785.1	LN:51258098
# skipping header line:	@SQ	SN:NC_035786.1	LN:57830854
# skipping header line:	@SQ	SN:NC_035787.1	LN:75944018
# skipping header line:	@SQ	SN:NC_035788.1	LN:104168038
# skipping header line:	@SQ	SN:NC_035789.1	LN:32650045
# skipping header line:	@SQ	SN:NC_007175.2	LN:17244
# skipping header line:	@PG	ID:Bismark	VN:v0.19.0	CL:"bismark --path_to_bowtie /Applications/bioinfo/bowtie2-2.3.4.1-macos-x86_64 --genome /Users/sr320/Dropbox/wd/18-03-15/genome --score_min L,0,-1.2 -u 10000 -p 2 --non_directional -1 /Users/sr320/Desktop/trim14/zr2096_8_s1_R1_val_1.fq.gz -2 /Users/sr320/Desktop/trim14/zr2096_8_s1_R2_val_2.fq.gz"
#
# Now testing Bismark result file zr2096_9_s1_R1_val_1_bismark_bt2_pe.bam for positional sorting (which would be bad...)	skipping header line:	@HD	VN:1.0	SO:unsorted
# skipping header line:	@SQ	SN:NC_035780.1	LN:65668440
# skipping header line:	@SQ	SN:NC_035781.1	LN:61752955
# skipping header line:	@SQ	SN:NC_035782.1	LN:77061148
# skipping header line:	@SQ	SN:NC_035783.1	LN:59691872
# skipping header line:	@SQ	SN:NC_035784.1	LN:98698416
# skipping header line:	@SQ	SN:NC_035785.1	LN:51258098
# skipping header line:	@SQ	SN:NC_035786.1	LN:57830854
# skipping header line:	@SQ	SN:NC_035787.1	LN:75944018
# skipping header line:	@SQ	SN:NC_035788.1	LN:104168038
# skipping header line:	@SQ	SN:NC_035789.1	LN:32650045
# skipping header line:	@SQ	SN:NC_007175.2	LN:17244
# skipping header line:	@PG	ID:Bismark	VN:v0.19.0	CL:"bismark --path_to_bowtie /Applications/bioinfo/bowtie2-2.3.4.1-macos-x86_64 --genome /Users/sr320/Dropbox/wd/18-03-15/genome --score_min L,0,-1.2 -u 10000 -p 2 --non_directional -1 /Users/sr320/Desktop/trim14/zr2096_9_s1_R1_val_1.fq.gz -2 /Users/sr320/Desktop/trim14/zr2096_9_s1_R2_val_2.fq.gz"

# %%
# %%bash
# /Applications/bioinfo/Bismark_v0.19.0/bismark_methylation_extractor \
# -p --bedGraph --counts --scaffolds \
# --multicore 2 \
# *deduplicated.bam \
# 2> bme.err
# Out:
# Now testing Bismark result file zr2096_10_s1_R1_val_1_bismark_bt2_pe.deduplicated.bam for positional sorting (which would be bad...)	zr2096_10_s1_R1_val_1_bismark_bt2_pe.deduplicated_splitting_report.txt.1
# zr2096_10_s1_R1_val_1_bismark_bt2_pe.deduplicated_splitting_report.txt.2
#
# zr2096_10_s1_R1_val_1_bismark_bt2_pe.deduplicated_splitting_report.txt.1.mbias
# zr2096_10_s1_R1_val_1_bismark_bt2_pe.deduplicated_splitting_report.txt.2.mbias
#
# /Users/sr320/Desktop/wd/0414/CpG_OT_zr2096_10_s1_R1_val_1_bismark_bt2_pe.deduplicated.txt	/Users/sr320/Desktop/wd/0414/CpG_CTOT_zr2096_10_s1_R1_val_1_bismark_bt2_pe.deduplicated.txt	/Users/sr320/Desktop/wd/0414/CpG_CTOB_zr2096_10_s1_R1_val_1_bismark_bt2_pe.deduplicated.txt	/Users/sr320/Desktop/wd/0414/CpG_OB_zr2096_10_s1_R1_val_1_bismark_bt2_pe.deduplicated.txt
#
#
# Now testing Bismark result file zr2096_1_s1_R1_val_1_bismark_bt2_pe.deduplicated.bam for positional sorting (which would be bad...)	zr2096_1_s1_R1_val_1_bismark_bt2_pe.deduplicated_splitting_report.txt.1
# zr2096_1_s1_R1_val_1_bismark_bt2_pe.deduplicated_splitting_report.txt.2
#
# zr2096_1_s1_R1_val_1_bismark_bt2_pe.deduplicated_splitting_report.txt.1.mbias
# zr2096_1_s1_R1_val_1_bismark_bt2_pe.deduplicated_splitting_report.txt.2.mbias
#
# /Users/sr320/Desktop/wd/0414/CpG_OT_zr2096_1_s1_R1_val_1_bismark_bt2_pe.deduplicated.txt	/Users/sr320/Desktop/wd/0414/CpG_CTOT_zr2096_1_s1_R1_val_1_bismark_bt2_pe.deduplicated.txt	/Users/sr320/Desktop/wd/0414/CpG_CTOB_zr2096_1_s1_R1_val_1_bismark_bt2_pe.deduplicated.txt	/Users/sr320/Desktop/wd/0414/CpG_OB_zr2096_1_s1_R1_val_1_bismark_bt2_pe.deduplicated.txt
#
#
# Now testing Bismark result file zr2096_2_s1_R1_val_1_bismark_bt2_pe.deduplicated.bam for positional sorting (which would be bad...)	zr2096_2_s1_R1_val_1_bismark_bt2_pe.deduplicated_splitting_report.txt.1
# zr2096_2_s1_R1_val_1_bismark_bt2_pe.deduplicated_splitting_report.txt.2
#
# zr2096_2_s1_R1_val_1_bismark_bt2_pe.deduplicated_splitting_report.txt.1.mbias
# zr2096_2_s1_R1_val_1_bismark_bt2_pe.deduplicated_splitting_report.txt.2.mbias
#
# /Users/sr320/Desktop/wd/0414/CpG_OT_zr2096_2_s1_R1_val_1_bismark_bt2_pe.deduplicated.txt	/Users/sr320/Desktop/wd/0414/CpG_CTOT_zr2096_2_s1_R1_val_1_bismark_bt2_pe.deduplicated.txt	/Users/sr320/Desktop/wd/0414/CpG_CTOB_zr2096_2_s1_R1_val_1_bismark_bt2_pe.deduplicated.txt	/Users/sr320/Desktop/wd/0414/CpG_OB_zr2096_2_s1_R1_val_1_bismark_bt2_pe.deduplicated.txt
#
#
# Now testing Bismark result file zr2096_3_s1_R1_val_1_bismark_bt2_pe.deduplicated.bam for positional sorting (which would be bad...)	zr2096_3_s1_R1_val_1_bismark_bt2_pe.deduplicated_splitting_report.txt.1
# zr2096_3_s1_R1_val_1_bismark_bt2_pe.deduplicated_splitting_report.txt.2
#
# zr2096_3_s1_R1_val_1_bismark_bt2_pe.deduplicated_splitting_report.txt.1.mbias
# zr2096_3_s1_R1_val_1_bismark_bt2_pe.deduplicated_splitting_report.txt.2.mbias
#
# /Users/sr320/Desktop/wd/0414/CpG_OT_zr2096_3_s1_R1_val_1_bismark_bt2_pe.deduplicated.txt	/Users/sr320/Desktop/wd/0414/CpG_CTOT_zr2096_3_s1_R1_val_1_bismark_bt2_pe.deduplicated.txt	/Users/sr320/Desktop/wd/0414/CpG_CTOB_zr2096_3_s1_R1_val_1_bismark_bt2_pe.deduplicated.txt	/Users/sr320/Desktop/wd/0414/CpG_OB_zr2096_3_s1_R1_val_1_bismark_bt2_pe.deduplicated.txt
#
#
# Now testing Bismark result file zr2096_4_s1_R1_val_1_bismark_bt2_pe.deduplicated.bam for positional sorting (which would be bad...)	zr2096_4_s1_R1_val_1_bismark_bt2_pe.deduplicated_splitting_report.txt.1
# zr2096_4_s1_R1_val_1_bismark_bt2_pe.deduplicated_splitting_report.txt.2
#
# zr2096_4_s1_R1_val_1_bismark_bt2_pe.deduplicated_splitting_report.txt.1.mbias
# zr2096_4_s1_R1_val_1_bismark_bt2_pe.deduplicated_splitting_report.txt.2.mbias
#
# /Users/sr320/Desktop/wd/0414/CpG_OT_zr2096_4_s1_R1_val_1_bismark_bt2_pe.deduplicated.txt	/Users/sr320/Desktop/wd/0414/CpG_CTOT_zr2096_4_s1_R1_val_1_bismark_bt2_pe.deduplicated.txt	/Users/sr320/Desktop/wd/0414/CpG_CTOB_zr2096_4_s1_R1_val_1_bismark_bt2_pe.deduplicated.txt	/Users/sr320/Desktop/wd/0414/CpG_OB_zr2096_4_s1_R1_val_1_bismark_bt2_pe.deduplicated.txt
#
#
# Now testing Bismark result file zr2096_5_s1_R1_val_1_bismark_bt2_pe.deduplicated.bam for positional sorting (which would be bad...)	zr2096_5_s1_R1_val_1_bismark_bt2_pe.deduplicated_splitting_report.txt.1
# zr2096_5_s1_R1_val_1_bismark_bt2_pe.deduplicated_splitting_report.txt.2
#
# zr2096_5_s1_R1_val_1_bismark_bt2_pe.deduplicated_splitting_report.txt.1.mbias
# zr2096_5_s1_R1_val_1_bismark_bt2_pe.deduplicated_splitting_report.txt.2.mbias
#
# /Users/sr320/Desktop/wd/0414/CpG_OT_zr2096_5_s1_R1_val_1_bismark_bt2_pe.deduplicated.txt	/Users/sr320/Desktop/wd/0414/CpG_CTOT_zr2096_5_s1_R1_val_1_bismark_bt2_pe.deduplicated.txt	/Users/sr320/Desktop/wd/0414/CpG_CTOB_zr2096_5_s1_R1_val_1_bismark_bt2_pe.deduplicated.txt	/Users/sr320/Desktop/wd/0414/CpG_OB_zr2096_5_s1_R1_val_1_bismark_bt2_pe.deduplicated.txt
#
#
# Now testing Bismark result file zr2096_6_s1_R1_val_1_bismark_bt2_pe.deduplicated.bam for positional sorting (which would be bad...)	zr2096_6_s1_R1_val_1_bismark_bt2_pe.deduplicated_splitting_report.txt.1
# zr2096_6_s1_R1_val_1_bismark_bt2_pe.deduplicated_splitting_report.txt.2
#
# zr2096_6_s1_R1_val_1_bismark_bt2_pe.deduplicated_splitting_report.txt.1.mbias
# zr2096_6_s1_R1_val_1_bismark_bt2_pe.deduplicated_splitting_report.txt.2.mbias
#
# /Users/sr320/Desktop/wd/0414/CpG_OT_zr2096_6_s1_R1_val_1_bismark_bt2_pe.deduplicated.txt	/Users/sr320/Desktop/wd/0414/CpG_CTOT_zr2096_6_s1_R1_val_1_bismark_bt2_pe.deduplicated.txt	/Users/sr320/Desktop/wd/0414/CpG_CTOB_zr2096_6_s1_R1_val_1_bismark_bt2_pe.deduplicated.txt	/Users/sr320/Desktop/wd/0414/CpG_OB_zr2096_6_s1_R1_val_1_bismark_bt2_pe.deduplicated.txt
#
#
# Now testing Bismark result file zr2096_7_s1_R1_val_1_bismark_bt2_pe.deduplicated.bam for positional sorting (which would be bad...)	zr2096_7_s1_R1_val_1_bismark_bt2_pe.deduplicated_splitting_report.txt.1
# zr2096_7_s1_R1_val_1_bismark_bt2_pe.deduplicated_splitting_report.txt.2
#
# zr2096_7_s1_R1_val_1_bismark_bt2_pe.deduplicated_splitting_report.txt.1.mbias
# zr2096_7_s1_R1_val_1_bismark_bt2_pe.deduplicated_splitting_report.txt.2.mbias
#
# /Users/sr320/Desktop/wd/0414/CpG_OT_zr2096_7_s1_R1_val_1_bismark_bt2_pe.deduplicated.txt	/Users/sr320/Desktop/wd/0414/CpG_CTOT_zr2096_7_s1_R1_val_1_bismark_bt2_pe.deduplicated.txt	/Users/sr320/Desktop/wd/0414/CpG_CTOB_zr2096_7_s1_R1_val_1_bismark_bt2_pe.deduplicated.txt	/Users/sr320/Desktop/wd/0414/CpG_OB_zr2096_7_s1_R1_val_1_bismark_bt2_pe.deduplicated.txt
#
#
# Now testing Bismark result file zr2096_8_s1_R1_val_1_bismark_bt2_pe.deduplicated.bam for positional sorting (which would be bad...)	zr2096_8_s1_R1_val_1_bismark_bt2_pe.deduplicated_splitting_report.txt.1
# zr2096_8_s1_R1_val_1_bismark_bt2_pe.deduplicated_splitting_report.txt.2
#
# zr2096_8_s1_R1_val_1_bismark_bt2_pe.deduplicated_splitting_report.txt.1.mbias
# zr2096_8_s1_R1_val_1_bismark_bt2_pe.deduplicated_splitting_report.txt.2.mbias
#
# /Users/sr320/Desktop/wd/0414/CpG_OT_zr2096_8_s1_R1_val_1_bismark_bt2_pe.deduplicated.txt	/Users/sr320/Desktop/wd/0414/CpG_CTOT_zr2096_8_s1_R1_val_1_bismark_bt2_pe.deduplicated.txt	/Users/sr320/Desktop/wd/0414/CpG_CTOB_zr2096_8_s1_R1_val_1_bismark_bt2_pe.deduplicated.txt	/Users/sr320/Desktop/wd/0414/CpG_OB_zr2096_8_s1_R1_val_1_bismark_bt2_pe.deduplicated.txt
#
#
# Now testing Bismark result file zr2096_9_s1_R1_val_1_bismark_bt2_pe.deduplicated.bam for positional sorting (which would be bad...)	zr2096_9_s1_R1_val_1_bismark_bt2_pe.deduplicated_splitting_report.txt.1
# zr2096_9_s1_R1_val_1_bismark_bt2_pe.deduplicated_splitting_report.txt.2
#
# zr2096_9_s1_R1_val_1_bismark_bt2_pe.deduplicated_splitting_report.txt.1.mbias
# zr2096_9_s1_R1_val_1_bismark_bt2_pe.deduplicated_splitting_report.txt.2.mbias
#
# /Users/sr320/Desktop/wd/0414/CpG_OT_zr2096_9_s1_R1_val_1_bismark_bt2_pe.deduplicated.txt	/Users/sr320/Desktop/wd/0414/CpG_CTOT_zr2096_9_s1_R1_val_1_bismark_bt2_pe.deduplicated.txt	/Users/sr320/Desktop/wd/0414/CpG_CTOB_zr2096_9_s1_R1_val_1_bismark_bt2_pe.deduplicated.txt	/Users/sr320/Desktop/wd/0414/CpG_OB_zr2096_9_s1_R1_val_1_bismark_bt2_pe.deduplicated.txt

# %%
# !gunzip *bedGraph.gz

# %%
# !head *.deduplicated.bedGraph
# Out:
# ==> zr2096_10_s1_R1_val_1_bismark_bt2_pe.deduplicated.bedGraph <==
# track type=bedGraph
# NC_007175.2	12154	12155	0
# NC_007175.2	12209	12210	0
# NC_007175.2	12219	12220	0
# NC_035780.1	257956	257957	100
# NC_035780.1	257970	257971	100
# NC_035780.1	257982	257983	100
# NC_035780.1	257994	257995	100
# NC_035780.1	258025	258026	100
# NC_035780.1	322880	322881	100
#
# ==> zr2096_1_s1_R1_val_1_bismark_bt2_pe.deduplicated.bedGraph <==
# track type=bedGraph
# NC_035780.1	100634	100635	100
# NC_035780.1	100643	100644	100
# NC_035780.1	100651	100652	100
# NC_035780.1	100664	100665	100
# NC_035780.1	471536	471537	100
# NC_035780.1	471539	471540	100
# NC_035780.1	471550	471551	100
# NC_035780.1	471584	471585	100
# NC_035780.1	471603	471604	100
#
# ==> zr2096_2_s1_R1_val_1_bismark_bt2_pe.deduplicated.bedGraph <==
# track type=bedGraph
# NC_007175.2	4394	4395	0
# NC_007175.2	4408	4409	0
# NC_007175.2	4448	4449	0
# NC_007175.2	4478	4479	0
# NC_007175.2	6458	6459	0
# NC_007175.2	6460	6461	0
# NC_007175.2	6466	6467	0
# NC_007175.2	11969	11970	0
# NC_007175.2	11971	11972	0
#
# ==> zr2096_3_s1_R1_val_1_bismark_bt2_pe.deduplicated.bedGraph <==
# track type=bedGraph
# NC_007175.2	48	49	0
# NC_007175.2	50	51	0
# NC_007175.2	87	88	0
# NC_007175.2	7089	7090	0
# NC_007175.2	7099	7100	0
# NC_007175.2	7121	7122	0
# NC_007175.2	7147	7148	0
# NC_007175.2	14357	14358	0
# NC_035780.1	257471	257472	100
#
# ==> zr2096_4_s1_R1_val_1_bismark_bt2_pe.deduplicated.bedGraph <==
# track type=bedGraph
# NC_007175.2	3345	3346	0
# NC_007175.2	3385	3386	0
# NC_007175.2	3396	3397	0
# NC_007175.2	3859	3860	0
# NC_007175.2	3886	3887	0
# NC_007175.2	7248	7249	0
# NC_007175.2	7253	7254	0
# NC_007175.2	7264	7265	0
# NC_007175.2	7284	7285	0
#
# ==> zr2096_5_s1_R1_val_1_bismark_bt2_pe.deduplicated.bedGraph <==
# track type=bedGraph
# NC_007175.2	245	246	0
# NC_007175.2	256	257	0
# NC_007175.2	263	264	0
# NC_007175.2	265	266	0
# NC_007175.2	724	725	0
# NC_007175.2	975	976	0
# NC_007175.2	994	995	0
# NC_007175.2	2145	2146	0
# NC_007175.2	2148	2149	0
#
# ==> zr2096_6_s1_R1_val_1_bismark_bt2_pe.deduplicated.bedGraph <==
# track type=bedGraph
# NC_035780.1	250559	250560	100
# NC_035780.1	269759	269760	100
# NC_035780.1	269762	269763	100
# NC_035780.1	269781	269782	100
# NC_035780.1	269789	269790	100
# NC_035780.1	269822	269823	100
# NC_035780.1	270312	270313	100
# NC_035780.1	285489	285490	100
# NC_035780.1	285494	285495	100
#
# ==> zr2096_7_s1_R1_val_1_bismark_bt2_pe.deduplicated.bedGraph <==
# track type=bedGraph
# NC_007175.2	664	665	0
# NC_007175.2	683	684	0
# NC_007175.2	708	709	0
# NC_007175.2	724	725	0
# NC_007175.2	9943	9944	0
# NC_007175.2	9947	9948	0
# NC_007175.2	9959	9960	0
# NC_007175.2	9964	9965	0
# NC_007175.2	13202	13203	0
#
# ==> zr2096_8_s1_R1_val_1_bismark_bt2_pe.deduplicated.bedGraph <==
# track type=bedGraph
# NC_007175.2	2301	2302	0
# NC_007175.2	2304	2305	0
# NC_007175.2	2356	2357	0
# NC_007175.2	2365	2366	0
# NC_007175.2	2472	2473	0
# NC_007175.2	2490	2491	0
# NC_007175.2	2635	2636	0
# NC_007175.2	2653	2654	0
# NC_007175.2	2657	2658	0
#
# ==> zr2096_9_s1_R1_val_1_bismark_bt2_pe.deduplicated.bedGraph <==
# track type=bedGraph
# NC_007175.2	3099	3100	0
# NC_007175.2	3102	3103	0
# NC_007175.2	3114	3115	0
# NC_007175.2	3213	3214	0
# NC_007175.2	3222	3223	0
# NC_007175.2	3245	3246	0
# NC_007175.2	10997	10998	0
# NC_007175.2	11102	11103	0
# NC_007175.2	11468	11469	0

# %%
# %%bash
# /Applications/bioinfo/Bismark_v0.19.0/bismark2report
# Out:
# Found 10 alignment reports in current directory. Now trying to figure out whether there are corresponding optional reports
#
# Writing Bismark HTML report to >> zr2096_10_s1_R1_val_1_bismark_bt2_PE_report.html <<
#
# ==============================================================================================================
# Using the following alignment report:		> zr2096_10_s1_R1_val_1_bismark_bt2_PE_report.txt <
# Processing alignment report zr2096_10_s1_R1_val_1_bismark_bt2_PE_report.txt ...
# Complete
#
# Using the following deduplication report:	> zr2096_10_s1_R1_val_1_bismark_bt2_pe.deduplication_report.txt <
# Processing deduplication report zr2096_10_s1_R1_val_1_bismark_bt2_pe.deduplication_report.txt ...
# Complete
#
# Using the following splitting report:		> zr2096_10_s1_R1_val_1_bismark_bt2_pe.deduplicated_splitting_report.txt <
# Processing splitting report zr2096_10_s1_R1_val_1_bismark_bt2_pe.deduplicated_splitting_report.txt ...
# Complete
#
# Using the following M-bias report:		> zr2096_10_s1_R1_val_1_bismark_bt2_pe.deduplicated.M-bias.txt <
# Processing M-bias report zr2096_10_s1_R1_val_1_bismark_bt2_pe.deduplicated.M-bias.txt ...
# Complete
#
# No nucleotide coverage report file specified, skipping this step
# ==============================================================================================================
#
#
#
# Writing Bismark HTML report to >> zr2096_1_s1_R1_val_1_bismark_bt2_PE_report.html <<
#
# ==============================================================================================================
# Using the following alignment report:		> zr2096_1_s1_R1_val_1_bismark_bt2_PE_report.txt <
# Processing alignment report zr2096_1_s1_R1_val_1_bismark_bt2_PE_report.txt ...
# Complete
#
# Using the following deduplication report:	> zr2096_1_s1_R1_val_1_bismark_bt2_pe.deduplication_report.txt <
# Processing deduplication report zr2096_1_s1_R1_val_1_bismark_bt2_pe.deduplication_report.txt ...
# Complete
#
# Using the following splitting report:		> zr2096_1_s1_R1_val_1_bismark_bt2_pe.deduplicated_splitting_report.txt <
# Processing splitting report zr2096_1_s1_R1_val_1_bismark_bt2_pe.deduplicated_splitting_report.txt ...
# Complete
#
# Using the following M-bias report:		> zr2096_1_s1_R1_val_1_bismark_bt2_pe.deduplicated.M-bias.txt <
# Processing M-bias report zr2096_1_s1_R1_val_1_bismark_bt2_pe.deduplicated.M-bias.txt ...
# Complete
#
# No nucleotide coverage report file specified, skipping this step
# ==============================================================================================================
#
#
#
# Writing Bismark HTML report to >> zr2096_2_s1_R1_val_1_bismark_bt2_PE_report.html <<
#
# ==============================================================================================================
# Using the following alignment report:		> zr2096_2_s1_R1_val_1_bismark_bt2_PE_report.txt <
# Processing alignment report zr2096_2_s1_R1_val_1_bismark_bt2_PE_report.txt ...
# Complete
#
# Using the following deduplication report:	> zr2096_2_s1_R1_val_1_bismark_bt2_pe.deduplication_report.txt <
# Processing deduplication report zr2096_2_s1_R1_val_1_bismark_bt2_pe.deduplication_report.txt ...
# Complete
#
# Using the following splitting report:		> zr2096_2_s1_R1_val_1_bismark_bt2_pe.deduplicated_splitting_report.txt <
# Processing splitting report zr2096_2_s1_R1_val_1_bismark_bt2_pe.deduplicated_splitting_report.txt ...
# Complete
#
# Using the following M-bias report:		> zr2096_2_s1_R1_val_1_bismark_bt2_pe.deduplicated.M-bias.txt <
# Processing M-bias report zr2096_2_s1_R1_val_1_bismark_bt2_pe.deduplicated.M-bias.txt ...
# Complete
#
# No nucleotide coverage report file specified, skipping this step
# ==============================================================================================================
#
#
#
# Writing Bismark HTML report to >> zr2096_3_s1_R1_val_1_bismark_bt2_PE_report.html <<
#
# ==============================================================================================================
# Using the following alignment report:		> zr2096_3_s1_R1_val_1_bismark_bt2_PE_report.txt <
# Processing alignment report zr2096_3_s1_R1_val_1_bismark_bt2_PE_report.txt ...
# Complete
#
# Using the following deduplication report:	> zr2096_3_s1_R1_val_1_bismark_bt2_pe.deduplication_report.txt <
# Processing deduplication report zr2096_3_s1_R1_val_1_bismark_bt2_pe.deduplication_report.txt ...
# Complete
#
# Using the following splitting report:		> zr2096_3_s1_R1_val_1_bismark_bt2_pe.deduplicated_splitting_report.txt <
# Processing splitting report zr2096_3_s1_R1_val_1_bismark_bt2_pe.deduplicated_splitting_report.txt ...
# Complete
#
# Using the following M-bias report:		> zr2096_3_s1_R1_val_1_bismark_bt2_pe.deduplicated.M-bias.txt <
# Processing M-bias report zr2096_3_s1_R1_val_1_bismark_bt2_pe.deduplicated.M-bias.txt ...
# Complete
#
# No nucleotide coverage report file specified, skipping this step
# ==============================================================================================================
#
#
#
# Writing Bismark HTML report to >> zr2096_4_s1_R1_val_1_bismark_bt2_PE_report.html <<
#
# ==============================================================================================================
# Using the following alignment report:		> zr2096_4_s1_R1_val_1_bismark_bt2_PE_report.txt <
# Processing alignment report zr2096_4_s1_R1_val_1_bismark_bt2_PE_report.txt ...
# Complete
#
# Using the following deduplication report:	> zr2096_4_s1_R1_val_1_bismark_bt2_pe.deduplication_report.txt <
# Processing deduplication report zr2096_4_s1_R1_val_1_bismark_bt2_pe.deduplication_report.txt ...
# Complete
#
# Using the following splitting report:		> zr2096_4_s1_R1_val_1_bismark_bt2_pe.deduplicated_splitting_report.txt <
# Processing splitting report zr2096_4_s1_R1_val_1_bismark_bt2_pe.deduplicated_splitting_report.txt ...
# Complete
#
# Using the following M-bias report:		> zr2096_4_s1_R1_val_1_bismark_bt2_pe.deduplicated.M-bias.txt <
# Processing M-bias report zr2096_4_s1_R1_val_1_bismark_bt2_pe.deduplicated.M-bias.txt ...
# Complete
#
# No nucleotide coverage report file specified, skipping this step
# ==============================================================================================================
#
#
#
# Writing Bismark HTML report to >> zr2096_5_s1_R1_val_1_bismark_bt2_PE_report.html <<
#
# ==============================================================================================================
# Using the following alignment report:		> zr2096_5_s1_R1_val_1_bismark_bt2_PE_report.txt <
# Processing alignment report zr2096_5_s1_R1_val_1_bismark_bt2_PE_report.txt ...
# Complete
#
# Using the following deduplication report:	> zr2096_5_s1_R1_val_1_bismark_bt2_pe.deduplication_report.txt <
# Processing deduplication report zr2096_5_s1_R1_val_1_bismark_bt2_pe.deduplication_report.txt ...
# Complete
#
# Using the following splitting report:		> zr2096_5_s1_R1_val_1_bismark_bt2_pe.deduplicated_splitting_report.txt <
# Processing splitting report zr2096_5_s1_R1_val_1_bismark_bt2_pe.deduplicated_splitting_report.txt ...
# Complete
#
# Using the following M-bias report:		> zr2096_5_s1_R1_val_1_bismark_bt2_pe.deduplicated.M-bias.txt <
# Processing M-bias report zr2096_5_s1_R1_val_1_bismark_bt2_pe.deduplicated.M-bias.txt ...
# Complete
#
# No nucleotide coverage report file specified, skipping this step
# ==============================================================================================================
#
#
#
# Writing Bismark HTML report to >> zr2096_6_s1_R1_val_1_bismark_bt2_PE_report.html <<
#
# ==============================================================================================================
# Using the following alignment report:		> zr2096_6_s1_R1_val_1_bismark_bt2_PE_report.txt <
# Processing alignment report zr2096_6_s1_R1_val_1_bismark_bt2_PE_report.txt ...
# Complete
#
# Using the following deduplication report:	> zr2096_6_s1_R1_val_1_bismark_bt2_pe.deduplication_report.txt <
# Processing deduplication report zr2096_6_s1_R1_val_1_bismark_bt2_pe.deduplication_report.txt ...
# Complete
#
# Using the following splitting report:		> zr2096_6_s1_R1_val_1_bismark_bt2_pe.deduplicated_splitting_report.txt <
# Processing splitting report zr2096_6_s1_R1_val_1_bismark_bt2_pe.deduplicated_splitting_report.txt ...
# Complete
#
# Using the following M-bias report:		> zr2096_6_s1_R1_val_1_bismark_bt2_pe.deduplicated.M-bias.txt <
# Processing M-bias report zr2096_6_s1_R1_val_1_bismark_bt2_pe.deduplicated.M-bias.txt ...
# Complete
#
# No nucleotide coverage report file specified, skipping this step
# ==============================================================================================================
#
#
#
# Writing Bismark HTML report to >> zr2096_7_s1_R1_val_1_bismark_bt2_PE_report.html <<
#
# ==============================================================================================================
# Using the following alignment report:		> zr2096_7_s1_R1_val_1_bismark_bt2_PE_report.txt <
# Processing alignment report zr2096_7_s1_R1_val_1_bismark_bt2_PE_report.txt ...
# Complete
#
# Using the following deduplication report:	> zr2096_7_s1_R1_val_1_bismark_bt2_pe.deduplication_report.txt <
# Processing deduplication report zr2096_7_s1_R1_val_1_bismark_bt2_pe.deduplication_report.txt ...
# Complete
#
# Using the following splitting report:		> zr2096_7_s1_R1_val_1_bismark_bt2_pe.deduplicated_splitting_report.txt <
# Processing splitting report zr2096_7_s1_R1_val_1_bismark_bt2_pe.deduplicated_splitting_report.txt ...
# Complete
#
# Using the following M-bias report:		> zr2096_7_s1_R1_val_1_bismark_bt2_pe.deduplicated.M-bias.txt <
# Processing M-bias report zr2096_7_s1_R1_val_1_bismark_bt2_pe.deduplicated.M-bias.txt ...
# Complete
#
# No nucleotide coverage report file specified, skipping this step
# ==============================================================================================================
#
#
#
# Writing Bismark HTML report to >> zr2096_8_s1_R1_val_1_bismark_bt2_PE_report.html <<
#
# ==============================================================================================================
# Using the following alignment report:		> zr2096_8_s1_R1_val_1_bismark_bt2_PE_report.txt <
# Processing alignment report zr2096_8_s1_R1_val_1_bismark_bt2_PE_report.txt ...
# Complete
#
# Using the following deduplication report:	> zr2096_8_s1_R1_val_1_bismark_bt2_pe.deduplication_report.txt <
# Processing deduplication report zr2096_8_s1_R1_val_1_bismark_bt2_pe.deduplication_report.txt ...
# Complete
#
# Using the following splitting report:		> zr2096_8_s1_R1_val_1_bismark_bt2_pe.deduplicated_splitting_report.txt <
# Processing splitting report zr2096_8_s1_R1_val_1_bismark_bt2_pe.deduplicated_splitting_report.txt ...
# Complete
#
# Using the following M-bias report:		> zr2096_8_s1_R1_val_1_bismark_bt2_pe.deduplicated.M-bias.txt <
# Processing M-bias report zr2096_8_s1_R1_val_1_bismark_bt2_pe.deduplicated.M-bias.txt ...
# Complete
#
# No nucleotide coverage report file specified, skipping this step
# ==============================================================================================================
#
#
#
# Writing Bismark HTML report to >> zr2096_9_s1_R1_val_1_bismark_bt2_PE_report.html <<
#
# ==============================================================================================================
# Using the following alignment report:		> zr2096_9_s1_R1_val_1_bismark_bt2_PE_report.txt <
# Processing alignment report zr2096_9_s1_R1_val_1_bismark_bt2_PE_report.txt ...
# Complete
#
# Using the following deduplication report:	> zr2096_9_s1_R1_val_1_bismark_bt2_pe.deduplication_report.txt <
# Processing deduplication report zr2096_9_s1_R1_val_1_bismark_bt2_pe.deduplication_report.txt ...
# Complete
#
# Using the following splitting report:		> zr2096_9_s1_R1_val_1_bismark_bt2_pe.deduplicated_splitting_report.txt <
# Processing splitting report zr2096_9_s1_R1_val_1_bismark_bt2_pe.deduplicated_splitting_report.txt ...
# Complete
#
# Using the following M-bias report:		> zr2096_9_s1_R1_val_1_bismark_bt2_pe.deduplicated.M-bias.txt <
# Processing M-bias report zr2096_9_s1_R1_val_1_bismark_bt2_pe.deduplicated.M-bias.txt ...
# Complete
#
# No nucleotide coverage report file specified, skipping this step
# ==============================================================================================================

# %%
# !open *report.html

# %%
# %%bash
# /Applications/bioinfo/Bismark_v0.19.0/bismark2summary
# Out:
# No Bismark/Bowtie2 single-end BAM files detected
# Found Bismark/Bowtie2 paired-end files
# No Bismark/Bowtie single-end BAM files detected
# No Bismark/Bowtie paired-end BAM files detected
#
# Generating Bismark summary report from 10 Bismark BAM file(s)...
# >> Reading from Bismark report: zr2096_10_s1_R1_val_1_bismark_bt2_PE_report.txt
# >> Reading from Bismark report: zr2096_1_s1_R1_val_1_bismark_bt2_PE_report.txt
# >> Reading from Bismark report: zr2096_2_s1_R1_val_1_bismark_bt2_PE_report.txt
# >> Reading from Bismark report: zr2096_3_s1_R1_val_1_bismark_bt2_PE_report.txt
# >> Reading from Bismark report: zr2096_4_s1_R1_val_1_bismark_bt2_PE_report.txt
# >> Reading from Bismark report: zr2096_5_s1_R1_val_1_bismark_bt2_PE_report.txt
# >> Reading from Bismark report: zr2096_6_s1_R1_val_1_bismark_bt2_PE_report.txt
# >> Reading from Bismark report: zr2096_7_s1_R1_val_1_bismark_bt2_PE_report.txt
# >> Reading from Bismark report: zr2096_8_s1_R1_val_1_bismark_bt2_PE_report.txt
# >> Reading from Bismark report: zr2096_9_s1_R1_val_1_bismark_bt2_PE_report.txt
#
# Wrote Bismark project summary to >> bismark_summary_report.html <<

# %%
ls *deduplicated.bam
# Out:
# zr2096_10_s1_R1_val_1_bismark_bt2_pe.deduplicated.bam
# zr2096_1_s1_R1_val_1_bismark_bt2_pe.deduplicated.bam
# zr2096_2_s1_R1_val_1_bismark_bt2_pe.deduplicated.bam
# zr2096_3_s1_R1_val_1_bismark_bt2_pe.deduplicated.bam
# zr2096_4_s1_R1_val_1_bismark_bt2_pe.deduplicated.bam
# zr2096_5_s1_R1_val_1_bismark_bt2_pe.deduplicated.bam
# zr2096_6_s1_R1_val_1_bismark_bt2_pe.deduplicated.bam
# zr2096_7_s1_R1_val_1_bismark_bt2_pe.deduplicated.bam
# zr2096_8_s1_R1_val_1_bismark_bt2_pe.deduplicated.bam
# zr2096_9_s1_R1_val_1_bismark_bt2_pe.deduplicated.bam

# %%
# %%bash
# /Applications/bioinfo/Bismark_v0.19.0/bam2nuc \
# --genome_folder /Users/sr320/Dropbox/wd/18-03-15/genome \
# *deduplicated.bam
# Out:
# Summary of parameters for nucleotide coverage report:
# =====================================================
# Output directory:			><
# Parent directory:			>/Users/sr320/Desktop/wd/0414/<
# Genome directory:			>/Users/sr320/Dropbox/wd/18-03-15/genome/<
# Samtools installation:			>/Applications/bioinfo/samtools-1.7/samtools<
#
# Now reading in and storing sequence information of the genome specified in: /Users/sr320/Dropbox/wd/18-03-15/genome/
#
# chr NC_035780.1 (65668440 bp)
# chr NC_035781.1 (61752955 bp)
# chr NC_035782.1 (77061148 bp)
# chr NC_035783.1 (59691872 bp)
# chr NC_035784.1 (98698416 bp)
# chr NC_035785.1 (51258098 bp)
# chr NC_035786.1 (57830854 bp)
# chr NC_035787.1 (75944018 bp)
# chr NC_035788.1 (104168038 bp)
# chr NC_035789.1 (32650045 bp)
# chr NC_007175.2 (17244 bp)
#
# Stored sequence information of 11 chromosomes/scaffolds in total
#
# ==================================================================
# Mono- and di-nucleotide coverage will now be written into a report
# ==================================================================
#
# Could not find genomic nucleotide frequency table in the genome folder, calculating genomic frequencies (this may take several minutes depending on genome size) ...
# ====================================================================================================================================================================
# Processing chromosome >> NC_035784.1 <<
# Processing chromosome >> NC_035781.1 <<
# Processing chromosome >> NC_035783.1 <<
# Processing chromosome >> NC_035788.1 <<
# Processing chromosome >> NC_007175.2 <<
# Processing chromosome >> NC_035786.1 <<
# Processing chromosome >> NC_035782.1 <<
# Processing chromosome >> NC_035787.1 <<
# Processing chromosome >> NC_035780.1 <<
# Processing chromosome >> NC_035789.1 <<
# Processing chromosome >> NC_035785.1 <<
# Writing genomic nucleotide frequencies to the file >/Users/sr320/Dropbox/wd/18-03-15/genome/genomic_nucleotide_frequencies.txt< for future re-use
# Writing count of (di-)nucleotide: A	223134775
# Writing count of (di-)nucleotide: AA	80795037
# Writing count of (di-)nucleotide: AC	37359527
# Writing count of (di-)nucleotide: AG	35548672
# Writing count of (di-)nucleotide: AT	69431301
# Writing count of (di-)nucleotide: C	119229119
# Writing count of (di-)nucleotide: CA	45827414
# Writing count of (di-)nucleotide: CC	23444678
# Writing count of (di-)nucleotide: CG	14458703
# Writing count of (di-)nucleotide: CT	35498217
# Writing count of (di-)nucleotide: G	119267677
# Writing count of (di-)nucleotide: GA	38810489
# Writing count of (di-)nucleotide: GC	19646670
# Writing count of (di-)nucleotide: GG	23423030
# Writing count of (di-)nucleotide: GT	37387368
# Writing count of (di-)nucleotide: T	223043757
# Writing count of (di-)nucleotide: TA	57701608
# Writing count of (di-)nucleotide: TC	38778132
# Writing count of (di-)nucleotide: TG	45837169
# Writing count of (di-)nucleotide: TT	80726644
#
#
# Calculating read frequencies from file 'zr2096_10_s1_R1_val_1_bismark_bt2_pe.deduplicated.bam'
# ==========================================================================================
# Determined the file to be paired-end
#
#
# Printing nucleotide stats to >> zr2096_10_s1_R1_val_1_bismark_bt2_pe.deduplicated.nucleotide_stats.txt <<
# Final Stage: Calculating averages
# =================================
#
# (di-)nucleotide	count sample	percent sample	count genomic	percent genomic	coverage
# A	121078	27.46	223134775	32.59	0.001
# C	91381	20.72	119229119	17.41	0.001
# G	104758	23.75	119267677	17.42	0.001
# T	123788	28.07	223043757	32.58	0.001
# AA	35023	8.05	80795037	11.80	0.000
# AC	23859	5.48	37359527	5.46	0.001
# AG	29337	6.74	35548672	5.19	0.001
# AT	31180	7.17	69431301	10.14	0.000
# CA	29589	6.80	45827414	6.69	0.001
# CC	21478	4.94	23444678	3.42	0.001
# CG	13077	3.01	14458703	2.11	0.001
# CT	25981	5.97	35498217	5.18	0.001
# GA	31192	7.17	38810489	5.67	0.001
# GC	18062	4.15	19646670	2.87	0.001
# GG	26092	6.00	23423030	3.42	0.001
# GT	28026	6.44	37387368	5.46	0.001
# TA	23822	5.48	57701608	8.43	0.000
# TC	26760	6.15	38778132	5.66	0.001
# TG	34741	7.99	45837169	6.69	0.001
# TT	36831	8.47	80726644	11.79	0.000
# ==================================================================
# Mono- and di-nucleotide coverage will now be written into a report
# ==================================================================
#
# Detected file 'genomic_nucleotide_frequencies.txt' in the genome folder /Users/sr320/Dropbox/wd/18-03-15/genome/ already. Using nucleotide frequencies contained therein ...
# ============================================================================================================================================================================================
#
#
# Calculating read frequencies from file 'zr2096_1_s1_R1_val_1_bismark_bt2_pe.deduplicated.bam'
# ==========================================================================================
# Determined the file to be paired-end
#
#
# Printing nucleotide stats to >> zr2096_1_s1_R1_val_1_bismark_bt2_pe.deduplicated.nucleotide_stats.txt <<
# Final Stage: Calculating averages
# =================================
#
# (di-)nucleotide	count sample	percent sample	count genomic	percent genomic	coverage
# A	51573	28.40	223134775	32.59	0.000
# C	36192	19.93	119229119	17.41	0.000
# G	41190	22.68	119267677	17.42	0.000
# T	52632	28.98	223043757	32.58	0.000
# AA	15711	8.77	80795037	11.80	0.000
# AC	9799	5.47	37359527	5.46	0.000
# AG	11759	6.57	35548672	5.19	0.000
# AT	13584	7.58	69431301	10.14	0.000
# CA	12014	6.71	45827414	6.69	0.000
# CC	8170	4.56	23444678	3.42	0.000
# CG	4777	2.67	14458703	2.11	0.000
# CT	10747	6.00	35498217	5.18	0.000
# GA	12630	7.05	38810489	5.67	0.000
# GC	6973	3.89	19646670	2.87	0.000
# GG	9739	5.44	23423030	3.42	0.000
# GT	11329	6.33	37387368	5.46	0.000
# TA	10604	5.92	57701608	8.43	0.000
# TC	10777	6.02	38778132	5.66	0.000
# TG	14270	7.97	45837169	6.69	0.000
# TT	16228	9.06	80726644	11.79	0.000
# ==================================================================
# Mono- and di-nucleotide coverage will now be written into a report
# ==================================================================
#
# Detected file 'genomic_nucleotide_frequencies.txt' in the genome folder /Users/sr320/Dropbox/wd/18-03-15/genome/ already. Using nucleotide frequencies contained therein ...
# ============================================================================================================================================================================================
#
#
# Calculating read frequencies from file 'zr2096_2_s1_R1_val_1_bismark_bt2_pe.deduplicated.bam'
# ==========================================================================================
# Determined the file to be paired-end
#
#
# Printing nucleotide stats to >> zr2096_2_s1_R1_val_1_bismark_bt2_pe.deduplicated.nucleotide_stats.txt <<
# Final Stage: Calculating averages
# =================================
#
# (di-)nucleotide	count sample	percent sample	count genomic	percent genomic	coverage
# A	98812	27.31	223134775	32.59	0.000
# C	72957	20.16	119229119	17.41	0.001
# G	87596	24.21	119267677	17.42	0.001
# T	102479	28.32	223043757	32.58	0.000
# AA	28470	7.99	80795037	11.80	0.000
# AC	19359	5.43	37359527	5.46	0.001
# AG	24148	6.77	35548672	5.19	0.001
# AT	25435	7.13	69431301	10.14	0.000
# CA	23774	6.67	45827414	6.69	0.001
# CC	16884	4.74	23444678	3.42	0.001
# CG	10293	2.89	14458703	2.11	0.001
# CT	20932	5.87	35498217	5.18	0.001
# GA	26228	7.36	38810489	5.67	0.001
# GC	14500	4.07	19646670	2.87	0.001
# GG	22071	6.19	23423030	3.42	0.001
# GT	23534	6.60	37387368	5.46	0.001
# TA	19034	5.34	57701608	8.43	0.000
# TC	21157	5.93	38778132	5.66	0.001
# TG	29668	8.32	45837169	6.69	0.001
# TT	31043	8.71	80726644	11.79	0.000
# ==================================================================
# Mono- and di-nucleotide coverage will now be written into a report
# ==================================================================
#
# Detected file 'genomic_nucleotide_frequencies.txt' in the genome folder /Users/sr320/Dropbox/wd/18-03-15/genome/ already. Using nucleotide frequencies contained therein ...
# ============================================================================================================================================================================================
#
#
# Calculating read frequencies from file 'zr2096_3_s1_R1_val_1_bismark_bt2_pe.deduplicated.bam'
# ==========================================================================================
# Determined the file to be paired-end
#
#
# Printing nucleotide stats to >> zr2096_3_s1_R1_val_1_bismark_bt2_pe.deduplicated.nucleotide_stats.txt <<
# Final Stage: Calculating averages
# =================================
#
# (di-)nucleotide	count sample	percent sample	count genomic	percent genomic	coverage
# A	119301	27.09	223134775	32.59	0.001
# C	92563	21.02	119229119	17.41	0.001
# G	105861	24.04	119267677	17.42	0.001
# T	122661	27.85	223043757	32.58	0.001
# AA	33785	7.78	80795037	11.80	0.000
# AC	24532	5.65	37359527	5.46	0.001
# AG	29145	6.71	35548672	5.19	0.001
# AT	30251	6.97	69431301	10.14	0.000
# CA	29568	6.81	45827414	6.69	0.001
# CC	21931	5.05	23444678	3.42	0.001
# CG	13707	3.16	14458703	2.11	0.001
# CT	26029	5.99	35498217	5.18	0.001
# GA	31406	7.23	38810489	5.67	0.001
# GC	18209	4.19	19646670	2.87	0.001
# GG	26558	6.11	23423030	3.42	0.001
# GT	28267	6.51	37387368	5.46	0.001
# TA	23156	5.33	57701608	8.43	0.000
# TC	26626	6.13	38778132	5.66	0.001
# TG	34775	8.01	45837169	6.69	0.001
# TT	36368	8.37	80726644	11.79	0.000
# ==================================================================
# Mono- and di-nucleotide coverage will now be written into a report
# ==================================================================
#
# Detected file 'genomic_nucleotide_frequencies.txt' in the genome folder /Users/sr320/Dropbox/wd/18-03-15/genome/ already. Using nucleotide frequencies contained therein ...
# ============================================================================================================================================================================================
#
#
# Calculating read frequencies from file 'zr2096_4_s1_R1_val_1_bismark_bt2_pe.deduplicated.bam'
# ==========================================================================================
# Determined the file to be paired-end
#
#
# Printing nucleotide stats to >> zr2096_4_s1_R1_val_1_bismark_bt2_pe.deduplicated.nucleotide_stats.txt <<
# Final Stage: Calculating averages
# =================================
#
# (di-)nucleotide	count sample	percent sample	count genomic	percent genomic	coverage
# A	116684	27.98	223134775	32.59	0.001
# C	83569	20.04	119229119	17.41	0.001
# G	98421	23.60	119267677	17.42	0.001
# T	118422	28.39	223043757	32.58	0.001
# AA	34595	8.42	80795037	11.80	0.000
# AC	22542	5.48	37359527	5.46	0.001
# AG	28003	6.81	35548672	5.19	0.001
# AT	29907	7.27	69431301	10.14	0.000
# CA	27849	6.77	45827414	6.69	0.001
# CC	19482	4.74	23444678	3.42	0.001
# CG	11074	2.69	14458703	2.11	0.001
# CT	23928	5.82	35498217	5.18	0.001
# GA	29938	7.28	38810489	5.67	0.001
# GC	16216	3.94	19646670	2.87	0.001
# GG	24352	5.92	23423030	3.42	0.001
# GT	26494	6.44	37387368	5.46	0.001
# TA	22822	5.55	57701608	8.43	0.000
# TC	24135	5.87	38778132	5.66	0.001
# TG	33435	8.13	45837169	6.69	0.001
# TT	36338	8.84	80726644	11.79	0.000
# ==================================================================
# Mono- and di-nucleotide coverage will now be written into a report
# ==================================================================
#
# Detected file 'genomic_nucleotide_frequencies.txt' in the genome folder /Users/sr320/Dropbox/wd/18-03-15/genome/ already. Using nucleotide frequencies contained therein ...
# ============================================================================================================================================================================================
#
#
# Calculating read frequencies from file 'zr2096_5_s1_R1_val_1_bismark_bt2_pe.deduplicated.bam'
# ==========================================================================================
# Determined the file to be paired-end
#
#
# Printing nucleotide stats to >> zr2096_5_s1_R1_val_1_bismark_bt2_pe.deduplicated.nucleotide_stats.txt <<
# Final Stage: Calculating averages
# =================================
#
# (di-)nucleotide	count sample	percent sample	count genomic	percent genomic	coverage
# A	112593	28.00	223134775	32.59	0.001
# C	81198	20.19	119229119	17.41	0.001
# G	91793	22.82	119267677	17.42	0.001
# T	116583	28.99	223043757	32.58	0.001
# AA	32910	8.30	80795037	11.80	0.000
# AC	21844	5.51	37359527	5.46	0.001
# AG	26534	6.69	35548672	5.19	0.001
# AT	29823	7.52	69431301	10.14	0.000
# CA	27247	6.87	45827414	6.69	0.001
# CC	18675	4.71	23444678	3.42	0.001
# CG	10532	2.66	14458703	2.11	0.001
# CT	23593	5.95	35498217	5.18	0.001
# GA	27761	7.00	38810489	5.67	0.001
# GC	15657	3.95	19646670	2.87	0.001
# GG	21578	5.44	23423030	3.42	0.001
# GT	25565	6.44	37387368	5.46	0.001
# TA	23323	5.88	57701608	8.43	0.000
# TC	23957	6.04	38778132	5.66	0.001
# TG	31757	8.01	45837169	6.69	0.001
# TT	35911	9.05	80726644	11.79	0.000
# ==================================================================
# Mono- and di-nucleotide coverage will now be written into a report
# ==================================================================
#
# Detected file 'genomic_nucleotide_frequencies.txt' in the genome folder /Users/sr320/Dropbox/wd/18-03-15/genome/ already. Using nucleotide frequencies contained therein ...
# ============================================================================================================================================================================================
#
#
# Calculating read frequencies from file 'zr2096_6_s1_R1_val_1_bismark_bt2_pe.deduplicated.bam'
# ==========================================================================================
# Determined the file to be paired-end
#
#
# Printing nucleotide stats to >> zr2096_6_s1_R1_val_1_bismark_bt2_pe.deduplicated.nucleotide_stats.txt <<
# Final Stage: Calculating averages
# =================================
#
# (di-)nucleotide	count sample	percent sample	count genomic	percent genomic	coverage
# A	118321	27.92	223134775	32.59	0.001
# C	84497	19.94	119229119	17.41	0.001
# G	98886	23.33	119267677	17.42	0.001
# T	122128	28.82	223043757	32.58	0.001
# AA	34700	8.31	80795037	11.80	0.000
# AC	22808	5.46	37359527	5.46	0.001
# AG	28049	6.71	35548672	5.19	0.001
# AT	31099	7.44	69431301	10.14	0.000
# CA	28301	6.77	45827414	6.69	0.001
# CC	19025	4.55	23444678	3.42	0.001
# CG	11751	2.81	14458703	2.11	0.001
# CT	24228	5.80	35498217	5.18	0.001
# GA	29721	7.11	38810489	5.67	0.001
# GC	16464	3.94	19646670	2.87	0.001
# GG	23733	5.68	23423030	3.42	0.001
# GT	27514	6.59	37387368	5.46	0.001
# TA	24142	5.78	57701608	8.43	0.000
# TC	25011	5.99	38778132	5.66	0.001
# TG	33764	8.08	45837169	6.69	0.001
# TT	37493	8.97	80726644	11.79	0.000
# ==================================================================
# Mono- and di-nucleotide coverage will now be written into a report
# ==================================================================
#
# Detected file 'genomic_nucleotide_frequencies.txt' in the genome folder /Users/sr320/Dropbox/wd/18-03-15/genome/ already. Using nucleotide frequencies contained therein ...
# ============================================================================================================================================================================================
#
#
# Calculating read frequencies from file 'zr2096_7_s1_R1_val_1_bismark_bt2_pe.deduplicated.bam'
# ==========================================================================================
# Determined the file to be paired-end
#
#
# Printing nucleotide stats to >> zr2096_7_s1_R1_val_1_bismark_bt2_pe.deduplicated.nucleotide_stats.txt <<
# Final Stage: Calculating averages
# =================================
#
# (di-)nucleotide	count sample	percent sample	count genomic	percent genomic	coverage
# A	115161	28.22	223134775	32.59	0.001
# C	81384	19.95	119229119	17.41	0.001
# G	93814	22.99	119267677	17.42	0.001
# T	117661	28.84	223043757	32.58	0.001
# AA	34132	8.48	80795037	11.80	0.000
# AC	22375	5.56	37359527	5.46	0.001
# AG	26945	6.69	35548672	5.19	0.001
# AT	30170	7.50	69431301	10.14	0.000
# CA	27657	6.87	45827414	6.69	0.001
# CC	18536	4.61	23444678	3.42	0.001
# CG	10443	2.59	14458703	2.11	0.001
# CT	23627	5.87	35498217	5.18	0.001
# GA	28649	7.12	38810489	5.67	0.001
# GC	15455	3.84	19646670	2.87	0.001
# GG	22488	5.59	23423030	3.42	0.001
# GT	25971	6.45	37387368	5.46	0.001
# TA	23372	5.81	57701608	8.43	0.000
# TC	23911	5.94	38778132	5.66	0.001
# TG	32587	8.10	45837169	6.69	0.001
# TT	36189	8.99	80726644	11.79	0.000
# ==================================================================
# Mono- and di-nucleotide coverage will now be written into a report
# ==================================================================
#
# Detected file 'genomic_nucleotide_frequencies.txt' in the genome folder /Users/sr320/Dropbox/wd/18-03-15/genome/ already. Using nucleotide frequencies contained therein ...
# ============================================================================================================================================================================================
#
#
# Calculating read frequencies from file 'zr2096_8_s1_R1_val_1_bismark_bt2_pe.deduplicated.bam'
# ==========================================================================================
# Determined the file to be paired-end
#
#
# Printing nucleotide stats to >> zr2096_8_s1_R1_val_1_bismark_bt2_pe.deduplicated.nucleotide_stats.txt <<
# Final Stage: Calculating averages
# =================================
#
# (di-)nucleotide	count sample	percent sample	count genomic	percent genomic	coverage
# A	105115	28.28	223134775	32.59	0.000
# C	72701	19.56	119229119	17.41	0.001
# G	85417	22.98	119267677	17.42	0.001
# T	108429	29.17	223043757	32.58	0.000
# AA	31488	8.59	80795037	11.80	0.000
# AC	19659	5.36	37359527	5.46	0.001
# AG	24452	6.67	35548672	5.19	0.001
# AT	28073	7.66	69431301	10.14	0.000
# CA	24535	6.69	45827414	6.69	0.001
# CC	16663	4.55	23444678	3.42	0.001
# CG	9161	2.50	14458703	2.11	0.001
# CT	21346	5.82	35498217	5.18	0.001
# GA	26133	7.13	38810489	5.67	0.001
# GC	13849	3.78	19646670	2.87	0.001
# GG	20589	5.62	23423030	3.42	0.001
# GT	23740	6.48	37387368	5.46	0.001
# TA	21683	5.91	57701608	8.43	0.000
# TC	21575	5.88	38778132	5.66	0.001
# TG	29970	8.17	45837169	6.69	0.001
# TT	33697	9.19	80726644	11.79	0.000
# ==================================================================
# Mono- and di-nucleotide coverage will now be written into a report
# ==================================================================
#
# Detected file 'genomic_nucleotide_frequencies.txt' in the genome folder /Users/sr320/Dropbox/wd/18-03-15/genome/ already. Using nucleotide frequencies contained therein ...
# ============================================================================================================================================================================================
#
#
# Calculating read frequencies from file 'zr2096_9_s1_R1_val_1_bismark_bt2_pe.deduplicated.bam'
# ==========================================================================================
# Determined the file to be paired-end
#
#
# Printing nucleotide stats to >> zr2096_9_s1_R1_val_1_bismark_bt2_pe.deduplicated.nucleotide_stats.txt <<
# Final Stage: Calculating averages
# =================================
#
# (di-)nucleotide	count sample	percent sample	count genomic	percent genomic	coverage
# A	108975	26.91	223134775	32.59	0.000
# C	87189	21.53	119229119	17.41	0.001
# G	95790	23.65	119267677	17.42	0.001
# T	113028	27.91	223043757	32.58	0.001
# AA	30091	7.54	80795037	11.80	0.000
# AC	23028	5.77	37359527	5.46	0.001
# AG	26107	6.54	35548672	5.19	0.001
# AT	28199	7.06	69431301	10.14	0.000
# CA	28231	7.07	45827414	6.69	0.001
# CC	20334	5.09	23444678	3.42	0.001
# CG	12687	3.18	14458703	2.11	0.001
# CT	24700	6.19	35498217	5.18	0.001
# GA	27762	6.95	38810489	5.67	0.001
# GC	17284	4.33	19646670	2.87	0.001
# GG	23595	5.91	23423030	3.42	0.001
# GT	25815	6.46	37387368	5.46	0.001
# TA	21593	5.41	57701608	8.43	0.000
# TC	25325	6.34	38778132	5.66	0.001
# TG	31968	8.01	45837169	6.69	0.001
# TT	32628	8.17	80726644	11.79	0.000

# %%
y
# Out:
# ---------------------------------------------------------------
# NameError                     Traceback (most recent call last)
# <ipython-input-10-009520053b00> in <module>()
# ----> 1 y
#
# NameError: name 'y' is not defined

# %%
ls *.cov
# Out:
# zr2096_10_s1_R1_val_1_bismark_bt2_pe.deduplicated.bismark.cov
# zr2096_1_s1_R1_val_1_bismark_bt2_pe.deduplicated.bismark.cov
# zr2096_2_s1_R1_val_1_bismark_bt2_pe.deduplicated.bismark.cov
# zr2096_3_s1_R1_val_1_bismark_bt2_pe.deduplicated.bismark.cov
# zr2096_4_s1_R1_val_1_bismark_bt2_pe.deduplicated.bismark.cov
# zr2096_5_s1_R1_val_1_bismark_bt2_pe.deduplicated.bismark.cov
# zr2096_6_s1_R1_val_1_bismark_bt2_pe.deduplicated.bismark.cov
# zr2096_7_s1_R1_val_1_bismark_bt2_pe.deduplicated.bismark.cov
# zr2096_8_s1_R1_val_1_bismark_bt2_pe.deduplicated.bismark.cov
# zr2096_9_s1_R1_val_1_bismark_bt2_pe.deduplicated.bismark.cov

# %%
tabulate_tsvs.py blah1.cov blah2.cov blah3.cov -k 0 1 -c 4 5 -v \
> compiled_coverage.pre-filt.meth_unmeth.tsv

# %%
# !python /Users/sr320/Documents/GitHub/nb-2018/scripts/working_with_dna_meth-master/tabulate_tsvs.py \
*.cov \
-k 0 1 -c 4 5 -v \
> compiled_coverage.pre-filt.meth_unmeth.tsv
# Out:
# Files used: zr2096_10_s1_R1_val_1_bismark_bt2_pe.deduplicated.bismark.cov, zr2096_1_s1_R1_val_1_bismark_bt2_pe.deduplicated.bismark.cov, zr2096_2_s1_R1_val_1_bismark_bt2_pe.deduplicated.bismark.cov, zr2096_3_s1_R1_val_1_bismark_bt2_pe.deduplicated.bismark.cov, zr2096_4_s1_R1_val_1_bismark_bt2_pe.deduplicated.bismark.cov, zr2096_5_s1_R1_val_1_bismark_bt2_pe.deduplicated.bismark.cov, zr2096_6_s1_R1_val_1_bismark_bt2_pe.deduplicated.bismark.cov, zr2096_7_s1_R1_val_1_bismark_bt2_pe.deduplicated.bismark.cov, zr2096_8_s1_R1_val_1_bismark_bt2_pe.deduplicated.bismark.cov, zr2096_9_s1_R1_val_1_bismark_bt2_pe.deduplicated.bismark.cov
# Headers are NOT PRESENT.
# Reading file #10
# Union of all files produces 112270 rows.

# %%
# !gzip compiled_coverage.pre-filt.meth_unmeth.tsv

# %%
# !python /Users/sr320/Documents/GitHub/nb-2018/scripts/working_with_dna_meth-master/merge_bismark_cov.py \
*.cov > all.merged.cov

# %%
# !python /Users/sr320/Documents/GitHub/nb-2018/scripts/working_with_dna_meth-master/filter_miscalled_Cs.py \
all.merged.cov > all.bona_fide_meth_pos.cov

# %%
# !python /Users/sr320/Documents/GitHub/nb-2018/scripts/working_with_dna_meth-master/filter_pos.four_criteria.py
# Out:
# Checking positions that are considered bona fide (criteria IV)...
# Traceback (most recent call last):
#   File "/Users/sr320/Documents/GitHub/nb-2018/scripts/working_with_dna_meth-master/filter_pos.four_criteria.py", line 46, in <module>
#     scaf_size = int(scaf.split('size')[-1])
# ValueError: invalid literal for int() with base 10: 'NC_007175.2'
