# %%
ls /Volumes/Serine/wd/18-03-14/*fastq.gz
# Out:
# /Volumes/Serine/wd/18-03-14/10_32_S32_L001_R1_001.fastq.gz
# /Volumes/Serine/wd/18-03-14/10_32_S32_L001_R2_001.fastq.gz
# /Volumes/Serine/wd/18-03-14/11_37_S37_L001_R1_001.fastq.gz
# /Volumes/Serine/wd/18-03-14/11_37_S37_L001_R2_001.fastq.gz
# /Volumes/Serine/wd/18-03-14/12_38_S38_L001_R1_001.fastq.gz
# /Volumes/Serine/wd/18-03-14/12_38_S38_L001_R2_001.fastq.gz
# /Volumes/Serine/wd/18-03-14/13_33_S33_L001_R1_001.fastq.gz
# /Volumes/Serine/wd/18-03-14/13_33_S33_L001_R2_001.fastq.gz
# /Volumes/Serine/wd/18-03-14/14_34_S34_L001_R1_001.fastq.gz
# /Volumes/Serine/wd/18-03-14/14_34_S34_L001_R2_001.fastq.gz
# /Volumes/Serine/wd/18-03-14/15_39_S39_L001_R1_001.fastq.gz
# /Volumes/Serine/wd/18-03-14/15_39_S39_L001_R2_001.fastq.gz
# /Volumes/Serine/wd/18-03-14/16_40_S40_L001_R1_001.fastq.gz
# /Volumes/Serine/wd/18-03-14/16_40_S40_L001_R2_001.fastq.gz
# /Volumes/Serine/wd/18-03-14/17_9_S9_L001_R1_001.fastq.gz
# /Volumes/Serine/wd/18-03-14/17_9_S9_L001_R2_001.fastq.gz
# ...

# %%
cp /Volumes/Serine/wd/18-03-14/*fastq.gz /Volumes/Serine/wd/18-09-15/

# %%
cp /Volumes/Serine/wd/18-03-14/20_8_S8_L001_R1_001.fastq.gz .

# %%
cp /Volumes/Serine/wd/18-03-14/20_8_S8_L001_R2_001.fastq.gz .

# %%
ls -lh /Volumes/Serine/wd/18-09-15/
# Out:
# total 1957488
# -rw-r--r--  1 sr320  staff    29M Sep 14 12:55 10_32_S32_L001_R1_001.fastq.gz
# -rw-r--r--  1 sr320  staff    28M Sep 14 12:55 10_32_S32_L001_R2_001.fastq.gz
# -rw-r--r--  1 sr320  staff    35M Sep 14 12:55 11_37_S37_L001_R1_001.fastq.gz
# -rw-r--r--  1 sr320  staff    35M Sep 14 12:55 11_37_S37_L001_R2_001.fastq.gz
# -rw-r--r--  1 sr320  staff    43M Sep 14 12:55 12_38_S38_L001_R1_001.fastq.gz
# -rw-r--r--  1 sr320  staff    43M Sep 14 12:55 12_38_S38_L001_R2_001.fastq.gz
# -rw-r--r--  1 sr320  staff    32M Sep 14 12:55 13_33_S33_L001_R1_001.fastq.gz
# -rw-r--r--  1 sr320  staff    32M Sep 14 12:55 13_33_S33_L001_R2_001.fastq.gz
# -rw-r--r--  1 sr320  staff    34M Sep 14 12:55 14_34_S34_L001_R1_001.fastq.gz
# -rw-r--r--  1 sr320  staff    35M Sep 14 12:55 14_34_S34_L001_R2_001.fastq.gz
# -rw-r--r--  1 sr320  staff    33M Sep 14 12:55 15_39_S39_L001_R1_001.fastq.gz
# -rw-r--r--  1 sr320  staff    34M Sep 14 12:55 15_39_S39_L001_R2_001.fastq.gz
# ...

# %%
cd /Volumes/Serine/wd/18-09-15/
# Out:
# /Volumes/Serine/wd/18-09-15

# %%
ls
# Out:
# 10_32_S32_L001_R1_001.fastq.gz  17_9_S9_L001_R1_001.fastq.gz
# 10_32_S32_L001_R2_001.fastq.gz  17_9_S9_L001_R2_001.fastq.gz
# 11_37_S37_L001_R1_001.fastq.gz  18_10_S10_L001_R1_001.fastq.gz
# 11_37_S37_L001_R2_001.fastq.gz  18_10_S10_L001_R2_001.fastq.gz
# 12_38_S38_L001_R1_001.fastq.gz  19_7_S7_L001_R1_001.fastq.gz
# 12_38_S38_L001_R2_001.fastq.gz  19_7_S7_L001_R2_001.fastq.gz
# 13_33_S33_L001_R1_001.fastq.gz  1_25_S25_L001_R1_001.fastq.gz
# 13_33_S33_L001_R2_001.fastq.gz  1_25_S25_L001_R2_001.fastq.gz
# 14_34_S34_L001_R1_001.fastq.gz  7_29_S29_L001_R1_001.fastq.gz
# 14_34_S34_L001_R2_001.fastq.gz  7_29_S29_L001_R2_001.fastq.gz
# 15_39_S39_L001_R1_001.fastq.gz  8_30_S30_L001_R1_001.fastq.gz
# 15_39_S39_L001_R2_001.fastq.gz  8_30_S30_L001_R2_001.fastq.gz
# 16_40_S40_L001_R1_001.fastq.gz  9_31_S31_L001_R1_001.fastq.gz
# 16_40_S40_L001_R2_001.fastq.gz  9_31_S31_L001_R2_001.fastq.gz

# %%
pwd
# Out:
# u'/Volumes/Serine/wd/18-09-15'

# %%
# %%bash
# find /Volumes/Serine/wd/18-09-15/*_R1_001.fastq.gz \
# | xargs basename -s _L001_R1_001.fastq.gz | xargs -I{} /Applications/bioinfo/Bismark_v0.19.0/bismark \
# --path_to_bowtie /Applications/bioinfo/bowtie2-2.3.4.1-macos-x86_64 \
# --genome /Volumes/Serine/wd/18-03-15/genome \
# -u 100000 \
# --score_min L,0,-1.2 \
# -p 4 \
# --non_directional \
# -1 /Volumes/Serine/wd/18-09-15/{}_L001_R1_001.fastq.gz \
# -2 /Volumes/Serine/wd/18-09-15/{}_L001_R2_001.fastq.gz \
# 2> bismark.err
# Out:
# FastQ format assumed (by default)
# Each Bowtie 2 instance is going to be run with 4 threads. Please monitor performance closely and tune down if needed!
# chr NC_035780.1 (65668440 bp)
# chr NC_035781.1 (61752955 bp)
# chr NC_035782.1 (77061148 bp)
# chr NC_035783.1 (59691872 bp)
# chr NC_035784.1 (98698416 bp)
# chr NC_035785.1 (51258098 bp)
# chr NC_035786.1 (57830854 bp)
# chr NC_035787.1 (75944018 bp)
# chr NC_035788.1 (104168038 bp)
# chr NC_035789.1 (32650045 bp)
# chr NC_007175.2 (17244 bp)
#
# Number of paired-end alignments with a unique best hit:	25591
# Mapping efficiency:	25.6%
#
# Sequence pairs with no alignments under any condition:	62909
# Sequence pairs did not map uniquely:	11500
# Sequence pairs which were discarded because genomic sequence could not be extracted:	0
#
# Number of sequence pairs with unique best (first) alignment came from the bowtie output:
# CT/GA/CT:	4891	((converted) top strand)
# GA/CT/CT:	7949	(complementary to (converted) top strand)
# ...

# %%
# %%bash
#
# /Applications/bioinfo/Bismark_v0.19.0/deduplicate_bismark \
# --bam -p \
# *.bam \
# 2> dedup.err
# Out:
# Now testing Bismark result file 01_25_S25_L001_R1_001_bismark_bt2_pe.bam for positional sorting (which would be bad...)	skipping header line:	@HD	VN:1.0	SO:unsorted
# skipping header line:	@SQ	SN:NC_035780.1	LN:65668440
# skipping header line:	@SQ	SN:NC_035781.1	LN:61752955
# skipping header line:	@SQ	SN:NC_035782.1	LN:77061148
# skipping header line:	@SQ	SN:NC_035783.1	LN:59691872
# skipping header line:	@SQ	SN:NC_035784.1	LN:98698416
# skipping header line:	@SQ	SN:NC_035785.1	LN:51258098
# skipping header line:	@SQ	SN:NC_035786.1	LN:57830854
# skipping header line:	@SQ	SN:NC_035787.1	LN:75944018
# skipping header line:	@SQ	SN:NC_035788.1	LN:104168038
# skipping header line:	@SQ	SN:NC_035789.1	LN:32650045
# skipping header line:	@SQ	SN:NC_007175.2	LN:17244
# ...

# %%
# %%bash
# /Applications/bioinfo/Bismark_v0.19.0/bismark_methylation_extractor \
# -p --bedGraph --counts --scaffolds \
# --multicore 4 \
# *deduplicated.bam \
# 2> bme.err
# Out:
# Now testing Bismark result file 01_25_S25_L001_R1_001_bismark_bt2_pe.deduplicated.bam for positional sorting (which would be bad...)	01_25_S25_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.1
# 01_25_S25_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.2
# 01_25_S25_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.3
# 01_25_S25_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.4
#
# 01_25_S25_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.1.mbias
# 01_25_S25_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.2.mbias
# 01_25_S25_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.3.mbias
# 01_25_S25_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.4.mbias
#
# ...

# %%
# %%bash
# /Applications/bioinfo/Bismark_v0.19.0/bismark2report
# Out:
# Found 15 alignment reports in current directory. Now trying to figure out whether there are corresponding optional reports
#
# Writing Bismark HTML report to >> 01_25_S25_L001_R1_001_bismark_bt2_PE_report.html <<
#
# ...
# Using the following alignment report:		> 01_25_S25_L001_R1_001_bismark_bt2_PE_report.txt <
# Processing alignment report 01_25_S25_L001_R1_001_bismark_bt2_PE_report.txt ...
# Complete
#
# Using the following deduplication report:	> 01_25_S25_L001_R1_001_bismark_bt2_pe.deduplication_report.txt <
# Processing deduplication report 01_25_S25_L001_R1_001_bismark_bt2_pe.deduplication_report.txt ...
# Complete
#
# Using the following splitting report:		> 01_25_S25_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt <
# Processing splitting report 01_25_S25_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt ...
# Complete
#
# Using the following M-bias report:		> 01_25_S25_L001_R1_001_bismark_bt2_pe.deduplicated.M-bias.txt <
# ...

# %%
# %%bash
# /Applications/bioinfo/Bismark_v0.19.0/bismark2summary
# Out:
# No Bismark/Bowtie2 single-end BAM files detected
# Found Bismark/Bowtie2 paired-end files
# No Bismark/Bowtie single-end BAM files detected
# No Bismark/Bowtie paired-end BAM files detected
#
# Generating Bismark summary report from 15 Bismark BAM file(s)...
# >> Reading from Bismark report: 01_25_S25_L001_R1_001_bismark_bt2_PE_report.txt
# >> Reading from Bismark report: 07_29_S29_L001_R1_001_bismark_bt2_PE_report.txt
# >> Reading from Bismark report: 08_30_S30_L001_R1_001_bismark_bt2_PE_report.txt
# >> Reading from Bismark report: 09_31_S31_L001_R1_001_bismark_bt2_PE_report.txt
# >> Reading from Bismark report: 10_32_S32_L001_R1_001_bismark_bt2_PE_report.txt
# >> Reading from Bismark report: 11_37_S37_L001_R1_001_bismark_bt2_PE_report.txt
# >> Reading from Bismark report: 12_38_S38_L001_R1_001_bismark_bt2_PE_report.txt
# >> Reading from Bismark report: 13_33_S33_L001_R1_001_bismark_bt2_PE_report.txt
# >> Reading from Bismark report: 14_34_S34_L001_R1_001_bismark_bt2_PE_report.txt
# ...

# %%
# %%bash
# /Applications/bioinfo/Bismark_v0.20.0/bismark2summary
# Out:
# No Bismark/Bowtie2 single-end BAM files detected
# Found Bismark/Bowtie2 paired-end files
# No Bismark/Bowtie single-end BAM files detected
# No Bismark/Bowtie paired-end BAM files detected
#
# Generating Bismark summary report from 15 Bismark BAM file(s)...
# >> Reading from Bismark report: 01_25_S25_L001_R1_001_bismark_bt2_PE_report.txt
# >> Reading from Bismark report: 07_29_S29_L001_R1_001_bismark_bt2_PE_report.txt
# >> Reading from Bismark report: 08_30_S30_L001_R1_001_bismark_bt2_PE_report.txt
# >> Reading from Bismark report: 09_31_S31_L001_R1_001_bismark_bt2_PE_report.txt
# >> Reading from Bismark report: 10_32_S32_L001_R1_001_bismark_bt2_PE_report.txt
# >> Reading from Bismark report: 11_37_S37_L001_R1_001_bismark_bt2_PE_report.txt
# >> Reading from Bismark report: 12_38_S38_L001_R1_001_bismark_bt2_PE_report.txt
# >> Reading from Bismark report: 13_33_S33_L001_R1_001_bismark_bt2_PE_report.txt
# >> Reading from Bismark report: 14_34_S34_L001_R1_001_bismark_bt2_PE_report.txt
# ...

# %% [markdown]
# ![img](img/q-report4.png)

# %% [markdown]
# looking at coverage files
# `<chromosome> <start position> <end position> <methylation percentage> <count methylated> <count unmethylated>
# `

# %%
# !head -20 /Volumes/Serine/wd/18-09-15/07_29_S29_L001_R1_001_bismark_bt2_pe.deduplicated.bismark.cov
# Out:
# NC_007175.2	1826	1826	0	0	1
# NC_007175.2	1837	1837	0	0	1
# NC_007175.2	1843	1843	0	0	1
# NC_007175.2	1847	1847	0	0	1
# NC_007175.2	1855	1855	0	0	1
# NC_007175.2	1874	1874	0	0	1
# NC_007175.2	1919	1919	0	0	1
# NC_007175.2	2149	2149	0	0	14
# NC_007175.2	2181	2181	0	0	14
# NC_007175.2	2182	2182	0	0	12
# NC_007175.2	2207	2207	0	0	13
# NC_007175.2	2208	2208	0	0	13
# NC_007175.2	2238	2238	0	0	14
# NC_007175.2	2239	2239	0	0	13
# NC_007175.2	2266	2266	0	0	10
# NC_007175.2	2267	2267	0	0	12
# NC_007175.2	2283	2283	0	0	9
# NC_007175.2	2284	2284	0	0	12
# NC_007175.2	2302	2302	9.09090909090909	1	10
# NC_007175.2	2305	2305	50	1	1

# %%
# !awk '{print $1, $2, $5+$6}' 07_29_S29_L001_R1_001_bismark_bt2_pe.deduplicated.bismark.cov \
| head -20
# Out:
# NC_007175.2 1826 1
# NC_007175.2 1837 1
# NC_007175.2 1843 1
# NC_007175.2 1847 1
# NC_007175.2 1855 1
# NC_007175.2 1874 1
# NC_007175.2 1919 1
# NC_007175.2 2149 14
# NC_007175.2 2181 14
# NC_007175.2 2182 12
# NC_007175.2 2207 13
# NC_007175.2 2208 13
# NC_007175.2 2238 14
# NC_007175.2 2239 13
# NC_007175.2 2266 10
# NC_007175.2 2267 12
# NC_007175.2 2283 9
# NC_007175.2 2284 12
# NC_007175.2 2302 11
# NC_007175.2 2305 2
# awk: write error on /dev/stdout
#  input record number 1549, file 07_29_S29_L001_R1_001_bismark_bt2_pe.deduplicated.bismark.cov
#  source line number 1

# %%
# !awk '{print $1, $2, $5+$6}' 07_29_S29_L001_R1_001_bismark_bt2_pe.deduplicated.bismark.cov \
| awk '{if ($3 > 10) { print }}' \
| head -20
# Out:
# NC_007175.2 2149 14
# NC_007175.2 2181 14
# NC_007175.2 2182 12
# NC_007175.2 2207 13
# NC_007175.2 2208 13
# NC_007175.2 2238 14
# NC_007175.2 2239 13
# NC_007175.2 2267 12
# NC_007175.2 2284 12
# NC_007175.2 2302 11
# NC_007175.2 2998 15
# NC_007175.2 3022 16
# NC_007175.2 3030 17
# NC_007175.2 3060 18
# NC_007175.2 3063 19
# NC_007175.2 14084 16
# NC_007175.2 14314 12
# NC_035780.1 988 12
# NC_035780.1 989 15
# NC_035780.1 1054 15

# %%
ls *pe.deduplicated.bismark.c*
# Out:
# 01_25_S25_L001_R1_001_bismark_bt2_pe.deduplicated.bismark.cov
# 01_25_S25_L001_R1_001_bismark_bt2_pe.deduplicated.bismark.cov.gz
# 07_29_S29_L001_R1_001_bismark_bt2_pe.deduplicated.bismark.cov
# 07_29_S29_L001_R1_001_bismark_bt2_pe.deduplicated.bismark.cov.gz
# 08_30_S30_L001_R1_001_bismark_bt2_pe.deduplicated.bismark.cov.gz
# 09_31_S31_L001_R1_001_bismark_bt2_pe.deduplicated.bismark.cov.gz
# 10_32_S32_L001_R1_001_bismark_bt2_pe.deduplicated.bismark.cov.gz
# 11_37_S37_L001_R1_001_bismark_bt2_pe.deduplicated.bismark.cov.gz
# 12_38_S38_L001_R1_001_bismark_bt2_pe.deduplicated.bismark.cov.gz
# 13_33_S33_L001_R1_001_bismark_bt2_pe.deduplicated.bismark.cov.gz
# 14_34_S34_L001_R1_001_bismark_bt2_pe.deduplicated.bismark.cov.gz
# 15_39_S39_L001_R1_001_bismark_bt2_pe.deduplicated.bismark.cov.gz
# 16_40_S40_L001_R1_001_bismark_bt2_pe.deduplicated.bismark.cov.gz
# 17_9_S9_L001_R1_001_bismark_bt2_pe.deduplicated.bismark.cov.gz
# 18_10_S10_L001_R1_001_bismark_bt2_pe.deduplicated.bismark.cov.gz
# ...

# %%
# %%bash
# find *deduplicated.bismark.cov.gz \
# | xargs basename -s .gz | xargs -I{} gunzip -k {}.gz
# Out:
# gunzip: 01_25_S25_L001_R1_001_bismark_bt2_pe.deduplicated.bismark.cov already exists -- skipping
# gunzip: 07_29_S29_L001_R1_001_bismark_bt2_pe.deduplicated.bismark.cov already exists -- skipping
# gunzip: 20_8_S8_L001_R1_001_bismark_bt2_pe.deduplicated.bismark.cov already exists -- skipping

# %%
ls *pe.deduplicated.bismark.c*
# Out:
# 01_25_S25_L001_R1_001_bismark_bt2_pe.deduplicated.bismark.cov
# 01_25_S25_L001_R1_001_bismark_bt2_pe.deduplicated.bismark.cov.gz
# 07_29_S29_L001_R1_001_bismark_bt2_pe.deduplicated.bismark.cov
# 07_29_S29_L001_R1_001_bismark_bt2_pe.deduplicated.bismark.cov.gz
# 08_30_S30_L001_R1_001_bismark_bt2_pe.deduplicated.bismark.cov
# 08_30_S30_L001_R1_001_bismark_bt2_pe.deduplicated.bismark.cov.gz
# 09_31_S31_L001_R1_001_bismark_bt2_pe.deduplicated.bismark.cov
# 09_31_S31_L001_R1_001_bismark_bt2_pe.deduplicated.bismark.cov.gz
# 10_32_S32_L001_R1_001_bismark_bt2_pe.deduplicated.bismark.cov
# 10_32_S32_L001_R1_001_bismark_bt2_pe.deduplicated.bismark.cov.gz
# 11_37_S37_L001_R1_001_bismark_bt2_pe.deduplicated.bismark.cov
# 11_37_S37_L001_R1_001_bismark_bt2_pe.deduplicated.bismark.cov.gz
# 12_38_S38_L001_R1_001_bismark_bt2_pe.deduplicated.bismark.cov
# 12_38_S38_L001_R1_001_bismark_bt2_pe.deduplicated.bismark.cov.gz
# 13_33_S33_L001_R1_001_bismark_bt2_pe.deduplicated.bismark.cov
# ...

# %%
# %%bash
# find *deduplicated.bismark.cov \
# | xargs basename -s .cov | xargs -I{} awk '{print $1, $2, $5+$6}' {}.cov \
# | awk '{if ($3 > 10) { print }}' | wc -l
# Out:
#      346

# %%
# %%bash
# find *deduplicated.bismark.cov \
# | xargs basename -s .cov | xargs -I{} awk '{print $1, $2, $5+$6}' {}.cov | wc -l
# Out:
#  2407830

# %%
pwd
# Out:
# '/Users/sr320/Documents/GitHub/nb-2018/C_virginica'

# %%
# %%bash
# for f in analyses/*.cov
# do
#     awk '{print $1, $2, $5+$6}' ${f} | awk '{if ($3 >= 10) { print }}' | wc -l
# done
# Out:
#       17
#      227
#      169
#       10
#        8
#        5
#        7
#        9
#       22
#       12
#        8
#        0
#        0
#        0
#        8

# %%
# %%bash
# for f in analyses/*.cov
# do
#     echo $f
#     awk '{print $1, $2, $5+$6}' ${f} | awk '{if ($3 >= 10) { print }}' | head -2
# done
# Out:
# analyses/01_25_S25_L001_R1_001_bismark_bt2_pe.deduplicated.bismark.cov
# NC_035780.1 22843741 10
# NC_035780.1 22843778 10
# analyses/07_29_S29_L001_R1_001_bismark_bt2_pe.deduplicated.bismark.cov
# NC_007175.2 2149 14
# NC_007175.2 2181 14
# analyses/08_30_S30_L001_R1_001_bismark_bt2_pe.deduplicated.bismark.cov
# NC_007175.2 2149 11
# NC_007175.2 2181 12
# analyses/09_31_S31_L001_R1_001_bismark_bt2_pe.deduplicated.bismark.cov
# NC_035780.1 30387637 11
# NC_035780.1 30387651 12
# analyses/10_32_S32_L001_R1_001_bismark_bt2_pe.deduplicated.bismark.cov
# NC_035780.1 30387940 10
# NC_035784.1 96593953 12
# analyses/11_37_S37_L001_R1_001_bismark_bt2_pe.deduplicated.bismark.cov
# NC_035780.1 30387818 12
# NC_035780.1 30387861 10
# analyses/12_38_S38_L001_R1_001_bismark_bt2_pe.deduplicated.bismark.cov
# NC_035784.1 6741185 10
# NC_035784.1 6741191 10
# analyses/13_33_S33_L001_R1_001_bismark_bt2_pe.deduplicated.bismark.cov
# NC_035781.1 637932 14
# NC_035784.1 6741185 13
# ...

# %%
# %%bash
# for f in analyses/*.cov
# do
#     #echo $f
#     awk '{print $1, $2, $5+$6}' ${f} | awk '{if ($3 >= 3) { print }}' | wc -l
# done
# Out:
#      742
#     5153
#     3943
#     1170
#     1037
#      496
#      582
#      873
#     1146
#      807
#      741
#       27
#       68
#       98
#      813

# %%
# %%bash
# find *deduplicated.bismark.cov \
# | xargs basename -s _L001_R1_001_bismark_bt2_pe.deduplicated.bismark.cov | xargs -I{} echo {}
# Out:
# 01_25_S25
# 07_29_S29
# 08_30_S30
# 09_31_S31
# 10_32_S32
# 11_37_S37
# 12_38_S38
# 13_33_S33
# 14_34_S34
# 15_39_S39
# 16_40_S40
# 17_9_S9
# 18_10_S10
# 19_7_S7
# 20_8_S8

# %%
# !ls analyses/01*cov
# Out:
# analyses/01_25_S25_L001_R1_001_bismark_bt2_pe.deduplicated.bismark.cov

# %%
# !head analyses/01_25_S25_L001_R1_001_bismark_bt2_pe.deduplicated.bismark.cov
# Out:
# NC_007175.2	257	257	0	0	1
# NC_007175.2	264	264	0	0	1
# NC_007175.2	266	266	0	0	1
# NC_007175.2	367	367	0	0	1
# NC_007175.2	725	725	0	0	3
# NC_007175.2	857	857	0	0	1
# NC_007175.2	870	870	0	0	1
# NC_007175.2	977	977	0	0	1
# NC_007175.2	996	996	0	0	1
# NC_007175.2	1011	1011	0	0	1

# %% [markdown]
# ```
# NC_007175.2	88	89	0
# NC_007175.2	147	148	0
# NC_007175.2	192	193	0
# NC_007175.2	193	194	0
# NC_007175.2	256	257	0
# NC_007175.2	263	264	0
# NC_007175.2	265	266	0
# NC_007175.2	366	367	0
# NC_007175.2	472	473	0
# ```

# %% [markdown]
# `<chromosome> <start position> <end position> <methylation percentage> <count methylated> <count unmethylated>`

# %%
# %%bash
# for f in analyses/*.cov
# do
#     echo $f
#     head $f
# done
# Out:
# analyses/01_25_S25_L001_R1_001_bismark_bt2_pe.deduplicated.bismark.cov
# NC_007175.2	257	257	0	0	1
# NC_007175.2	264	264	0	0	1
# NC_007175.2	266	266	0	0	1
# NC_007175.2	367	367	0	0	1
# NC_007175.2	725	725	0	0	3
# NC_007175.2	857	857	0	0	1
# NC_007175.2	870	870	0	0	1
# NC_007175.2	977	977	0	0	1
# NC_007175.2	996	996	0	0	1
# NC_007175.2	1011	1011	0	0	1
# analyses/07_29_S29_L001_R1_001_bismark_bt2_pe.deduplicated.bismark.cov
# NC_007175.2	1826	1826	0	0	1
# NC_007175.2	1837	1837	0	0	1
# NC_007175.2	1843	1843	0	0	1
# NC_007175.2	1847	1847	0	0	1
# NC_007175.2	1855	1855	0	0	1
# NC_007175.2	1874	1874	0	0	1
# NC_007175.2	1919	1919	0	0	1
# NC_007175.2	2149	2149	0	0	14
# NC_007175.2	2181	2181	0	0	14
# NC_007175.2	2182	2182	0	0	12
# analyses/08_30_S30_L001_R1_001_bismark_bt2_pe.deduplicated.bismark.cov
# NC_007175.2	49	49	0	0	1
# NC_007175.2	51	51	0	0	1
# NC_007175.2	88	88	0	0	1
# NC_007175.2	147	147	0	0	1
# NC_007175.2	1291	1291	0	0	1
# NC_007175.2	1440	1440	0	0	1
# NC_007175.2	1445	1445	0	0	1
# ...

# %%
# %%bash
# for f in analyses/*.cov
# do
#     echo $f
#     awk '{print $1, $2-1, $2, $4, $5+$6}' ${f} | awk '{if ($5 >= 3) { print $1, $2-1, $2, $4 }}' | head
# done
# Out:
# analyses/01_25_S25_L001_R1_001_bismark_bt2_pe.deduplicated.bismark.cov
# NC_007175.2 723 724 0
# NC_007175.2 1096 1097 0
# NC_007175.2 1097 1098 0
# NC_007175.2 1105 1106 0
# NC_007175.2 1123 1124 0
# NC_007175.2 2147 2148 0
# NC_007175.2 2179 2180 0
# NC_007175.2 2205 2206 0
# NC_007175.2 2236 2237 0
# NC_007175.2 2264 2265 0
# analyses/07_29_S29_L001_R1_001_bismark_bt2_pe.deduplicated.bismark.cov
# NC_007175.2 2147 2148 0
# NC_007175.2 2179 2180 0
# NC_007175.2 2180 2181 0
# NC_007175.2 2205 2206 0
# NC_007175.2 2206 2207 0
# NC_007175.2 2236 2237 0
# NC_007175.2 2237 2238 0
# NC_007175.2 2264 2265 0
# NC_007175.2 2265 2266 0
# NC_007175.2 2281 2282 0
# analyses/08_30_S30_L001_R1_001_bismark_bt2_pe.deduplicated.bismark.cov
# NC_007175.2 2147 2148 0
# NC_007175.2 2179 2180 0
# NC_007175.2 2180 2181 0
# NC_007175.2 2205 2206 0
# NC_007175.2 2206 2207 0
# NC_007175.2 2236 2237 0
# NC_007175.2 2237 2238 0
# NC_007175.2 2264 2265 0
# NC_007175.2 2265 2266 0
# NC_007175.2 2281 2282 0
# ...

# %%
# %%bash
# for f in analyses/*.cov
# do
#     awk '{print $1, $2-1, $2, $4, $5+$6}' ${f} | awk '{if ($5 >= 3) { print $1, $2-1, $2, $4 }}' \
# > ${f}_3x.bedgraph
# done

# %%
cat analyses/*3x* | wc -l
# Out:
#    17696

# %%
ls analyses/*3x* | sed 's/_L001_R1_001_bismark_bt2_pe.deduplicated.bismark.cov_/_/g'
# Out:
# analyses/01_25_S25_3x.bedgraph
# analyses/07_29_S29_3x.bedgraph
# analyses/08_30_S30_3x.bedgraph
# analyses/09_31_S31_3x.bedgraph
# analyses/10_32_S32_3x.bedgraph
# analyses/11_37_S37_3x.bedgraph
# analyses/12_38_S38_3x.bedgraph
# analyses/13_33_S33_3x.bedgraph
# analyses/14_34_S34_3x.bedgraph
# analyses/15_39_S39_3x.bedgraph
# analyses/16_40_S40_3x.bedgraph
# analyses/17_9_S9_3x.bedgraph
# analyses/18_10_S10_3x.bedgraph
# analyses/19_7_S7_3x.bedgraph
# analyses/20_8_S8_3x.bedgraph
