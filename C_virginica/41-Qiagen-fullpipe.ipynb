# %% [markdown]
# # Set working directory

# %%
wd="/Volumes/Serine/wd/18-07-30"

# %%
mkdir $wd
# Out:
# mkdir: /Volumes/Serine/wd/18-07-30: File exists

# %%
cd $wd
# Out:
# /Volumes/Serine/wd/18-07-30

# %%
# !/Applications/bioinfo/FastQC/fastqc -h
# Out:
#             FastQC - A high throughput sequence QC analysis tool
#
# SYNOPSIS
#
# 	fastqc seqfile1 seqfile2 .. seqfileN
#
#     fastqc [-o output dir] [--(no)extract] [-f fastq|bam|sam]
#            [-c contaminant file] seqfile1 .. seqfileN
#
# DESCRIPTION
#
#     FastQC reads a set of sequence files and produces from each one a quality
#     control report consisting of a number of different modules, each one of
#     which will help to identify a different potential type of problem in your
#     data.
#
#     If no files to process are specified on the command line then the program
#     will start as an interactive graphical application.  If files are provided
#     on the command line then the program will run with no user interaction
#     required.  In this mode it is suitable for inclusion into a standardised
#     analysis pipeline.
#
#     The options for the program as as follows:
#
#     -h --help       Print this help file and exit
#
#     -v --version    Print the version of the program and exit
#
#     -o --outdir     Create all output files in the specified output directory.
#                     Please note that this directory must exist as the program
#                     will not create it.  If this option is not set then the
#                     output file for each sequence file is created in the same
#                     directory as the sequence file which was processed.
#
#     --casava        Files come from raw casava output. Files in the same sample
#                     group (differing only by the group number) will be analysed
#                     as a set rather than individually. Sequences with the filter
#                     flag set in the header will be excluded from the analysis.
#                     Files must have the same names given to them by casava
#                     (including being gzipped and ending with .gz) otherwise they
#                     won't be grouped together correctly.
#
#     --nano          Files come from naopore sequences and are in fast5 format. In
#                     this mode you can pass in directories to process and the program
#                     will take in all fast5 files within those directories and produce
#                     a single output file from the sequences found in all files.
#
#     --nofilter      If running with --casava then don't remove read flagged by
#                     casava as poor quality when performing the QC analysis.
#
#     --extract       If set then the zipped output file will be uncompressed in
#                     the same directory after it has been created.  By default
#                     this option will be set if fastqc is run in non-interactive
#                     mode.
#
#     -j --java       Provides the full path to the java binary you want to use to
#                     launch fastqc. If not supplied then java is assumed to be in
#                     your path.
#
#     --noextract     Do not uncompress the output file after creating it.  You
#                     should set this option if you do not wish to uncompress
#                     the output when running in non-interactive mode.
#
#     --nogroup       Disable grouping of bases for reads >50bp. All reports will
#                     show data for every base in the read.  WARNING: Using this
#                     option will cause fastqc to crash and burn if you use it on
#                     really long reads, and your plots may end up a ridiculous size.
#                     You have been warned!
#
#     -f --format     Bypasses the normal sequence file format detection and
#                     forces the program to use the specified format.  Valid
#                     formats are bam,sam,bam_mapped,sam_mapped and fastq
#
#     -t --threads    Specifies the number of files which can be processed
#                     simultaneously.  Each thread will be allocated 250MB of
#                     memory so you shouldn't run more threads than your
#                     available memory will cope with, and not more than
#                     6 threads on a 32 bit machine
#
#     -c              Specifies a non-default file which contains the list of
#     --contaminants  contaminants to screen overrepresented sequences against.
#                     The file must contain sets of named contaminants in the
#                     form name[tab]sequence.  Lines prefixed with a hash will
#                     be ignored.
#
#     -a              Specifies a non-default file which contains the list of
#     --adapters      adapter sequences which will be explicity searched against
#                     the library. The file must contain sets of named adapters
#                     in the form name[tab]sequence.  Lines prefixed with a hash
#                     will be ignored.
#
#     -l              Specifies a non-default file which contains a set of criteria
#     --limits        which will be used to determine the warn/error limits for the
#                     various modules.  This file can also be used to selectively
#                     remove some modules from the output all together.  The format
#                     needs to mirror the default limits.txt file found in the
#                     Configuration folder.
#
#    -k --kmers       Specifies the length of Kmer to look for in the Kmer content
#                     module. Specified Kmer length must be between 2 and 10. Default
#                     length is 7 if not specified.
#
#    -q --quiet       Supress all progress messages on stdout and only report errors.
#
#    -d --dir         Selects a directory to be used for temporary files written when
#                     generating report images. Defaults to system temp directory if
#                     not specified.
#
# BUGS
#
#     Any bugs in fastqc should be reported either to simon.andrews@babraham.ac.uk
#     or in www.bioinformatics.babraham.ac.uk/bugzilla/

# %%
mkdir qc

# %%
# !/Applications/bioinfo/FastQC/fastqc /Volumes/Serine/wd/18-03-14/*.fastq.gz \
--outdir qc/
# Out:
# Started analysis of 10_32_S32_L001_R1_001.fastq.gz
# Approx 5% complete for 10_32_S32_L001_R1_001.fastq.gz
# Approx 10% complete for 10_32_S32_L001_R1_001.fastq.gz
# Approx 15% complete for 10_32_S32_L001_R1_001.fastq.gz
# Approx 20% complete for 10_32_S32_L001_R1_001.fastq.gz
# Approx 25% complete for 10_32_S32_L001_R1_001.fastq.gz
# Approx 30% complete for 10_32_S32_L001_R1_001.fastq.gz
# Approx 35% complete for 10_32_S32_L001_R1_001.fastq.gz
# Approx 40% complete for 10_32_S32_L001_R1_001.fastq.gz
# Approx 45% complete for 10_32_S32_L001_R1_001.fastq.gz
# Approx 50% complete for 10_32_S32_L001_R1_001.fastq.gz
# Approx 55% complete for 10_32_S32_L001_R1_001.fastq.gz
# Approx 60% complete for 10_32_S32_L001_R1_001.fastq.gz
# Approx 65% complete for 10_32_S32_L001_R1_001.fastq.gz
# Approx 70% complete for 10_32_S32_L001_R1_001.fastq.gz
# Approx 75% complete for 10_32_S32_L001_R1_001.fastq.gz
# Approx 80% complete for 10_32_S32_L001_R1_001.fastq.gz
# Approx 85% complete for 10_32_S32_L001_R1_001.fastq.gz
# Approx 90% complete for 10_32_S32_L001_R1_001.fastq.gz
# Approx 95% complete for 10_32_S32_L001_R1_001.fastq.gz
# Analysis complete for 10_32_S32_L001_R1_001.fastq.gz
# Started analysis of 10_32_S32_L001_R2_001.fastq.gz
# Approx 5% complete for 10_32_S32_L001_R2_001.fastq.gz
# Approx 10% complete for 10_32_S32_L001_R2_001.fastq.gz
# Approx 15% complete for 10_32_S32_L001_R2_001.fastq.gz
# Approx 20% complete for 10_32_S32_L001_R2_001.fastq.gz
# Approx 25% complete for 10_32_S32_L001_R2_001.fastq.gz
# Approx 30% complete for 10_32_S32_L001_R2_001.fastq.gz
# Approx 35% complete for 10_32_S32_L001_R2_001.fastq.gz
# Approx 40% complete for 10_32_S32_L001_R2_001.fastq.gz
# Approx 45% complete for 10_32_S32_L001_R2_001.fastq.gz
# Approx 50% complete for 10_32_S32_L001_R2_001.fastq.gz
# Approx 55% complete for 10_32_S32_L001_R2_001.fastq.gz
# Approx 60% complete for 10_32_S32_L001_R2_001.fastq.gz
# Approx 65% complete for 10_32_S32_L001_R2_001.fastq.gz
# Approx 70% complete for 10_32_S32_L001_R2_001.fastq.gz
# Approx 75% complete for 10_32_S32_L001_R2_001.fastq.gz
# Approx 80% complete for 10_32_S32_L001_R2_001.fastq.gz
# Approx 85% complete for 10_32_S32_L001_R2_001.fastq.gz
# Approx 90% complete for 10_32_S32_L001_R2_001.fastq.gz
# Approx 95% complete for 10_32_S32_L001_R2_001.fastq.gz
# Analysis complete for 10_32_S32_L001_R2_001.fastq.gz
# Started analysis of 11_37_S37_L001_R1_001.fastq.gz
# Approx 5% complete for 11_37_S37_L001_R1_001.fastq.gz
# Approx 10% complete for 11_37_S37_L001_R1_001.fastq.gz
# Approx 15% complete for 11_37_S37_L001_R1_001.fastq.gz
# Approx 20% complete for 11_37_S37_L001_R1_001.fastq.gz
# Approx 25% complete for 11_37_S37_L001_R1_001.fastq.gz
# Approx 30% complete for 11_37_S37_L001_R1_001.fastq.gz
# Approx 35% complete for 11_37_S37_L001_R1_001.fastq.gz
# Approx 40% complete for 11_37_S37_L001_R1_001.fastq.gz
# Approx 45% complete for 11_37_S37_L001_R1_001.fastq.gz
# Approx 50% complete for 11_37_S37_L001_R1_001.fastq.gz
# Approx 55% complete for 11_37_S37_L001_R1_001.fastq.gz
# Approx 60% complete for 11_37_S37_L001_R1_001.fastq.gz
# Approx 65% complete for 11_37_S37_L001_R1_001.fastq.gz
# Approx 70% complete for 11_37_S37_L001_R1_001.fastq.gz
# Approx 75% complete for 11_37_S37_L001_R1_001.fastq.gz
# Approx 80% complete for 11_37_S37_L001_R1_001.fastq.gz
# Approx 85% complete for 11_37_S37_L001_R1_001.fastq.gz
# Approx 90% complete for 11_37_S37_L001_R1_001.fastq.gz
# Approx 95% complete for 11_37_S37_L001_R1_001.fastq.gz
# Analysis complete for 11_37_S37_L001_R1_001.fastq.gz
# Started analysis of 11_37_S37_L001_R2_001.fastq.gz
# Approx 5% complete for 11_37_S37_L001_R2_001.fastq.gz
# Approx 10% complete for 11_37_S37_L001_R2_001.fastq.gz
# Approx 15% complete for 11_37_S37_L001_R2_001.fastq.gz
# Approx 20% complete for 11_37_S37_L001_R2_001.fastq.gz
# Approx 25% complete for 11_37_S37_L001_R2_001.fastq.gz
# Approx 30% complete for 11_37_S37_L001_R2_001.fastq.gz
# Approx 35% complete for 11_37_S37_L001_R2_001.fastq.gz
# Approx 40% complete for 11_37_S37_L001_R2_001.fastq.gz
# Approx 45% complete for 11_37_S37_L001_R2_001.fastq.gz
# Approx 50% complete for 11_37_S37_L001_R2_001.fastq.gz
# Approx 55% complete for 11_37_S37_L001_R2_001.fastq.gz
# Approx 60% complete for 11_37_S37_L001_R2_001.fastq.gz
# Approx 65% complete for 11_37_S37_L001_R2_001.fastq.gz
# Approx 70% complete for 11_37_S37_L001_R2_001.fastq.gz
# Approx 75% complete for 11_37_S37_L001_R2_001.fastq.gz
# Approx 80% complete for 11_37_S37_L001_R2_001.fastq.gz
# Approx 85% complete for 11_37_S37_L001_R2_001.fastq.gz
# Approx 90% complete for 11_37_S37_L001_R2_001.fastq.gz
# Approx 95% complete for 11_37_S37_L001_R2_001.fastq.gz
# Analysis complete for 11_37_S37_L001_R2_001.fastq.gz
# Started analysis of 12_38_S38_L001_R1_001.fastq.gz
# Approx 5% complete for 12_38_S38_L001_R1_001.fastq.gz
# Approx 10% complete for 12_38_S38_L001_R1_001.fastq.gz
# Approx 15% complete for 12_38_S38_L001_R1_001.fastq.gz
# Approx 20% complete for 12_38_S38_L001_R1_001.fastq.gz
# Approx 25% complete for 12_38_S38_L001_R1_001.fastq.gz
# Approx 30% complete for 12_38_S38_L001_R1_001.fastq.gz
# Approx 35% complete for 12_38_S38_L001_R1_001.fastq.gz
# Approx 40% complete for 12_38_S38_L001_R1_001.fastq.gz
# Approx 45% complete for 12_38_S38_L001_R1_001.fastq.gz
# Approx 50% complete for 12_38_S38_L001_R1_001.fastq.gz
# Approx 55% complete for 12_38_S38_L001_R1_001.fastq.gz
# Approx 60% complete for 12_38_S38_L001_R1_001.fastq.gz
# Approx 65% complete for 12_38_S38_L001_R1_001.fastq.gz
# Approx 70% complete for 12_38_S38_L001_R1_001.fastq.gz
# Approx 75% complete for 12_38_S38_L001_R1_001.fastq.gz
# Approx 80% complete for 12_38_S38_L001_R1_001.fastq.gz
# Approx 85% complete for 12_38_S38_L001_R1_001.fastq.gz
# Approx 90% complete for 12_38_S38_L001_R1_001.fastq.gz
# Approx 95% complete for 12_38_S38_L001_R1_001.fastq.gz
# Analysis complete for 12_38_S38_L001_R1_001.fastq.gz
# Started analysis of 12_38_S38_L001_R2_001.fastq.gz
# Approx 5% complete for 12_38_S38_L001_R2_001.fastq.gz
# Approx 10% complete for 12_38_S38_L001_R2_001.fastq.gz
# Approx 15% complete for 12_38_S38_L001_R2_001.fastq.gz
# Approx 20% complete for 12_38_S38_L001_R2_001.fastq.gz
# Approx 25% complete for 12_38_S38_L001_R2_001.fastq.gz
# Approx 30% complete for 12_38_S38_L001_R2_001.fastq.gz
# Approx 35% complete for 12_38_S38_L001_R2_001.fastq.gz
# Approx 40% complete for 12_38_S38_L001_R2_001.fastq.gz
# Approx 45% complete for 12_38_S38_L001_R2_001.fastq.gz
# Approx 50% complete for 12_38_S38_L001_R2_001.fastq.gz
# Approx 55% complete for 12_38_S38_L001_R2_001.fastq.gz
# Approx 60% complete for 12_38_S38_L001_R2_001.fastq.gz
# Approx 65% complete for 12_38_S38_L001_R2_001.fastq.gz
# Approx 70% complete for 12_38_S38_L001_R2_001.fastq.gz
# Approx 75% complete for 12_38_S38_L001_R2_001.fastq.gz
# Approx 80% complete for 12_38_S38_L001_R2_001.fastq.gz
# Approx 85% complete for 12_38_S38_L001_R2_001.fastq.gz
# Approx 90% complete for 12_38_S38_L001_R2_001.fastq.gz
# Approx 95% complete for 12_38_S38_L001_R2_001.fastq.gz
# Analysis complete for 12_38_S38_L001_R2_001.fastq.gz
# Started analysis of 13_33_S33_L001_R1_001.fastq.gz
# Approx 5% complete for 13_33_S33_L001_R1_001.fastq.gz
# Approx 10% complete for 13_33_S33_L001_R1_001.fastq.gz
# Approx 15% complete for 13_33_S33_L001_R1_001.fastq.gz
# Approx 20% complete for 13_33_S33_L001_R1_001.fastq.gz
# Approx 25% complete for 13_33_S33_L001_R1_001.fastq.gz
# Approx 30% complete for 13_33_S33_L001_R1_001.fastq.gz
# Approx 35% complete for 13_33_S33_L001_R1_001.fastq.gz
# Approx 40% complete for 13_33_S33_L001_R1_001.fastq.gz
# Approx 45% complete for 13_33_S33_L001_R1_001.fastq.gz
# Approx 50% complete for 13_33_S33_L001_R1_001.fastq.gz
# Approx 55% complete for 13_33_S33_L001_R1_001.fastq.gz
# Approx 60% complete for 13_33_S33_L001_R1_001.fastq.gz
# Approx 65% complete for 13_33_S33_L001_R1_001.fastq.gz
# Approx 70% complete for 13_33_S33_L001_R1_001.fastq.gz
# Approx 75% complete for 13_33_S33_L001_R1_001.fastq.gz
# Approx 80% complete for 13_33_S33_L001_R1_001.fastq.gz
# Approx 85% complete for 13_33_S33_L001_R1_001.fastq.gz
# Approx 90% complete for 13_33_S33_L001_R1_001.fastq.gz
# Approx 95% complete for 13_33_S33_L001_R1_001.fastq.gz
# Analysis complete for 13_33_S33_L001_R1_001.fastq.gz
# Started analysis of 13_33_S33_L001_R2_001.fastq.gz
# Approx 5% complete for 13_33_S33_L001_R2_001.fastq.gz
# Approx 10% complete for 13_33_S33_L001_R2_001.fastq.gz
# Approx 15% complete for 13_33_S33_L001_R2_001.fastq.gz
# Approx 20% complete for 13_33_S33_L001_R2_001.fastq.gz
# Approx 25% complete for 13_33_S33_L001_R2_001.fastq.gz
# Approx 30% complete for 13_33_S33_L001_R2_001.fastq.gz
# Approx 35% complete for 13_33_S33_L001_R2_001.fastq.gz
# Approx 40% complete for 13_33_S33_L001_R2_001.fastq.gz
# Approx 45% complete for 13_33_S33_L001_R2_001.fastq.gz
# Approx 50% complete for 13_33_S33_L001_R2_001.fastq.gz
# Approx 55% complete for 13_33_S33_L001_R2_001.fastq.gz
# Approx 60% complete for 13_33_S33_L001_R2_001.fastq.gz
# Approx 65% complete for 13_33_S33_L001_R2_001.fastq.gz
# Approx 70% complete for 13_33_S33_L001_R2_001.fastq.gz
# Approx 75% complete for 13_33_S33_L001_R2_001.fastq.gz
# Approx 80% complete for 13_33_S33_L001_R2_001.fastq.gz
# Approx 85% complete for 13_33_S33_L001_R2_001.fastq.gz
# Approx 90% complete for 13_33_S33_L001_R2_001.fastq.gz
# Approx 95% complete for 13_33_S33_L001_R2_001.fastq.gz
# Analysis complete for 13_33_S33_L001_R2_001.fastq.gz
# Started analysis of 14_34_S34_L001_R1_001.fastq.gz
# Approx 5% complete for 14_34_S34_L001_R1_001.fastq.gz
# Approx 10% complete for 14_34_S34_L001_R1_001.fastq.gz
# Approx 15% complete for 14_34_S34_L001_R1_001.fastq.gz
# Approx 20% complete for 14_34_S34_L001_R1_001.fastq.gz
# Approx 25% complete for 14_34_S34_L001_R1_001.fastq.gz
# Approx 30% complete for 14_34_S34_L001_R1_001.fastq.gz
# Approx 35% complete for 14_34_S34_L001_R1_001.fastq.gz
# Approx 40% complete for 14_34_S34_L001_R1_001.fastq.gz
# Approx 45% complete for 14_34_S34_L001_R1_001.fastq.gz
# Approx 50% complete for 14_34_S34_L001_R1_001.fastq.gz
# Approx 55% complete for 14_34_S34_L001_R1_001.fastq.gz
# Approx 60% complete for 14_34_S34_L001_R1_001.fastq.gz
# Approx 65% complete for 14_34_S34_L001_R1_001.fastq.gz
# Approx 70% complete for 14_34_S34_L001_R1_001.fastq.gz
# Approx 75% complete for 14_34_S34_L001_R1_001.fastq.gz
# Approx 80% complete for 14_34_S34_L001_R1_001.fastq.gz
# Approx 85% complete for 14_34_S34_L001_R1_001.fastq.gz
# Approx 90% complete for 14_34_S34_L001_R1_001.fastq.gz
# Approx 95% complete for 14_34_S34_L001_R1_001.fastq.gz
# Analysis complete for 14_34_S34_L001_R1_001.fastq.gz
# Started analysis of 14_34_S34_L001_R2_001.fastq.gz
# Approx 5% complete for 14_34_S34_L001_R2_001.fastq.gz
# Approx 10% complete for 14_34_S34_L001_R2_001.fastq.gz
# Approx 15% complete for 14_34_S34_L001_R2_001.fastq.gz
# Approx 20% complete for 14_34_S34_L001_R2_001.fastq.gz
# Approx 25% complete for 14_34_S34_L001_R2_001.fastq.gz
# Approx 30% complete for 14_34_S34_L001_R2_001.fastq.gz
# Approx 35% complete for 14_34_S34_L001_R2_001.fastq.gz
# Approx 40% complete for 14_34_S34_L001_R2_001.fastq.gz
# Approx 45% complete for 14_34_S34_L001_R2_001.fastq.gz
# Approx 50% complete for 14_34_S34_L001_R2_001.fastq.gz
# Approx 55% complete for 14_34_S34_L001_R2_001.fastq.gz
# Approx 60% complete for 14_34_S34_L001_R2_001.fastq.gz
# Approx 65% complete for 14_34_S34_L001_R2_001.fastq.gz
# Approx 70% complete for 14_34_S34_L001_R2_001.fastq.gz
# Approx 75% complete for 14_34_S34_L001_R2_001.fastq.gz
# Approx 80% complete for 14_34_S34_L001_R2_001.fastq.gz
# Approx 85% complete for 14_34_S34_L001_R2_001.fastq.gz
# Approx 90% complete for 14_34_S34_L001_R2_001.fastq.gz
# Approx 95% complete for 14_34_S34_L001_R2_001.fastq.gz
# Analysis complete for 14_34_S34_L001_R2_001.fastq.gz
# Started analysis of 15_39_S39_L001_R1_001.fastq.gz
# Approx 5% complete for 15_39_S39_L001_R1_001.fastq.gz
# Approx 10% complete for 15_39_S39_L001_R1_001.fastq.gz
# Approx 15% complete for 15_39_S39_L001_R1_001.fastq.gz
# Approx 20% complete for 15_39_S39_L001_R1_001.fastq.gz
# Approx 25% complete for 15_39_S39_L001_R1_001.fastq.gz
# Approx 30% complete for 15_39_S39_L001_R1_001.fastq.gz
# Approx 35% complete for 15_39_S39_L001_R1_001.fastq.gz
# Approx 40% complete for 15_39_S39_L001_R1_001.fastq.gz
# Approx 45% complete for 15_39_S39_L001_R1_001.fastq.gz
# Approx 50% complete for 15_39_S39_L001_R1_001.fastq.gz
# Approx 55% complete for 15_39_S39_L001_R1_001.fastq.gz
# Approx 60% complete for 15_39_S39_L001_R1_001.fastq.gz
# Approx 65% complete for 15_39_S39_L001_R1_001.fastq.gz
# Approx 70% complete for 15_39_S39_L001_R1_001.fastq.gz
# Approx 75% complete for 15_39_S39_L001_R1_001.fastq.gz
# Approx 80% complete for 15_39_S39_L001_R1_001.fastq.gz
# Approx 85% complete for 15_39_S39_L001_R1_001.fastq.gz
# Approx 90% complete for 15_39_S39_L001_R1_001.fastq.gz
# Approx 95% complete for 15_39_S39_L001_R1_001.fastq.gz
# Analysis complete for 15_39_S39_L001_R1_001.fastq.gz
# Started analysis of 15_39_S39_L001_R2_001.fastq.gz
# Approx 5% complete for 15_39_S39_L001_R2_001.fastq.gz
# Approx 10% complete for 15_39_S39_L001_R2_001.fastq.gz
# Approx 15% complete for 15_39_S39_L001_R2_001.fastq.gz
# Approx 20% complete for 15_39_S39_L001_R2_001.fastq.gz
# Approx 25% complete for 15_39_S39_L001_R2_001.fastq.gz
# Approx 30% complete for 15_39_S39_L001_R2_001.fastq.gz
# Approx 35% complete for 15_39_S39_L001_R2_001.fastq.gz
# Approx 40% complete for 15_39_S39_L001_R2_001.fastq.gz
# Approx 45% complete for 15_39_S39_L001_R2_001.fastq.gz
# Approx 50% complete for 15_39_S39_L001_R2_001.fastq.gz
# Approx 55% complete for 15_39_S39_L001_R2_001.fastq.gz
# Approx 60% complete for 15_39_S39_L001_R2_001.fastq.gz
# Approx 65% complete for 15_39_S39_L001_R2_001.fastq.gz
# Approx 70% complete for 15_39_S39_L001_R2_001.fastq.gz
# Approx 75% complete for 15_39_S39_L001_R2_001.fastq.gz
# Approx 80% complete for 15_39_S39_L001_R2_001.fastq.gz
# Approx 85% complete for 15_39_S39_L001_R2_001.fastq.gz
# Approx 90% complete for 15_39_S39_L001_R2_001.fastq.gz
# Approx 95% complete for 15_39_S39_L001_R2_001.fastq.gz
# Analysis complete for 15_39_S39_L001_R2_001.fastq.gz
# Started analysis of 16_40_S40_L001_R1_001.fastq.gz
# Approx 5% complete for 16_40_S40_L001_R1_001.fastq.gz
# Approx 10% complete for 16_40_S40_L001_R1_001.fastq.gz
# Approx 15% complete for 16_40_S40_L001_R1_001.fastq.gz
# Approx 20% complete for 16_40_S40_L001_R1_001.fastq.gz
# Approx 25% complete for 16_40_S40_L001_R1_001.fastq.gz
# Approx 30% complete for 16_40_S40_L001_R1_001.fastq.gz
# Approx 35% complete for 16_40_S40_L001_R1_001.fastq.gz
# Approx 40% complete for 16_40_S40_L001_R1_001.fastq.gz
# Approx 45% complete for 16_40_S40_L001_R1_001.fastq.gz
# Approx 50% complete for 16_40_S40_L001_R1_001.fastq.gz
# Approx 55% complete for 16_40_S40_L001_R1_001.fastq.gz
# Approx 60% complete for 16_40_S40_L001_R1_001.fastq.gz
# Approx 65% complete for 16_40_S40_L001_R1_001.fastq.gz
# Approx 70% complete for 16_40_S40_L001_R1_001.fastq.gz
# Approx 75% complete for 16_40_S40_L001_R1_001.fastq.gz
# Approx 80% complete for 16_40_S40_L001_R1_001.fastq.gz
# Approx 85% complete for 16_40_S40_L001_R1_001.fastq.gz
# Approx 90% complete for 16_40_S40_L001_R1_001.fastq.gz
# Approx 95% complete for 16_40_S40_L001_R1_001.fastq.gz
# Analysis complete for 16_40_S40_L001_R1_001.fastq.gz
# Started analysis of 16_40_S40_L001_R2_001.fastq.gz
# Approx 5% complete for 16_40_S40_L001_R2_001.fastq.gz
# Approx 10% complete for 16_40_S40_L001_R2_001.fastq.gz
# Approx 15% complete for 16_40_S40_L001_R2_001.fastq.gz
# Approx 20% complete for 16_40_S40_L001_R2_001.fastq.gz
# Approx 25% complete for 16_40_S40_L001_R2_001.fastq.gz
# Approx 30% complete for 16_40_S40_L001_R2_001.fastq.gz
# Approx 35% complete for 16_40_S40_L001_R2_001.fastq.gz
# Approx 40% complete for 16_40_S40_L001_R2_001.fastq.gz
# Approx 45% complete for 16_40_S40_L001_R2_001.fastq.gz
# Approx 50% complete for 16_40_S40_L001_R2_001.fastq.gz
# Approx 55% complete for 16_40_S40_L001_R2_001.fastq.gz
# Approx 60% complete for 16_40_S40_L001_R2_001.fastq.gz
# Approx 65% complete for 16_40_S40_L001_R2_001.fastq.gz
# Approx 70% complete for 16_40_S40_L001_R2_001.fastq.gz
# Approx 75% complete for 16_40_S40_L001_R2_001.fastq.gz
# Approx 80% complete for 16_40_S40_L001_R2_001.fastq.gz
# Approx 85% complete for 16_40_S40_L001_R2_001.fastq.gz
# Approx 90% complete for 16_40_S40_L001_R2_001.fastq.gz
# Approx 95% complete for 16_40_S40_L001_R2_001.fastq.gz
# Analysis complete for 16_40_S40_L001_R2_001.fastq.gz
# Started analysis of 17_9_S9_L001_R1_001.fastq.gz
# Approx 5% complete for 17_9_S9_L001_R1_001.fastq.gz
# Approx 10% complete for 17_9_S9_L001_R1_001.fastq.gz
# Approx 15% complete for 17_9_S9_L001_R1_001.fastq.gz
# Approx 20% complete for 17_9_S9_L001_R1_001.fastq.gz
# Approx 25% complete for 17_9_S9_L001_R1_001.fastq.gz
# Approx 30% complete for 17_9_S9_L001_R1_001.fastq.gz
# Approx 35% complete for 17_9_S9_L001_R1_001.fastq.gz
# Approx 40% complete for 17_9_S9_L001_R1_001.fastq.gz
# Approx 45% complete for 17_9_S9_L001_R1_001.fastq.gz
# Approx 50% complete for 17_9_S9_L001_R1_001.fastq.gz
# Approx 55% complete for 17_9_S9_L001_R1_001.fastq.gz
# Approx 60% complete for 17_9_S9_L001_R1_001.fastq.gz
# Approx 65% complete for 17_9_S9_L001_R1_001.fastq.gz
# Approx 70% complete for 17_9_S9_L001_R1_001.fastq.gz
# Approx 75% complete for 17_9_S9_L001_R1_001.fastq.gz
# Approx 80% complete for 17_9_S9_L001_R1_001.fastq.gz
# Approx 85% complete for 17_9_S9_L001_R1_001.fastq.gz
# Approx 90% complete for 17_9_S9_L001_R1_001.fastq.gz
# Approx 95% complete for 17_9_S9_L001_R1_001.fastq.gz
# Analysis complete for 17_9_S9_L001_R1_001.fastq.gz
# Started analysis of 17_9_S9_L001_R2_001.fastq.gz
# Approx 5% complete for 17_9_S9_L001_R2_001.fastq.gz
# Approx 10% complete for 17_9_S9_L001_R2_001.fastq.gz
# Approx 15% complete for 17_9_S9_L001_R2_001.fastq.gz
# Approx 20% complete for 17_9_S9_L001_R2_001.fastq.gz
# Approx 25% complete for 17_9_S9_L001_R2_001.fastq.gz
# Approx 30% complete for 17_9_S9_L001_R2_001.fastq.gz
# Approx 35% complete for 17_9_S9_L001_R2_001.fastq.gz
# Approx 40% complete for 17_9_S9_L001_R2_001.fastq.gz
# Approx 45% complete for 17_9_S9_L001_R2_001.fastq.gz
# Approx 50% complete for 17_9_S9_L001_R2_001.fastq.gz
# Approx 55% complete for 17_9_S9_L001_R2_001.fastq.gz
# Approx 60% complete for 17_9_S9_L001_R2_001.fastq.gz
# Approx 65% complete for 17_9_S9_L001_R2_001.fastq.gz
# Approx 70% complete for 17_9_S9_L001_R2_001.fastq.gz
# Approx 75% complete for 17_9_S9_L001_R2_001.fastq.gz
# Approx 80% complete for 17_9_S9_L001_R2_001.fastq.gz
# Approx 85% complete for 17_9_S9_L001_R2_001.fastq.gz
# Approx 90% complete for 17_9_S9_L001_R2_001.fastq.gz
# Approx 95% complete for 17_9_S9_L001_R2_001.fastq.gz
# Analysis complete for 17_9_S9_L001_R2_001.fastq.gz
# Started analysis of 18_10_S10_L001_R1_001.fastq.gz
# Approx 5% complete for 18_10_S10_L001_R1_001.fastq.gz
# Approx 10% complete for 18_10_S10_L001_R1_001.fastq.gz
# Approx 15% complete for 18_10_S10_L001_R1_001.fastq.gz
# Approx 20% complete for 18_10_S10_L001_R1_001.fastq.gz
# Approx 25% complete for 18_10_S10_L001_R1_001.fastq.gz
# Approx 30% complete for 18_10_S10_L001_R1_001.fastq.gz
# Approx 35% complete for 18_10_S10_L001_R1_001.fastq.gz
# Approx 40% complete for 18_10_S10_L001_R1_001.fastq.gz
# Approx 45% complete for 18_10_S10_L001_R1_001.fastq.gz
# Approx 50% complete for 18_10_S10_L001_R1_001.fastq.gz
# Approx 55% complete for 18_10_S10_L001_R1_001.fastq.gz
# Approx 60% complete for 18_10_S10_L001_R1_001.fastq.gz
# Approx 65% complete for 18_10_S10_L001_R1_001.fastq.gz
# Approx 70% complete for 18_10_S10_L001_R1_001.fastq.gz
# Approx 75% complete for 18_10_S10_L001_R1_001.fastq.gz
# Approx 80% complete for 18_10_S10_L001_R1_001.fastq.gz
# Approx 85% complete for 18_10_S10_L001_R1_001.fastq.gz
# Approx 90% complete for 18_10_S10_L001_R1_001.fastq.gz
# Approx 95% complete for 18_10_S10_L001_R1_001.fastq.gz
# Analysis complete for 18_10_S10_L001_R1_001.fastq.gz
# Started analysis of 18_10_S10_L001_R2_001.fastq.gz
# Approx 5% complete for 18_10_S10_L001_R2_001.fastq.gz
# Approx 10% complete for 18_10_S10_L001_R2_001.fastq.gz
# Approx 15% complete for 18_10_S10_L001_R2_001.fastq.gz
# Approx 20% complete for 18_10_S10_L001_R2_001.fastq.gz
# Approx 25% complete for 18_10_S10_L001_R2_001.fastq.gz
# Approx 30% complete for 18_10_S10_L001_R2_001.fastq.gz
# Approx 35% complete for 18_10_S10_L001_R2_001.fastq.gz
# Approx 40% complete for 18_10_S10_L001_R2_001.fastq.gz
# Approx 45% complete for 18_10_S10_L001_R2_001.fastq.gz
# Approx 50% complete for 18_10_S10_L001_R2_001.fastq.gz
# Approx 55% complete for 18_10_S10_L001_R2_001.fastq.gz
# Approx 60% complete for 18_10_S10_L001_R2_001.fastq.gz
# Approx 65% complete for 18_10_S10_L001_R2_001.fastq.gz
# Approx 70% complete for 18_10_S10_L001_R2_001.fastq.gz
# Approx 75% complete for 18_10_S10_L001_R2_001.fastq.gz
# Approx 80% complete for 18_10_S10_L001_R2_001.fastq.gz
# Approx 85% complete for 18_10_S10_L001_R2_001.fastq.gz
# Approx 90% complete for 18_10_S10_L001_R2_001.fastq.gz
# Approx 95% complete for 18_10_S10_L001_R2_001.fastq.gz
# Analysis complete for 18_10_S10_L001_R2_001.fastq.gz
# Started analysis of 19_7_S7_L001_R1_001.fastq.gz
# Approx 5% complete for 19_7_S7_L001_R1_001.fastq.gz
# Approx 10% complete for 19_7_S7_L001_R1_001.fastq.gz
# Approx 15% complete for 19_7_S7_L001_R1_001.fastq.gz
# Approx 20% complete for 19_7_S7_L001_R1_001.fastq.gz
# Approx 25% complete for 19_7_S7_L001_R1_001.fastq.gz
# Approx 30% complete for 19_7_S7_L001_R1_001.fastq.gz
# Approx 35% complete for 19_7_S7_L001_R1_001.fastq.gz
# Approx 40% complete for 19_7_S7_L001_R1_001.fastq.gz
# Approx 45% complete for 19_7_S7_L001_R1_001.fastq.gz
# Approx 50% complete for 19_7_S7_L001_R1_001.fastq.gz
# Approx 55% complete for 19_7_S7_L001_R1_001.fastq.gz
# Approx 60% complete for 19_7_S7_L001_R1_001.fastq.gz
# Approx 65% complete for 19_7_S7_L001_R1_001.fastq.gz
# Approx 70% complete for 19_7_S7_L001_R1_001.fastq.gz
# Approx 75% complete for 19_7_S7_L001_R1_001.fastq.gz
# Approx 80% complete for 19_7_S7_L001_R1_001.fastq.gz
# Approx 85% complete for 19_7_S7_L001_R1_001.fastq.gz
# Approx 90% complete for 19_7_S7_L001_R1_001.fastq.gz
# Approx 95% complete for 19_7_S7_L001_R1_001.fastq.gz
# Analysis complete for 19_7_S7_L001_R1_001.fastq.gz
# Started analysis of 19_7_S7_L001_R2_001.fastq.gz
# Approx 5% complete for 19_7_S7_L001_R2_001.fastq.gz
# Approx 10% complete for 19_7_S7_L001_R2_001.fastq.gz
# Approx 15% complete for 19_7_S7_L001_R2_001.fastq.gz
# Approx 20% complete for 19_7_S7_L001_R2_001.fastq.gz
# Approx 25% complete for 19_7_S7_L001_R2_001.fastq.gz
# Approx 30% complete for 19_7_S7_L001_R2_001.fastq.gz
# Approx 35% complete for 19_7_S7_L001_R2_001.fastq.gz
# Approx 40% complete for 19_7_S7_L001_R2_001.fastq.gz
# Approx 45% complete for 19_7_S7_L001_R2_001.fastq.gz
# Approx 50% complete for 19_7_S7_L001_R2_001.fastq.gz
# Approx 55% complete for 19_7_S7_L001_R2_001.fastq.gz
# Approx 60% complete for 19_7_S7_L001_R2_001.fastq.gz
# Approx 65% complete for 19_7_S7_L001_R2_001.fastq.gz
# Approx 70% complete for 19_7_S7_L001_R2_001.fastq.gz
# Approx 75% complete for 19_7_S7_L001_R2_001.fastq.gz
# Approx 80% complete for 19_7_S7_L001_R2_001.fastq.gz
# Approx 85% complete for 19_7_S7_L001_R2_001.fastq.gz
# Approx 90% complete for 19_7_S7_L001_R2_001.fastq.gz
# Approx 95% complete for 19_7_S7_L001_R2_001.fastq.gz
# Analysis complete for 19_7_S7_L001_R2_001.fastq.gz
# Started analysis of 1_25_S25_L001_R1_001.fastq.gz
# Approx 5% complete for 1_25_S25_L001_R1_001.fastq.gz
# Approx 10% complete for 1_25_S25_L001_R1_001.fastq.gz
# Approx 15% complete for 1_25_S25_L001_R1_001.fastq.gz
# Approx 20% complete for 1_25_S25_L001_R1_001.fastq.gz
# Approx 25% complete for 1_25_S25_L001_R1_001.fastq.gz
# Approx 30% complete for 1_25_S25_L001_R1_001.fastq.gz
# Approx 35% complete for 1_25_S25_L001_R1_001.fastq.gz
# Approx 40% complete for 1_25_S25_L001_R1_001.fastq.gz
# Approx 45% complete for 1_25_S25_L001_R1_001.fastq.gz
# Approx 50% complete for 1_25_S25_L001_R1_001.fastq.gz
# Approx 55% complete for 1_25_S25_L001_R1_001.fastq.gz
# Approx 60% complete for 1_25_S25_L001_R1_001.fastq.gz
# Approx 65% complete for 1_25_S25_L001_R1_001.fastq.gz
# Approx 70% complete for 1_25_S25_L001_R1_001.fastq.gz
# Approx 75% complete for 1_25_S25_L001_R1_001.fastq.gz
# Approx 80% complete for 1_25_S25_L001_R1_001.fastq.gz
# Approx 85% complete for 1_25_S25_L001_R1_001.fastq.gz
# Approx 90% complete for 1_25_S25_L001_R1_001.fastq.gz
# Approx 95% complete for 1_25_S25_L001_R1_001.fastq.gz
# Analysis complete for 1_25_S25_L001_R1_001.fastq.gz
# Started analysis of 1_25_S25_L001_R2_001.fastq.gz
# Approx 5% complete for 1_25_S25_L001_R2_001.fastq.gz
# Approx 10% complete for 1_25_S25_L001_R2_001.fastq.gz
# Approx 15% complete for 1_25_S25_L001_R2_001.fastq.gz
# Approx 20% complete for 1_25_S25_L001_R2_001.fastq.gz
# Approx 25% complete for 1_25_S25_L001_R2_001.fastq.gz
# Approx 30% complete for 1_25_S25_L001_R2_001.fastq.gz
# Approx 35% complete for 1_25_S25_L001_R2_001.fastq.gz
# Approx 40% complete for 1_25_S25_L001_R2_001.fastq.gz
# Approx 45% complete for 1_25_S25_L001_R2_001.fastq.gz
# Approx 50% complete for 1_25_S25_L001_R2_001.fastq.gz
# Approx 55% complete for 1_25_S25_L001_R2_001.fastq.gz
# Approx 60% complete for 1_25_S25_L001_R2_001.fastq.gz
# Approx 65% complete for 1_25_S25_L001_R2_001.fastq.gz
# Approx 70% complete for 1_25_S25_L001_R2_001.fastq.gz
# Approx 75% complete for 1_25_S25_L001_R2_001.fastq.gz
# Approx 80% complete for 1_25_S25_L001_R2_001.fastq.gz
# Approx 85% complete for 1_25_S25_L001_R2_001.fastq.gz
# Approx 90% complete for 1_25_S25_L001_R2_001.fastq.gz
# Approx 95% complete for 1_25_S25_L001_R2_001.fastq.gz
# Analysis complete for 1_25_S25_L001_R2_001.fastq.gz
# Started analysis of 20_8_S8_L001_R1_001.fastq.gz
# Approx 5% complete for 20_8_S8_L001_R1_001.fastq.gz
# Approx 10% complete for 20_8_S8_L001_R1_001.fastq.gz
# Approx 15% complete for 20_8_S8_L001_R1_001.fastq.gz
# Approx 20% complete for 20_8_S8_L001_R1_001.fastq.gz
# Approx 25% complete for 20_8_S8_L001_R1_001.fastq.gz
# Approx 30% complete for 20_8_S8_L001_R1_001.fastq.gz
# Approx 35% complete for 20_8_S8_L001_R1_001.fastq.gz
# Approx 40% complete for 20_8_S8_L001_R1_001.fastq.gz
# Approx 45% complete for 20_8_S8_L001_R1_001.fastq.gz
# Approx 50% complete for 20_8_S8_L001_R1_001.fastq.gz
# Approx 55% complete for 20_8_S8_L001_R1_001.fastq.gz
# Approx 60% complete for 20_8_S8_L001_R1_001.fastq.gz
# Approx 65% complete for 20_8_S8_L001_R1_001.fastq.gz
# Approx 70% complete for 20_8_S8_L001_R1_001.fastq.gz
# Approx 75% complete for 20_8_S8_L001_R1_001.fastq.gz
# Approx 80% complete for 20_8_S8_L001_R1_001.fastq.gz
# Approx 85% complete for 20_8_S8_L001_R1_001.fastq.gz
# Approx 90% complete for 20_8_S8_L001_R1_001.fastq.gz
# Approx 95% complete for 20_8_S8_L001_R1_001.fastq.gz
# Analysis complete for 20_8_S8_L001_R1_001.fastq.gz
# Started analysis of 20_8_S8_L001_R2_001.fastq.gz
# Approx 5% complete for 20_8_S8_L001_R2_001.fastq.gz
# Approx 10% complete for 20_8_S8_L001_R2_001.fastq.gz
# Approx 15% complete for 20_8_S8_L001_R2_001.fastq.gz
# Approx 20% complete for 20_8_S8_L001_R2_001.fastq.gz
# Approx 25% complete for 20_8_S8_L001_R2_001.fastq.gz
# Approx 30% complete for 20_8_S8_L001_R2_001.fastq.gz
# Approx 35% complete for 20_8_S8_L001_R2_001.fastq.gz
# Approx 40% complete for 20_8_S8_L001_R2_001.fastq.gz
# Approx 45% complete for 20_8_S8_L001_R2_001.fastq.gz
# Approx 50% complete for 20_8_S8_L001_R2_001.fastq.gz
# Approx 55% complete for 20_8_S8_L001_R2_001.fastq.gz
# Approx 60% complete for 20_8_S8_L001_R2_001.fastq.gz
# Approx 65% complete for 20_8_S8_L001_R2_001.fastq.gz
# Approx 70% complete for 20_8_S8_L001_R2_001.fastq.gz
# Approx 75% complete for 20_8_S8_L001_R2_001.fastq.gz
# Approx 80% complete for 20_8_S8_L001_R2_001.fastq.gz
# Approx 85% complete for 20_8_S8_L001_R2_001.fastq.gz
# Approx 90% complete for 20_8_S8_L001_R2_001.fastq.gz
# Approx 95% complete for 20_8_S8_L001_R2_001.fastq.gz
# Analysis complete for 20_8_S8_L001_R2_001.fastq.gz
# Started analysis of 2_26_S26_L001_R1_001.fastq.gz
# Approx 5% complete for 2_26_S26_L001_R1_001.fastq.gz
# Approx 10% complete for 2_26_S26_L001_R1_001.fastq.gz
# Approx 15% complete for 2_26_S26_L001_R1_001.fastq.gz
# Approx 20% complete for 2_26_S26_L001_R1_001.fastq.gz
# Approx 25% complete for 2_26_S26_L001_R1_001.fastq.gz
# Approx 30% complete for 2_26_S26_L001_R1_001.fastq.gz
# Approx 35% complete for 2_26_S26_L001_R1_001.fastq.gz
# Approx 40% complete for 2_26_S26_L001_R1_001.fastq.gz
# Approx 45% complete for 2_26_S26_L001_R1_001.fastq.gz
# Approx 50% complete for 2_26_S26_L001_R1_001.fastq.gz
# Approx 55% complete for 2_26_S26_L001_R1_001.fastq.gz
# Approx 60% complete for 2_26_S26_L001_R1_001.fastq.gz
# Approx 65% complete for 2_26_S26_L001_R1_001.fastq.gz
# Approx 70% complete for 2_26_S26_L001_R1_001.fastq.gz
# Approx 75% complete for 2_26_S26_L001_R1_001.fastq.gz
# Approx 80% complete for 2_26_S26_L001_R1_001.fastq.gz
# Approx 85% complete for 2_26_S26_L001_R1_001.fastq.gz
# Approx 90% complete for 2_26_S26_L001_R1_001.fastq.gz
# Approx 95% complete for 2_26_S26_L001_R1_001.fastq.gz
# Analysis complete for 2_26_S26_L001_R1_001.fastq.gz
# Started analysis of 2_26_S26_L001_R2_001.fastq.gz
# Approx 5% complete for 2_26_S26_L001_R2_001.fastq.gz
# Approx 10% complete for 2_26_S26_L001_R2_001.fastq.gz
# Approx 15% complete for 2_26_S26_L001_R2_001.fastq.gz
# Approx 20% complete for 2_26_S26_L001_R2_001.fastq.gz
# Approx 25% complete for 2_26_S26_L001_R2_001.fastq.gz
# Approx 30% complete for 2_26_S26_L001_R2_001.fastq.gz
# Approx 35% complete for 2_26_S26_L001_R2_001.fastq.gz
# Approx 40% complete for 2_26_S26_L001_R2_001.fastq.gz
# Approx 45% complete for 2_26_S26_L001_R2_001.fastq.gz
# Approx 50% complete for 2_26_S26_L001_R2_001.fastq.gz
# Approx 55% complete for 2_26_S26_L001_R2_001.fastq.gz
# Approx 60% complete for 2_26_S26_L001_R2_001.fastq.gz
# Approx 65% complete for 2_26_S26_L001_R2_001.fastq.gz
# Approx 70% complete for 2_26_S26_L001_R2_001.fastq.gz
# Approx 75% complete for 2_26_S26_L001_R2_001.fastq.gz
# Approx 80% complete for 2_26_S26_L001_R2_001.fastq.gz
# Approx 85% complete for 2_26_S26_L001_R2_001.fastq.gz
# Approx 90% complete for 2_26_S26_L001_R2_001.fastq.gz
# Approx 95% complete for 2_26_S26_L001_R2_001.fastq.gz
# Analysis complete for 2_26_S26_L001_R2_001.fastq.gz
# Started analysis of 3_27_S27_L001_R1_001.fastq.gz
# Approx 5% complete for 3_27_S27_L001_R1_001.fastq.gz
# Approx 10% complete for 3_27_S27_L001_R1_001.fastq.gz
# Approx 15% complete for 3_27_S27_L001_R1_001.fastq.gz
# Approx 20% complete for 3_27_S27_L001_R1_001.fastq.gz
# Approx 25% complete for 3_27_S27_L001_R1_001.fastq.gz
# Approx 30% complete for 3_27_S27_L001_R1_001.fastq.gz
# Approx 35% complete for 3_27_S27_L001_R1_001.fastq.gz
# Approx 40% complete for 3_27_S27_L001_R1_001.fastq.gz
# Approx 45% complete for 3_27_S27_L001_R1_001.fastq.gz
# Approx 50% complete for 3_27_S27_L001_R1_001.fastq.gz
# Approx 55% complete for 3_27_S27_L001_R1_001.fastq.gz
# Approx 60% complete for 3_27_S27_L001_R1_001.fastq.gz
# Approx 65% complete for 3_27_S27_L001_R1_001.fastq.gz
# Approx 70% complete for 3_27_S27_L001_R1_001.fastq.gz
# Approx 75% complete for 3_27_S27_L001_R1_001.fastq.gz
# Approx 80% complete for 3_27_S27_L001_R1_001.fastq.gz
# Approx 85% complete for 3_27_S27_L001_R1_001.fastq.gz
# Approx 90% complete for 3_27_S27_L001_R1_001.fastq.gz
# Approx 95% complete for 3_27_S27_L001_R1_001.fastq.gz
# Analysis complete for 3_27_S27_L001_R1_001.fastq.gz
# Started analysis of 3_27_S27_L001_R2_001.fastq.gz
# Approx 5% complete for 3_27_S27_L001_R2_001.fastq.gz
# Approx 10% complete for 3_27_S27_L001_R2_001.fastq.gz
# Approx 15% complete for 3_27_S27_L001_R2_001.fastq.gz
# Approx 20% complete for 3_27_S27_L001_R2_001.fastq.gz
# Approx 25% complete for 3_27_S27_L001_R2_001.fastq.gz
# Approx 30% complete for 3_27_S27_L001_R2_001.fastq.gz
# Approx 35% complete for 3_27_S27_L001_R2_001.fastq.gz
# Approx 40% complete for 3_27_S27_L001_R2_001.fastq.gz
# Approx 45% complete for 3_27_S27_L001_R2_001.fastq.gz
# Approx 50% complete for 3_27_S27_L001_R2_001.fastq.gz
# Approx 55% complete for 3_27_S27_L001_R2_001.fastq.gz
# Approx 60% complete for 3_27_S27_L001_R2_001.fastq.gz
# Approx 65% complete for 3_27_S27_L001_R2_001.fastq.gz
# Approx 70% complete for 3_27_S27_L001_R2_001.fastq.gz
# Approx 75% complete for 3_27_S27_L001_R2_001.fastq.gz
# Approx 80% complete for 3_27_S27_L001_R2_001.fastq.gz
# Approx 85% complete for 3_27_S27_L001_R2_001.fastq.gz
# Approx 90% complete for 3_27_S27_L001_R2_001.fastq.gz
# Approx 95% complete for 3_27_S27_L001_R2_001.fastq.gz
# Analysis complete for 3_27_S27_L001_R2_001.fastq.gz
# Started analysis of 4_28_S28_L001_R1_001.fastq.gz
# Approx 5% complete for 4_28_S28_L001_R1_001.fastq.gz
# Approx 10% complete for 4_28_S28_L001_R1_001.fastq.gz
# Approx 15% complete for 4_28_S28_L001_R1_001.fastq.gz
# Approx 20% complete for 4_28_S28_L001_R1_001.fastq.gz
# Approx 25% complete for 4_28_S28_L001_R1_001.fastq.gz
# Approx 30% complete for 4_28_S28_L001_R1_001.fastq.gz
# Approx 35% complete for 4_28_S28_L001_R1_001.fastq.gz
# Approx 40% complete for 4_28_S28_L001_R1_001.fastq.gz
# Approx 45% complete for 4_28_S28_L001_R1_001.fastq.gz
# Approx 50% complete for 4_28_S28_L001_R1_001.fastq.gz
# Approx 55% complete for 4_28_S28_L001_R1_001.fastq.gz
# Approx 60% complete for 4_28_S28_L001_R1_001.fastq.gz
# Approx 65% complete for 4_28_S28_L001_R1_001.fastq.gz
# Approx 70% complete for 4_28_S28_L001_R1_001.fastq.gz
# Approx 75% complete for 4_28_S28_L001_R1_001.fastq.gz
# Approx 80% complete for 4_28_S28_L001_R1_001.fastq.gz
# Approx 85% complete for 4_28_S28_L001_R1_001.fastq.gz
# Approx 90% complete for 4_28_S28_L001_R1_001.fastq.gz
# Approx 95% complete for 4_28_S28_L001_R1_001.fastq.gz
# Analysis complete for 4_28_S28_L001_R1_001.fastq.gz
# Started analysis of 4_28_S28_L001_R2_001.fastq.gz
# Approx 5% complete for 4_28_S28_L001_R2_001.fastq.gz
# Approx 10% complete for 4_28_S28_L001_R2_001.fastq.gz
# Approx 15% complete for 4_28_S28_L001_R2_001.fastq.gz
# Approx 20% complete for 4_28_S28_L001_R2_001.fastq.gz
# Approx 25% complete for 4_28_S28_L001_R2_001.fastq.gz
# Approx 30% complete for 4_28_S28_L001_R2_001.fastq.gz
# Approx 35% complete for 4_28_S28_L001_R2_001.fastq.gz
# Approx 40% complete for 4_28_S28_L001_R2_001.fastq.gz
# Approx 45% complete for 4_28_S28_L001_R2_001.fastq.gz
# Approx 50% complete for 4_28_S28_L001_R2_001.fastq.gz
# Approx 55% complete for 4_28_S28_L001_R2_001.fastq.gz
# Approx 60% complete for 4_28_S28_L001_R2_001.fastq.gz
# Approx 65% complete for 4_28_S28_L001_R2_001.fastq.gz
# Approx 70% complete for 4_28_S28_L001_R2_001.fastq.gz
# Approx 75% complete for 4_28_S28_L001_R2_001.fastq.gz
# Approx 80% complete for 4_28_S28_L001_R2_001.fastq.gz
# Approx 85% complete for 4_28_S28_L001_R2_001.fastq.gz
# Approx 90% complete for 4_28_S28_L001_R2_001.fastq.gz
# Approx 95% complete for 4_28_S28_L001_R2_001.fastq.gz
# Analysis complete for 4_28_S28_L001_R2_001.fastq.gz
# Started analysis of 5_35_S35_L001_R1_001.fastq.gz
# Approx 5% complete for 5_35_S35_L001_R1_001.fastq.gz
# Approx 10% complete for 5_35_S35_L001_R1_001.fastq.gz
# Approx 15% complete for 5_35_S35_L001_R1_001.fastq.gz
# Approx 20% complete for 5_35_S35_L001_R1_001.fastq.gz
# Approx 25% complete for 5_35_S35_L001_R1_001.fastq.gz
# Approx 30% complete for 5_35_S35_L001_R1_001.fastq.gz
# Approx 35% complete for 5_35_S35_L001_R1_001.fastq.gz
# Approx 40% complete for 5_35_S35_L001_R1_001.fastq.gz
# Approx 45% complete for 5_35_S35_L001_R1_001.fastq.gz
# Approx 50% complete for 5_35_S35_L001_R1_001.fastq.gz
# Approx 55% complete for 5_35_S35_L001_R1_001.fastq.gz
# Approx 60% complete for 5_35_S35_L001_R1_001.fastq.gz
# Approx 65% complete for 5_35_S35_L001_R1_001.fastq.gz
# Approx 70% complete for 5_35_S35_L001_R1_001.fastq.gz
# Approx 75% complete for 5_35_S35_L001_R1_001.fastq.gz
# Approx 80% complete for 5_35_S35_L001_R1_001.fastq.gz
# Approx 85% complete for 5_35_S35_L001_R1_001.fastq.gz
# Approx 90% complete for 5_35_S35_L001_R1_001.fastq.gz
# Approx 95% complete for 5_35_S35_L001_R1_001.fastq.gz
# Analysis complete for 5_35_S35_L001_R1_001.fastq.gz
# Started analysis of 5_35_S35_L001_R2_001.fastq.gz
# Approx 5% complete for 5_35_S35_L001_R2_001.fastq.gz
# Approx 10% complete for 5_35_S35_L001_R2_001.fastq.gz
# Approx 15% complete for 5_35_S35_L001_R2_001.fastq.gz
# Approx 20% complete for 5_35_S35_L001_R2_001.fastq.gz
# Approx 25% complete for 5_35_S35_L001_R2_001.fastq.gz
# Approx 30% complete for 5_35_S35_L001_R2_001.fastq.gz
# Approx 35% complete for 5_35_S35_L001_R2_001.fastq.gz
# Approx 40% complete for 5_35_S35_L001_R2_001.fastq.gz
# Approx 45% complete for 5_35_S35_L001_R2_001.fastq.gz
# Approx 50% complete for 5_35_S35_L001_R2_001.fastq.gz
# Approx 55% complete for 5_35_S35_L001_R2_001.fastq.gz
# Approx 60% complete for 5_35_S35_L001_R2_001.fastq.gz
# Approx 65% complete for 5_35_S35_L001_R2_001.fastq.gz
# Approx 70% complete for 5_35_S35_L001_R2_001.fastq.gz
# Approx 75% complete for 5_35_S35_L001_R2_001.fastq.gz
# Approx 80% complete for 5_35_S35_L001_R2_001.fastq.gz
# Approx 85% complete for 5_35_S35_L001_R2_001.fastq.gz
# Approx 90% complete for 5_35_S35_L001_R2_001.fastq.gz
# Approx 95% complete for 5_35_S35_L001_R2_001.fastq.gz
# Analysis complete for 5_35_S35_L001_R2_001.fastq.gz
# Started analysis of 6_36_S36_L001_R1_001.fastq.gz
# Approx 5% complete for 6_36_S36_L001_R1_001.fastq.gz
# Approx 10% complete for 6_36_S36_L001_R1_001.fastq.gz
# Approx 15% complete for 6_36_S36_L001_R1_001.fastq.gz
# Approx 20% complete for 6_36_S36_L001_R1_001.fastq.gz
# Approx 25% complete for 6_36_S36_L001_R1_001.fastq.gz
# Approx 30% complete for 6_36_S36_L001_R1_001.fastq.gz
# Approx 35% complete for 6_36_S36_L001_R1_001.fastq.gz
# Approx 40% complete for 6_36_S36_L001_R1_001.fastq.gz
# Approx 45% complete for 6_36_S36_L001_R1_001.fastq.gz
# Approx 50% complete for 6_36_S36_L001_R1_001.fastq.gz
# Approx 55% complete for 6_36_S36_L001_R1_001.fastq.gz
# Approx 60% complete for 6_36_S36_L001_R1_001.fastq.gz
# Approx 65% complete for 6_36_S36_L001_R1_001.fastq.gz
# Approx 70% complete for 6_36_S36_L001_R1_001.fastq.gz
# Approx 75% complete for 6_36_S36_L001_R1_001.fastq.gz
# Approx 80% complete for 6_36_S36_L001_R1_001.fastq.gz
# Approx 85% complete for 6_36_S36_L001_R1_001.fastq.gz
# Approx 90% complete for 6_36_S36_L001_R1_001.fastq.gz
# Approx 95% complete for 6_36_S36_L001_R1_001.fastq.gz
# Analysis complete for 6_36_S36_L001_R1_001.fastq.gz
# Started analysis of 6_36_S36_L001_R2_001.fastq.gz
# Approx 5% complete for 6_36_S36_L001_R2_001.fastq.gz
# Approx 10% complete for 6_36_S36_L001_R2_001.fastq.gz
# Approx 15% complete for 6_36_S36_L001_R2_001.fastq.gz
# Approx 20% complete for 6_36_S36_L001_R2_001.fastq.gz
# Approx 25% complete for 6_36_S36_L001_R2_001.fastq.gz
# Approx 30% complete for 6_36_S36_L001_R2_001.fastq.gz
# Approx 35% complete for 6_36_S36_L001_R2_001.fastq.gz
# Approx 40% complete for 6_36_S36_L001_R2_001.fastq.gz
# Approx 45% complete for 6_36_S36_L001_R2_001.fastq.gz
# Approx 50% complete for 6_36_S36_L001_R2_001.fastq.gz
# Approx 55% complete for 6_36_S36_L001_R2_001.fastq.gz
# Approx 60% complete for 6_36_S36_L001_R2_001.fastq.gz
# Approx 65% complete for 6_36_S36_L001_R2_001.fastq.gz
# Approx 70% complete for 6_36_S36_L001_R2_001.fastq.gz
# Approx 75% complete for 6_36_S36_L001_R2_001.fastq.gz
# Approx 80% complete for 6_36_S36_L001_R2_001.fastq.gz
# Approx 85% complete for 6_36_S36_L001_R2_001.fastq.gz
# Approx 90% complete for 6_36_S36_L001_R2_001.fastq.gz
# Approx 95% complete for 6_36_S36_L001_R2_001.fastq.gz
# Analysis complete for 6_36_S36_L001_R2_001.fastq.gz
# Started analysis of 7_29_S29_L001_R1_001.fastq.gz
# Approx 5% complete for 7_29_S29_L001_R1_001.fastq.gz
# Approx 10% complete for 7_29_S29_L001_R1_001.fastq.gz
# Approx 15% complete for 7_29_S29_L001_R1_001.fastq.gz
# Approx 20% complete for 7_29_S29_L001_R1_001.fastq.gz
# Approx 25% complete for 7_29_S29_L001_R1_001.fastq.gz
# Approx 30% complete for 7_29_S29_L001_R1_001.fastq.gz
# Approx 35% complete for 7_29_S29_L001_R1_001.fastq.gz
# Approx 40% complete for 7_29_S29_L001_R1_001.fastq.gz
# Approx 45% complete for 7_29_S29_L001_R1_001.fastq.gz
# Approx 50% complete for 7_29_S29_L001_R1_001.fastq.gz
# Approx 55% complete for 7_29_S29_L001_R1_001.fastq.gz
# Approx 60% complete for 7_29_S29_L001_R1_001.fastq.gz
# Approx 65% complete for 7_29_S29_L001_R1_001.fastq.gz
# Approx 70% complete for 7_29_S29_L001_R1_001.fastq.gz
# Approx 75% complete for 7_29_S29_L001_R1_001.fastq.gz
# Approx 80% complete for 7_29_S29_L001_R1_001.fastq.gz
# Approx 85% complete for 7_29_S29_L001_R1_001.fastq.gz
# Approx 90% complete for 7_29_S29_L001_R1_001.fastq.gz
# Approx 95% complete for 7_29_S29_L001_R1_001.fastq.gz
# Analysis complete for 7_29_S29_L001_R1_001.fastq.gz
# Started analysis of 7_29_S29_L001_R2_001.fastq.gz
# Approx 5% complete for 7_29_S29_L001_R2_001.fastq.gz
# Approx 10% complete for 7_29_S29_L001_R2_001.fastq.gz
# Approx 15% complete for 7_29_S29_L001_R2_001.fastq.gz
# Approx 20% complete for 7_29_S29_L001_R2_001.fastq.gz
# Approx 25% complete for 7_29_S29_L001_R2_001.fastq.gz
# Approx 30% complete for 7_29_S29_L001_R2_001.fastq.gz
# Approx 35% complete for 7_29_S29_L001_R2_001.fastq.gz
# Approx 40% complete for 7_29_S29_L001_R2_001.fastq.gz
# Approx 45% complete for 7_29_S29_L001_R2_001.fastq.gz
# Approx 50% complete for 7_29_S29_L001_R2_001.fastq.gz
# Approx 55% complete for 7_29_S29_L001_R2_001.fastq.gz
# Approx 60% complete for 7_29_S29_L001_R2_001.fastq.gz
# Approx 65% complete for 7_29_S29_L001_R2_001.fastq.gz
# Approx 70% complete for 7_29_S29_L001_R2_001.fastq.gz
# Approx 75% complete for 7_29_S29_L001_R2_001.fastq.gz
# Approx 80% complete for 7_29_S29_L001_R2_001.fastq.gz
# Approx 85% complete for 7_29_S29_L001_R2_001.fastq.gz
# Approx 90% complete for 7_29_S29_L001_R2_001.fastq.gz
# Approx 95% complete for 7_29_S29_L001_R2_001.fastq.gz
# Analysis complete for 7_29_S29_L001_R2_001.fastq.gz
# Started analysis of 8_30_S30_L001_R1_001.fastq.gz
# Approx 5% complete for 8_30_S30_L001_R1_001.fastq.gz
# Approx 10% complete for 8_30_S30_L001_R1_001.fastq.gz
# Approx 15% complete for 8_30_S30_L001_R1_001.fastq.gz
# Approx 20% complete for 8_30_S30_L001_R1_001.fastq.gz
# Approx 25% complete for 8_30_S30_L001_R1_001.fastq.gz
# Approx 30% complete for 8_30_S30_L001_R1_001.fastq.gz
# Approx 35% complete for 8_30_S30_L001_R1_001.fastq.gz
# Approx 40% complete for 8_30_S30_L001_R1_001.fastq.gz
# Approx 45% complete for 8_30_S30_L001_R1_001.fastq.gz
# Approx 50% complete for 8_30_S30_L001_R1_001.fastq.gz
# Approx 55% complete for 8_30_S30_L001_R1_001.fastq.gz
# Approx 60% complete for 8_30_S30_L001_R1_001.fastq.gz
# Approx 65% complete for 8_30_S30_L001_R1_001.fastq.gz
# Approx 70% complete for 8_30_S30_L001_R1_001.fastq.gz
# Approx 75% complete for 8_30_S30_L001_R1_001.fastq.gz
# Approx 80% complete for 8_30_S30_L001_R1_001.fastq.gz
# Approx 85% complete for 8_30_S30_L001_R1_001.fastq.gz
# Approx 90% complete for 8_30_S30_L001_R1_001.fastq.gz
# Approx 95% complete for 8_30_S30_L001_R1_001.fastq.gz
# Analysis complete for 8_30_S30_L001_R1_001.fastq.gz
# Started analysis of 8_30_S30_L001_R2_001.fastq.gz
# Approx 5% complete for 8_30_S30_L001_R2_001.fastq.gz
# Approx 10% complete for 8_30_S30_L001_R2_001.fastq.gz
# Approx 15% complete for 8_30_S30_L001_R2_001.fastq.gz
# Approx 20% complete for 8_30_S30_L001_R2_001.fastq.gz
# Approx 25% complete for 8_30_S30_L001_R2_001.fastq.gz
# Approx 30% complete for 8_30_S30_L001_R2_001.fastq.gz
# Approx 35% complete for 8_30_S30_L001_R2_001.fastq.gz
# Approx 40% complete for 8_30_S30_L001_R2_001.fastq.gz
# Approx 45% complete for 8_30_S30_L001_R2_001.fastq.gz
# Approx 50% complete for 8_30_S30_L001_R2_001.fastq.gz
# Approx 55% complete for 8_30_S30_L001_R2_001.fastq.gz
# Approx 60% complete for 8_30_S30_L001_R2_001.fastq.gz
# Approx 65% complete for 8_30_S30_L001_R2_001.fastq.gz
# Approx 70% complete for 8_30_S30_L001_R2_001.fastq.gz
# Approx 75% complete for 8_30_S30_L001_R2_001.fastq.gz
# Approx 80% complete for 8_30_S30_L001_R2_001.fastq.gz
# Approx 85% complete for 8_30_S30_L001_R2_001.fastq.gz
# Approx 90% complete for 8_30_S30_L001_R2_001.fastq.gz
# Approx 95% complete for 8_30_S30_L001_R2_001.fastq.gz
# Analysis complete for 8_30_S30_L001_R2_001.fastq.gz
# Started analysis of 9_31_S31_L001_R1_001.fastq.gz
# Approx 5% complete for 9_31_S31_L001_R1_001.fastq.gz
# Approx 10% complete for 9_31_S31_L001_R1_001.fastq.gz
# Approx 15% complete for 9_31_S31_L001_R1_001.fastq.gz
# Approx 20% complete for 9_31_S31_L001_R1_001.fastq.gz
# Approx 25% complete for 9_31_S31_L001_R1_001.fastq.gz
# Approx 30% complete for 9_31_S31_L001_R1_001.fastq.gz
# Approx 35% complete for 9_31_S31_L001_R1_001.fastq.gz
# Approx 40% complete for 9_31_S31_L001_R1_001.fastq.gz
# Approx 45% complete for 9_31_S31_L001_R1_001.fastq.gz
# Approx 50% complete for 9_31_S31_L001_R1_001.fastq.gz
# Approx 55% complete for 9_31_S31_L001_R1_001.fastq.gz
# Approx 60% complete for 9_31_S31_L001_R1_001.fastq.gz
# Approx 65% complete for 9_31_S31_L001_R1_001.fastq.gz
# Approx 70% complete for 9_31_S31_L001_R1_001.fastq.gz
# Approx 75% complete for 9_31_S31_L001_R1_001.fastq.gz
# Approx 80% complete for 9_31_S31_L001_R1_001.fastq.gz
# Approx 85% complete for 9_31_S31_L001_R1_001.fastq.gz
# Approx 90% complete for 9_31_S31_L001_R1_001.fastq.gz
# Approx 95% complete for 9_31_S31_L001_R1_001.fastq.gz
# Analysis complete for 9_31_S31_L001_R1_001.fastq.gz
# Started analysis of 9_31_S31_L001_R2_001.fastq.gz
# Approx 5% complete for 9_31_S31_L001_R2_001.fastq.gz
# Approx 10% complete for 9_31_S31_L001_R2_001.fastq.gz
# Approx 15% complete for 9_31_S31_L001_R2_001.fastq.gz
# Approx 20% complete for 9_31_S31_L001_R2_001.fastq.gz
# Approx 25% complete for 9_31_S31_L001_R2_001.fastq.gz
# Approx 30% complete for 9_31_S31_L001_R2_001.fastq.gz
# Approx 35% complete for 9_31_S31_L001_R2_001.fastq.gz
# Approx 40% complete for 9_31_S31_L001_R2_001.fastq.gz
# Approx 45% complete for 9_31_S31_L001_R2_001.fastq.gz
# Approx 50% complete for 9_31_S31_L001_R2_001.fastq.gz
# Approx 55% complete for 9_31_S31_L001_R2_001.fastq.gz
# Approx 60% complete for 9_31_S31_L001_R2_001.fastq.gz
# Approx 65% complete for 9_31_S31_L001_R2_001.fastq.gz
# Approx 70% complete for 9_31_S31_L001_R2_001.fastq.gz
# Approx 75% complete for 9_31_S31_L001_R2_001.fastq.gz
# Approx 80% complete for 9_31_S31_L001_R2_001.fastq.gz
# Approx 85% complete for 9_31_S31_L001_R2_001.fastq.gz
# Approx 90% complete for 9_31_S31_L001_R2_001.fastq.gz
# Approx 95% complete for 9_31_S31_L001_R2_001.fastq.gz
# Analysis complete for 9_31_S31_L001_R2_001.fastq.gz

# %% [markdown]
# ## --score_min L,0,-0.6

# %%
# %%bash
# find /Volumes/Serine/wd/18-03-14/*_R1_001.fastq.gz \
# | xargs basename -s _L001_R1_001.fastq.gz | xargs -I{} /Applications/bioinfo/Bismark_v0.19.0/bismark \
# --path_to_bowtie /Applications/bioinfo/bowtie2-2.3.4.1-macos-x86_64 \
# --genome /Volumes/Serine/wd/18-03-15/genome \
# --score_min L,0,-0.6 \
# -p 4 \
# -u 10000 \
# --non_directional \
# -1 /Volumes/Serine/wd/18-03-14/{}_L001_R1_001.fastq.gz \
# -2 /Volumes/Serine/wd/18-03-14/{}_L001_R2_001.fastq.gz \
# 2> bismark.err
# Out:
# FastQ format assumed (by default)
# Each Bowtie 2 instance is going to be run with 4 threads. Please monitor performance closely and tune down if needed!
# chr NC_035780.1 (65668440 bp)
# chr NC_035781.1 (61752955 bp)
# chr NC_035782.1 (77061148 bp)
# chr NC_035783.1 (59691872 bp)
# chr NC_035784.1 (98698416 bp)
# chr NC_035785.1 (51258098 bp)
# chr NC_035786.1 (57830854 bp)
# chr NC_035787.1 (75944018 bp)
# chr NC_035788.1 (104168038 bp)
# chr NC_035789.1 (32650045 bp)
# chr NC_007175.2 (17244 bp)
#
# Number of paired-end alignments with a unique best hit:	4008
# Mapping efficiency:	40.1%
#
# Sequence pairs with no alignments under any condition:	4574
# Sequence pairs did not map uniquely:	1418
# Sequence pairs which were discarded because genomic sequence could not be extracted:	0
#
# Number of sequence pairs with unique best (first) alignment came from the bowtie output:
# CT/GA/CT:	631	((converted) top strand)
# GA/CT/CT:	1352	(complementary to (converted) top strand)
# GA/CT/GA:	1373	(complementary to (converted) bottom strand)
# CT/GA/GA:	652	((converted) bottom strand)
#
# FastQ format assumed (by default)
# Each Bowtie 2 instance is going to be run with 4 threads. Please monitor performance closely and tune down if needed!
# chr NC_035780.1 (65668440 bp)
# chr NC_035781.1 (61752955 bp)
# chr NC_035782.1 (77061148 bp)
# chr NC_035783.1 (59691872 bp)
# chr NC_035784.1 (98698416 bp)
# chr NC_035785.1 (51258098 bp)
# chr NC_035786.1 (57830854 bp)
# chr NC_035787.1 (75944018 bp)
# chr NC_035788.1 (104168038 bp)
# chr NC_035789.1 (32650045 bp)
# chr NC_007175.2 (17244 bp)
#
# Number of paired-end alignments with a unique best hit:	2795
# Mapping efficiency:	27.9%
#
# Sequence pairs with no alignments under any condition:	6247
# Sequence pairs did not map uniquely:	958
# Sequence pairs which were discarded because genomic sequence could not be extracted:	0
#
# Number of sequence pairs with unique best (first) alignment came from the bowtie output:
# CT/GA/CT:	474	((converted) top strand)
# GA/CT/CT:	865	(complementary to (converted) top strand)
# GA/CT/GA:	936	(complementary to (converted) bottom strand)
# CT/GA/GA:	520	((converted) bottom strand)
#
# FastQ format assumed (by default)
# Each Bowtie 2 instance is going to be run with 4 threads. Please monitor performance closely and tune down if needed!
# chr NC_035780.1 (65668440 bp)
# chr NC_035781.1 (61752955 bp)
# chr NC_035782.1 (77061148 bp)
# chr NC_035783.1 (59691872 bp)
# chr NC_035784.1 (98698416 bp)
# chr NC_035785.1 (51258098 bp)
# chr NC_035786.1 (57830854 bp)
# chr NC_035787.1 (75944018 bp)
# chr NC_035788.1 (104168038 bp)
# chr NC_035789.1 (32650045 bp)
# chr NC_007175.2 (17244 bp)
#
# Number of paired-end alignments with a unique best hit:	2712
# Mapping efficiency:	27.1%
#
# Sequence pairs with no alignments under any condition:	6327
# Sequence pairs did not map uniquely:	961
# Sequence pairs which were discarded because genomic sequence could not be extracted:	0
#
# Number of sequence pairs with unique best (first) alignment came from the bowtie output:
# CT/GA/CT:	496	((converted) top strand)
# GA/CT/CT:	928	(complementary to (converted) top strand)
# GA/CT/GA:	855	(complementary to (converted) bottom strand)
# CT/GA/GA:	433	((converted) bottom strand)
#
# FastQ format assumed (by default)
# Each Bowtie 2 instance is going to be run with 4 threads. Please monitor performance closely and tune down if needed!
# chr NC_035780.1 (65668440 bp)
# chr NC_035781.1 (61752955 bp)
# chr NC_035782.1 (77061148 bp)
# chr NC_035783.1 (59691872 bp)
# chr NC_035784.1 (98698416 bp)
# chr NC_035785.1 (51258098 bp)
# chr NC_035786.1 (57830854 bp)
# chr NC_035787.1 (75944018 bp)
# chr NC_035788.1 (104168038 bp)
# chr NC_035789.1 (32650045 bp)
# chr NC_007175.2 (17244 bp)
#
# Number of paired-end alignments with a unique best hit:	4245
# Mapping efficiency:	42.5%
#
# Sequence pairs with no alignments under any condition:	4312
# Sequence pairs did not map uniquely:	1443
# Sequence pairs which were discarded because genomic sequence could not be extracted:	0
#
# Number of sequence pairs with unique best (first) alignment came from the bowtie output:
# CT/GA/CT:	760	((converted) top strand)
# GA/CT/CT:	1367	(complementary to (converted) top strand)
# GA/CT/GA:	1387	(complementary to (converted) bottom strand)
# CT/GA/GA:	731	((converted) bottom strand)
#
# FastQ format assumed (by default)
# Each Bowtie 2 instance is going to be run with 4 threads. Please monitor performance closely and tune down if needed!
# chr NC_035780.1 (65668440 bp)
# chr NC_035781.1 (61752955 bp)
# chr NC_035782.1 (77061148 bp)
# chr NC_035783.1 (59691872 bp)
# chr NC_035784.1 (98698416 bp)
# chr NC_035785.1 (51258098 bp)
# chr NC_035786.1 (57830854 bp)
# chr NC_035787.1 (75944018 bp)
# chr NC_035788.1 (104168038 bp)
# chr NC_035789.1 (32650045 bp)
# chr NC_007175.2 (17244 bp)
#
# Number of paired-end alignments with a unique best hit:	4531
# Mapping efficiency:	45.3%
#
# Sequence pairs with no alignments under any condition:	3905
# Sequence pairs did not map uniquely:	1564
# Sequence pairs which were discarded because genomic sequence could not be extracted:	0
#
# Number of sequence pairs with unique best (first) alignment came from the bowtie output:
# CT/GA/CT:	824	((converted) top strand)
# GA/CT/CT:	1421	(complementary to (converted) top strand)
# GA/CT/GA:	1443	(complementary to (converted) bottom strand)
# CT/GA/GA:	843	((converted) bottom strand)
#
# FastQ format assumed (by default)
# Each Bowtie 2 instance is going to be run with 4 threads. Please monitor performance closely and tune down if needed!
# chr NC_035780.1 (65668440 bp)
# chr NC_035781.1 (61752955 bp)
# chr NC_035782.1 (77061148 bp)
# chr NC_035783.1 (59691872 bp)
# chr NC_035784.1 (98698416 bp)
# chr NC_035785.1 (51258098 bp)
# chr NC_035786.1 (57830854 bp)
# chr NC_035787.1 (75944018 bp)
# chr NC_035788.1 (104168038 bp)
# chr NC_035789.1 (32650045 bp)
# chr NC_007175.2 (17244 bp)
#
# Number of paired-end alignments with a unique best hit:	2971
# Mapping efficiency:	29.7%
#
# Sequence pairs with no alignments under any condition:	5943
# Sequence pairs did not map uniquely:	1086
# Sequence pairs which were discarded because genomic sequence could not be extracted:	0
#
# Number of sequence pairs with unique best (first) alignment came from the bowtie output:
# CT/GA/CT:	480	((converted) top strand)
# GA/CT/CT:	997	(complementary to (converted) top strand)
# GA/CT/GA:	998	(complementary to (converted) bottom strand)
# CT/GA/GA:	496	((converted) bottom strand)
#
# FastQ format assumed (by default)
# Each Bowtie 2 instance is going to be run with 4 threads. Please monitor performance closely and tune down if needed!
# chr NC_035780.1 (65668440 bp)
# chr NC_035781.1 (61752955 bp)
# chr NC_035782.1 (77061148 bp)
# chr NC_035783.1 (59691872 bp)
# chr NC_035784.1 (98698416 bp)
# chr NC_035785.1 (51258098 bp)
# chr NC_035786.1 (57830854 bp)
# chr NC_035787.1 (75944018 bp)
# chr NC_035788.1 (104168038 bp)
# chr NC_035789.1 (32650045 bp)
# chr NC_007175.2 (17244 bp)
#
# Number of paired-end alignments with a unique best hit:	3159
# Mapping efficiency:	31.6%
#
# Sequence pairs with no alignments under any condition:	5784
# Sequence pairs did not map uniquely:	1057
# Sequence pairs which were discarded because genomic sequence could not be extracted:	0
#
# Number of sequence pairs with unique best (first) alignment came from the bowtie output:
# CT/GA/CT:	547	((converted) top strand)
# GA/CT/CT:	999	(complementary to (converted) top strand)
# GA/CT/GA:	1020	(complementary to (converted) bottom strand)
# CT/GA/GA:	593	((converted) bottom strand)
#
# FastQ format assumed (by default)
# Each Bowtie 2 instance is going to be run with 4 threads. Please monitor performance closely and tune down if needed!
# chr NC_035780.1 (65668440 bp)
# chr NC_035781.1 (61752955 bp)
# chr NC_035782.1 (77061148 bp)
# chr NC_035783.1 (59691872 bp)
# chr NC_035784.1 (98698416 bp)
# chr NC_035785.1 (51258098 bp)
# chr NC_035786.1 (57830854 bp)
# chr NC_035787.1 (75944018 bp)
# chr NC_035788.1 (104168038 bp)
# chr NC_035789.1 (32650045 bp)
# chr NC_007175.2 (17244 bp)
#
# Number of paired-end alignments with a unique best hit:	2046
# Mapping efficiency:	20.5%
#
# Sequence pairs with no alignments under any condition:	7163
# Sequence pairs did not map uniquely:	791
# Sequence pairs which were discarded because genomic sequence could not be extracted:	0
#
# Number of sequence pairs with unique best (first) alignment came from the bowtie output:
# CT/GA/CT:	275	((converted) top strand)
# GA/CT/CT:	704	(complementary to (converted) top strand)
# GA/CT/GA:	786	(complementary to (converted) bottom strand)
# CT/GA/GA:	281	((converted) bottom strand)
#
# FastQ format assumed (by default)
# Each Bowtie 2 instance is going to be run with 4 threads. Please monitor performance closely and tune down if needed!
# chr NC_035780.1 (65668440 bp)
# chr NC_035781.1 (61752955 bp)
# chr NC_035782.1 (77061148 bp)
# chr NC_035783.1 (59691872 bp)
# chr NC_035784.1 (98698416 bp)
# chr NC_035785.1 (51258098 bp)
# chr NC_035786.1 (57830854 bp)
# chr NC_035787.1 (75944018 bp)
# chr NC_035788.1 (104168038 bp)
# chr NC_035789.1 (32650045 bp)
# chr NC_007175.2 (17244 bp)
#
# Number of paired-end alignments with a unique best hit:	3658
# Mapping efficiency:	36.6%
#
# Sequence pairs with no alignments under any condition:	5057
# Sequence pairs did not map uniquely:	1285
# Sequence pairs which were discarded because genomic sequence could not be extracted:	0
#
# Number of sequence pairs with unique best (first) alignment came from the bowtie output:
# CT/GA/CT:	649	((converted) top strand)
# GA/CT/CT:	1239	(complementary to (converted) top strand)
# GA/CT/GA:	1167	(complementary to (converted) bottom strand)
# CT/GA/GA:	603	((converted) bottom strand)
#
# FastQ format assumed (by default)
# Each Bowtie 2 instance is going to be run with 4 threads. Please monitor performance closely and tune down if needed!
# chr NC_035780.1 (65668440 bp)
# chr NC_035781.1 (61752955 bp)
# chr NC_035782.1 (77061148 bp)
# chr NC_035783.1 (59691872 bp)
# chr NC_035784.1 (98698416 bp)
# chr NC_035785.1 (51258098 bp)
# chr NC_035786.1 (57830854 bp)
# chr NC_035787.1 (75944018 bp)
# chr NC_035788.1 (104168038 bp)
# chr NC_035789.1 (32650045 bp)
# chr NC_007175.2 (17244 bp)
#
# Number of paired-end alignments with a unique best hit:	3154
# Mapping efficiency:	31.5%
#
# Sequence pairs with no alignments under any condition:	5728
# Sequence pairs did not map uniquely:	1118
# Sequence pairs which were discarded because genomic sequence could not be extracted:	0
#
# Number of sequence pairs with unique best (first) alignment came from the bowtie output:
# CT/GA/CT:	566	((converted) top strand)
# GA/CT/CT:	1008	(complementary to (converted) top strand)
# GA/CT/GA:	1071	(complementary to (converted) bottom strand)
# CT/GA/GA:	509	((converted) bottom strand)
#
# FastQ format assumed (by default)
# Each Bowtie 2 instance is going to be run with 4 threads. Please monitor performance closely and tune down if needed!
# chr NC_035780.1 (65668440 bp)
# chr NC_035781.1 (61752955 bp)
# chr NC_035782.1 (77061148 bp)
# chr NC_035783.1 (59691872 bp)
# chr NC_035784.1 (98698416 bp)
# chr NC_035785.1 (51258098 bp)
# chr NC_035786.1 (57830854 bp)
# chr NC_035787.1 (75944018 bp)
# chr NC_035788.1 (104168038 bp)
# chr NC_035789.1 (32650045 bp)
# chr NC_007175.2 (17244 bp)
#
# Number of paired-end alignments with a unique best hit:	1597
# Mapping efficiency:	16.0%
#
# Sequence pairs with no alignments under any condition:	7531
# Sequence pairs did not map uniquely:	872
# Sequence pairs which were discarded because genomic sequence could not be extracted:	0
#
# Number of sequence pairs with unique best (first) alignment came from the bowtie output:
# CT/GA/CT:	282	((converted) top strand)
# GA/CT/CT:	524	(complementary to (converted) top strand)
# GA/CT/GA:	511	(complementary to (converted) bottom strand)
# CT/GA/GA:	280	((converted) bottom strand)
#
# FastQ format assumed (by default)
# Each Bowtie 2 instance is going to be run with 4 threads. Please monitor performance closely and tune down if needed!
# chr NC_035780.1 (65668440 bp)
# chr NC_035781.1 (61752955 bp)
# chr NC_035782.1 (77061148 bp)
# chr NC_035783.1 (59691872 bp)
# chr NC_035784.1 (98698416 bp)
# chr NC_035785.1 (51258098 bp)
# chr NC_035786.1 (57830854 bp)
# chr NC_035787.1 (75944018 bp)
# chr NC_035788.1 (104168038 bp)
# chr NC_035789.1 (32650045 bp)
# chr NC_007175.2 (17244 bp)
#
# Number of paired-end alignments with a unique best hit:	4450
# Mapping efficiency:	44.5%
#
# Sequence pairs with no alignments under any condition:	3958
# Sequence pairs did not map uniquely:	1592
# Sequence pairs which were discarded because genomic sequence could not be extracted:	0
#
# Number of sequence pairs with unique best (first) alignment came from the bowtie output:
# CT/GA/CT:	765	((converted) top strand)
# GA/CT/CT:	1525	(complementary to (converted) top strand)
# GA/CT/GA:	1487	(complementary to (converted) bottom strand)
# CT/GA/GA:	673	((converted) bottom strand)
#
# FastQ format assumed (by default)
# Each Bowtie 2 instance is going to be run with 4 threads. Please monitor performance closely and tune down if needed!
# chr NC_035780.1 (65668440 bp)
# chr NC_035781.1 (61752955 bp)
# chr NC_035782.1 (77061148 bp)
# chr NC_035783.1 (59691872 bp)
# chr NC_035784.1 (98698416 bp)
# chr NC_035785.1 (51258098 bp)
# chr NC_035786.1 (57830854 bp)
# chr NC_035787.1 (75944018 bp)
# chr NC_035788.1 (104168038 bp)
# chr NC_035789.1 (32650045 bp)
# chr NC_007175.2 (17244 bp)
#
# Number of paired-end alignments with a unique best hit:	1141
# Mapping efficiency:	11.4%
#
# Sequence pairs with no alignments under any condition:	8385
# Sequence pairs did not map uniquely:	474
# Sequence pairs which were discarded because genomic sequence could not be extracted:	0
#
# Number of sequence pairs with unique best (first) alignment came from the bowtie output:
# CT/GA/CT:	182	((converted) top strand)
# GA/CT/CT:	379	(complementary to (converted) top strand)
# GA/CT/GA:	394	(complementary to (converted) bottom strand)
# CT/GA/GA:	186	((converted) bottom strand)
#
# FastQ format assumed (by default)
# Each Bowtie 2 instance is going to be run with 4 threads. Please monitor performance closely and tune down if needed!
# chr NC_035780.1 (65668440 bp)
# chr NC_035781.1 (61752955 bp)
# chr NC_035782.1 (77061148 bp)
# chr NC_035783.1 (59691872 bp)
# chr NC_035784.1 (98698416 bp)
# chr NC_035785.1 (51258098 bp)
# chr NC_035786.1 (57830854 bp)
# chr NC_035787.1 (75944018 bp)
# chr NC_035788.1 (104168038 bp)
# chr NC_035789.1 (32650045 bp)
# chr NC_007175.2 (17244 bp)
#
# Number of paired-end alignments with a unique best hit:	230
# Mapping efficiency:	2.3%
#
# Sequence pairs with no alignments under any condition:	9632
# Sequence pairs did not map uniquely:	138
# Sequence pairs which were discarded because genomic sequence could not be extracted:	0
#
# Number of sequence pairs with unique best (first) alignment came from the bowtie output:
# CT/GA/CT:	25	((converted) top strand)
# GA/CT/CT:	88	(complementary to (converted) top strand)
# GA/CT/GA:	88	(complementary to (converted) bottom strand)
# CT/GA/GA:	29	((converted) bottom strand)
#
# FastQ format assumed (by default)
# Each Bowtie 2 instance is going to be run with 4 threads. Please monitor performance closely and tune down if needed!
# chr NC_035780.1 (65668440 bp)
# chr NC_035781.1 (61752955 bp)
# chr NC_035782.1 (77061148 bp)
# chr NC_035783.1 (59691872 bp)
# chr NC_035784.1 (98698416 bp)
# chr NC_035785.1 (51258098 bp)
# chr NC_035786.1 (57830854 bp)
# chr NC_035787.1 (75944018 bp)
# chr NC_035788.1 (104168038 bp)
# chr NC_035789.1 (32650045 bp)
# chr NC_007175.2 (17244 bp)
#
# Number of paired-end alignments with a unique best hit:	1109
# Mapping efficiency:	11.1%
#
# Sequence pairs with no alignments under any condition:	8480
# Sequence pairs did not map uniquely:	411
# Sequence pairs which were discarded because genomic sequence could not be extracted:	0
#
# Number of sequence pairs with unique best (first) alignment came from the bowtie output:
# CT/GA/CT:	152	((converted) top strand)
# GA/CT/CT:	394	(complementary to (converted) top strand)
# GA/CT/GA:	423	(complementary to (converted) bottom strand)
# CT/GA/GA:	140	((converted) bottom strand)
#
# FastQ format assumed (by default)
# Each Bowtie 2 instance is going to be run with 4 threads. Please monitor performance closely and tune down if needed!
# chr NC_035780.1 (65668440 bp)
# chr NC_035781.1 (61752955 bp)
# chr NC_035782.1 (77061148 bp)
# chr NC_035783.1 (59691872 bp)
# chr NC_035784.1 (98698416 bp)
# chr NC_035785.1 (51258098 bp)
# chr NC_035786.1 (57830854 bp)
# chr NC_035787.1 (75944018 bp)
# chr NC_035788.1 (104168038 bp)
# chr NC_035789.1 (32650045 bp)
# chr NC_007175.2 (17244 bp)
#
# Number of paired-end alignments with a unique best hit:	1839
# Mapping efficiency:	18.4%
#
# Sequence pairs with no alignments under any condition:	7508
# Sequence pairs did not map uniquely:	653
# Sequence pairs which were discarded because genomic sequence could not be extracted:	0
#
# Number of sequence pairs with unique best (first) alignment came from the bowtie output:
# CT/GA/CT:	283	((converted) top strand)
# GA/CT/CT:	656	(complementary to (converted) top strand)
# GA/CT/GA:	622	(complementary to (converted) bottom strand)
# CT/GA/GA:	278	((converted) bottom strand)
#
# FastQ format assumed (by default)
# Each Bowtie 2 instance is going to be run with 4 threads. Please monitor performance closely and tune down if needed!
# chr NC_035780.1 (65668440 bp)
# chr NC_035781.1 (61752955 bp)
# chr NC_035782.1 (77061148 bp)
# chr NC_035783.1 (59691872 bp)
# chr NC_035784.1 (98698416 bp)
# chr NC_035785.1 (51258098 bp)
# chr NC_035786.1 (57830854 bp)
# chr NC_035787.1 (75944018 bp)
# chr NC_035788.1 (104168038 bp)
# chr NC_035789.1 (32650045 bp)
# chr NC_007175.2 (17244 bp)
#
# Number of paired-end alignments with a unique best hit:	1922
# Mapping efficiency:	19.2%
#
# Sequence pairs with no alignments under any condition:	7404
# Sequence pairs did not map uniquely:	674
# Sequence pairs which were discarded because genomic sequence could not be extracted:	0
#
# Number of sequence pairs with unique best (first) alignment came from the bowtie output:
# CT/GA/CT:	290	((converted) top strand)
# GA/CT/CT:	670	(complementary to (converted) top strand)
# GA/CT/GA:	671	(complementary to (converted) bottom strand)
# CT/GA/GA:	291	((converted) bottom strand)
#
# FastQ format assumed (by default)
# Each Bowtie 2 instance is going to be run with 4 threads. Please monitor performance closely and tune down if needed!
# chr NC_035780.1 (65668440 bp)
# chr NC_035781.1 (61752955 bp)
# chr NC_035782.1 (77061148 bp)
# chr NC_035783.1 (59691872 bp)
# chr NC_035784.1 (98698416 bp)
# chr NC_035785.1 (51258098 bp)
# chr NC_035786.1 (57830854 bp)
# chr NC_035787.1 (75944018 bp)
# chr NC_035788.1 (104168038 bp)
# chr NC_035789.1 (32650045 bp)
# chr NC_007175.2 (17244 bp)
#
# Number of paired-end alignments with a unique best hit:	3584
# Mapping efficiency:	35.8%
#
# Sequence pairs with no alignments under any condition:	4433
# Sequence pairs did not map uniquely:	1983
# Sequence pairs which were discarded because genomic sequence could not be extracted:	0
#
# Number of sequence pairs with unique best (first) alignment came from the bowtie output:
# CT/GA/CT:	719	((converted) top strand)
# GA/CT/CT:	1109	(complementary to (converted) top strand)
# GA/CT/GA:	1063	(complementary to (converted) bottom strand)
# CT/GA/GA:	693	((converted) bottom strand)
#
# FastQ format assumed (by default)
# Each Bowtie 2 instance is going to be run with 4 threads. Please monitor performance closely and tune down if needed!
# chr NC_035780.1 (65668440 bp)
# chr NC_035781.1 (61752955 bp)
# chr NC_035782.1 (77061148 bp)
# chr NC_035783.1 (59691872 bp)
# chr NC_035784.1 (98698416 bp)
# chr NC_035785.1 (51258098 bp)
# chr NC_035786.1 (57830854 bp)
# chr NC_035787.1 (75944018 bp)
# chr NC_035788.1 (104168038 bp)
# chr NC_035789.1 (32650045 bp)
# chr NC_007175.2 (17244 bp)
#
# Number of paired-end alignments with a unique best hit:	3226
# Mapping efficiency:	32.3%
#
# Sequence pairs with no alignments under any condition:	4906
# Sequence pairs did not map uniquely:	1868
# Sequence pairs which were discarded because genomic sequence could not be extracted:	0
#
# Number of sequence pairs with unique best (first) alignment came from the bowtie output:
# CT/GA/CT:	618	((converted) top strand)
# GA/CT/CT:	971	(complementary to (converted) top strand)
# GA/CT/GA:	984	(complementary to (converted) bottom strand)
# CT/GA/GA:	653	((converted) bottom strand)
#
# FastQ format assumed (by default)
# Each Bowtie 2 instance is going to be run with 4 threads. Please monitor performance closely and tune down if needed!
# chr NC_035780.1 (65668440 bp)
# chr NC_035781.1 (61752955 bp)
# chr NC_035782.1 (77061148 bp)
# chr NC_035783.1 (59691872 bp)
# chr NC_035784.1 (98698416 bp)
# chr NC_035785.1 (51258098 bp)
# chr NC_035786.1 (57830854 bp)
# chr NC_035787.1 (75944018 bp)
# chr NC_035788.1 (104168038 bp)
# chr NC_035789.1 (32650045 bp)
# chr NC_007175.2 (17244 bp)
#
# Number of paired-end alignments with a unique best hit:	4306
# Mapping efficiency:	43.1%
#
# Sequence pairs with no alignments under any condition:	4186
# Sequence pairs did not map uniquely:	1508
# Sequence pairs which were discarded because genomic sequence could not be extracted:	0
#
# Number of sequence pairs with unique best (first) alignment came from the bowtie output:
# CT/GA/CT:	735	((converted) top strand)
# GA/CT/CT:	1361	(complementary to (converted) top strand)
# GA/CT/GA:	1380	(complementary to (converted) bottom strand)
# CT/GA/GA:	830	((converted) bottom strand)

# %%
ls
# Out:
# 10_32_S32_L001_R1_001_bismark_bt2_PE_report.txt
# 10_32_S32_L001_R1_001_bismark_bt2_pe.bam
# 11_37_S37_L001_R1_001_bismark_bt2_PE_report.txt
# 11_37_S37_L001_R1_001_bismark_bt2_pe.bam
# 12_38_S38_L001_R1_001_bismark_bt2_PE_report.txt
# 12_38_S38_L001_R1_001_bismark_bt2_pe.bam
# 13_33_S33_L001_R1_001_bismark_bt2_PE_report.txt
# 13_33_S33_L001_R1_001_bismark_bt2_pe.bam
# 14_34_S34_L001_R1_001_bismark_bt2_PE_report.txt
# 14_34_S34_L001_R1_001_bismark_bt2_pe.bam
# 15_39_S39_L001_R1_001_bismark_bt2_PE_report.txt
# 15_39_S39_L001_R1_001_bismark_bt2_pe.bam
# 16_40_S40_L001_R1_001_bismark_bt2_PE_report.txt
# 16_40_S40_L001_R1_001_bismark_bt2_pe.bam
# 17_9_S9_L001_R1_001_bismark_bt2_PE_report.txt
# 17_9_S9_L001_R1_001_bismark_bt2_pe.bam
# 18_10_S10_L001_R1_001_bismark_bt2_PE_report.txt
# 18_10_S10_L001_R1_001_bismark_bt2_pe.bam
# 19_7_S7_L001_R1_001_bismark_bt2_PE_report.txt
# 19_7_S7_L001_R1_001_bismark_bt2_pe.bam
# 1_25_S25_L001_R1_001_bismark_bt2_PE_report.txt
# 1_25_S25_L001_R1_001_bismark_bt2_pe.bam
# 20_8_S8_L001_R1_001_bismark_bt2_PE_report.txt
# 20_8_S8_L001_R1_001_bismark_bt2_pe.bam
# 2_26_S26_L001_R1_001_bismark_bt2_PE_report.txt
# 2_26_S26_L001_R1_001_bismark_bt2_pe.bam
# 3_27_S27_L001_R1_001_bismark_bt2_PE_report.txt
# 3_27_S27_L001_R1_001_bismark_bt2_pe.bam
# 4_28_S28_L001_R1_001_bismark_bt2_PE_report.txt
# 4_28_S28_L001_R1_001_bismark_bt2_pe.bam
# 5_35_S35_L001_R1_001_bismark_bt2_PE_report.txt
# 5_35_S35_L001_R1_001_bismark_bt2_pe.bam
# 6_36_S36_L001_R1_001_bismark_bt2_PE_report.txt
# 6_36_S36_L001_R1_001_bismark_bt2_pe.bam
# 7_29_S29_L001_R1_001_bismark_bt2_PE_report.txt
# 7_29_S29_L001_R1_001_bismark_bt2_pe.bam
# 8_30_S30_L001_R1_001_bismark_bt2_PE_report.txt
# 8_30_S30_L001_R1_001_bismark_bt2_pe.bam
# 9_31_S31_L001_R1_001_bismark_bt2_PE_report.txt
# 9_31_S31_L001_R1_001_bismark_bt2_pe.bam
# bismark.err

# %%
# %%bash
#
# /Applications/bioinfo/Bismark_v0.19.0/deduplicate_bismark \
# --bam -p \
# *.bam \
# 2> dedup.err
# Out:
# Now testing Bismark result file 10_32_S32_L001_R1_001_bismark_bt2_pe.bam for positional sorting (which would be bad...)	skipping header line:	@HD	VN:1.0	SO:unsorted
# skipping header line:	@SQ	SN:NC_035780.1	LN:65668440
# skipping header line:	@SQ	SN:NC_035781.1	LN:61752955
# skipping header line:	@SQ	SN:NC_035782.1	LN:77061148
# skipping header line:	@SQ	SN:NC_035783.1	LN:59691872
# skipping header line:	@SQ	SN:NC_035784.1	LN:98698416
# skipping header line:	@SQ	SN:NC_035785.1	LN:51258098
# skipping header line:	@SQ	SN:NC_035786.1	LN:57830854
# skipping header line:	@SQ	SN:NC_035787.1	LN:75944018
# skipping header line:	@SQ	SN:NC_035788.1	LN:104168038
# skipping header line:	@SQ	SN:NC_035789.1	LN:32650045
# skipping header line:	@SQ	SN:NC_007175.2	LN:17244
# skipping header line:	@PG	ID:Bismark	VN:v0.19.0	CL:"bismark --path_to_bowtie /Applications/bioinfo/bowtie2-2.3.4.1-macos-x86_64 --genome /Volumes/Serine/wd/18-03-15/genome --score_min L,0,-0.6 -p 4 -u 10000 --non_directional -1 /Volumes/Serine/wd/18-03-14/10_32_S32_L001_R1_001.fastq.gz -2 /Volumes/Serine/wd/18-03-14/10_32_S32_L001_R2_001.fastq.gz"
#
# Now testing Bismark result file 11_37_S37_L001_R1_001_bismark_bt2_pe.bam for positional sorting (which would be bad...)	skipping header line:	@HD	VN:1.0	SO:unsorted
# skipping header line:	@SQ	SN:NC_035780.1	LN:65668440
# skipping header line:	@SQ	SN:NC_035781.1	LN:61752955
# skipping header line:	@SQ	SN:NC_035782.1	LN:77061148
# skipping header line:	@SQ	SN:NC_035783.1	LN:59691872
# skipping header line:	@SQ	SN:NC_035784.1	LN:98698416
# skipping header line:	@SQ	SN:NC_035785.1	LN:51258098
# skipping header line:	@SQ	SN:NC_035786.1	LN:57830854
# skipping header line:	@SQ	SN:NC_035787.1	LN:75944018
# skipping header line:	@SQ	SN:NC_035788.1	LN:104168038
# skipping header line:	@SQ	SN:NC_035789.1	LN:32650045
# skipping header line:	@SQ	SN:NC_007175.2	LN:17244
# skipping header line:	@PG	ID:Bismark	VN:v0.19.0	CL:"bismark --path_to_bowtie /Applications/bioinfo/bowtie2-2.3.4.1-macos-x86_64 --genome /Volumes/Serine/wd/18-03-15/genome --score_min L,0,-0.6 -p 4 -u 10000 --non_directional -1 /Volumes/Serine/wd/18-03-14/11_37_S37_L001_R1_001.fastq.gz -2 /Volumes/Serine/wd/18-03-14/11_37_S37_L001_R2_001.fastq.gz"
#
# Now testing Bismark result file 12_38_S38_L001_R1_001_bismark_bt2_pe.bam for positional sorting (which would be bad...)	skipping header line:	@HD	VN:1.0	SO:unsorted
# skipping header line:	@SQ	SN:NC_035780.1	LN:65668440
# skipping header line:	@SQ	SN:NC_035781.1	LN:61752955
# skipping header line:	@SQ	SN:NC_035782.1	LN:77061148
# skipping header line:	@SQ	SN:NC_035783.1	LN:59691872
# skipping header line:	@SQ	SN:NC_035784.1	LN:98698416
# skipping header line:	@SQ	SN:NC_035785.1	LN:51258098
# skipping header line:	@SQ	SN:NC_035786.1	LN:57830854
# skipping header line:	@SQ	SN:NC_035787.1	LN:75944018
# skipping header line:	@SQ	SN:NC_035788.1	LN:104168038
# skipping header line:	@SQ	SN:NC_035789.1	LN:32650045
# skipping header line:	@SQ	SN:NC_007175.2	LN:17244
# skipping header line:	@PG	ID:Bismark	VN:v0.19.0	CL:"bismark --path_to_bowtie /Applications/bioinfo/bowtie2-2.3.4.1-macos-x86_64 --genome /Volumes/Serine/wd/18-03-15/genome --score_min L,0,-0.6 -p 4 -u 10000 --non_directional -1 /Volumes/Serine/wd/18-03-14/12_38_S38_L001_R1_001.fastq.gz -2 /Volumes/Serine/wd/18-03-14/12_38_S38_L001_R2_001.fastq.gz"
#
# Now testing Bismark result file 13_33_S33_L001_R1_001_bismark_bt2_pe.bam for positional sorting (which would be bad...)	skipping header line:	@HD	VN:1.0	SO:unsorted
# skipping header line:	@SQ	SN:NC_035780.1	LN:65668440
# skipping header line:	@SQ	SN:NC_035781.1	LN:61752955
# skipping header line:	@SQ	SN:NC_035782.1	LN:77061148
# skipping header line:	@SQ	SN:NC_035783.1	LN:59691872
# skipping header line:	@SQ	SN:NC_035784.1	LN:98698416
# skipping header line:	@SQ	SN:NC_035785.1	LN:51258098
# skipping header line:	@SQ	SN:NC_035786.1	LN:57830854
# skipping header line:	@SQ	SN:NC_035787.1	LN:75944018
# skipping header line:	@SQ	SN:NC_035788.1	LN:104168038
# skipping header line:	@SQ	SN:NC_035789.1	LN:32650045
# skipping header line:	@SQ	SN:NC_007175.2	LN:17244
# skipping header line:	@PG	ID:Bismark	VN:v0.19.0	CL:"bismark --path_to_bowtie /Applications/bioinfo/bowtie2-2.3.4.1-macos-x86_64 --genome /Volumes/Serine/wd/18-03-15/genome --score_min L,0,-0.6 -p 4 -u 10000 --non_directional -1 /Volumes/Serine/wd/18-03-14/13_33_S33_L001_R1_001.fastq.gz -2 /Volumes/Serine/wd/18-03-14/13_33_S33_L001_R2_001.fastq.gz"
#
# Now testing Bismark result file 14_34_S34_L001_R1_001_bismark_bt2_pe.bam for positional sorting (which would be bad...)	skipping header line:	@HD	VN:1.0	SO:unsorted
# skipping header line:	@SQ	SN:NC_035780.1	LN:65668440
# skipping header line:	@SQ	SN:NC_035781.1	LN:61752955
# skipping header line:	@SQ	SN:NC_035782.1	LN:77061148
# skipping header line:	@SQ	SN:NC_035783.1	LN:59691872
# skipping header line:	@SQ	SN:NC_035784.1	LN:98698416
# skipping header line:	@SQ	SN:NC_035785.1	LN:51258098
# skipping header line:	@SQ	SN:NC_035786.1	LN:57830854
# skipping header line:	@SQ	SN:NC_035787.1	LN:75944018
# skipping header line:	@SQ	SN:NC_035788.1	LN:104168038
# skipping header line:	@SQ	SN:NC_035789.1	LN:32650045
# skipping header line:	@SQ	SN:NC_007175.2	LN:17244
# skipping header line:	@PG	ID:Bismark	VN:v0.19.0	CL:"bismark --path_to_bowtie /Applications/bioinfo/bowtie2-2.3.4.1-macos-x86_64 --genome /Volumes/Serine/wd/18-03-15/genome --score_min L,0,-0.6 -p 4 -u 10000 --non_directional -1 /Volumes/Serine/wd/18-03-14/14_34_S34_L001_R1_001.fastq.gz -2 /Volumes/Serine/wd/18-03-14/14_34_S34_L001_R2_001.fastq.gz"
#
# Now testing Bismark result file 15_39_S39_L001_R1_001_bismark_bt2_pe.bam for positional sorting (which would be bad...)	skipping header line:	@HD	VN:1.0	SO:unsorted
# skipping header line:	@SQ	SN:NC_035780.1	LN:65668440
# skipping header line:	@SQ	SN:NC_035781.1	LN:61752955
# skipping header line:	@SQ	SN:NC_035782.1	LN:77061148
# skipping header line:	@SQ	SN:NC_035783.1	LN:59691872
# skipping header line:	@SQ	SN:NC_035784.1	LN:98698416
# skipping header line:	@SQ	SN:NC_035785.1	LN:51258098
# skipping header line:	@SQ	SN:NC_035786.1	LN:57830854
# skipping header line:	@SQ	SN:NC_035787.1	LN:75944018
# skipping header line:	@SQ	SN:NC_035788.1	LN:104168038
# skipping header line:	@SQ	SN:NC_035789.1	LN:32650045
# skipping header line:	@SQ	SN:NC_007175.2	LN:17244
# skipping header line:	@PG	ID:Bismark	VN:v0.19.0	CL:"bismark --path_to_bowtie /Applications/bioinfo/bowtie2-2.3.4.1-macos-x86_64 --genome /Volumes/Serine/wd/18-03-15/genome --score_min L,0,-0.6 -p 4 -u 10000 --non_directional -1 /Volumes/Serine/wd/18-03-14/15_39_S39_L001_R1_001.fastq.gz -2 /Volumes/Serine/wd/18-03-14/15_39_S39_L001_R2_001.fastq.gz"
#
# Now testing Bismark result file 16_40_S40_L001_R1_001_bismark_bt2_pe.bam for positional sorting (which would be bad...)	skipping header line:	@HD	VN:1.0	SO:unsorted
# skipping header line:	@SQ	SN:NC_035780.1	LN:65668440
# skipping header line:	@SQ	SN:NC_035781.1	LN:61752955
# skipping header line:	@SQ	SN:NC_035782.1	LN:77061148
# skipping header line:	@SQ	SN:NC_035783.1	LN:59691872
# skipping header line:	@SQ	SN:NC_035784.1	LN:98698416
# skipping header line:	@SQ	SN:NC_035785.1	LN:51258098
# skipping header line:	@SQ	SN:NC_035786.1	LN:57830854
# skipping header line:	@SQ	SN:NC_035787.1	LN:75944018
# skipping header line:	@SQ	SN:NC_035788.1	LN:104168038
# skipping header line:	@SQ	SN:NC_035789.1	LN:32650045
# skipping header line:	@SQ	SN:NC_007175.2	LN:17244
# skipping header line:	@PG	ID:Bismark	VN:v0.19.0	CL:"bismark --path_to_bowtie /Applications/bioinfo/bowtie2-2.3.4.1-macos-x86_64 --genome /Volumes/Serine/wd/18-03-15/genome --score_min L,0,-0.6 -p 4 -u 10000 --non_directional -1 /Volumes/Serine/wd/18-03-14/16_40_S40_L001_R1_001.fastq.gz -2 /Volumes/Serine/wd/18-03-14/16_40_S40_L001_R2_001.fastq.gz"
#
# Now testing Bismark result file 17_9_S9_L001_R1_001_bismark_bt2_pe.bam for positional sorting (which would be bad...)	skipping header line:	@HD	VN:1.0	SO:unsorted
# skipping header line:	@SQ	SN:NC_035780.1	LN:65668440
# skipping header line:	@SQ	SN:NC_035781.1	LN:61752955
# skipping header line:	@SQ	SN:NC_035782.1	LN:77061148
# skipping header line:	@SQ	SN:NC_035783.1	LN:59691872
# skipping header line:	@SQ	SN:NC_035784.1	LN:98698416
# skipping header line:	@SQ	SN:NC_035785.1	LN:51258098
# skipping header line:	@SQ	SN:NC_035786.1	LN:57830854
# skipping header line:	@SQ	SN:NC_035787.1	LN:75944018
# skipping header line:	@SQ	SN:NC_035788.1	LN:104168038
# skipping header line:	@SQ	SN:NC_035789.1	LN:32650045
# skipping header line:	@SQ	SN:NC_007175.2	LN:17244
# skipping header line:	@PG	ID:Bismark	VN:v0.19.0	CL:"bismark --path_to_bowtie /Applications/bioinfo/bowtie2-2.3.4.1-macos-x86_64 --genome /Volumes/Serine/wd/18-03-15/genome --score_min L,0,-0.6 -p 4 -u 10000 --non_directional -1 /Volumes/Serine/wd/18-03-14/17_9_S9_L001_R1_001.fastq.gz -2 /Volumes/Serine/wd/18-03-14/17_9_S9_L001_R2_001.fastq.gz"
#
# Now testing Bismark result file 18_10_S10_L001_R1_001_bismark_bt2_pe.bam for positional sorting (which would be bad...)	skipping header line:	@HD	VN:1.0	SO:unsorted
# skipping header line:	@SQ	SN:NC_035780.1	LN:65668440
# skipping header line:	@SQ	SN:NC_035781.1	LN:61752955
# skipping header line:	@SQ	SN:NC_035782.1	LN:77061148
# skipping header line:	@SQ	SN:NC_035783.1	LN:59691872
# skipping header line:	@SQ	SN:NC_035784.1	LN:98698416
# skipping header line:	@SQ	SN:NC_035785.1	LN:51258098
# skipping header line:	@SQ	SN:NC_035786.1	LN:57830854
# skipping header line:	@SQ	SN:NC_035787.1	LN:75944018
# skipping header line:	@SQ	SN:NC_035788.1	LN:104168038
# skipping header line:	@SQ	SN:NC_035789.1	LN:32650045
# skipping header line:	@SQ	SN:NC_007175.2	LN:17244
# skipping header line:	@PG	ID:Bismark	VN:v0.19.0	CL:"bismark --path_to_bowtie /Applications/bioinfo/bowtie2-2.3.4.1-macos-x86_64 --genome /Volumes/Serine/wd/18-03-15/genome --score_min L,0,-0.6 -p 4 -u 10000 --non_directional -1 /Volumes/Serine/wd/18-03-14/18_10_S10_L001_R1_001.fastq.gz -2 /Volumes/Serine/wd/18-03-14/18_10_S10_L001_R2_001.fastq.gz"
#
# Now testing Bismark result file 19_7_S7_L001_R1_001_bismark_bt2_pe.bam for positional sorting (which would be bad...)	skipping header line:	@HD	VN:1.0	SO:unsorted
# skipping header line:	@SQ	SN:NC_035780.1	LN:65668440
# skipping header line:	@SQ	SN:NC_035781.1	LN:61752955
# skipping header line:	@SQ	SN:NC_035782.1	LN:77061148
# skipping header line:	@SQ	SN:NC_035783.1	LN:59691872
# skipping header line:	@SQ	SN:NC_035784.1	LN:98698416
# skipping header line:	@SQ	SN:NC_035785.1	LN:51258098
# skipping header line:	@SQ	SN:NC_035786.1	LN:57830854
# skipping header line:	@SQ	SN:NC_035787.1	LN:75944018
# skipping header line:	@SQ	SN:NC_035788.1	LN:104168038
# skipping header line:	@SQ	SN:NC_035789.1	LN:32650045
# skipping header line:	@SQ	SN:NC_007175.2	LN:17244
# skipping header line:	@PG	ID:Bismark	VN:v0.19.0	CL:"bismark --path_to_bowtie /Applications/bioinfo/bowtie2-2.3.4.1-macos-x86_64 --genome /Volumes/Serine/wd/18-03-15/genome --score_min L,0,-0.6 -p 4 -u 10000 --non_directional -1 /Volumes/Serine/wd/18-03-14/19_7_S7_L001_R1_001.fastq.gz -2 /Volumes/Serine/wd/18-03-14/19_7_S7_L001_R2_001.fastq.gz"
#
# Now testing Bismark result file 1_25_S25_L001_R1_001_bismark_bt2_pe.bam for positional sorting (which would be bad...)	skipping header line:	@HD	VN:1.0	SO:unsorted
# skipping header line:	@SQ	SN:NC_035780.1	LN:65668440
# skipping header line:	@SQ	SN:NC_035781.1	LN:61752955
# skipping header line:	@SQ	SN:NC_035782.1	LN:77061148
# skipping header line:	@SQ	SN:NC_035783.1	LN:59691872
# skipping header line:	@SQ	SN:NC_035784.1	LN:98698416
# skipping header line:	@SQ	SN:NC_035785.1	LN:51258098
# skipping header line:	@SQ	SN:NC_035786.1	LN:57830854
# skipping header line:	@SQ	SN:NC_035787.1	LN:75944018
# skipping header line:	@SQ	SN:NC_035788.1	LN:104168038
# skipping header line:	@SQ	SN:NC_035789.1	LN:32650045
# skipping header line:	@SQ	SN:NC_007175.2	LN:17244
# skipping header line:	@PG	ID:Bismark	VN:v0.19.0	CL:"bismark --path_to_bowtie /Applications/bioinfo/bowtie2-2.3.4.1-macos-x86_64 --genome /Volumes/Serine/wd/18-03-15/genome --score_min L,0,-0.6 -p 4 -u 10000 --non_directional -1 /Volumes/Serine/wd/18-03-14/1_25_S25_L001_R1_001.fastq.gz -2 /Volumes/Serine/wd/18-03-14/1_25_S25_L001_R2_001.fastq.gz"
#
# Now testing Bismark result file 20_8_S8_L001_R1_001_bismark_bt2_pe.bam for positional sorting (which would be bad...)	skipping header line:	@HD	VN:1.0	SO:unsorted
# skipping header line:	@SQ	SN:NC_035780.1	LN:65668440
# skipping header line:	@SQ	SN:NC_035781.1	LN:61752955
# skipping header line:	@SQ	SN:NC_035782.1	LN:77061148
# skipping header line:	@SQ	SN:NC_035783.1	LN:59691872
# skipping header line:	@SQ	SN:NC_035784.1	LN:98698416
# skipping header line:	@SQ	SN:NC_035785.1	LN:51258098
# skipping header line:	@SQ	SN:NC_035786.1	LN:57830854
# skipping header line:	@SQ	SN:NC_035787.1	LN:75944018
# skipping header line:	@SQ	SN:NC_035788.1	LN:104168038
# skipping header line:	@SQ	SN:NC_035789.1	LN:32650045
# skipping header line:	@SQ	SN:NC_007175.2	LN:17244
# skipping header line:	@PG	ID:Bismark	VN:v0.19.0	CL:"bismark --path_to_bowtie /Applications/bioinfo/bowtie2-2.3.4.1-macos-x86_64 --genome /Volumes/Serine/wd/18-03-15/genome --score_min L,0,-0.6 -p 4 -u 10000 --non_directional -1 /Volumes/Serine/wd/18-03-14/20_8_S8_L001_R1_001.fastq.gz -2 /Volumes/Serine/wd/18-03-14/20_8_S8_L001_R2_001.fastq.gz"
#
# Now testing Bismark result file 2_26_S26_L001_R1_001_bismark_bt2_pe.bam for positional sorting (which would be bad...)	skipping header line:	@HD	VN:1.0	SO:unsorted
# skipping header line:	@SQ	SN:NC_035780.1	LN:65668440
# skipping header line:	@SQ	SN:NC_035781.1	LN:61752955
# skipping header line:	@SQ	SN:NC_035782.1	LN:77061148
# skipping header line:	@SQ	SN:NC_035783.1	LN:59691872
# skipping header line:	@SQ	SN:NC_035784.1	LN:98698416
# skipping header line:	@SQ	SN:NC_035785.1	LN:51258098
# skipping header line:	@SQ	SN:NC_035786.1	LN:57830854
# skipping header line:	@SQ	SN:NC_035787.1	LN:75944018
# skipping header line:	@SQ	SN:NC_035788.1	LN:104168038
# skipping header line:	@SQ	SN:NC_035789.1	LN:32650045
# skipping header line:	@SQ	SN:NC_007175.2	LN:17244
# skipping header line:	@PG	ID:Bismark	VN:v0.19.0	CL:"bismark --path_to_bowtie /Applications/bioinfo/bowtie2-2.3.4.1-macos-x86_64 --genome /Volumes/Serine/wd/18-03-15/genome --score_min L,0,-0.6 -p 4 -u 10000 --non_directional -1 /Volumes/Serine/wd/18-03-14/2_26_S26_L001_R1_001.fastq.gz -2 /Volumes/Serine/wd/18-03-14/2_26_S26_L001_R2_001.fastq.gz"
#
# Now testing Bismark result file 3_27_S27_L001_R1_001_bismark_bt2_pe.bam for positional sorting (which would be bad...)	skipping header line:	@HD	VN:1.0	SO:unsorted
# skipping header line:	@SQ	SN:NC_035780.1	LN:65668440
# skipping header line:	@SQ	SN:NC_035781.1	LN:61752955
# skipping header line:	@SQ	SN:NC_035782.1	LN:77061148
# skipping header line:	@SQ	SN:NC_035783.1	LN:59691872
# skipping header line:	@SQ	SN:NC_035784.1	LN:98698416
# skipping header line:	@SQ	SN:NC_035785.1	LN:51258098
# skipping header line:	@SQ	SN:NC_035786.1	LN:57830854
# skipping header line:	@SQ	SN:NC_035787.1	LN:75944018
# skipping header line:	@SQ	SN:NC_035788.1	LN:104168038
# skipping header line:	@SQ	SN:NC_035789.1	LN:32650045
# skipping header line:	@SQ	SN:NC_007175.2	LN:17244
# skipping header line:	@PG	ID:Bismark	VN:v0.19.0	CL:"bismark --path_to_bowtie /Applications/bioinfo/bowtie2-2.3.4.1-macos-x86_64 --genome /Volumes/Serine/wd/18-03-15/genome --score_min L,0,-0.6 -p 4 -u 10000 --non_directional -1 /Volumes/Serine/wd/18-03-14/3_27_S27_L001_R1_001.fastq.gz -2 /Volumes/Serine/wd/18-03-14/3_27_S27_L001_R2_001.fastq.gz"
#
# Now testing Bismark result file 4_28_S28_L001_R1_001_bismark_bt2_pe.bam for positional sorting (which would be bad...)	skipping header line:	@HD	VN:1.0	SO:unsorted
# skipping header line:	@SQ	SN:NC_035780.1	LN:65668440
# skipping header line:	@SQ	SN:NC_035781.1	LN:61752955
# skipping header line:	@SQ	SN:NC_035782.1	LN:77061148
# skipping header line:	@SQ	SN:NC_035783.1	LN:59691872
# skipping header line:	@SQ	SN:NC_035784.1	LN:98698416
# skipping header line:	@SQ	SN:NC_035785.1	LN:51258098
# skipping header line:	@SQ	SN:NC_035786.1	LN:57830854
# skipping header line:	@SQ	SN:NC_035787.1	LN:75944018
# skipping header line:	@SQ	SN:NC_035788.1	LN:104168038
# skipping header line:	@SQ	SN:NC_035789.1	LN:32650045
# skipping header line:	@SQ	SN:NC_007175.2	LN:17244
# skipping header line:	@PG	ID:Bismark	VN:v0.19.0	CL:"bismark --path_to_bowtie /Applications/bioinfo/bowtie2-2.3.4.1-macos-x86_64 --genome /Volumes/Serine/wd/18-03-15/genome --score_min L,0,-0.6 -p 4 -u 10000 --non_directional -1 /Volumes/Serine/wd/18-03-14/4_28_S28_L001_R1_001.fastq.gz -2 /Volumes/Serine/wd/18-03-14/4_28_S28_L001_R2_001.fastq.gz"
#
# Now testing Bismark result file 5_35_S35_L001_R1_001_bismark_bt2_pe.bam for positional sorting (which would be bad...)	skipping header line:	@HD	VN:1.0	SO:unsorted
# skipping header line:	@SQ	SN:NC_035780.1	LN:65668440
# skipping header line:	@SQ	SN:NC_035781.1	LN:61752955
# skipping header line:	@SQ	SN:NC_035782.1	LN:77061148
# skipping header line:	@SQ	SN:NC_035783.1	LN:59691872
# skipping header line:	@SQ	SN:NC_035784.1	LN:98698416
# skipping header line:	@SQ	SN:NC_035785.1	LN:51258098
# skipping header line:	@SQ	SN:NC_035786.1	LN:57830854
# skipping header line:	@SQ	SN:NC_035787.1	LN:75944018
# skipping header line:	@SQ	SN:NC_035788.1	LN:104168038
# skipping header line:	@SQ	SN:NC_035789.1	LN:32650045
# skipping header line:	@SQ	SN:NC_007175.2	LN:17244
# skipping header line:	@PG	ID:Bismark	VN:v0.19.0	CL:"bismark --path_to_bowtie /Applications/bioinfo/bowtie2-2.3.4.1-macos-x86_64 --genome /Volumes/Serine/wd/18-03-15/genome --score_min L,0,-0.6 -p 4 -u 10000 --non_directional -1 /Volumes/Serine/wd/18-03-14/5_35_S35_L001_R1_001.fastq.gz -2 /Volumes/Serine/wd/18-03-14/5_35_S35_L001_R2_001.fastq.gz"
#
# Now testing Bismark result file 6_36_S36_L001_R1_001_bismark_bt2_pe.bam for positional sorting (which would be bad...)	skipping header line:	@HD	VN:1.0	SO:unsorted
# skipping header line:	@SQ	SN:NC_035780.1	LN:65668440
# skipping header line:	@SQ	SN:NC_035781.1	LN:61752955
# skipping header line:	@SQ	SN:NC_035782.1	LN:77061148
# skipping header line:	@SQ	SN:NC_035783.1	LN:59691872
# skipping header line:	@SQ	SN:NC_035784.1	LN:98698416
# skipping header line:	@SQ	SN:NC_035785.1	LN:51258098
# skipping header line:	@SQ	SN:NC_035786.1	LN:57830854
# skipping header line:	@SQ	SN:NC_035787.1	LN:75944018
# skipping header line:	@SQ	SN:NC_035788.1	LN:104168038
# skipping header line:	@SQ	SN:NC_035789.1	LN:32650045
# skipping header line:	@SQ	SN:NC_007175.2	LN:17244
# skipping header line:	@PG	ID:Bismark	VN:v0.19.0	CL:"bismark --path_to_bowtie /Applications/bioinfo/bowtie2-2.3.4.1-macos-x86_64 --genome /Volumes/Serine/wd/18-03-15/genome --score_min L,0,-0.6 -p 4 -u 10000 --non_directional -1 /Volumes/Serine/wd/18-03-14/6_36_S36_L001_R1_001.fastq.gz -2 /Volumes/Serine/wd/18-03-14/6_36_S36_L001_R2_001.fastq.gz"
#
# Now testing Bismark result file 7_29_S29_L001_R1_001_bismark_bt2_pe.bam for positional sorting (which would be bad...)	skipping header line:	@HD	VN:1.0	SO:unsorted
# skipping header line:	@SQ	SN:NC_035780.1	LN:65668440
# skipping header line:	@SQ	SN:NC_035781.1	LN:61752955
# skipping header line:	@SQ	SN:NC_035782.1	LN:77061148
# skipping header line:	@SQ	SN:NC_035783.1	LN:59691872
# skipping header line:	@SQ	SN:NC_035784.1	LN:98698416
# skipping header line:	@SQ	SN:NC_035785.1	LN:51258098
# skipping header line:	@SQ	SN:NC_035786.1	LN:57830854
# skipping header line:	@SQ	SN:NC_035787.1	LN:75944018
# skipping header line:	@SQ	SN:NC_035788.1	LN:104168038
# skipping header line:	@SQ	SN:NC_035789.1	LN:32650045
# skipping header line:	@SQ	SN:NC_007175.2	LN:17244
# skipping header line:	@PG	ID:Bismark	VN:v0.19.0	CL:"bismark --path_to_bowtie /Applications/bioinfo/bowtie2-2.3.4.1-macos-x86_64 --genome /Volumes/Serine/wd/18-03-15/genome --score_min L,0,-0.6 -p 4 -u 10000 --non_directional -1 /Volumes/Serine/wd/18-03-14/7_29_S29_L001_R1_001.fastq.gz -2 /Volumes/Serine/wd/18-03-14/7_29_S29_L001_R2_001.fastq.gz"
#
# Now testing Bismark result file 8_30_S30_L001_R1_001_bismark_bt2_pe.bam for positional sorting (which would be bad...)	skipping header line:	@HD	VN:1.0	SO:unsorted
# skipping header line:	@SQ	SN:NC_035780.1	LN:65668440
# skipping header line:	@SQ	SN:NC_035781.1	LN:61752955
# skipping header line:	@SQ	SN:NC_035782.1	LN:77061148
# skipping header line:	@SQ	SN:NC_035783.1	LN:59691872
# skipping header line:	@SQ	SN:NC_035784.1	LN:98698416
# skipping header line:	@SQ	SN:NC_035785.1	LN:51258098
# skipping header line:	@SQ	SN:NC_035786.1	LN:57830854
# skipping header line:	@SQ	SN:NC_035787.1	LN:75944018
# skipping header line:	@SQ	SN:NC_035788.1	LN:104168038
# skipping header line:	@SQ	SN:NC_035789.1	LN:32650045
# skipping header line:	@SQ	SN:NC_007175.2	LN:17244
# skipping header line:	@PG	ID:Bismark	VN:v0.19.0	CL:"bismark --path_to_bowtie /Applications/bioinfo/bowtie2-2.3.4.1-macos-x86_64 --genome /Volumes/Serine/wd/18-03-15/genome --score_min L,0,-0.6 -p 4 -u 10000 --non_directional -1 /Volumes/Serine/wd/18-03-14/8_30_S30_L001_R1_001.fastq.gz -2 /Volumes/Serine/wd/18-03-14/8_30_S30_L001_R2_001.fastq.gz"
#
# Now testing Bismark result file 9_31_S31_L001_R1_001_bismark_bt2_pe.bam for positional sorting (which would be bad...)	skipping header line:	@HD	VN:1.0	SO:unsorted
# skipping header line:	@SQ	SN:NC_035780.1	LN:65668440
# skipping header line:	@SQ	SN:NC_035781.1	LN:61752955
# skipping header line:	@SQ	SN:NC_035782.1	LN:77061148
# skipping header line:	@SQ	SN:NC_035783.1	LN:59691872
# skipping header line:	@SQ	SN:NC_035784.1	LN:98698416
# skipping header line:	@SQ	SN:NC_035785.1	LN:51258098
# skipping header line:	@SQ	SN:NC_035786.1	LN:57830854
# skipping header line:	@SQ	SN:NC_035787.1	LN:75944018
# skipping header line:	@SQ	SN:NC_035788.1	LN:104168038
# skipping header line:	@SQ	SN:NC_035789.1	LN:32650045
# skipping header line:	@SQ	SN:NC_007175.2	LN:17244
# skipping header line:	@PG	ID:Bismark	VN:v0.19.0	CL:"bismark --path_to_bowtie /Applications/bioinfo/bowtie2-2.3.4.1-macos-x86_64 --genome /Volumes/Serine/wd/18-03-15/genome --score_min L,0,-0.6 -p 4 -u 10000 --non_directional -1 /Volumes/Serine/wd/18-03-14/9_31_S31_L001_R1_001.fastq.gz -2 /Volumes/Serine/wd/18-03-14/9_31_S31_L001_R2_001.fastq.gz"

# %%
# %%bash
# /Applications/bioinfo/Bismark_v0.19.0/bismark_methylation_extractor \
# -p --bedGraph --counts --scaffolds \
# --multicore 4 \
# *deduplicated.bam \
# 2> bme.err
# Out:
# Now testing Bismark result file 10_32_S32_L001_R1_001_bismark_bt2_pe.deduplicated.bam for positional sorting (which would be bad...)	10_32_S32_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.1
# 10_32_S32_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.2
# 10_32_S32_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.3
# 10_32_S32_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.4
#
# 10_32_S32_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.1.mbias
# 10_32_S32_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.2.mbias
# 10_32_S32_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.3.mbias
# 10_32_S32_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.4.mbias
#
# /Volumes/Serine/wd/18-07-30/CpG_OT_10_32_S32_L001_R1_001_bismark_bt2_pe.deduplicated.txt	/Volumes/Serine/wd/18-07-30/CpG_CTOT_10_32_S32_L001_R1_001_bismark_bt2_pe.deduplicated.txt	/Volumes/Serine/wd/18-07-30/CpG_CTOB_10_32_S32_L001_R1_001_bismark_bt2_pe.deduplicated.txt	/Volumes/Serine/wd/18-07-30/CpG_OB_10_32_S32_L001_R1_001_bismark_bt2_pe.deduplicated.txt
#
#
# Now testing Bismark result file 11_37_S37_L001_R1_001_bismark_bt2_pe.deduplicated.bam for positional sorting (which would be bad...)	11_37_S37_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.1
# 11_37_S37_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.2
# 11_37_S37_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.3
# 11_37_S37_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.4
#
# 11_37_S37_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.1.mbias
# 11_37_S37_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.2.mbias
# 11_37_S37_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.3.mbias
# 11_37_S37_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.4.mbias
#
# /Volumes/Serine/wd/18-07-30/CpG_OT_11_37_S37_L001_R1_001_bismark_bt2_pe.deduplicated.txt	/Volumes/Serine/wd/18-07-30/CpG_CTOT_11_37_S37_L001_R1_001_bismark_bt2_pe.deduplicated.txt	/Volumes/Serine/wd/18-07-30/CpG_CTOB_11_37_S37_L001_R1_001_bismark_bt2_pe.deduplicated.txt	/Volumes/Serine/wd/18-07-30/CpG_OB_11_37_S37_L001_R1_001_bismark_bt2_pe.deduplicated.txt
#
#
# Now testing Bismark result file 12_38_S38_L001_R1_001_bismark_bt2_pe.deduplicated.bam for positional sorting (which would be bad...)	12_38_S38_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.1
# 12_38_S38_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.2
# 12_38_S38_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.3
# 12_38_S38_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.4
#
# 12_38_S38_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.1.mbias
# 12_38_S38_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.2.mbias
# 12_38_S38_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.3.mbias
# 12_38_S38_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.4.mbias
#
# /Volumes/Serine/wd/18-07-30/CpG_OT_12_38_S38_L001_R1_001_bismark_bt2_pe.deduplicated.txt	/Volumes/Serine/wd/18-07-30/CpG_CTOT_12_38_S38_L001_R1_001_bismark_bt2_pe.deduplicated.txt	/Volumes/Serine/wd/18-07-30/CpG_CTOB_12_38_S38_L001_R1_001_bismark_bt2_pe.deduplicated.txt	/Volumes/Serine/wd/18-07-30/CpG_OB_12_38_S38_L001_R1_001_bismark_bt2_pe.deduplicated.txt
#
#
# Now testing Bismark result file 13_33_S33_L001_R1_001_bismark_bt2_pe.deduplicated.bam for positional sorting (which would be bad...)	13_33_S33_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.1
# 13_33_S33_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.2
# 13_33_S33_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.3
# 13_33_S33_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.4
#
# 13_33_S33_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.1.mbias
# 13_33_S33_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.2.mbias
# 13_33_S33_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.3.mbias
# 13_33_S33_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.4.mbias
#
# /Volumes/Serine/wd/18-07-30/CpG_OT_13_33_S33_L001_R1_001_bismark_bt2_pe.deduplicated.txt	/Volumes/Serine/wd/18-07-30/CpG_CTOT_13_33_S33_L001_R1_001_bismark_bt2_pe.deduplicated.txt	/Volumes/Serine/wd/18-07-30/CpG_CTOB_13_33_S33_L001_R1_001_bismark_bt2_pe.deduplicated.txt	/Volumes/Serine/wd/18-07-30/CpG_OB_13_33_S33_L001_R1_001_bismark_bt2_pe.deduplicated.txt
#
#
# Now testing Bismark result file 14_34_S34_L001_R1_001_bismark_bt2_pe.deduplicated.bam for positional sorting (which would be bad...)	14_34_S34_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.1
# 14_34_S34_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.2
# 14_34_S34_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.3
# 14_34_S34_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.4
#
# 14_34_S34_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.1.mbias
# 14_34_S34_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.2.mbias
# 14_34_S34_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.3.mbias
# 14_34_S34_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.4.mbias
#
# /Volumes/Serine/wd/18-07-30/CpG_OT_14_34_S34_L001_R1_001_bismark_bt2_pe.deduplicated.txt	/Volumes/Serine/wd/18-07-30/CpG_CTOT_14_34_S34_L001_R1_001_bismark_bt2_pe.deduplicated.txt	/Volumes/Serine/wd/18-07-30/CpG_CTOB_14_34_S34_L001_R1_001_bismark_bt2_pe.deduplicated.txt	/Volumes/Serine/wd/18-07-30/CpG_OB_14_34_S34_L001_R1_001_bismark_bt2_pe.deduplicated.txt
#
#
# Now testing Bismark result file 15_39_S39_L001_R1_001_bismark_bt2_pe.deduplicated.bam for positional sorting (which would be bad...)	15_39_S39_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.1
# 15_39_S39_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.2
# 15_39_S39_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.3
# 15_39_S39_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.4
#
# 15_39_S39_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.1.mbias
# 15_39_S39_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.2.mbias
# 15_39_S39_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.3.mbias
# 15_39_S39_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.4.mbias
#
# /Volumes/Serine/wd/18-07-30/CpG_OT_15_39_S39_L001_R1_001_bismark_bt2_pe.deduplicated.txt	/Volumes/Serine/wd/18-07-30/CpG_CTOT_15_39_S39_L001_R1_001_bismark_bt2_pe.deduplicated.txt	/Volumes/Serine/wd/18-07-30/CpG_CTOB_15_39_S39_L001_R1_001_bismark_bt2_pe.deduplicated.txt	/Volumes/Serine/wd/18-07-30/CpG_OB_15_39_S39_L001_R1_001_bismark_bt2_pe.deduplicated.txt
#
#
# Now testing Bismark result file 16_40_S40_L001_R1_001_bismark_bt2_pe.deduplicated.bam for positional sorting (which would be bad...)	16_40_S40_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.1
# 16_40_S40_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.2
# 16_40_S40_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.3
# 16_40_S40_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.4
#
# 16_40_S40_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.1.mbias
# 16_40_S40_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.2.mbias
# 16_40_S40_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.3.mbias
# 16_40_S40_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.4.mbias
#
# /Volumes/Serine/wd/18-07-30/CpG_OT_16_40_S40_L001_R1_001_bismark_bt2_pe.deduplicated.txt	/Volumes/Serine/wd/18-07-30/CpG_CTOT_16_40_S40_L001_R1_001_bismark_bt2_pe.deduplicated.txt	/Volumes/Serine/wd/18-07-30/CpG_CTOB_16_40_S40_L001_R1_001_bismark_bt2_pe.deduplicated.txt	/Volumes/Serine/wd/18-07-30/CpG_OB_16_40_S40_L001_R1_001_bismark_bt2_pe.deduplicated.txt
#
#
# Now testing Bismark result file 17_9_S9_L001_R1_001_bismark_bt2_pe.deduplicated.bam for positional sorting (which would be bad...)	17_9_S9_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.1
# 17_9_S9_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.2
# 17_9_S9_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.3
# 17_9_S9_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.4
#
# 17_9_S9_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.1.mbias
# 17_9_S9_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.2.mbias
# 17_9_S9_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.3.mbias
# 17_9_S9_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.4.mbias
#
# /Volumes/Serine/wd/18-07-30/CpG_OT_17_9_S9_L001_R1_001_bismark_bt2_pe.deduplicated.txt	/Volumes/Serine/wd/18-07-30/CpG_CTOT_17_9_S9_L001_R1_001_bismark_bt2_pe.deduplicated.txt	/Volumes/Serine/wd/18-07-30/CpG_CTOB_17_9_S9_L001_R1_001_bismark_bt2_pe.deduplicated.txt	/Volumes/Serine/wd/18-07-30/CpG_OB_17_9_S9_L001_R1_001_bismark_bt2_pe.deduplicated.txt
#
#
# Now testing Bismark result file 18_10_S10_L001_R1_001_bismark_bt2_pe.deduplicated.bam for positional sorting (which would be bad...)	18_10_S10_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.1
# 18_10_S10_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.2
# 18_10_S10_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.3
# 18_10_S10_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.4
#
# 18_10_S10_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.1.mbias
# 18_10_S10_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.2.mbias
# 18_10_S10_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.3.mbias
# 18_10_S10_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.4.mbias
#
# /Volumes/Serine/wd/18-07-30/CpG_OT_18_10_S10_L001_R1_001_bismark_bt2_pe.deduplicated.txt	/Volumes/Serine/wd/18-07-30/CpG_CTOT_18_10_S10_L001_R1_001_bismark_bt2_pe.deduplicated.txt	/Volumes/Serine/wd/18-07-30/CpG_CTOB_18_10_S10_L001_R1_001_bismark_bt2_pe.deduplicated.txt	/Volumes/Serine/wd/18-07-30/CpG_OB_18_10_S10_L001_R1_001_bismark_bt2_pe.deduplicated.txt
#
#
# Now testing Bismark result file 19_7_S7_L001_R1_001_bismark_bt2_pe.deduplicated.bam for positional sorting (which would be bad...)	19_7_S7_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.1
# 19_7_S7_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.2
# 19_7_S7_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.3
# 19_7_S7_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.4
#
# 19_7_S7_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.1.mbias
# 19_7_S7_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.2.mbias
# 19_7_S7_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.3.mbias
# 19_7_S7_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.4.mbias
#
# /Volumes/Serine/wd/18-07-30/CpG_OT_19_7_S7_L001_R1_001_bismark_bt2_pe.deduplicated.txt	/Volumes/Serine/wd/18-07-30/CpG_CTOT_19_7_S7_L001_R1_001_bismark_bt2_pe.deduplicated.txt	/Volumes/Serine/wd/18-07-30/CpG_CTOB_19_7_S7_L001_R1_001_bismark_bt2_pe.deduplicated.txt	/Volumes/Serine/wd/18-07-30/CpG_OB_19_7_S7_L001_R1_001_bismark_bt2_pe.deduplicated.txt
#
#
# Now testing Bismark result file 1_25_S25_L001_R1_001_bismark_bt2_pe.deduplicated.bam for positional sorting (which would be bad...)	1_25_S25_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.1
# 1_25_S25_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.2
# 1_25_S25_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.3
# 1_25_S25_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.4
#
# 1_25_S25_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.1.mbias
# 1_25_S25_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.2.mbias
# 1_25_S25_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.3.mbias
# 1_25_S25_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.4.mbias
#
# /Volumes/Serine/wd/18-07-30/CpG_OT_1_25_S25_L001_R1_001_bismark_bt2_pe.deduplicated.txt	/Volumes/Serine/wd/18-07-30/CpG_CTOT_1_25_S25_L001_R1_001_bismark_bt2_pe.deduplicated.txt	/Volumes/Serine/wd/18-07-30/CpG_CTOB_1_25_S25_L001_R1_001_bismark_bt2_pe.deduplicated.txt	/Volumes/Serine/wd/18-07-30/CpG_OB_1_25_S25_L001_R1_001_bismark_bt2_pe.deduplicated.txt
#
#
# Now testing Bismark result file 20_8_S8_L001_R1_001_bismark_bt2_pe.deduplicated.bam for positional sorting (which would be bad...)	20_8_S8_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.1
# 20_8_S8_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.2
# 20_8_S8_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.3
# 20_8_S8_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.4
#
# 20_8_S8_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.1.mbias
# 20_8_S8_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.2.mbias
# 20_8_S8_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.3.mbias
# 20_8_S8_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.4.mbias
#
# /Volumes/Serine/wd/18-07-30/CpG_OT_20_8_S8_L001_R1_001_bismark_bt2_pe.deduplicated.txt	/Volumes/Serine/wd/18-07-30/CpG_CTOT_20_8_S8_L001_R1_001_bismark_bt2_pe.deduplicated.txt	/Volumes/Serine/wd/18-07-30/CpG_CTOB_20_8_S8_L001_R1_001_bismark_bt2_pe.deduplicated.txt	/Volumes/Serine/wd/18-07-30/CpG_OB_20_8_S8_L001_R1_001_bismark_bt2_pe.deduplicated.txt
#
#
# Now testing Bismark result file 2_26_S26_L001_R1_001_bismark_bt2_pe.deduplicated.bam for positional sorting (which would be bad...)	2_26_S26_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.1
# 2_26_S26_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.2
# 2_26_S26_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.3
# 2_26_S26_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.4
#
# 2_26_S26_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.1.mbias
# 2_26_S26_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.2.mbias
# 2_26_S26_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.3.mbias
# 2_26_S26_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.4.mbias
#
# /Volumes/Serine/wd/18-07-30/CpG_OT_2_26_S26_L001_R1_001_bismark_bt2_pe.deduplicated.txt	/Volumes/Serine/wd/18-07-30/CpG_CTOT_2_26_S26_L001_R1_001_bismark_bt2_pe.deduplicated.txt	/Volumes/Serine/wd/18-07-30/CpG_CTOB_2_26_S26_L001_R1_001_bismark_bt2_pe.deduplicated.txt	/Volumes/Serine/wd/18-07-30/CpG_OB_2_26_S26_L001_R1_001_bismark_bt2_pe.deduplicated.txt
#
#
# Now testing Bismark result file 3_27_S27_L001_R1_001_bismark_bt2_pe.deduplicated.bam for positional sorting (which would be bad...)	3_27_S27_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.1
# 3_27_S27_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.2
# 3_27_S27_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.3
# 3_27_S27_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.4
#
# 3_27_S27_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.1.mbias
# 3_27_S27_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.2.mbias
# 3_27_S27_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.3.mbias
# 3_27_S27_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.4.mbias
#
# /Volumes/Serine/wd/18-07-30/CpG_OT_3_27_S27_L001_R1_001_bismark_bt2_pe.deduplicated.txt	/Volumes/Serine/wd/18-07-30/CpG_CTOT_3_27_S27_L001_R1_001_bismark_bt2_pe.deduplicated.txt	/Volumes/Serine/wd/18-07-30/CpG_CTOB_3_27_S27_L001_R1_001_bismark_bt2_pe.deduplicated.txt	/Volumes/Serine/wd/18-07-30/CpG_OB_3_27_S27_L001_R1_001_bismark_bt2_pe.deduplicated.txt
#
#
# Now testing Bismark result file 4_28_S28_L001_R1_001_bismark_bt2_pe.deduplicated.bam for positional sorting (which would be bad...)	4_28_S28_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.1
# 4_28_S28_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.2
# 4_28_S28_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.3
# 4_28_S28_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.4
#
# 4_28_S28_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.1.mbias
# 4_28_S28_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.2.mbias
# 4_28_S28_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.3.mbias
# 4_28_S28_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.4.mbias
#
# /Volumes/Serine/wd/18-07-30/CpG_OT_4_28_S28_L001_R1_001_bismark_bt2_pe.deduplicated.txt	/Volumes/Serine/wd/18-07-30/CpG_CTOT_4_28_S28_L001_R1_001_bismark_bt2_pe.deduplicated.txt	/Volumes/Serine/wd/18-07-30/CpG_CTOB_4_28_S28_L001_R1_001_bismark_bt2_pe.deduplicated.txt	/Volumes/Serine/wd/18-07-30/CpG_OB_4_28_S28_L001_R1_001_bismark_bt2_pe.deduplicated.txt
#
#
# Now testing Bismark result file 5_35_S35_L001_R1_001_bismark_bt2_pe.deduplicated.bam for positional sorting (which would be bad...)	5_35_S35_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.1
# 5_35_S35_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.2
# 5_35_S35_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.3
# 5_35_S35_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.4
#
# 5_35_S35_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.1.mbias
# 5_35_S35_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.2.mbias
# 5_35_S35_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.3.mbias
# 5_35_S35_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.4.mbias
#
# /Volumes/Serine/wd/18-07-30/CpG_OT_5_35_S35_L001_R1_001_bismark_bt2_pe.deduplicated.txt	/Volumes/Serine/wd/18-07-30/CpG_CTOT_5_35_S35_L001_R1_001_bismark_bt2_pe.deduplicated.txt	/Volumes/Serine/wd/18-07-30/CpG_CTOB_5_35_S35_L001_R1_001_bismark_bt2_pe.deduplicated.txt	/Volumes/Serine/wd/18-07-30/CpG_OB_5_35_S35_L001_R1_001_bismark_bt2_pe.deduplicated.txt
#
#
# Now testing Bismark result file 6_36_S36_L001_R1_001_bismark_bt2_pe.deduplicated.bam for positional sorting (which would be bad...)	6_36_S36_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.1
# 6_36_S36_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.2
# 6_36_S36_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.3
# 6_36_S36_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.4
#
# 6_36_S36_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.1.mbias
# 6_36_S36_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.2.mbias
# 6_36_S36_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.3.mbias
# 6_36_S36_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.4.mbias
#
# /Volumes/Serine/wd/18-07-30/CpG_OT_6_36_S36_L001_R1_001_bismark_bt2_pe.deduplicated.txt	/Volumes/Serine/wd/18-07-30/CpG_CTOT_6_36_S36_L001_R1_001_bismark_bt2_pe.deduplicated.txt	/Volumes/Serine/wd/18-07-30/CpG_CTOB_6_36_S36_L001_R1_001_bismark_bt2_pe.deduplicated.txt	/Volumes/Serine/wd/18-07-30/CpG_OB_6_36_S36_L001_R1_001_bismark_bt2_pe.deduplicated.txt
#
#
# Now testing Bismark result file 7_29_S29_L001_R1_001_bismark_bt2_pe.deduplicated.bam for positional sorting (which would be bad...)	7_29_S29_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.1
# 7_29_S29_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.2
# 7_29_S29_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.3
# 7_29_S29_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.4
#
# 7_29_S29_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.1.mbias
# 7_29_S29_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.2.mbias
# 7_29_S29_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.3.mbias
# 7_29_S29_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.4.mbias
#
# /Volumes/Serine/wd/18-07-30/CpG_OT_7_29_S29_L001_R1_001_bismark_bt2_pe.deduplicated.txt	/Volumes/Serine/wd/18-07-30/CpG_CTOT_7_29_S29_L001_R1_001_bismark_bt2_pe.deduplicated.txt	/Volumes/Serine/wd/18-07-30/CpG_CTOB_7_29_S29_L001_R1_001_bismark_bt2_pe.deduplicated.txt	/Volumes/Serine/wd/18-07-30/CpG_OB_7_29_S29_L001_R1_001_bismark_bt2_pe.deduplicated.txt
#
#
# Now testing Bismark result file 8_30_S30_L001_R1_001_bismark_bt2_pe.deduplicated.bam for positional sorting (which would be bad...)	8_30_S30_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.1
# 8_30_S30_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.2
# 8_30_S30_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.3
# 8_30_S30_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.4
#
# 8_30_S30_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.1.mbias
# 8_30_S30_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.2.mbias
# 8_30_S30_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.3.mbias
# 8_30_S30_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.4.mbias
#
# /Volumes/Serine/wd/18-07-30/CpG_OT_8_30_S30_L001_R1_001_bismark_bt2_pe.deduplicated.txt	/Volumes/Serine/wd/18-07-30/CpG_CTOT_8_30_S30_L001_R1_001_bismark_bt2_pe.deduplicated.txt	/Volumes/Serine/wd/18-07-30/CpG_CTOB_8_30_S30_L001_R1_001_bismark_bt2_pe.deduplicated.txt	/Volumes/Serine/wd/18-07-30/CpG_OB_8_30_S30_L001_R1_001_bismark_bt2_pe.deduplicated.txt
#
#
# Now testing Bismark result file 9_31_S31_L001_R1_001_bismark_bt2_pe.deduplicated.bam for positional sorting (which would be bad...)	9_31_S31_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.1
# 9_31_S31_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.2
# 9_31_S31_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.3
# 9_31_S31_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.4
#
# 9_31_S31_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.1.mbias
# 9_31_S31_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.2.mbias
# 9_31_S31_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.3.mbias
# 9_31_S31_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt.4.mbias
#
# /Volumes/Serine/wd/18-07-30/CpG_OT_9_31_S31_L001_R1_001_bismark_bt2_pe.deduplicated.txt	/Volumes/Serine/wd/18-07-30/CpG_CTOT_9_31_S31_L001_R1_001_bismark_bt2_pe.deduplicated.txt	/Volumes/Serine/wd/18-07-30/CpG_CTOB_9_31_S31_L001_R1_001_bismark_bt2_pe.deduplicated.txt	/Volumes/Serine/wd/18-07-30/CpG_OB_9_31_S31_L001_R1_001_bismark_bt2_pe.deduplicated.txt

# %%
# !gunzip *bedGraph.gz

# %%
# !head *.deduplicated.bedGraph
# Out:
# ==> 10_32_S32_L001_R1_001_bismark_bt2_pe.deduplicated.bedGraph <==
# track type=bedGraph
# NC_035780.1	264571	264572	0
# NC_035780.1	264610	264611	100
# NC_035780.1	264628	264629	100
# NC_035780.1	269387	269388	100
# NC_035780.1	269403	269404	100
# NC_035780.1	269427	269428	100
# NC_035780.1	269437	269438	100
# NC_035780.1	269494	269495	100
# NC_035780.1	269514	269515	100
#
# ==> 11_37_S37_L001_R1_001_bismark_bt2_pe.deduplicated.bedGraph <==
# track type=bedGraph
# NC_035780.1	291108	291109	0
# NC_035780.1	291143	291144	0
# NC_035780.1	291198	291199	0
# NC_035780.1	291211	291212	0
# NC_035780.1	291232	291233	0
# NC_035780.1	320516	320517	100
# NC_035780.1	320524	320525	100
# NC_035780.1	334842	334843	100
# NC_035780.1	334890	334891	100
#
# ==> 12_38_S38_L001_R1_001_bismark_bt2_pe.deduplicated.bedGraph <==
# track type=bedGraph
# NC_007175.2	5039	5040	0
# NC_035780.1	28	29	0
# NC_035780.1	54	55	0
# NC_035780.1	75	76	0
# NC_035780.1	103	104	0
# NC_035780.1	116	117	0
# NC_035780.1	134	135	0
# NC_035780.1	159	160	0
# NC_035780.1	260203	260204	100
#
# ==> 13_33_S33_L001_R1_001_bismark_bt2_pe.deduplicated.bedGraph <==
# track type=bedGraph
# NC_035780.1	6036	6037	0
# NC_035780.1	6109	6110	0
# NC_035780.1	6128	6129	0
# NC_035780.1	6130	6131	0
# NC_035780.1	6609	6610	0
# NC_035780.1	6631	6632	0
# NC_035780.1	6691	6692	0
# NC_035780.1	80897	80898	100
# NC_035780.1	81019	81020	100
#
# ==> 14_34_S34_L001_R1_001_bismark_bt2_pe.deduplicated.bedGraph <==
# track type=bedGraph
# NC_035780.1	52268	52269	0
# NC_035780.1	52286	52287	0
# NC_035780.1	52293	52294	0
# NC_035780.1	52329	52330	0
# NC_035780.1	256446	256447	100
# NC_035780.1	256466	256467	100
# NC_035780.1	260477	260478	100
# NC_035780.1	264649	264650	100
# NC_035780.1	264704	264705	100
#
# ==> 15_39_S39_L001_R1_001_bismark_bt2_pe.deduplicated.bedGraph <==
# track type=bedGraph
# NC_007175.2	12638	12639	0
# NC_007175.2	12677	12678	0
# NC_007175.2	12695	12696	0
# NC_007175.2	12698	12699	0
# NC_007175.2	12732	12733	0
# NC_007175.2	12755	12756	0
# NC_007175.2	12773	12774	0
# NC_035780.1	262024	262025	100
# NC_035780.1	262054	262055	100
#
# ==> 16_40_S40_L001_R1_001_bismark_bt2_pe.deduplicated.bedGraph <==
# track type=bedGraph
# NC_007175.2	15485	15486	0
# NC_007175.2	15508	15509	0
# NC_007175.2	15513	15514	0
# NC_007175.2	15574	15575	0
# NC_007175.2	15592	15593	0
# NC_007175.2	15601	15602	0
# NC_007175.2	15611	15612	0
# NC_007175.2	15622	15623	0
# NC_035780.1	264854	264855	100
#
# ==> 17_9_S9_L001_R1_001_bismark_bt2_pe.deduplicated.bedGraph <==
# track type=bedGraph
# NC_007175.2	2237	2238	0
# NC_007175.2	2265	2266	0
# NC_007175.2	2282	2283	0
# NC_007175.2	3886	3887	0
# NC_007175.2	3908	3909	0
# NC_007175.2	3933	3934	0
# NC_007175.2	3944	3945	0
# NC_007175.2	3946	3947	0
# NC_007175.2	8591	8592	0
#
# ==> 18_10_S10_L001_R1_001_bismark_bt2_pe.deduplicated.bedGraph <==
# track type=bedGraph
# NC_007175.2	1749	1750	0
# NC_007175.2	1766	1767	0
# NC_007175.2	1825	1826	0
# NC_007175.2	1826	1827	0
# NC_007175.2	1836	1837	0
# NC_007175.2	1837	1838	0
# NC_007175.2	1842	1843	0
# NC_007175.2	1843	1844	0
# NC_007175.2	1846	1847	0
#
# ==> 19_7_S7_L001_R1_001_bismark_bt2_pe.deduplicated.bedGraph <==
# track type=bedGraph
# NC_007175.2	2300	2301	0
# NC_007175.2	2303	2304	0
# NC_007175.2	2355	2356	0
# NC_007175.2	2364	2365	0
# NC_007175.2	2433	2434	0
# NC_007175.2	2434	2435	0
# NC_007175.2	2471	2472	0
# NC_007175.2	2472	2473	0
# NC_007175.2	2490	2491	0
#
# ==> 1_25_S25_L001_R1_001_bismark_bt2_pe.deduplicated.bedGraph <==
# track type=bedGraph
# NC_007175.2	256	257	0
# NC_007175.2	263	264	0
# NC_007175.2	265	266	0
# NC_007175.2	366	367	0
# NC_007175.2	976	977	0
# NC_007175.2	995	996	0
# NC_007175.2	1010	1011	0
# NC_007175.2	1016	1017	0
# NC_007175.2	1019	1020	0
#
# ==> 20_8_S8_L001_R1_001_bismark_bt2_pe.deduplicated.bedGraph <==
# track type=bedGraph
# NC_035780.1	254242	254243	100
# NC_035780.1	254295	254296	100
# NC_035780.1	254312	254313	100
# NC_035780.1	254334	254335	100
# NC_035780.1	268595	268596	100
# NC_035780.1	268659	268660	100
# NC_035780.1	270866	270867	0
# NC_035780.1	270943	270944	100
# NC_035780.1	270974	270975	100
#
# ==> 2_26_S26_L001_R1_001_bismark_bt2_pe.deduplicated.bedGraph <==
# track type=bedGraph
# NC_007175.2	245	246	0
# NC_007175.2	256	257	0
# NC_007175.2	263	264	0
# NC_007175.2	265	266	0
# NC_007175.2	331	332	0
# NC_007175.2	366	367	0
# NC_007175.2	5697	5698	0
# NC_007175.2	5724	5725	0
# NC_007175.2	6933	6934	0
#
# ==> 3_27_S27_L001_R1_001_bismark_bt2_pe.deduplicated.bedGraph <==
# track type=bedGraph
# NC_007175.2	8386	8387	0
# NC_007175.2	8407	8408	0
# NC_007175.2	8591	8592	0
# NC_007175.2	8599	8600	0
# NC_007175.2	8624	8625	0
# NC_007175.2	8651	8652	0
# NC_035780.1	39621	39622	0
# NC_035780.1	39640	39641	0
# NC_035780.1	39643	39644	0
#
# ==> 4_28_S28_L001_R1_001_bismark_bt2_pe.deduplicated.bedGraph <==
# track type=bedGraph
# NC_007175.2	994	995	0
# NC_007175.2	1009	1010	0
# NC_007175.2	1015	1016	0
# NC_007175.2	1018	1019	0
# NC_007175.2	1036	1037	0
# NC_007175.2	5040	5041	0
# NC_007175.2	5171	5172	0
# NC_007175.2	10392	10393	0
# NC_007175.2	13583	13584	100
#
# ==> 5_35_S35_L001_R1_001_bismark_bt2_pe.deduplicated.bedGraph <==
# track type=bedGraph
# NC_007175.2	1009	1010	0
# NC_007175.2	1015	1016	0
# NC_007175.2	1018	1019	0
# NC_007175.2	1036	1037	0
# NC_007175.2	1097	1098	0
# NC_007175.2	1106	1107	0
# NC_007175.2	8749	8750	0
# NC_007175.2	10817	10818	0
# NC_007175.2	10826	10827	0
#
# ==> 6_36_S36_L001_R1_001_bismark_bt2_pe.deduplicated.bedGraph <==
# track type=bedGraph
# NC_007175.2	6357	6358	0
# NC_007175.2	6372	6373	0
# NC_007175.2	12566	12567	0
# NC_007175.2	12590	12591	0
# NC_007175.2	17045	17046	0
# NC_007175.2	17086	17087	0
# NC_007175.2	17120	17121	0
# NC_007175.2	17130	17131	0
# NC_007175.2	17164	17165	0
#
# ==> 7_29_S29_L001_R1_001_bismark_bt2_pe.deduplicated.bedGraph <==
# track type=bedGraph
# NC_007175.2	2148	2149	0
# NC_007175.2	2180	2181	0
# NC_007175.2	2206	2207	0
# NC_007175.2	2237	2238	0
# NC_007175.2	2265	2266	0
# NC_007175.2	2282	2283	0
# NC_007175.2	2304	2305	0
# NC_007175.2	2356	2357	0
# NC_007175.2	2365	2366	0
#
# ==> 8_30_S30_L001_R1_001_bismark_bt2_pe.deduplicated.bedGraph <==
# track type=bedGraph
# NC_007175.2	2181	2182	0
# NC_007175.2	2207	2208	0
# NC_007175.2	2238	2239	0
# NC_007175.2	2266	2267	0
# NC_007175.2	2283	2284	0
# NC_007175.2	2301	2302	0
# NC_007175.2	2768	2769	0
# NC_007175.2	2815	2816	0
# NC_007175.2	2997	2998	0
#
# ==> 9_31_S31_L001_R1_001_bismark_bt2_pe.deduplicated.bedGraph <==
# track type=bedGraph
# NC_035780.1	166289	166290	0
# NC_035780.1	166291	166292	100
# NC_035780.1	261705	261706	100
# NC_035780.1	261715	261716	100
# NC_035780.1	261726	261727	100
# NC_035780.1	261738	261739	100
# NC_035780.1	261743	261744	100
# NC_035780.1	261977	261978	100
# NC_035780.1	261992	261993	100

# %%
# %%bash
# /Applications/bioinfo/Bismark_v0.19.0/bismark2report
# Out:
# Found 20 alignment reports in current directory. Now trying to figure out whether there are corresponding optional reports
#
# Writing Bismark HTML report to >> 10_32_S32_L001_R1_001_bismark_bt2_PE_report.html <<
#
# ==============================================================================================================
# Using the following alignment report:		> 10_32_S32_L001_R1_001_bismark_bt2_PE_report.txt <
# Processing alignment report 10_32_S32_L001_R1_001_bismark_bt2_PE_report.txt ...
# Complete
#
# Using the following deduplication report:	> 10_32_S32_L001_R1_001_bismark_bt2_pe.deduplication_report.txt <
# Processing deduplication report 10_32_S32_L001_R1_001_bismark_bt2_pe.deduplication_report.txt ...
# Complete
#
# Using the following splitting report:		> 10_32_S32_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt <
# Processing splitting report 10_32_S32_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt ...
# Complete
#
# Using the following M-bias report:		> 10_32_S32_L001_R1_001_bismark_bt2_pe.deduplicated.M-bias.txt <
# Processing M-bias report 10_32_S32_L001_R1_001_bismark_bt2_pe.deduplicated.M-bias.txt ...
# Complete
#
# No nucleotide coverage report file specified, skipping this step
# ==============================================================================================================
#
#
#
# Writing Bismark HTML report to >> 11_37_S37_L001_R1_001_bismark_bt2_PE_report.html <<
#
# ==============================================================================================================
# Using the following alignment report:		> 11_37_S37_L001_R1_001_bismark_bt2_PE_report.txt <
# Processing alignment report 11_37_S37_L001_R1_001_bismark_bt2_PE_report.txt ...
# Complete
#
# Using the following deduplication report:	> 11_37_S37_L001_R1_001_bismark_bt2_pe.deduplication_report.txt <
# Processing deduplication report 11_37_S37_L001_R1_001_bismark_bt2_pe.deduplication_report.txt ...
# Complete
#
# Using the following splitting report:		> 11_37_S37_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt <
# Processing splitting report 11_37_S37_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt ...
# Complete
#
# Using the following M-bias report:		> 11_37_S37_L001_R1_001_bismark_bt2_pe.deduplicated.M-bias.txt <
# Processing M-bias report 11_37_S37_L001_R1_001_bismark_bt2_pe.deduplicated.M-bias.txt ...
# Complete
#
# No nucleotide coverage report file specified, skipping this step
# ==============================================================================================================
#
#
#
# Writing Bismark HTML report to >> 12_38_S38_L001_R1_001_bismark_bt2_PE_report.html <<
#
# ==============================================================================================================
# Using the following alignment report:		> 12_38_S38_L001_R1_001_bismark_bt2_PE_report.txt <
# Processing alignment report 12_38_S38_L001_R1_001_bismark_bt2_PE_report.txt ...
# Complete
#
# Using the following deduplication report:	> 12_38_S38_L001_R1_001_bismark_bt2_pe.deduplication_report.txt <
# Processing deduplication report 12_38_S38_L001_R1_001_bismark_bt2_pe.deduplication_report.txt ...
# Complete
#
# Using the following splitting report:		> 12_38_S38_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt <
# Processing splitting report 12_38_S38_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt ...
# Complete
#
# Using the following M-bias report:		> 12_38_S38_L001_R1_001_bismark_bt2_pe.deduplicated.M-bias.txt <
# Processing M-bias report 12_38_S38_L001_R1_001_bismark_bt2_pe.deduplicated.M-bias.txt ...
# Complete
#
# No nucleotide coverage report file specified, skipping this step
# ==============================================================================================================
#
#
#
# Writing Bismark HTML report to >> 13_33_S33_L001_R1_001_bismark_bt2_PE_report.html <<
#
# ==============================================================================================================
# Using the following alignment report:		> 13_33_S33_L001_R1_001_bismark_bt2_PE_report.txt <
# Processing alignment report 13_33_S33_L001_R1_001_bismark_bt2_PE_report.txt ...
# Complete
#
# Using the following deduplication report:	> 13_33_S33_L001_R1_001_bismark_bt2_pe.deduplication_report.txt <
# Processing deduplication report 13_33_S33_L001_R1_001_bismark_bt2_pe.deduplication_report.txt ...
# Complete
#
# Using the following splitting report:		> 13_33_S33_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt <
# Processing splitting report 13_33_S33_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt ...
# Complete
#
# Using the following M-bias report:		> 13_33_S33_L001_R1_001_bismark_bt2_pe.deduplicated.M-bias.txt <
# Processing M-bias report 13_33_S33_L001_R1_001_bismark_bt2_pe.deduplicated.M-bias.txt ...
# Complete
#
# No nucleotide coverage report file specified, skipping this step
# ==============================================================================================================
#
#
#
# Writing Bismark HTML report to >> 14_34_S34_L001_R1_001_bismark_bt2_PE_report.html <<
#
# ==============================================================================================================
# Using the following alignment report:		> 14_34_S34_L001_R1_001_bismark_bt2_PE_report.txt <
# Processing alignment report 14_34_S34_L001_R1_001_bismark_bt2_PE_report.txt ...
# Complete
#
# Using the following deduplication report:	> 14_34_S34_L001_R1_001_bismark_bt2_pe.deduplication_report.txt <
# Processing deduplication report 14_34_S34_L001_R1_001_bismark_bt2_pe.deduplication_report.txt ...
# Complete
#
# Using the following splitting report:		> 14_34_S34_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt <
# Processing splitting report 14_34_S34_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt ...
# Complete
#
# Using the following M-bias report:		> 14_34_S34_L001_R1_001_bismark_bt2_pe.deduplicated.M-bias.txt <
# Processing M-bias report 14_34_S34_L001_R1_001_bismark_bt2_pe.deduplicated.M-bias.txt ...
# Complete
#
# No nucleotide coverage report file specified, skipping this step
# ==============================================================================================================
#
#
#
# Writing Bismark HTML report to >> 15_39_S39_L001_R1_001_bismark_bt2_PE_report.html <<
#
# ==============================================================================================================
# Using the following alignment report:		> 15_39_S39_L001_R1_001_bismark_bt2_PE_report.txt <
# Processing alignment report 15_39_S39_L001_R1_001_bismark_bt2_PE_report.txt ...
# Complete
#
# Using the following deduplication report:	> 15_39_S39_L001_R1_001_bismark_bt2_pe.deduplication_report.txt <
# Processing deduplication report 15_39_S39_L001_R1_001_bismark_bt2_pe.deduplication_report.txt ...
# Complete
#
# Using the following splitting report:		> 15_39_S39_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt <
# Processing splitting report 15_39_S39_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt ...
# Complete
#
# Using the following M-bias report:		> 15_39_S39_L001_R1_001_bismark_bt2_pe.deduplicated.M-bias.txt <
# Processing M-bias report 15_39_S39_L001_R1_001_bismark_bt2_pe.deduplicated.M-bias.txt ...
# Complete
#
# No nucleotide coverage report file specified, skipping this step
# ==============================================================================================================
#
#
#
# Writing Bismark HTML report to >> 16_40_S40_L001_R1_001_bismark_bt2_PE_report.html <<
#
# ==============================================================================================================
# Using the following alignment report:		> 16_40_S40_L001_R1_001_bismark_bt2_PE_report.txt <
# Processing alignment report 16_40_S40_L001_R1_001_bismark_bt2_PE_report.txt ...
# Complete
#
# Using the following deduplication report:	> 16_40_S40_L001_R1_001_bismark_bt2_pe.deduplication_report.txt <
# Processing deduplication report 16_40_S40_L001_R1_001_bismark_bt2_pe.deduplication_report.txt ...
# Complete
#
# Using the following splitting report:		> 16_40_S40_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt <
# Processing splitting report 16_40_S40_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt ...
# Complete
#
# Using the following M-bias report:		> 16_40_S40_L001_R1_001_bismark_bt2_pe.deduplicated.M-bias.txt <
# Processing M-bias report 16_40_S40_L001_R1_001_bismark_bt2_pe.deduplicated.M-bias.txt ...
# Complete
#
# No nucleotide coverage report file specified, skipping this step
# ==============================================================================================================
#
#
#
# Writing Bismark HTML report to >> 17_9_S9_L001_R1_001_bismark_bt2_PE_report.html <<
#
# ==============================================================================================================
# Using the following alignment report:		> 17_9_S9_L001_R1_001_bismark_bt2_PE_report.txt <
# Processing alignment report 17_9_S9_L001_R1_001_bismark_bt2_PE_report.txt ...
# Complete
#
# Using the following deduplication report:	> 17_9_S9_L001_R1_001_bismark_bt2_pe.deduplication_report.txt <
# Processing deduplication report 17_9_S9_L001_R1_001_bismark_bt2_pe.deduplication_report.txt ...
# Complete
#
# Using the following splitting report:		> 17_9_S9_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt <
# Processing splitting report 17_9_S9_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt ...
# Complete
#
# Using the following M-bias report:		> 17_9_S9_L001_R1_001_bismark_bt2_pe.deduplicated.M-bias.txt <
# Processing M-bias report 17_9_S9_L001_R1_001_bismark_bt2_pe.deduplicated.M-bias.txt ...
# Complete
#
# No nucleotide coverage report file specified, skipping this step
# ==============================================================================================================
#
#
#
# Writing Bismark HTML report to >> 18_10_S10_L001_R1_001_bismark_bt2_PE_report.html <<
#
# ==============================================================================================================
# Using the following alignment report:		> 18_10_S10_L001_R1_001_bismark_bt2_PE_report.txt <
# Processing alignment report 18_10_S10_L001_R1_001_bismark_bt2_PE_report.txt ...
# Complete
#
# Using the following deduplication report:	> 18_10_S10_L001_R1_001_bismark_bt2_pe.deduplication_report.txt <
# Processing deduplication report 18_10_S10_L001_R1_001_bismark_bt2_pe.deduplication_report.txt ...
# Complete
#
# Using the following splitting report:		> 18_10_S10_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt <
# Processing splitting report 18_10_S10_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt ...
# Complete
#
# Using the following M-bias report:		> 18_10_S10_L001_R1_001_bismark_bt2_pe.deduplicated.M-bias.txt <
# Processing M-bias report 18_10_S10_L001_R1_001_bismark_bt2_pe.deduplicated.M-bias.txt ...
# Complete
#
# No nucleotide coverage report file specified, skipping this step
# ==============================================================================================================
#
#
#
# Writing Bismark HTML report to >> 19_7_S7_L001_R1_001_bismark_bt2_PE_report.html <<
#
# ==============================================================================================================
# Using the following alignment report:		> 19_7_S7_L001_R1_001_bismark_bt2_PE_report.txt <
# Processing alignment report 19_7_S7_L001_R1_001_bismark_bt2_PE_report.txt ...
# Complete
#
# Using the following deduplication report:	> 19_7_S7_L001_R1_001_bismark_bt2_pe.deduplication_report.txt <
# Processing deduplication report 19_7_S7_L001_R1_001_bismark_bt2_pe.deduplication_report.txt ...
# Complete
#
# Using the following splitting report:		> 19_7_S7_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt <
# Processing splitting report 19_7_S7_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt ...
# Complete
#
# Using the following M-bias report:		> 19_7_S7_L001_R1_001_bismark_bt2_pe.deduplicated.M-bias.txt <
# Processing M-bias report 19_7_S7_L001_R1_001_bismark_bt2_pe.deduplicated.M-bias.txt ...
# Complete
#
# No nucleotide coverage report file specified, skipping this step
# ==============================================================================================================
#
#
#
# Writing Bismark HTML report to >> 1_25_S25_L001_R1_001_bismark_bt2_PE_report.html <<
#
# ==============================================================================================================
# Using the following alignment report:		> 1_25_S25_L001_R1_001_bismark_bt2_PE_report.txt <
# Processing alignment report 1_25_S25_L001_R1_001_bismark_bt2_PE_report.txt ...
# Complete
#
# Using the following deduplication report:	> 1_25_S25_L001_R1_001_bismark_bt2_pe.deduplication_report.txt <
# Processing deduplication report 1_25_S25_L001_R1_001_bismark_bt2_pe.deduplication_report.txt ...
# Complete
#
# Using the following splitting report:		> 1_25_S25_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt <
# Processing splitting report 1_25_S25_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt ...
# Complete
#
# Using the following M-bias report:		> 1_25_S25_L001_R1_001_bismark_bt2_pe.deduplicated.M-bias.txt <
# Processing M-bias report 1_25_S25_L001_R1_001_bismark_bt2_pe.deduplicated.M-bias.txt ...
# Complete
#
# No nucleotide coverage report file specified, skipping this step
# ==============================================================================================================
#
#
#
# Writing Bismark HTML report to >> 20_8_S8_L001_R1_001_bismark_bt2_PE_report.html <<
#
# ==============================================================================================================
# Using the following alignment report:		> 20_8_S8_L001_R1_001_bismark_bt2_PE_report.txt <
# Processing alignment report 20_8_S8_L001_R1_001_bismark_bt2_PE_report.txt ...
# Complete
#
# Using the following deduplication report:	> 20_8_S8_L001_R1_001_bismark_bt2_pe.deduplication_report.txt <
# Processing deduplication report 20_8_S8_L001_R1_001_bismark_bt2_pe.deduplication_report.txt ...
# Complete
#
# Using the following splitting report:		> 20_8_S8_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt <
# Processing splitting report 20_8_S8_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt ...
# Complete
#
# Using the following M-bias report:		> 20_8_S8_L001_R1_001_bismark_bt2_pe.deduplicated.M-bias.txt <
# Processing M-bias report 20_8_S8_L001_R1_001_bismark_bt2_pe.deduplicated.M-bias.txt ...
# Complete
#
# No nucleotide coverage report file specified, skipping this step
# ==============================================================================================================
#
#
#
# Writing Bismark HTML report to >> 2_26_S26_L001_R1_001_bismark_bt2_PE_report.html <<
#
# ==============================================================================================================
# Using the following alignment report:		> 2_26_S26_L001_R1_001_bismark_bt2_PE_report.txt <
# Processing alignment report 2_26_S26_L001_R1_001_bismark_bt2_PE_report.txt ...
# Complete
#
# Using the following deduplication report:	> 2_26_S26_L001_R1_001_bismark_bt2_pe.deduplication_report.txt <
# Processing deduplication report 2_26_S26_L001_R1_001_bismark_bt2_pe.deduplication_report.txt ...
# Complete
#
# Using the following splitting report:		> 2_26_S26_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt <
# Processing splitting report 2_26_S26_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt ...
# Complete
#
# Using the following M-bias report:		> 2_26_S26_L001_R1_001_bismark_bt2_pe.deduplicated.M-bias.txt <
# Processing M-bias report 2_26_S26_L001_R1_001_bismark_bt2_pe.deduplicated.M-bias.txt ...
# Complete
#
# No nucleotide coverage report file specified, skipping this step
# ==============================================================================================================
#
#
#
# Writing Bismark HTML report to >> 3_27_S27_L001_R1_001_bismark_bt2_PE_report.html <<
#
# ==============================================================================================================
# Using the following alignment report:		> 3_27_S27_L001_R1_001_bismark_bt2_PE_report.txt <
# Processing alignment report 3_27_S27_L001_R1_001_bismark_bt2_PE_report.txt ...
# Complete
#
# Using the following deduplication report:	> 3_27_S27_L001_R1_001_bismark_bt2_pe.deduplication_report.txt <
# Processing deduplication report 3_27_S27_L001_R1_001_bismark_bt2_pe.deduplication_report.txt ...
# Complete
#
# Using the following splitting report:		> 3_27_S27_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt <
# Processing splitting report 3_27_S27_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt ...
# Complete
#
# Using the following M-bias report:		> 3_27_S27_L001_R1_001_bismark_bt2_pe.deduplicated.M-bias.txt <
# Processing M-bias report 3_27_S27_L001_R1_001_bismark_bt2_pe.deduplicated.M-bias.txt ...
# Complete
#
# No nucleotide coverage report file specified, skipping this step
# ==============================================================================================================
#
#
#
# Writing Bismark HTML report to >> 4_28_S28_L001_R1_001_bismark_bt2_PE_report.html <<
#
# ==============================================================================================================
# Using the following alignment report:		> 4_28_S28_L001_R1_001_bismark_bt2_PE_report.txt <
# Processing alignment report 4_28_S28_L001_R1_001_bismark_bt2_PE_report.txt ...
# Complete
#
# Using the following deduplication report:	> 4_28_S28_L001_R1_001_bismark_bt2_pe.deduplication_report.txt <
# Processing deduplication report 4_28_S28_L001_R1_001_bismark_bt2_pe.deduplication_report.txt ...
# Complete
#
# Using the following splitting report:		> 4_28_S28_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt <
# Processing splitting report 4_28_S28_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt ...
# Complete
#
# Using the following M-bias report:		> 4_28_S28_L001_R1_001_bismark_bt2_pe.deduplicated.M-bias.txt <
# Processing M-bias report 4_28_S28_L001_R1_001_bismark_bt2_pe.deduplicated.M-bias.txt ...
# Complete
#
# No nucleotide coverage report file specified, skipping this step
# ==============================================================================================================
#
#
#
# Writing Bismark HTML report to >> 5_35_S35_L001_R1_001_bismark_bt2_PE_report.html <<
#
# ==============================================================================================================
# Using the following alignment report:		> 5_35_S35_L001_R1_001_bismark_bt2_PE_report.txt <
# Processing alignment report 5_35_S35_L001_R1_001_bismark_bt2_PE_report.txt ...
# Complete
#
# Using the following deduplication report:	> 5_35_S35_L001_R1_001_bismark_bt2_pe.deduplication_report.txt <
# Processing deduplication report 5_35_S35_L001_R1_001_bismark_bt2_pe.deduplication_report.txt ...
# Complete
#
# Using the following splitting report:		> 5_35_S35_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt <
# Processing splitting report 5_35_S35_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt ...
# Complete
#
# Using the following M-bias report:		> 5_35_S35_L001_R1_001_bismark_bt2_pe.deduplicated.M-bias.txt <
# Processing M-bias report 5_35_S35_L001_R1_001_bismark_bt2_pe.deduplicated.M-bias.txt ...
# Complete
#
# No nucleotide coverage report file specified, skipping this step
# ==============================================================================================================
#
#
#
# Writing Bismark HTML report to >> 6_36_S36_L001_R1_001_bismark_bt2_PE_report.html <<
#
# ==============================================================================================================
# Using the following alignment report:		> 6_36_S36_L001_R1_001_bismark_bt2_PE_report.txt <
# Processing alignment report 6_36_S36_L001_R1_001_bismark_bt2_PE_report.txt ...
# Complete
#
# Using the following deduplication report:	> 6_36_S36_L001_R1_001_bismark_bt2_pe.deduplication_report.txt <
# Processing deduplication report 6_36_S36_L001_R1_001_bismark_bt2_pe.deduplication_report.txt ...
# Complete
#
# Using the following splitting report:		> 6_36_S36_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt <
# Processing splitting report 6_36_S36_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt ...
# Complete
#
# Using the following M-bias report:		> 6_36_S36_L001_R1_001_bismark_bt2_pe.deduplicated.M-bias.txt <
# Processing M-bias report 6_36_S36_L001_R1_001_bismark_bt2_pe.deduplicated.M-bias.txt ...
# Complete
#
# No nucleotide coverage report file specified, skipping this step
# ==============================================================================================================
#
#
#
# Writing Bismark HTML report to >> 7_29_S29_L001_R1_001_bismark_bt2_PE_report.html <<
#
# ==============================================================================================================
# Using the following alignment report:		> 7_29_S29_L001_R1_001_bismark_bt2_PE_report.txt <
# Processing alignment report 7_29_S29_L001_R1_001_bismark_bt2_PE_report.txt ...
# Complete
#
# Using the following deduplication report:	> 7_29_S29_L001_R1_001_bismark_bt2_pe.deduplication_report.txt <
# Processing deduplication report 7_29_S29_L001_R1_001_bismark_bt2_pe.deduplication_report.txt ...
# Complete
#
# Using the following splitting report:		> 7_29_S29_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt <
# Processing splitting report 7_29_S29_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt ...
# Complete
#
# Using the following M-bias report:		> 7_29_S29_L001_R1_001_bismark_bt2_pe.deduplicated.M-bias.txt <
# Processing M-bias report 7_29_S29_L001_R1_001_bismark_bt2_pe.deduplicated.M-bias.txt ...
# Complete
#
# No nucleotide coverage report file specified, skipping this step
# ==============================================================================================================
#
#
#
# Writing Bismark HTML report to >> 8_30_S30_L001_R1_001_bismark_bt2_PE_report.html <<
#
# ==============================================================================================================
# Using the following alignment report:		> 8_30_S30_L001_R1_001_bismark_bt2_PE_report.txt <
# Processing alignment report 8_30_S30_L001_R1_001_bismark_bt2_PE_report.txt ...
# Complete
#
# Using the following deduplication report:	> 8_30_S30_L001_R1_001_bismark_bt2_pe.deduplication_report.txt <
# Processing deduplication report 8_30_S30_L001_R1_001_bismark_bt2_pe.deduplication_report.txt ...
# Complete
#
# Using the following splitting report:		> 8_30_S30_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt <
# Processing splitting report 8_30_S30_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt ...
# Complete
#
# Using the following M-bias report:		> 8_30_S30_L001_R1_001_bismark_bt2_pe.deduplicated.M-bias.txt <
# Processing M-bias report 8_30_S30_L001_R1_001_bismark_bt2_pe.deduplicated.M-bias.txt ...
# Complete
#
# No nucleotide coverage report file specified, skipping this step
# ==============================================================================================================
#
#
#
# Writing Bismark HTML report to >> 9_31_S31_L001_R1_001_bismark_bt2_PE_report.html <<
#
# ==============================================================================================================
# Using the following alignment report:		> 9_31_S31_L001_R1_001_bismark_bt2_PE_report.txt <
# Processing alignment report 9_31_S31_L001_R1_001_bismark_bt2_PE_report.txt ...
# Complete
#
# Using the following deduplication report:	> 9_31_S31_L001_R1_001_bismark_bt2_pe.deduplication_report.txt <
# Processing deduplication report 9_31_S31_L001_R1_001_bismark_bt2_pe.deduplication_report.txt ...
# Complete
#
# Using the following splitting report:		> 9_31_S31_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt <
# Processing splitting report 9_31_S31_L001_R1_001_bismark_bt2_pe.deduplicated_splitting_report.txt ...
# Complete
#
# Using the following M-bias report:		> 9_31_S31_L001_R1_001_bismark_bt2_pe.deduplicated.M-bias.txt <
# Processing M-bias report 9_31_S31_L001_R1_001_bismark_bt2_pe.deduplicated.M-bias.txt ...
# Complete
#
# No nucleotide coverage report file specified, skipping this step
# ==============================================================================================================

# %%
!#open *report.html

# %%
# %%bash
# /Applications/bioinfo/Bismark_v0.19.0/bismark2summary
# Out:
# No Bismark/Bowtie2 single-end BAM files detected
# Found Bismark/Bowtie2 paired-end files
# No Bismark/Bowtie single-end BAM files detected
# No Bismark/Bowtie paired-end BAM files detected
#
# Generating Bismark summary report from 20 Bismark BAM file(s)...
# >> Reading from Bismark report: 10_32_S32_L001_R1_001_bismark_bt2_PE_report.txt
# >> Reading from Bismark report: 11_37_S37_L001_R1_001_bismark_bt2_PE_report.txt
# >> Reading from Bismark report: 12_38_S38_L001_R1_001_bismark_bt2_PE_report.txt
# >> Reading from Bismark report: 13_33_S33_L001_R1_001_bismark_bt2_PE_report.txt
# >> Reading from Bismark report: 14_34_S34_L001_R1_001_bismark_bt2_PE_report.txt
# >> Reading from Bismark report: 15_39_S39_L001_R1_001_bismark_bt2_PE_report.txt
# >> Reading from Bismark report: 16_40_S40_L001_R1_001_bismark_bt2_PE_report.txt
# >> Reading from Bismark report: 17_9_S9_L001_R1_001_bismark_bt2_PE_report.txt
# >> Reading from Bismark report: 18_10_S10_L001_R1_001_bismark_bt2_PE_report.txt
# >> Reading from Bismark report: 19_7_S7_L001_R1_001_bismark_bt2_PE_report.txt
# >> Reading from Bismark report: 1_25_S25_L001_R1_001_bismark_bt2_PE_report.txt
# >> Reading from Bismark report: 20_8_S8_L001_R1_001_bismark_bt2_PE_report.txt
# >> Reading from Bismark report: 2_26_S26_L001_R1_001_bismark_bt2_PE_report.txt
# >> Reading from Bismark report: 3_27_S27_L001_R1_001_bismark_bt2_PE_report.txt
# >> Reading from Bismark report: 4_28_S28_L001_R1_001_bismark_bt2_PE_report.txt
# >> Reading from Bismark report: 5_35_S35_L001_R1_001_bismark_bt2_PE_report.txt
# >> Reading from Bismark report: 6_36_S36_L001_R1_001_bismark_bt2_PE_report.txt
# >> Reading from Bismark report: 7_29_S29_L001_R1_001_bismark_bt2_PE_report.txt
# >> Reading from Bismark report: 8_30_S30_L001_R1_001_bismark_bt2_PE_report.txt
# >> Reading from Bismark report: 9_31_S31_L001_R1_001_bismark_bt2_PE_report.txt
#
# Wrote Bismark project summary to >> bismark_summary_report.html <<
