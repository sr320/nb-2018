# %% [markdown]
# # Running Bismark

# %%
wd="/Volumes/Orange_block/wd/18-06-13"

# %%
mkdir $wd

# %%
cd $wd
# Out:
# /Volumes/Orange_block/wd/18-06-13

# %% [markdown]
# ## Genome Preparation

# %%
# !mkdir genome

# %%
# !cp /Users/sr320/Desktop/oly/Olurida_v081.fa genome//Olurida_v081.fa

# %%
# %%bash
# /Applications/bioinfo/Bismark_v0.19.0/bismark_genome_preparation \
# --path_to_bowtie /Applications/bioinfo/bowtie2-2.3.4.1-macos-x86_64 \
# genome
# Out:
# Total number of conversions performed:
# C->T:	197058296
# G->A:	197049137
# Please be aware that this process can - depending on genome size - take several hours!
# Settings:
#   Output files: "BS_CT.*.bt2"
#   Line rate: 6 (line is 64 bytes)
#   Lines per side: 1 (side is 64 bytes)
#   Offset rate: 4 (one in 16)
#   FTable chars: 10
#   Strings: unpacked
#   Max bucket size: default
#   Max bucket size, sqrt multiplier: default
#   Max bucket size, len divisor: 4
#   Difference-cover sample period: 1024
#   Endianness: little
#   Actual local endianness: little
#   Sanity checking: disabled
#   Assertions: disabled
#   Random seed: 0
#   Sizeofs: void*:8, int:4, long:8, size_t:8
# Input files DNA, FASTA:
#   genome_mfa.CT_conversion.fa
# Reading reference sizes
# Settings:
#   Output files: "BS_GA.*.bt2"
#   Line rate: 6 (line is 64 bytes)
#   Lines per side: 1 (side is 64 bytes)
#   Offset rate: 4 (one in 16)
#   FTable chars: 10
#   Strings: unpacked
#   Max bucket size: default
#   Max bucket size, sqrt multiplier: default
#   Max bucket size, len divisor: 4
#   Difference-cover sample period: 1024
#   Endianness: little
#   Actual local endianness: little
#   Sanity checking: disabled
#   Assertions: disabled
#   Random seed: 0
#   Sizeofs: void*:8, int:4, long:8, size_t:8
# Input files DNA, FASTA:
#   genome_mfa.GA_conversion.fa
# Reading reference sizes
#   Time reading reference sizes: 00:00:37
# Calculating joined length
# Writing header
# Reserving space for joined string
# Joining reference sequences
#   Time reading reference sizes: 00:00:38
# Calculating joined length
# Writing header
# Reserving space for joined string
# Joining reference sequences
#   Time to join reference sequences: 00:00:25
# bmax according to bmaxDivN setting: 269313774
# Using parameters --bmax 201985331 --dcv 1024
#   Doing ahead-of-time memory usage test
#   Passed!  Constructing with these parameters: --bmax 201985331 --dcv 1024
# Constructing suffix-array element generator
# Building DifferenceCoverSample
#   Building sPrime
#   Building sPrimeOrder
#   V-Sorting samples
#   Time to join reference sequences: 00:00:28
# bmax according to bmaxDivN setting: 269313774
# Using parameters --bmax 201985331 --dcv 1024
#   Doing ahead-of-time memory usage test
#   Passed!  Constructing with these parameters: --bmax 201985331 --dcv 1024
# Constructing suffix-array element generator
# Building DifferenceCoverSample
#   Building sPrime
#   Building sPrimeOrder
#   V-Sorting samples
#   V-Sorting samples time: 00:00:30
#   Allocating rank array
#   Ranking v-sort output
#   V-Sorting samples time: 00:00:31
#   Allocating rank array
#   Ranking v-sort output
#   Ranking v-sort output time: 00:00:09
#   Invoking Larsson-Sadakane on ranks
#   Ranking v-sort output time: 00:00:09
#   Invoking Larsson-Sadakane on ranks
#   Invoking Larsson-Sadakane on ranks time: 00:00:15
#   Sanity-checking and returning
# Building samples
# Reserving space for 12 sample suffixes
# Generating random suffixes
# QSorting 12 sample offsets, eliminating duplicates
# QSorting sample offsets, eliminating duplicates time: 00:00:00
# Multikey QSorting 12 samples
#   (Using difference cover)
#   Multikey QSorting samples time: 00:00:00
# Calculating bucket sizes
# Splitting and merging
#   Splitting and merging time: 00:00:00
# Avg bucket size: 1.07726e+09 (target: 201985330)
# Converting suffix-array elements to index image
# Allocating ftab, absorbFtab
# Entering Ebwt loop
# Getting block 1 of 1
#   No samples; assembling all-inclusive block
#   Sorting block of length 1077255099 for bucket 1
#   (Using difference cover)
#   Invoking Larsson-Sadakane on ranks time: 00:00:18
#   Sanity-checking and returning
# Building samples
# Reserving space for 12 sample suffixes
# Generating random suffixes
# QSorting 12 sample offsets, eliminating duplicates
# QSorting sample offsets, eliminating duplicates time: 00:00:00
# Multikey QSorting 12 samples
#   (Using difference cover)
#   Multikey QSorting samples time: 00:00:00
# Calculating bucket sizes
# Splitting and merging
#   Splitting and merging time: 00:00:00
# Avg bucket size: 1.07726e+09 (target: 201985330)
# Converting suffix-array elements to index image
# Allocating ftab, absorbFtab
# Entering Ebwt loop
# Getting block 1 of 1
#   No samples; assembling all-inclusive block
#   Sorting block of length 1077255099 for bucket 1
#   (Using difference cover)
#   Sorting block time: 01:00:36
# Returning block of 1077255100 for bucket 1
# Exited Ebwt loop
# fchr[A]: 0
# fchr[C]: 538568663
# fchr[G]: 735626959
# fchr[T]: 735626959
# fchr[$]: 1077255099
# Exiting Ebwt::buildToDisk()
# Returning from initFromVector
# Wrote 374057575 bytes to primary EBWT file: BS_GA.1.bt2
# Wrote 269313780 bytes to secondary EBWT file: BS_GA.2.bt2
# Re-opening _in1 and _in2 as input streams
# Returning from Ebwt constructor
# Headers:
#     len: 1077255099
#     bwtLen: 1077255100
#     sz: 269313775
#     bwtSz: 269313775
#     lineRate: 6
#     offRate: 4
#     offMask: 0xfffffff0
#     ftabChars: 10
#     eftabLen: 20
#     eftabSz: 80
#     ftabLen: 1048577
#     ftabSz: 4194308
#     offsLen: 67328444
#     offsSz: 269313776
#     lineSz: 64
#     sideSz: 64
#     sideBwtSz: 48
#     sideBwtLen: 192
#     numSides: 5610704
#     numLines: 5610704
#     ebwtTotLen: 359085056
#     ebwtTotSz: 359085056
#     color: 0
#     reverse: 0
# Total time for call to driver() for forward index: 01:09:11
# Reading reference sizes
#   Time reading reference sizes: 00:00:19
# Calculating joined length
# Writing header
# Reserving space for joined string
# Joining reference sequences
#   Time to join reference sequences: 00:00:08
#   Time to reverse reference sequence: 00:00:01
# bmax according to bmaxDivN setting: 269313774
# Using parameters --bmax 201985331 --dcv 1024
#   Doing ahead-of-time memory usage test
#   Passed!  Constructing with these parameters: --bmax 201985331 --dcv 1024
# Constructing suffix-array element generator
# Building DifferenceCoverSample
#   Building sPrime
#   Building sPrimeOrder
#   V-Sorting samples
#   Sorting block time: 01:07:52
# Returning block of 1077255100 for bucket 1
#   V-Sorting samples time: 00:00:29
#   Allocating rank array
#   Ranking v-sort output
#   Ranking v-sort output time: 00:00:18
#   Invoking Larsson-Sadakane on ranks
#   Invoking Larsson-Sadakane on ranks time: 00:00:15
#   Sanity-checking and returning
# Building samples
# Reserving space for 12 sample suffixes
# Generating random suffixes
# QSorting 12 sample offsets, eliminating duplicates
# QSorting sample offsets, eliminating duplicates time: 00:00:00
# Multikey QSorting 12 samples
#   (Using difference cover)
#   Multikey QSorting samples time: 00:00:00
# Calculating bucket sizes
# Splitting and merging
#   Splitting and merging time: 00:00:00
# Avg bucket size: 1.07726e+09 (target: 201985330)
# Converting suffix-array elements to index image
# Allocating ftab, absorbFtab
# Entering Ebwt loop
# Getting block 1 of 1
#   No samples; assembling all-inclusive block
#   Sorting block of length 1077255099 for bucket 1
#   (Using difference cover)
# Exited Ebwt loop
# fchr[A]: 0
# fchr[C]: 341519526
# fchr[G]: 341519526
# fchr[T]: 538568663
# fchr[$]: 1077255099
# Exiting Ebwt::buildToDisk()
# Returning from initFromVector
# Wrote 374057575 bytes to primary EBWT file: BS_CT.1.bt2
# Wrote 269313780 bytes to secondary EBWT file: BS_CT.2.bt2
# Re-opening _in1 and _in2 as input streams
# Returning from Ebwt constructor
# Headers:
#     len: 1077255099
#     bwtLen: 1077255100
#     sz: 269313775
#     bwtSz: 269313775
#     lineRate: 6
#     offRate: 4
#     offMask: 0xfffffff0
#     ftabChars: 10
#     eftabLen: 20
#     eftabSz: 80
#     ftabLen: 1048577
#     ftabSz: 4194308
#     offsLen: 67328444
#     offsSz: 269313776
#     lineSz: 64
#     sideSz: 64
#     sideBwtSz: 48
#     sideBwtLen: 192
#     numSides: 5610704
#     numLines: 5610704
#     ebwtTotLen: 359085056
#     ebwtTotSz: 359085056
#     color: 0
#     reverse: 0
# Total time for call to driver() for forward index: 01:18:01
# Reading reference sizes
#   Time reading reference sizes: 00:00:19
# Calculating joined length
# Writing header
# Reserving space for joined string
# Joining reference sequences
#   Time to join reference sequences: 00:00:09
#   Time to reverse reference sequence: 00:00:02
# bmax according to bmaxDivN setting: 269313774
# Using parameters --bmax 201985331 --dcv 1024
#   Doing ahead-of-time memory usage test
#   Passed!  Constructing with these parameters: --bmax 201985331 --dcv 1024
# Constructing suffix-array element generator
# Building DifferenceCoverSample
#   Building sPrime
#   Building sPrimeOrder
#   V-Sorting samples
#   V-Sorting samples time: 00:00:30
#   Allocating rank array
#   Ranking v-sort output
#   Ranking v-sort output time: 00:00:11
#   Invoking Larsson-Sadakane on ranks
#   Invoking Larsson-Sadakane on ranks time: 00:00:14
#   Sanity-checking and returning
# Building samples
# Reserving space for 12 sample suffixes
# Generating random suffixes
# QSorting 12 sample offsets, eliminating duplicates
# QSorting sample offsets, eliminating duplicates time: 00:00:00
# Multikey QSorting 12 samples
#   (Using difference cover)
#   Multikey QSorting samples time: 00:00:00
# Calculating bucket sizes
# Splitting and merging
#   Splitting and merging time: 00:00:00
# Avg bucket size: 1.07726e+09 (target: 201985330)
# Converting suffix-array elements to index image
# Allocating ftab, absorbFtab
# Entering Ebwt loop
# Getting block 1 of 1
#   No samples; assembling all-inclusive block
#   Sorting block of length 1077255099 for bucket 1
#   (Using difference cover)
#   Sorting block time: 00:21:29
# Returning block of 1077255100 for bucket 1
# Exited Ebwt loop
# fchr[A]: 0
# fchr[C]: 538568663
# fchr[G]: 735626959
# fchr[T]: 735626959
# fchr[$]: 1077255099
# Exiting Ebwt::buildToDisk()
# Returning from initFromVector
# Wrote 374057575 bytes to primary EBWT file: BS_GA.rev.1.bt2
# Wrote 269313780 bytes to secondary EBWT file: BS_GA.rev.2.bt2
# Re-opening _in1 and _in2 as input streams
# Returning from Ebwt constructor
# Headers:
#     len: 1077255099
#     bwtLen: 1077255100
#     sz: 269313775
#     bwtSz: 269313775
#     lineRate: 6
#     offRate: 4
#     offMask: 0xfffffff0
#     ftabChars: 10
#     eftabLen: 20
#     eftabSz: 80
#     ftabLen: 1048577
#     ftabSz: 4194308
#     offsLen: 67328444
#     offsSz: 269313776
#     lineSz: 64
#     sideSz: 64
#     sideBwtSz: 48
#     sideBwtLen: 192
#     numSides: 5610704
#     numLines: 5610704
#     ebwtTotLen: 359085056
#     ebwtTotSz: 359085056
#     color: 0
#     reverse: 1
# Total time for backward call to driver() for mirror index: 00:27:46
#   Sorting block time: 00:20:57
# Returning block of 1077255100 for bucket 1
# Exited Ebwt loop
# fchr[A]: 0
# fchr[C]: 341519526
# fchr[G]: 341519526
# fchr[T]: 538568663
# fchr[$]: 1077255099
# Exiting Ebwt::buildToDisk()
# Returning from initFromVector
# Wrote 374057575 bytes to primary EBWT file: BS_CT.rev.1.bt2
# Wrote 269313780 bytes to secondary EBWT file: BS_CT.rev.2.bt2
# Re-opening _in1 and _in2 as input streams
# Returning from Ebwt constructor
# Headers:
#     len: 1077255099
#     bwtLen: 1077255100
#     sz: 269313775
#     bwtSz: 269313775
#     lineRate: 6
#     offRate: 4
#     offMask: 0xfffffff0
#     ftabChars: 10
#     eftabLen: 20
#     eftabSz: 80
#     ftabLen: 1048577
#     ftabSz: 4194308
#     offsLen: 67328444
#     offsSz: 269313776
#     lineSz: 64
#     sideSz: 64
#     sideBwtSz: 48
#     sideBwtLen: 192
#     numSides: 5610704
#     numLines: 5610704
#     ebwtTotLen: 359085056
#     ebwtTotSz: 359085056
#     color: 0
#     reverse: 1
# Total time for backward call to driver() for mirror index: 00:26:31
# Writing bisulfite genomes out into a single MFA (multi FastA) file
#
# Bisulfite Genome Indexer version v0.19.0 (last modified 07 November 2016)
#
# Step I - Prepare genome folders - completed
#
#
#
# Step II - Genome bisulfite conversions - completed
#
#
# Bismark Genome Preparation - Step III: Launching the Bowtie 2 indexer
# Building a SMALL index
# Building a SMALL index

# %%
# !ls genome/Bisulfite_Genome/
# Out:
# CT_conversion GA_conversion

# %% [markdown]
# # Download Seq Read Files

# %%
# !mkdir data

# %%
# !wget --accept "[1-8]_*.gz" --reject "index" --recursive -nd -np \
http://owl.fish.washington.edu/nightingales/O_lurida/
# Out:
# --2018-06-13 12:33:22--  http://owl.fish.washington.edu/nightingales/O_lurida/
# Resolving owl.fish.washington.edu (owl.fish.washington.edu)... 128.95.149.83
# Connecting to owl.fish.washington.edu (owl.fish.washington.edu)|128.95.149.83|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘index.html.tmp’
#
# index.html.tmp          [ <=>                ]  31.90K  --.-KB/s    in 0.002s
#
# 2018-06-13 12:33:23 (15.5 MB/s) - ‘index.html.tmp’ saved [32669]
#
# Loading robots.txt; please ignore errors.
# --2018-06-13 12:33:23--  http://owl.fish.washington.edu/robots.txt
# Reusing existing connection to owl.fish.washington.edu:80.
# HTTP request sent, awaiting response... 404 Not Found
# 2018-06-13 12:33:23 ERROR 404: Not Found.
#
# Removing index.html.tmp since it should be rejected.
#
# --2018-06-13 12:33:23--  http://owl.fish.washington.edu/nightingales/O_lurida/?C=N;O=D
# Reusing existing connection to owl.fish.washington.edu:80.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘index.html?C=N;O=D.tmp’
#
# index.html?C=N;O=D.     [ <=>                ]  31.90K  --.-KB/s    in 0.001s
#
# 2018-06-13 12:33:23 (29.6 MB/s) - ‘index.html?C=N;O=D.tmp’ saved [32669]
#
# Removing index.html?C=N;O=D.tmp since it should be rejected.
#
# --2018-06-13 12:33:23--  http://owl.fish.washington.edu/nightingales/O_lurida/?C=M;O=A
# Reusing existing connection to owl.fish.washington.edu:80.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘index.html?C=M;O=A.tmp’
#
# index.html?C=M;O=A.     [ <=>                ]  31.90K  --.-KB/s    in 0.001s
#
# 2018-06-13 12:33:23 (33.1 MB/s) - ‘index.html?C=M;O=A.tmp’ saved [32669]
#
# Removing index.html?C=M;O=A.tmp since it should be rejected.
#
# --2018-06-13 12:33:23--  http://owl.fish.washington.edu/nightingales/O_lurida/?C=S;O=A
# Reusing existing connection to owl.fish.washington.edu:80.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘index.html?C=S;O=A.tmp’
#
# index.html?C=S;O=A.     [ <=>                ]  31.90K  --.-KB/s    in 0.001s
#
# 2018-06-13 12:33:23 (33.9 MB/s) - ‘index.html?C=S;O=A.tmp’ saved [32669]
#
# Removing index.html?C=S;O=A.tmp since it should be rejected.
#
# --2018-06-13 12:33:23--  http://owl.fish.washington.edu/nightingales/O_lurida/?C=D;O=A
# Reusing existing connection to owl.fish.washington.edu:80.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘index.html?C=D;O=A.tmp’
#
# index.html?C=D;O=A.     [ <=>                ]  31.90K  --.-KB/s    in 0.001s
#
# 2018-06-13 12:33:23 (22.7 MB/s) - ‘index.html?C=D;O=A.tmp’ saved [32669]
#
# Removing index.html?C=D;O=A.tmp since it should be rejected.
#
# --2018-06-13 12:33:23--  http://owl.fish.washington.edu/nightingales/O_lurida/1_ATCACG_L001_R1_001.fastq.gz
# Reusing existing connection to owl.fish.washington.edu:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 526965148 (503M) [application/x-gzip]
# Saving to: ‘1_ATCACG_L001_R1_001.fastq.gz.1.tmp’
#
# 1_ATCACG_L001_R1_00 100%[===================>] 502.55M  46.4MB/s    in 10s
#
# 2018-06-13 12:33:34 (49.1 MB/s) - ‘1_ATCACG_L001_R1_001.fastq.gz.1.tmp’ saved [526965148/526965148]
#
# Removing 1_ATCACG_L001_R1_001.fastq.gz.1.tmp since it should be rejected.
#
# --2018-06-13 12:33:34--  http://owl.fish.washington.edu/nightingales/O_lurida/2_CGATGT_L001_R1_001.fastq.gz
# Reusing existing connection to owl.fish.washington.edu:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 668680694 (638M) [application/x-gzip]
# Saving to: ‘2_CGATGT_L001_R1_001.fastq.gz.1.tmp’
#
# 2_CGATGT_L001_R1_00 100%[===================>] 637.70M  50.1MB/s    in 14s
#
# 2018-06-13 12:33:48 (46.9 MB/s) - ‘2_CGATGT_L001_R1_001.fastq.gz.1.tmp’ saved [668680694/668680694]
#
# Removing 2_CGATGT_L001_R1_001.fastq.gz.1.tmp since it should be rejected.
#
# --2018-06-13 12:33:48--  http://owl.fish.washington.edu/nightingales/O_lurida/2bRAD_Dec2015/
# Reusing existing connection to owl.fish.washington.edu:80.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘index.html.tmp’
#
# index.html.tmp          [ <=>                ]  80.95K  --.-KB/s    in 0.006s
#
# 2018-06-13 12:33:49 (13.7 MB/s) - ‘index.html.tmp’ saved [82896]
#
# Removing index.html.tmp since it should be rejected.
#
# --2018-06-13 12:33:49--  http://owl.fish.washington.edu/nightingales/O_lurida/2bRAD_Jan2017/
# Reusing existing connection to owl.fish.washington.edu:80.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘index.html.tmp’
#
# index.html.tmp          [ <=>                ]  13.97K  --.-KB/s    in 0.001s
#
# 2018-06-13 12:33:49 (24.9 MB/s) - ‘index.html.tmp’ saved [14310]
#
# Removing index.html.tmp since it should be rejected.
#
# --2018-06-13 12:33:49--  http://owl.fish.washington.edu/nightingales/O_lurida/3_TTAGGC_L001_R1_001.fastq.gz
# Reusing existing connection to owl.fish.washington.edu:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 663855515 (633M) [application/x-gzip]
# Saving to: ‘3_TTAGGC_L001_R1_001.fastq.gz.1.tmp’
#
# 3_TTAGGC_L001_R1_00 100%[===================>] 633.10M  54.1MB/s    in 12s
#
# 2018-06-13 12:34:01 (54.7 MB/s) - ‘3_TTAGGC_L001_R1_001.fastq.gz.1.tmp’ saved [663855515/663855515]
#
# Removing 3_TTAGGC_L001_R1_001.fastq.gz.1.tmp since it should be rejected.
#
# --2018-06-13 12:34:01--  http://owl.fish.washington.edu/nightingales/O_lurida/4_TGACCA_L001_R1_001.fastq.gz
# Reusing existing connection to owl.fish.washington.edu:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 649308301 (619M) [application/x-gzip]
# Saving to: ‘4_TGACCA_L001_R1_001.fastq.gz.1.tmp’
#
# 4_TGACCA_L001_R1_00 100%[===================>] 619.23M  22.8MB/s    in 16s
#
# 2018-06-13 12:34:17 (38.5 MB/s) - ‘4_TGACCA_L001_R1_001.fastq.gz.1.tmp’ saved [649308301/649308301]
#
# Removing 4_TGACCA_L001_R1_001.fastq.gz.1.tmp since it should be rejected.
#
# --2018-06-13 12:34:17--  http://owl.fish.washington.edu/nightingales/O_lurida/5_ACAGTG_L001_R1_001.fastq.gz
# Reusing existing connection to owl.fish.washington.edu:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 704024744 (671M) [application/x-gzip]
# Saving to: ‘5_ACAGTG_L001_R1_001.fastq.gz.1.tmp’
#
# 001_R1_001.fastq.gz  36%[======>             ] 245.97M  63.2MB/s    eta 7s

# %%
ls
# Out:
# 1_ATCACG_L001_R1_001.fastq.gz  6_GCCAAT_L001_R1_001.fastq.gz
# 2_CGATGT_L001_R1_001.fastq.gz  7_CAGATC_L001_R1_001.fastq.gz
# 3_TTAGGC_L001_R1_001.fastq.gz  8_ACTTGA_L001_R1_001.fastq.gz
# 4_TGACCA_L001_R1_001.fastq.gz  data/
# 5_ACAGTG_L001_R1_001.fastq.gz  genome/

# %%
# %%bash
# find /Volumes/Serine/wd/18-04-27/zr2096_*R1* \
# | xargs basename -s _s1_R1_val_1.fq.gz | xargs -I{} /Applications/bioinfo/Bismark_v0.19.0/bismark \
# --path_to_bowtie /Applications/bioinfo/bowtie2-2.3.4.1-macos-x86_64 \
# --genome /Volumes/Serine/wd/18-03-15/genome \
# --score_min L,0,-0.9 \
# -p 4 \
# --non_directional \
# -1 /Volumes/Serine/wd/18-04-27/{}_s1_R1_val_1.fq.gz \
# -2 /Volumes/Serine/wd/18-04-27/{}_s1_R2_val_2.fq.gz \
# 2> bismark.err
