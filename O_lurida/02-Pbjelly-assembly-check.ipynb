# %%
# !ls /Volumes/Serine/wd/18-01-25b/
# Out:
# bsmap_out_jelly.sam    jelly.out.fasta        stderr_bsmap_jelly.txt zr_1-sub001.fastq

# %%
# !head /Volumes/Serine/wd/18-01-25b/jelly.out.fasta
# Out:
# >Contig0
# ...
# >Contig1
# ...
# >Contig2
# ...
# >Contig3
# ...
# >Contig4
# ...

# %%
# !perl ../scripts/count_fasta.pl -i 10000 \
/Volumes/Serine/wd/18-01-25b/jelly.out.fasta
# Out:
# 0:9999 	661626
# 10000:19999 	23819
# 20000:29999 	6980
# 30000:39999 	2582
# 40000:49999 	1045
# 50000:59999 	449
# 60000:69999 	216
# 70000:79999 	120
# 80000:89999 	54
# 90000:99999 	23
# 100000:109999 	12
# 110000:119999 	8
# 120000:129999 	6
# 130000:139999 	4
# 140000:149999 	1
# 150000:159999 	0
# 160000:169999 	0
# 170000:179999 	0
# 180000:189999 	0
# 190000:199999 	1
#
# Total length of sequence:	1253001795 bp
# Total number of sequences:	696946
# N25 stats:			25% of total sequence length is contained in the 9256 sequences >= 22114 bp
# N50 stats:			50% of total sequence length is contained in the 29267 sequences >= 11531 bp
# N75 stats:			75% of total sequence length is contained in the 70273 sequences >= 4835 bp
# Total GC count:			427979910 bp
# GC %:				34.16 %

# %% [markdown]
# ![quast](http://eagle.fish.washington.edu/cnidarian/skitch/owl_fish_washington_edu_Athaliana_quast_results_results_2018_01_16_10_08_35_report_html_201A3078.png)

# %%
# !awk '!/^>/ { next } { getline seq } length(seq) >= 10000 { print $0 "\n" seq }' \
/Volumes/Serine/wd/18-01-25b/jelly.out.fasta \
> /Volumes/Serine/wd/18-01-25b/jelly-10k.fasta

# %%
# !perl ../scripts/count_fasta.pl -i 10000 \
/Volumes/Serine/wd/18-01-25b/jelly-10k.fasta
# Out:
# 10000:19999 	23819
# 20000:29999 	6980
# 30000:39999 	2582
# 40000:49999 	1045
# 50000:59999 	449
# 60000:69999 	216
# 70000:79999 	120
# 80000:89999 	54
# 90000:99999 	23
# 100000:109999 	12
# 110000:119999 	8
# 120000:129999 	6
# 130000:139999 	4
# 140000:149999 	1
# 150000:159999 	0
# 160000:169999 	0
# 170000:179999 	0
# 180000:189999 	0
# 190000:199999 	1
#
# Total length of sequence:	691523275 bp
# Total number of sequences:	35320
# N25 stats:			25% of total sequence length is contained in the 3885 sequences >= 31761 bp
# N50 stats:			50% of total sequence length is contained in the 10777 sequences >= 20628 bp
# N75 stats:			75% of total sequence length is contained in the 20887 sequences >= 14411 bp
# Total GC count:			247539412 bp
# GC %:				35.80 %
